# %% [markdown]
# ## Define Gameweek and Periods for FDR calculation

# %%
gameweek = 5
next_n_games = 2

#define percentage of time player needs to have played to be counted as active
min_min = ((gameweek-1)*90)/4     #<---- Currently 25% of playtime

# %% [markdown]
# ## Define Budget, Team Formation, and Budget Allocation by Position

# %%
#Budget
budget = 100

#Team Formation
DF = 3
MD = 4
ST = 3

#Total players needed per position
DF_max = 5
MD_max = 5
ST_max = 3

#Budget Allocation
GK_coef = 0.1
DF_coef = 0.22
MD_coef = 0.42
ST_coef = 0.26

# %% [markdown]
# ## Scraped list of Schedules

# %%
schedules = ['Arsenal NEW (A) BUR (H) LIV (A) TOT (H) WAT (A) AVL (H) MUN (A) BOU (H) SHU (A) CRY (H) WOL (H) LEI (A) SOU (H) NOR (A) BHA (H) WHU (A) MCI (H) EVE (A) BOU (A) CHE (H) MUN (H) CRY (A) SHU (H) CHE (A) BUR (A) NEW (H) EVE (H) MCI (A) WHU (H) BHA (A) SOU (A) NOR (H) WOL (A) LEI (H) TOT (A) LIV (H) AVL (A) WAT (H)',
 'Aston Villa TOT (A) BOU (H) EVE (H) CRY (A) WHU (H) ARS (A) BUR (H) NOR (A) BHA (H) MCI (A) LIV (H) WOL (A) NEW (H) MUN (A) CHE (A) LEI (H) SHU (A) SOU (H) NOR (H) WAT (A) BUR (A) MCI (H) BHA (A) WAT (H) BOU (A) TOT (H) SOU (A) SHU (H) LEI (A) CHE (H) NEW (A) WOL (H) LIV (A) MUN (H) CRY (H) EVE (A) ARS (H) WHU (A)',
 'Bournemouth SHU (H) AVL (A) MCI (H) LEI (A) EVE (H) SOU (A) WHU (H) ARS (A) NOR (H) WAT (A) MUN (H) NEW (A) WOL (H) TOT (A) CRY (A) LIV (H) CHE (A) BUR (H) ARS (H) BHA (A) WHU (A) WAT (H) NOR (A) BHA (H) AVL (H) SHU (A) BUR (A) CHE (H) LIV (A) CRY (H) WOL (A) NEW (H) MUN (A) TOT (H) LEI (H) MCI (A) SOU (H) EVE (A)',
 'Brighton WAT (A) WHU (H) SOU (H) MCI (A) BUR (H) NEW (A) CHE (A) TOT (H) AVL (A) EVE (H) NOR (H) MUN (A) LEI (H) LIV (A) ARS (A) WOL (H) CRY (A) SHU (H) TOT (A) BOU (H) CHE (H) EVE (A) AVL (H) BOU (A) WHU (A) WAT (H) SHU (A) CRY (H) WOL (A) ARS (H) LEI (A) MUN (H) NOR (A) LIV (H) MCI (H) SOU (A) NEW (H) BUR (A)',
 'Burnley SOU (H) ARS (A) WOL (A) LIV (H) BHA (A) NOR (H) AVL (A) EVE (H) LEI (A) CHE (H) SHU (A) WHU (H) WAT (A) CRY (H) MCI (H) TOT (A) NEW (H) BOU (A) EVE (A) MUN (H) AVL (H) CHE (A) LEI (H) MUN (A) ARS (H) SOU (A) BOU (H) NEW (A) TOT (H) MCI (A) WAT (H) CRY (A) SHU (H) WHU (A) LIV (A) WOL (H) NOR (A) BHA (H)',
 'Chelsea MUN (A) LEI (H) NOR (A) SHU (H) WOL (A) LIV (H) BHA (H) SOU (A) NEW (H) BUR (A) WAT (A) CRY (H) MCI (A) WHU (H) AVL (H) EVE (A) BOU (H) TOT (A) SOU (H) ARS (A) BHA (A) BUR (H) NEW (A) ARS (H) LEI (A) MUN (H) TOT (H) BOU (A) EVE (H) AVL (A) MCI (H) WHU (A) WAT (H) CRY (A) SHU (A) NOR (H) LIV (A) WOL (H)',
 'Crystal Palace EVE (H) SHU (A) MUN (A) AVL (H) TOT (A) WOL (H) NOR (H) WHU (A) MCI (H) ARS (A) LEI (H) CHE (A) LIV (H) BUR (A) BOU (H) WAT (A) BHA (H) NEW (A) WHU (H) SOU (A) NOR (A) ARS (H) MCI (A) SOU (H) SHU (H) EVE (A) NEW (H) BHA (A) WAT (H) BOU (A) LIV (A) BUR (H) LEI (A) CHE (H) AVL (A) MUN (H) WOL (A) TOT (H)',
 'Everton CRY (A) WAT (H) AVL (A) WOL (H) BOU (A) SHU (H) MCI (H) BUR (A) WHU (H) BHA (A) TOT (H) SOU (A) NOR (H) LEI (A) LIV (A) CHE (H) MUN (A) ARS (H) BUR (H) NEW (A) MCI (A) BHA (H) WHU (A) NEW (H) WAT (A) CRY (H) ARS (A) MUN (H) CHE (A) LIV (H) NOR (A) LEI (H) TOT (A) SOU (H) WOL (A) AVL (H) SHU (A) BOU (H)',
 'Leicester WOL (H) CHE (A) SHU (A) BOU (H) MUN (A) TOT (H) NEW (H) LIV (A) BUR (H) SOU (A) CRY (A) ARS (H) BHA (A) EVE (H) WAT (H) AVL (A) NOR (H) MCI (A) LIV (H) WHU (A) NEW (A) SOU (H) BUR (A) WHU (H) CHE (H) WOL (A) MCI (H) NOR (A) AVL (H) WAT (A) BHA (H) EVE (A) CRY (H) ARS (A) BOU (A) SHU (H) TOT (A) MUN (H)',
 'Liverpool NOR (H) SOU (A) ARS (H) BUR (A) NEW (H) CHE (A) SHU (A) LEI (H) MUN (A) TOT (H) AVL (A) MCI (H) CRY (A) BHA (H) EVE (H) BOU (A) WAT (H) WHU (A) LEI (A) WOL (H) SHU (H) TOT (A) MUN (H) WOL (A) SOU (H) NOR (A) WHU (H) WAT (A) BOU (H) EVE (A) CRY (H) MCI (A) AVL (H) BHA (A) BUR (H) ARS (A) CHE (H) NEW (A)',
 'Man City WHU (A) TOT (H) BOU (A) BHA (H) NOR (A) WAT (H) EVE (A) WOL (H) CRY (A) AVL (H) SOU (H) LIV (A) CHE (H) NEW (A) BUR (A) MUN (H) ARS (A) LEI (H) WOL (A) SHU (H) EVE (H) AVL (A) CRY (H) SHU (A) TOT (A) WHU (H) LEI (A) ARS (H) MUN (A) BUR (H) CHE (A) LIV (H) SOU (A) NEW (H) BHA (A) BOU (H) WAT (A) NOR (H)',
 'Man Utd CHE (H) WOL (A) CRY (H) SOU (A) LEI (H) WHU (A) ARS (H) NEW (A) LIV (H) NOR (A) BOU (A) BHA (H) SHU (A) AVL (H) TOT (H) MCI (A) EVE (H) WAT (A) NEW (H) BUR (A) ARS (A) NOR (H) LIV (A) BUR (H) WOL (H) CHE (A) WAT (H) EVE (A) MCI (H) TOT (A) SHU (H) BHA (A) BOU (H) AVL (A) SOU (H) CRY (A) WHU (H) LEI (A)',
 'Newcastle ARS (H) NOR (A) TOT (A) WAT (H) LIV (A) BHA (H) LEI (A) MUN (H) CHE (A) WOL (H) WHU (A) BOU (H) AVL (A) MCI (H) SHU (A) SOU (H) BUR (A) CRY (H) MUN (A) EVE (H) LEI (H) WOL (A) CHE (H) EVE (A) NOR (H) ARS (A) CRY (A) BUR (H) SOU (A) SHU (H) AVL (H) BOU (A) WHU (H) MCI (A) WAT (A) TOT (H) BHA (A) LIV (H)',
 'Norwich LIV (A) NEW (H) CHE (H) WHU (A) MCI (H) BUR (A) CRY (A) AVL (H) BOU (A) MUN (H) BHA (A) WAT (H) EVE (A) ARS (H) SOU (A) SHU (H) LEI (A) WOL (H) AVL (A) TOT (H) CRY (H) MUN (A) BOU (H) TOT (A) NEW (A) LIV (H) WOL (A) LEI (H) SHU (A) SOU (H) EVE (H) ARS (A) BHA (H) WAT (A) WHU (H) CHE (A) BUR (H) MCI (A)',
 'Sheffield Utd BOU (A) CRY (H) LEI (H) CHE (A) SOU (H) EVE (A) LIV (H) WAT (A) ARS (H) WHU (A) BUR (H) TOT (A) MUN (H) WOL (A) NEW (H) NOR (A) AVL (H) BHA (A) WAT (H) MCI (A) LIV (A) WHU (H) ARS (A) MCI (H) CRY (A) BOU (H) BHA (H) AVL (A) NOR (H) NEW (A) MUN (A) TOT (H) BUR (A) WOL (H) CHE (H) LEI (A) EVE (H) SOU (A)',
 'Southampton BUR (A) LIV (H) BHA (A) MUN (H) SHU (A) BOU (H) TOT (A) CHE (H) WOL (A) LEI (H) MCI (A) EVE (H) ARS (A) WAT (H) NOR (H) NEW (A) WHU (H) AVL (A) CHE (A) CRY (H) TOT (H) LEI (A) WOL (H) CRY (A) LIV (A) BUR (H) AVL (H) WHU (A) NEW (H) NOR (A) ARS (H) WAT (A) MCI (H) EVE (A) MUN (A) BHA (H) BOU (A) SHU (H)',
 'Spurs AVL (H) MCI (A) NEW (H) ARS (A) CRY (H) LEI (A) SOU (H) BHA (A) WAT (H) LIV (A) EVE (A) SHU (H) WHU (A) BOU (H) MUN (A) BUR (H) WOL (A) CHE (H) BHA (H) NOR (A) SOU (A) LIV (H) WAT (A) NOR (H) MCI (H) AVL (A) CHE (A) WOL (H) BUR (A) MUN (H) WHU (H) SHU (A) EVE (H) BOU (A) ARS (H) NEW (A) LEI (H) CRY (A)',
 'Watford BHA (H) EVE (A) WHU (H) NEW (A) ARS (H) MCI (A) WOL (A) SHU (H) TOT (A) BOU (H) CHE (H) NOR (A) BUR (H) SOU (A) LEI (A) CRY (H) LIV (A) MUN (H) SHU (A) AVL (H) WOL (H) BOU (A) TOT (H) AVL (A) EVE (H) BHA (A) MUN (A) LIV (H) CRY (A) LEI (H) BUR (A) SOU (H) CHE (A) NOR (H) NEW (H) WHU (A) MCI (H) ARS (A)',
 'West Ham MCI (H) BHA (A) WAT (A) NOR (H) AVL (A) MUN (H) BOU (A) CRY (H) EVE (A) SHU (H) NEW (H) BUR (A) TOT (H) CHE (A) WOL (A) ARS (H) SOU (A) LIV (H) CRY (A) LEI (H) BOU (H) SHU (A) EVE (H) LEI (A) BHA (H) MCI (A) LIV (A) SOU (H) ARS (A) WOL (H) TOT (A) CHE (H) NEW (A) BUR (H) NOR (A) WAT (H) MUN (A) AVL (H)',
 'Wolves LEI (A) MUN (H) BUR (H) EVE (A) CHE (H) CRY (A) WAT (H) MCI (A) SOU (H) NEW (A) ARS (A) AVL (H) BOU (A) SHU (H) WHU (H) BHA (A) TOT (H) NOR (A) MCI (H) LIV (A) WAT (A) NEW (H) SOU (A) LIV (H) MUN (A) LEI (H) NOR (H) TOT (A) BHA (H) WHU (A) BOU (H) AVL (A) ARS (H) SHU (A) EVE (H) BUR (A) CRY (H) CHE (A)']

# %% [markdown]
# ### Import Data

# %%
import json
import requests
import pandas as pd

# url = "https://fantasy.premierleague.com/drf/bootstrap-static"
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %% [markdown]
# ### Get Team Table

# %%
table_url = 'https://www.premierleague.com/tables'

def build_table(table_url):
    team_table = pd.read_html(table_url)
    team_df = pd.DataFrame(team_table[0])
    team_df = team_df[team_df['Unnamed: 12'].isna()]
    team_df = team_df.iloc[:,1:10]
    team_df.Club = team_df.Club.map(lambda x: x[-3:])
    team_df.reset_index()
    team_df.index = np.arange(1, len(team_df) + 1)
    team_df.columns = ['Team', 'Played', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']
    team_df.index.name = 'Position'
    
    return team_df

# %%
table_df = build_table(table_url)

# %%
table_df.head()
# Out:
#          Team Played  W  D  L  GF GA   GD Pts
# Position
# 1         LIV      4  4  0  0  12  3   +9  12
# 2         MCI      4  3  1  0  14  3  +11  10
# 3         LEI      4  2  2  0   6  3   +3   8
# 4         CRY      4  2  1  1   3  2   +1   7
# 5         ARS      4  2  1  1   6  6    0   7

# %% [markdown]
# ## Add player status and ROI, pts-per-90min metrics to final player_df

# %%
def attach_team_and_position(main_players, all_teams, positons):
    players = main_players.copy()
    for team in all_teams:
        for player in players:
            if team['code'] == player['team_code']:
                player['team_name'] = team['name']
    for position in positions:
        for player in players:
            if position['id'] == player['element_type']:
                player['position'] = position['singular_name']
    for player in players:
        if player['status'] == "a":
            player['status'] = "available"
        elif player['status'] == "d":
            player['status'] = "doubtful"
        elif player['status'] == "i":
            player['status'] = "injured"
        elif player['status'] == "s":
            player['status'] = "suspended"
    return players


#### Temporarily took out the "main_players" filter because no players have played 330 minutes ####

# player_positions_teams = attach_team_and_position(main_players, all_teams_new, positions)
player_positions_teams = attach_team_and_position(all_players, all_teams, positions)


def final_players_list(player_positions_teams):
    players = player_positions_teams.copy()
    empty = []
    for player in players:
        stats = dict(team_code = player['team_code'],
        team_name = player['team_name'],
        name = player['first_name'] + " " + player['second_name'],
        status = player['status'],
        position = player['position'],
        cost = (player['now_cost'])/10,
        total_points = player['total_points'],
        roi = round((player['total_points'] / player['now_cost'])*10, 2),
        pts_per_90min = round((player['total_points'] / (player['minutes'] + 1))*90, 2),
        bonus = player['bonus'],
        red_cards = player['red_cards'],
        minutes = player['minutes'],
        transfers_out = player['transfers_out'],
        transfers_in = player['transfers_in'])
        empty.append(stats)
    return empty

# %%
final = final_players_list(player_positions_teams)

# %%
final[0]
# Out:
# {'team_code': 3,
#  'team_name': 'Arsenal',
#  'name': 'Shkodran Mustafi',
#  'status': 'available',
#  'position': 'Defender',
#  'cost': 5.3,
#  'total_points': 0,
#  'roi': 0.0,
#  'pts_per_90min': 0.0,
#  'bonus': 0,
#  'red_cards': 0,
#  'minutes': 0,
#  'transfers_out': 21962,
#  'transfers_in': 4229}

# %%
all_teams[0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1250,
#  'strength_overall_away': 1330,
#  'strength_attack_home': 1240,
#  'strength_attack_away': 1270,
#  'strength_defence_home': 1290,
#  'strength_defence_away': 1330}

# %% [markdown]
# ### Get Total ROI, Points and 90min before filtering injured and FDR

# %%
total_roi = sorted(final, key = lambda x: x['roi'], reverse = True)

# %%
total_roi[:2]
# Out:
# [{'team_code': 45,
#   'team_name': 'Norwich',
#   'name': 'Teemu Pukki',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 7.0,
#   'total_points': 37,
#   'roi': 5.29,
#   'pts_per_90min': 9.43,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 352,
#   'transfers_out': 277547,
#   'transfers_in': 2386244},
#  {'team_code': 20,
#   'team_name': 'Southampton',
#   'name': 'Jannik Vestergaard',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 5.0,
#   'total_points': 22,
#   'roi': 4.4,
#   'pts_per_90min': 5.48,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 360,
#   'transfers_out': 18608,
#   'transfers_in': 163535}]

# %% [markdown]
# ### Total_Points

# %%
total_max_pts = sorted(total_roi, key = lambda x: x['total_points'], reverse = True)

# %%
total_max_pts[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.1,
#   'total_points': 40,
#   'roi': 3.31,
#   'pts_per_90min': 13.48,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 266,
#   'transfers_out': 292073,
#   'transfers_in': 672193},
#  {'team_code': 45,
#   'team_name': 'Norwich',
#   'name': 'Teemu Pukki',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 7.0,
#   'total_points': 37,
#   'roi': 5.29,
#   'pts_per_90min': 9.43,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 352,
#   'transfers_out': 277547,
#   'transfers_in': 2386244}]

# %% [markdown]
# ### 90 min

# %%
total_90min = sorted(total_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
total_90min = [player for player in total_90min if player['minutes'] >= min_min]

# %%
total_90min[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.1,
#   'total_points': 40,
#   'roi': 3.31,
#   'pts_per_90min': 13.48,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 266,
#   'transfers_out': 292073,
#   'transfers_in': 672193},
#  {'team_code': 8,
#   'team_name': 'Chelsea',
#   'name': 'Tammy Abraham',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 7.2,
#   'total_points': 28,
#   'roi': 3.89,
#   'pts_per_90min': 10.0,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 251,
#   'transfers_out': 165474,
#   'transfers_in': 928228}]

# %% [markdown]
# ### Create Players DataFrame

# %%
player_df = pd.DataFrame(final)

# %%
player_df.sort_values(by = ['roi'], ascending = False, inplace = True)

# %%
player_df.head()
# Out:
#      bonus  cost  minutes                 name    position  pts_per_90min  \
# 350      6   7.0      352          Teemu Pukki     Forward           9.43
# 394      6   5.0      360   Jannik Vestergaard    Defender           5.48
# 359      2   4.8      347        Todd Cantwell  Midfielder           5.43
# 163      2   5.6      360  Patrick van Aanholt    Defender           5.98
# 376      4   4.2      347       John Lundstram    Defender           4.66
#
#      red_cards   roi     status  team_code       team_name  total_points  \
# 350          0  5.29  available         45         Norwich            37
# 394          0  4.40  available         20     Southampton            22
# 359          0  4.38  available         45         Norwich            21
# 163          0  4.29  available         31  Crystal Palace            24
# 376          0  4.29  available         49   Sheffield Utd            18
#
#      transfers_in  transfers_out
# 350       2386244         277547
# 394        163535          18608
# 359       1251203         157944
# 163        401943         127895
# 376       1006663         124729

# %% [markdown]
# ### Merge two team tables s owe have all data

# %%
def merged_teams(table_df, all_teams):
    table_dic = table_df.to_dict('records')
    
    for team in table_dic:
        for item in all_teams:
            if team['Team'] == item['short_name']:
                team['code'] = item['code']
                team['name'] = item['name']
                team['strength'] = item['strength']
            
    new_df = pd.DataFrame(table_dic)
    
    new_order = ['code', 'strength', 'Team','name', 'Played', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'Pts']
    
    table_df = new_df[new_order]
    
    table_df.index = np.arange(1, len(table_df) + 1)
    table_df.index.name = 'Position'
    
    return table_df

# %%
team_df = merged_teams(table_df, all_teams)

# %%
team_df.head()
# Out:
#           code  strength Team            name Played  W  L  D  GF GA   GD Pts
# Position
# 1           14         5  LIV       Liverpool      4  4  0  0  12  3   +9  12
# 2           43         5  MCI        Man City      4  3  0  1  14  3  +11  10
# 3           13         3  LEI       Leicester      4  2  0  2   6  3   +3   8
# 4           31         3  CRY  Crystal Palace      4  2  1  1   3  2   +1   7
# 5            3         4  ARS         Arsenal      4  2  1  1   6  6    0   7

# %%
team_names = list(team_df.name)

# %%
team_names.sort()

# %%
team_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %% [markdown]
# ## Create Schedule DF

# %%
def extract_sched(schedules):
    dic = {}
    for i, item in enumerate(schedules):
        name = item.partition(team_names[i])[1]
        sche = item.partition(team_names[i])[2]
        sche = sche.split()
        clean = [item for item in sche if item != "(A)"]
        clean2 = [item for item in clean if item != "(H)"]
        dic[name] = clean2
    return dic

# %%
wonders = extract_sched(schedules)

# %%
schedule_df = pd.DataFrame(wonders)

# %%
schedule_df.index.name = 'Gameweek'

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
schedule_df.Arsenal[0:3]
# Out:
# Gameweek
# 0    NEW
# 1    BUR
# 2    LIV
# Name: Arsenal, dtype: object

# %% [markdown]
# ## Create FDR scores for calculating next-n opponents AVG strength

# %%
scores = list(zip(team_df.Team, team_df.strength))

# %%
scores = dict(scores)

# %%
sorted(scores.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('LIV', 5),
#  ('MCI', 5),
#  ('ARS', 4),
#  ('MUN', 4),
#  ('TOT', 4),
#  ('CHE', 4),
#  ('LEI', 3),
#  ('CRY', 3),
#  ('EVE', 3),
#  ('WHU', 3),
#  ('BUR', 3),
#  ('SOU', 3),
#  ('NEW', 3),
#  ('BOU', 3),
#  ('WOL', 3),
#  ('WAT', 3),
#  ('SHU', 2),
#  ('BHA', 2),
#  ('AVL', 2),
#  ('NOR', 2)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

sorted_data = sorted(scores.items(), key = lambda x: x[1], reverse = True)

Team = [item[0] for item in sorted_data]
strength = [item[1] for item in sorted_data]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
schedule_df.columns
# Out:
# Index(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brighton', 'Burnley',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Leicester', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Sheffield Utd',
#        'Southampton', 'Spurs', 'Watford', 'West Ham', 'Wolves'],
#       dtype='object')

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
def avg_FDR(week = gameweek, periods = next_n_games):
    dic = {}
    for team in schedule_df.columns:
        oponents = schedule_df[team][(week-1):(week+periods)]
        avg_FDR = round(sum([scores[oponent] for oponent in oponents])/len(oponents), 2)
        dic[team] = avg_FDR
    return dic

# %%
calculate_FDR = avg_FDR()

# %%
sorted_FDR = sorted(calculate_FDR.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_FDR
# Out:
# [('Watford', 4.0),
#  ('Leicester', 3.67),
#  ('Norwich', 3.67),
#  ('Sheffield Utd', 3.67),
#  ('Aston Villa', 3.33),
#  ('Brighton', 3.33),
#  ('Chelsea', 3.33),
#  ('Everton', 3.33),
#  ('Man Utd', 3.33),
#  ('Newcastle', 3.33),
#  ('Wolves', 3.33),
#  ('Arsenal', 3.0),
#  ('Bournemouth', 3.0),
#  ('Crystal Palace', 3.0),
#  ('Liverpool', 3.0),
#  ('Southampton', 3.0),
#  ('Spurs', 3.0),
#  ('West Ham', 3.0),
#  ('Man City', 2.67),
#  ('Burnley', 2.0)]

# %%
rcParams['figure.figsize'] = 14, 6

Team = [item[0] for item in sorted_FDR]
FDR = [item[1] for item in sorted_FDR]
cutoff = 3.56

plt.bar(Team, FDR)
plt.axhline(y=cutoff, linestyle='-', color='#33D977', label='Cutoff Difficulty = ' + str(cutoff))
plt.ylabel('AVG Opponent Difficulty', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('AVG Opponenet Difficulty Next ' + str(next_n_games +1) + ' Games', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Clean final list of available players by FDR score <= 3.56 and status = 'available'

# %%
player_df.head()
# Out:
#      bonus  cost  minutes                 name    position  pts_per_90min  \
# 350      6   7.0      352          Teemu Pukki     Forward           9.43
# 394      6   5.0      360   Jannik Vestergaard    Defender           5.48
# 359      2   4.8      347        Todd Cantwell  Midfielder           5.43
# 163      2   5.6      360  Patrick van Aanholt    Defender           5.98
# 376      4   4.2      347       John Lundstram    Defender           4.66
#
#      red_cards   roi     status  team_code       team_name  total_points  \
# 350          0  5.29  available         45         Norwich            37
# 394          0  4.40  available         20     Southampton            22
# 359          0  4.38  available         45         Norwich            21
# 163          0  4.29  available         31  Crystal Palace            24
# 376          0  4.29  available         49   Sheffield Utd            18
#
#      transfers_in  transfers_out
# 350       2386244         277547
# 394        163535          18608
# 359       1251203         157944
# 163        401943         127895
# 376       1006663         124729

# %%
player_df.shape
# Out:
# (532, 14)

# %%
clean_df = player_df[player_df.status == 'available']

# %%
clean_df.status.value_counts()
# Out:
# available    387
# Name: status, dtype: int64

# %% [markdown]
# ## Remove teams with FDR scores > 3.56 from DF - optional

# %%
teams_low_FDR = [key for (key,value) in calculate_FDR.items() if value <= 3.56]

# %%
teams_low_FDR
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Southampton',
#  'Spurs',
#  'West Ham',
#  'Wolves']

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes                 name    position  pts_per_90min  \
# 350      6   7.0      352          Teemu Pukki     Forward           9.43
# 394      6   5.0      360   Jannik Vestergaard    Defender           5.48
# 359      2   4.8      347        Todd Cantwell  Midfielder           5.43
# 163      2   5.6      360  Patrick van Aanholt    Defender           5.98
# 376      4   4.2      347       John Lundstram    Defender           4.66
#
#      red_cards   roi     status  team_code       team_name  total_points  \
# 350          0  5.29  available         45         Norwich            37
# 394          0  4.40  available         20     Southampton            22
# 359          0  4.38  available         45         Norwich            21
# 163          0  4.29  available         31  Crystal Palace            24
# 376          0  4.29  available         49   Sheffield Utd            18
#
#      transfers_in  transfers_out
# 350       2386244         277547
# 394        163535          18608
# 359       1251203         157944
# 163        401943         127895
# 376       1006663         124729

# %%
final_df = clean_df.loc[clean_df.team_name.isin(teams_low_FDR)]

# %%
final_df.head(15)
# Out:
#      bonus  cost  minutes                           name    position  \
# 394      6   5.0      360             Jannik Vestergaard    Defender
# 163      2   5.6      360            Patrick van Aanholt    Defender
# 166      2   4.5      360                      Joel Ward    Defender
# 182      6   5.1      223                    Jordan Ayew     Forward
# 519      2   5.1      360  Rui Pedro dos Santos Patrício  Goalkeeper
# 133      2   4.6      360                   Erik Pieters    Defender
# 156      6   7.2      251                  Tammy Abraham     Forward
# 317      2   5.0      354                   Fabian Schär    Defender
# 186      3   6.1      342                    Lucas Digne    Defender
# 274      6   9.8      326                Kevin De Bruyne  Midfielder
# 48       3   4.5      360                   Tyrone Mings    Defender
# 307      1   6.1      284                   Daniel James  Midfielder
# 159      4   6.4      360                    Mason Mount  Midfielder
# 483      3   4.5      270                 Arthur Masuaku    Defender
# 408      1   4.5      360                     Angus Gunn  Goalkeeper
#
#      pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 394           5.48          0  4.40  available         20     Southampton
# 163           5.98          0  4.29  available         31  Crystal Palace
# 166           4.49          0  4.00  available         31  Crystal Palace
# 182           8.04          0  3.92  available         31  Crystal Palace
# 519           4.99          0  3.92  available         39          Wolves
# 133           4.49          0  3.91  available         90         Burnley
# 156          10.00          0  3.89  available          8         Chelsea
# 317           4.82          0  3.80  available          4       Newcastle
# 186           6.03          0  3.77  available         11         Everton
# 274           9.91          0  3.67  available         43        Man City
# 48            3.99          0  3.56  available          7     Aston Villa
# 307           6.63          0  3.44  available          1         Man Utd
# 159           5.48          0  3.44  available          8         Chelsea
# 483           4.98          0  3.33  available         21        West Ham
# 408           3.74          0  3.33  available         20     Southampton
#
#      total_points  transfers_in  transfers_out
# 394            22        163535          18608
# 163            24        401943         127895
# 166            18         88023          26060
# 182            20        391052         153149
# 519            20        333056          98383
# 133            18        552584         140175
# 156            28        928228         165474
# 317            19         45165          41341
# 186            23        624597         309277
# 274            36       1280713         235549
# 48             16        256387          71314
# 307            21        641766         113948
# 159            22       1414446         199459
# 483            15         46796          15174
# 408            15         49735          20651

# %%
clean_players = final_df.to_dict('records')

# %%
clean_players[:2]
# Out:
# [{'bonus': 6,
#   'cost': 5.0,
#   'minutes': 360,
#   'name': 'Jannik Vestergaard',
#   'position': 'Defender',
#   'pts_per_90min': 5.48,
#   'red_cards': 0,
#   'roi': 4.4,
#   'status': 'available',
#   'team_code': 20,
#   'team_name': 'Southampton',
#   'total_points': 22,
#   'transfers_in': 163535,
#   'transfers_out': 18608},
#  {'bonus': 2,
#   'cost': 5.6,
#   'minutes': 360,
#   'name': 'Patrick van Aanholt',
#   'position': 'Defender',
#   'pts_per_90min': 5.98,
#   'red_cards': 0,
#   'roi': 4.29,
#   'status': 'available',
#   'team_code': 31,
#   'team_name': 'Crystal Palace',
#   'total_points': 24,
#   'transfers_in': 401943,
#   'transfers_out': 127895}]

# %% [markdown]
# ## Get list of players by ROI, Total Points and Points Per 90 min

# %%
players_roi = sorted(clean_players, key = lambda x: x['roi'], reverse = True)

# %%
players_roi[:3]
# Out:
# [{'bonus': 6,
#   'cost': 5.0,
#   'minutes': 360,
#   'name': 'Jannik Vestergaard',
#   'position': 'Defender',
#   'pts_per_90min': 5.48,
#   'red_cards': 0,
#   'roi': 4.4,
#   'status': 'available',
#   'team_code': 20,
#   'team_name': 'Southampton',
#   'total_points': 22,
#   'transfers_in': 163535,
#   'transfers_out': 18608},
#  {'bonus': 2,
#   'cost': 5.6,
#   'minutes': 360,
#   'name': 'Patrick van Aanholt',
#   'position': 'Defender',
#   'pts_per_90min': 5.98,
#   'red_cards': 0,
#   'roi': 4.29,
#   'status': 'available',
#   'team_code': 31,
#   'team_name': 'Crystal Palace',
#   'total_points': 24,
#   'transfers_in': 401943,
#   'transfers_out': 127895},
#  {'bonus': 2,
#   'cost': 4.5,
#   'minutes': 360,
#   'name': 'Joel Ward',
#   'position': 'Defender',
#   'pts_per_90min': 4.49,
#   'red_cards': 0,
#   'roi': 4.0,
#   'status': 'available',
#   'team_code': 31,
#   'team_name': 'Crystal Palace',
#   'total_points': 18,
#   'transfers_in': 88023,
#   'transfers_out': 26060}]

# %% [markdown]
# ### Total Points

# %%
players_max_pts = sorted(players_roi, key = lambda x: x['total_points'], reverse = True)

# %%
players_max_pts[:3]
# Out:
# [{'bonus': 6,
#   'cost': 12.1,
#   'minutes': 266,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 13.48,
#   'red_cards': 0,
#   'roi': 3.31,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 40,
#   'transfers_in': 672193,
#   'transfers_out': 292073},
#  {'bonus': 4,
#   'cost': 12.3,
#   'minutes': 360,
#   'name': 'Raheem Sterling',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.22,
#   'red_cards': 0,
#   'roi': 3.01,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 37,
#   'transfers_in': 1025539,
#   'transfers_out': 197881},
#  {'bonus': 6,
#   'cost': 9.8,
#   'minutes': 326,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.91,
#   'red_cards': 0,
#   'roi': 3.67,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 36,
#   'transfers_in': 1280713,
#   'transfers_out': 235549}]

# %% [markdown]
# ### Per 90 mins played

# %%
players_90min = sorted(players_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
players_90min = [player for player in players_90min if player['minutes'] >= min_min]

# %%
players_90min[:3]
# Out:
# [{'bonus': 6,
#   'cost': 12.1,
#   'minutes': 266,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 13.48,
#   'red_cards': 0,
#   'roi': 3.31,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 40,
#   'transfers_in': 672193,
#   'transfers_out': 292073},
#  {'bonus': 6,
#   'cost': 7.2,
#   'minutes': 251,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 10.0,
#   'red_cards': 0,
#   'roi': 3.89,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 28,
#   'transfers_in': 928228,
#   'transfers_out': 165474},
#  {'bonus': 6,
#   'cost': 9.8,
#   'minutes': 326,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.91,
#   'red_cards': 0,
#   'roi': 3.67,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 36,
#   'transfers_in': 1280713,
#   'transfers_out': 235549}]

# %% [markdown]
# ### Create player lists by position and metric we want to select by

# %%
GK_roi = [item for item in players_roi if item['position'] == 'Goalkeeper']
DF_roi = [item for item in players_roi if item['position'] == 'Defender']
MD_roi = [item for item in players_roi if item['position'] == 'Midfielder']
ST_roi = [item for item in players_roi if item['position'] == 'Forward']

# %%
GK_pts = [item for item in players_max_pts if item['position'] == 'Goalkeeper']
DF_pts = [item for item in players_max_pts if item['position'] == 'Defender']
MD_pts = [item for item in players_max_pts if item['position'] == 'Midfielder']
ST_pts = [item for item in players_max_pts if item['position'] == 'Forward']

# %%
GK_90min = [item for item in players_90min if item['position'] == 'Goalkeeper']
DF_90min = [item for item in players_90min if item['position'] == 'Defender']
MD_90min = [item for item in players_90min if item['position'] == 'Midfielder']
ST_90min = [item for item in players_90min if item['position'] == 'Forward']

# %% [markdown]
# ## Start by selecting top GKs by ROI

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_roi:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 10.0
# Player Selected: Rui Pedro dos Santos Patrício
# GK budget left: 4.9
# Player Selected: Angus Gunn
# GK budget left: 0.40000000000000036
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn']
# ['Wolves', 'Southampton']

# %% [markdown]
# ## Select Top player by points from DF, MD, ST

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 22.4 42.0 26.0
# Player Selected: Patrick van Aanholt
# DF budget left: 16.799999999999997
# Player Selected: Raheem Sterling
# MD budget left: 29.7
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City']

# %%
ST_pts[:3]
# Out:
# [{'bonus': 6,
#   'cost': 12.1,
#   'minutes': 266,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 13.48,
#   'red_cards': 0,
#   'roi': 3.31,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 40,
#   'transfers_in': 672193,
#   'transfers_out': 292073},
#  {'bonus': 6,
#   'cost': 7.2,
#   'minutes': 251,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 10.0,
#   'red_cards': 0,
#   'roi': 3.89,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 28,
#   'transfers_in': 928228,
#   'transfers_out': 165474},
#  {'bonus': 5,
#   'cost': 9.5,
#   'minutes': 344,
#   'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'pts_per_90min': 7.04,
#   'red_cards': 0,
#   'roi': 2.84,
#   'status': 'available',
#   'team_code': 14,
#   'team_name': 'Liverpool',
#   'total_points': 27,
#   'transfers_in': 307895,
#   'transfers_out': 281773}]

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Sergio Agüero
# ST budget left: 13.9
# 5
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with top ROI players

# %%
for item in DF_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
        print('# of DFs selected: ' + str(DF_curr))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Jannik Vestergaard
# DF budget left: 11.799999999999997
# # of DFs selected: 2
# Player Selected: Joel Ward
# DF budget left: 7.299999999999997
# # of DFs selected: 3
# 7
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Jannik Vestergaard', 'Joel Ward']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Southampton', 'Crystal Palace']

# %% [markdown]
# ## Fill MD position

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Kevin De Bruyne
# MD budget left: 27.2
# Player Selected: Daniel James
# MD budget left: 21.1
# Player Selected: Mason Mount
# MD budget left: 14.700000000000001
# Player Selected: Douglas Luiz Soares de Paulo
# MD budget left: 10.100000000000001
# 11
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Jannik Vestergaard', 'Joel Ward', 'Kevin De Bruyne', 'Daniel James', 'Mason Mount', 'Douglas Luiz Soares de Paulo']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Southampton', 'Crystal Palace', 'Man City', 'Man Utd', 'Chelsea', 'Aston Villa']

# %% [markdown]
# ## Fill ST position

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Jordan Ayew
# ST budget left: 18.9
# Player Selected: Tammy Abraham
# ST budget left: 11.7
# 13
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Jannik Vestergaard', 'Joel Ward', 'Kevin De Bruyne', 'Daniel James', 'Mason Mount', 'Douglas Luiz Soares de Paulo', 'Jordan Ayew', 'Tammy Abraham']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Southampton', 'Crystal Palace', 'Man City', 'Man Utd', 'Chelsea', 'Aston Villa', 'Crystal Palace', 'Chelsea']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                           name    position  \
# 0       2   5.1      360  Rui Pedro dos Santos Patrício  Goalkeeper
# 1       1   4.5      360                     Angus Gunn  Goalkeeper
# 2       2   5.6      360            Patrick van Aanholt    Defender
# 3       4  12.3      360                Raheem Sterling  Midfielder
# 4       6  12.1      266                  Sergio Agüero     Forward
# 5       6   5.0      360             Jannik Vestergaard    Defender
# 6       2   4.5      360                      Joel Ward    Defender
# 7       6   9.8      326                Kevin De Bruyne  Midfielder
# 8       1   6.1      284                   Daniel James  Midfielder
# 9       4   6.4      360                    Mason Mount  Midfielder
# 10      2   4.6      258   Douglas Luiz Soares de Paulo  Midfielder
# 11      6   5.1      223                    Jordan Ayew     Forward
# 12      6   7.2      251                  Tammy Abraham     Forward
#
#     pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 0            4.99          0  3.92  available         39          Wolves
# 1            3.74          0  3.33  available         20     Southampton
# 2            5.98          0  4.29  available         31  Crystal Palace
# 3            9.22          0  3.01  available         43        Man City
# 4           13.48          0  3.31  available         43        Man City
# 5            5.48          0  4.40  available         20     Southampton
# 6            4.49          0  4.00  available         31  Crystal Palace
# 7            9.91          0  3.67  available         43        Man City
# 8            6.63          0  3.44  available          1         Man Utd
# 9            5.48          0  3.44  available          8         Chelsea
# 10           5.21          0  3.26  available          7     Aston Villa
# 11           8.04          0  3.92  available         31  Crystal Palace
# 12          10.00          0  3.89  available          8         Chelsea
#
#     total_points  transfers_in  transfers_out
# 0             20        333056          98383
# 1             15         49735          20651
# 2             24        401943         127895
# 3             37       1025539         197881
# 4             40        672193         292073
# 5             22        163535          18608
# 6             18         88023          26060
# 7             36       1280713         235549
# 8             21        641766         113948
# 9             22       1414446         199459
# 10            15        342766          95612
# 11            20        391052         153149
# 12            28        928228         165474

# %%
money_x = money_df.roi
money_y = money_df.name
ST_75th = round(money_df.describe().roi['75%'], 2)
ST_AVG = round(money_df.describe().roi['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Top 10 ROI players by position

# %%
GK_df = pd.DataFrame(GK_roi)
GK_df.head(10)
# Out:
#    bonus  cost  minutes                            name    position  \
# 0      2   5.1      360   Rui Pedro dos Santos Patrício  Goalkeeper
# 1      1   4.5      360                      Angus Gunn  Goalkeeper
# 2      1   4.6      360                       Nick Pope  Goalkeeper
# 3      0   5.0      360                  Vicente Guaita  Goalkeeper
# 4      1   5.6      360                 Jordan Pickford  Goalkeeper
# 5      1   5.0      360                      Bernd Leno  Goalkeeper
# 6      0   6.1      360       Ederson Santana de Moraes  Goalkeeper
# 7      2   5.6      360                    David de Gea  Goalkeeper
# 8      0   4.5      360                      Tom Heaton  Goalkeeper
# 9      0   4.6      321  Adrián San Miguel del Castillo  Goalkeeper
#
#    pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 0           4.99          0  3.92  available         39          Wolves
# 1           3.74          0  3.33  available         20     Southampton
# 2           3.74          0  3.26  available         90         Burnley
# 3           3.74          0  3.00  available         31  Crystal Palace
# 4           3.99          0  2.86  available         11         Everton
# 5           3.49          0  2.80  available          3         Arsenal
# 6           4.24          0  2.79  available         43        Man City
# 7           3.74          0  2.68  available          1         Man Utd
# 8           2.99          0  2.67  available          7     Aston Villa
# 9           3.35          0  2.61  available         14       Liverpool
#
#    total_points  transfers_in  transfers_out
# 0            20        333056          98383
# 1            15         49735          20651
# 2            15        481416         128038
# 3            15         22748          16306
# 4            16        294196         164748
# 5            14        176742         150298
# 6            17        513778         285050
# 7            15        573035         307224
# 8            12        136316         102396
# 9            12        409260          99490

# %%
DF_df = pd.DataFrame(DF_roi)
DF_df.head(10)
# Out:
#    bonus  cost  minutes                 name  position  pts_per_90min  \
# 0      6   5.0      360   Jannik Vestergaard  Defender           5.48
# 1      2   5.6      360  Patrick van Aanholt  Defender           5.98
# 2      2   4.5      360            Joel Ward  Defender           4.49
# 3      2   4.6      360         Erik Pieters  Defender           4.49
# 4      2   5.0      354         Fabian Schär  Defender           4.82
# 5      3   6.1      342          Lucas Digne  Defender           6.03
# 6      3   4.5      360         Tyrone Mings  Defender           3.99
# 7      3   4.5      270       Arthur Masuaku  Defender           4.98
# 8      4   5.6      360           Yerry Mina  Defender           4.49
# 9      1   5.4      270           Joel Matip  Defender           5.65
#
#    red_cards   roi     status  team_code       team_name  total_points  \
# 0          0  4.40  available         20     Southampton            22
# 1          0  4.29  available         31  Crystal Palace            24
# 2          0  4.00  available         31  Crystal Palace            18
# 3          0  3.91  available         90         Burnley            18
# 4          0  3.80  available          4       Newcastle            19
# 5          0  3.77  available         11         Everton            23
# 6          0  3.56  available          7     Aston Villa            16
# 7          0  3.33  available         21        West Ham            15
# 8          0  3.21  available         11         Everton            18
# 9          0  3.15  available         14       Liverpool            17
#
#    transfers_in  transfers_out
# 0        163535          18608
# 1        401943         127895
# 2         88023          26060
# 3        552584         140175
# 4         45165          41341
# 5        624597         309277
# 6        256387          71314
# 7         46796          15174
# 8        317650         132930
# 9        209382          69673

# %%
MD_df = pd.DataFrame(MD_roi)
MD_df.head(10)
# Out:
#    bonus  cost  minutes                          name    position  \
# 0      6   9.8      326               Kevin De Bruyne  Midfielder
# 1      1   6.1      284                  Daniel James  Midfielder
# 2      4   6.4      360                   Mason Mount  Midfielder
# 3      2   4.6      258  Douglas Luiz Soares de Paulo  Midfielder
# 4      3   7.5      258                   David Silva  Midfielder
# 5      2   4.5      355              Matteo Guendouzi  Midfielder
# 6      0   5.6      360                   John McGinn  Midfielder
# 7      4  12.3      360               Raheem Sterling  Midfielder
# 8      2   6.0      291                   Erik Lamela  Midfielder
# 9      3   5.0      345               Scott McTominay  Midfielder
#
#    pts_per_90min  red_cards   roi     status  team_code    team_name  \
# 0           9.91          0  3.67  available         43     Man City
# 1           6.63          0  3.44  available          1      Man Utd
# 2           5.48          0  3.44  available          8      Chelsea
# 3           5.21          0  3.26  available          7  Aston Villa
# 4           8.34          0  3.20  available         43     Man City
# 5           3.54          0  3.11  available          3      Arsenal
# 6           4.24          0  3.04  available          7  Aston Villa
# 7           9.22          0  3.01  available         43     Man City
# 8           5.55          0  3.00  available          6        Spurs
# 9           3.90          0  3.00  available          1      Man Utd
#
#    total_points  transfers_in  transfers_out
# 0            36       1280713         235549
# 1            21        641766         113948
# 2            22       1414446         199459
# 3            15        342766          95612
# 4            24        335043         168207
# 5            14        357568         176248
# 6            17        414773         170026
# 7            37       1025539         197881
# 8            18        209214          96380
# 9            15         47134          29888

# %%
ST_df = pd.DataFrame(ST_roi)
ST_df.head(10)
# Out:
#    bonus  cost  minutes              name position  pts_per_90min  red_cards  \
# 0      6   5.1      223       Jordan Ayew  Forward           8.04          0
# 1      6   7.2      251     Tammy Abraham  Forward          10.00          0
# 2      6  12.1      266     Sergio Agüero  Forward          13.48          0
# 3      5   7.5      270  Sébastien Haller  Forward           7.64          0
# 4      5   9.5      344   Roberto Firmino  Forward           7.04          0
# 5      0   7.8      337     Callum Wilson  Forward           5.33          0
# 6      3   5.5       89      Divock Origi  Forward          14.00          0
# 7      1   6.0      250        Danny Ings  Forward           5.38          0
# 8      3   6.0      337     Wesley Moraes  Forward           3.99          0
# 9      4   8.5      353   Marcus Rashford  Forward           5.34          0
#
#     roi     status  team_code       team_name  total_points  transfers_in  \
# 0  3.92  available         31  Crystal Palace            20        391052
# 1  3.89  available          8         Chelsea            28        928228
# 2  3.31  available         43        Man City            40        672193
# 3  3.07  available         21        West Ham            23        312330
# 4  2.84  available         14       Liverpool            27        307895
# 5  2.56  available         91     Bournemouth            20         99774
# 6  2.55  available         14       Liverpool            14        308226
# 7  2.50  available         20     Southampton            15         80676
# 8  2.50  available          7     Aston Villa            15        124659
# 9  2.47  available          1         Man Utd            21        768778
#
#    transfers_out
# 0         153149
# 1         165474
# 2         292073
# 3         170677
# 4         281773
# 5         614013
# 6         332848
# 7          83301
# 8          70805
# 9         686002

# %% [markdown]
# ## Define Clean df for graphing purposes

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes                 name    position  pts_per_90min  \
# 350      6   7.0      352          Teemu Pukki     Forward           9.43
# 394      6   5.0      360   Jannik Vestergaard    Defender           5.48
# 359      2   4.8      347        Todd Cantwell  Midfielder           5.43
# 163      2   5.6      360  Patrick van Aanholt    Defender           5.98
# 376      4   4.2      347       John Lundstram    Defender           4.66
#
#      red_cards   roi     status  team_code       team_name  total_points  \
# 350          0  5.29  available         45         Norwich            37
# 394          0  4.40  available         20     Southampton            22
# 359          0  4.38  available         45         Norwich            21
# 163          0  4.29  available         31  Crystal Palace            24
# 376          0  4.29  available         49   Sheffield Utd            18
#
#      transfers_in  transfers_out
# 350       2386244         277547
# 394        163535          18608
# 359       1251203         157944
# 163        401943         127895
# 376       1006663         124729

# %%
graph_roi = []
for row, player in clean_df.iterrows():
    playa = dict(name = player['name'], position = player.position, team=player.team_name, cost = player.cost, points = player.total_points, minutes = player.minutes, ROI = player.roi, pts_per_90min = player.pts_per_90min)
    graph_roi.append(playa)

# %%
graph_roi[:3]
# Out:
# [{'name': 'Teemu Pukki',
#   'position': 'Forward',
#   'team': 'Norwich',
#   'cost': 7.0,
#   'points': 37,
#   'minutes': 352,
#   'ROI': 5.29,
#   'pts_per_90min': 9.43},
#  {'name': 'Jannik Vestergaard',
#   'position': 'Defender',
#   'team': 'Southampton',
#   'cost': 5.0,
#   'points': 22,
#   'minutes': 360,
#   'ROI': 4.4,
#   'pts_per_90min': 5.48},
#  {'name': 'Todd Cantwell',
#   'position': 'Midfielder',
#   'team': 'Norwich',
#   'cost': 4.8,
#   'points': 21,
#   'minutes': 347,
#   'ROI': 4.38,
#   'pts_per_90min': 5.43}]

# %% [markdown]
# ### Graph by ROI

# %%
GK_graph = clean_df[clean_df['position'] == 'Goalkeeper']
DF_graph = clean_df[clean_df['position'] == 'Defender']
MD_graph = clean_df[clean_df['position'] == 'Midfielder']
ST_graph = clean_df[clean_df['position'] == 'Forward']

# %% [markdown]
# ### Graph by 90_min Stat

# %%
sorted_players_90min = sorted(graph_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
sorted_players_90min = [player for player in sorted_players_90min if player['minutes'] >= min_min]

# %%
sorted_players_90min[:3]
# Out:
# [{'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'team': 'Man City',
#   'cost': 12.1,
#   'points': 40,
#   'minutes': 266,
#   'ROI': 3.31,
#   'pts_per_90min': 13.48},
#  {'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'team': 'Chelsea',
#   'cost': 7.2,
#   'points': 28,
#   'minutes': 251,
#   'ROI': 3.89,
#   'pts_per_90min': 10.0},
#  {'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'team': 'Man City',
#   'cost': 9.8,
#   'points': 36,
#   'minutes': 326,
#   'ROI': 3.67,
#   'pts_per_90min': 9.91}]

# %%
df_90min = pd.DataFrame(sorted_players_90min)

# %%
df_90min.head()
# Out:
#     ROI  cost  minutes             name  points    position  pts_per_90min  \
# 0  3.31  12.1      266    Sergio Agüero      40     Forward          13.48
# 1  3.89   7.2      251    Tammy Abraham      28     Forward          10.00
# 2  3.67   9.8      326  Kevin De Bruyne      36  Midfielder           9.91
# 3  5.29   7.0      352      Teemu Pukki      37     Forward           9.43
# 4  2.88  12.5      348    Mohamed Salah      36  Midfielder           9.28
#
#         team
# 0   Man City
# 1    Chelsea
# 2   Man City
# 3    Norwich
# 4  Liverpool

# %%
GK_90min_graph = df_90min[df_90min['position'] == 'Goalkeeper']
DF_90min_graph = df_90min[df_90min['position'] == 'Defender']
MD_90min_graph = df_90min[df_90min['position'] == 'Midfielder']
ST_90min_graph = df_90min[df_90min['position'] == 'Forward']

# %%
GK_90min_graph.head()
# Out:
#      ROI  cost  minutes                           name  points    position  \
# 47  3.92   5.1      360  Rui Pedro dos Santos Patrício      20  Goalkeeper
# 65  2.79   6.1      360      Ederson Santana de Moraes      17  Goalkeeper
# 72  2.86   5.6      360                Jordan Pickford      16  Goalkeeper
# 79  3.33   4.5      360                     Angus Gunn      15  Goalkeeper
# 80  3.26   4.6      360                      Nick Pope      15  Goalkeeper
#
#     pts_per_90min         team
# 47           4.99       Wolves
# 65           4.24     Man City
# 72           3.99      Everton
# 79           3.74  Southampton
# 80           3.74      Burnley

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %% [markdown]
# ## Top 10 Keepers ROI

# %%
GK_x = GK_graph[:10].roi
GK_y = GK_graph[:10].name
GK_75th = round(GK_graph.describe().roi['75%'], 2)
GK_AVG = round(GK_graph.describe().roi['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK ROI = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK ROI = ' + str(GK_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Keepers 90_min

# %%
GK_x = GK_90min_graph[:10].pts_per_90min
GK_y = GK_90min_graph[:10].name
GK_75th = round(GK_90min_graph.describe().pts_per_90min['75%'], 2)
GK_AVG = round(GK_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK pts_per_90min = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK pts_per_90min = ' + str(GK_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders

# %%
DF_x = DF_graph[:10].roi
DF_y = DF_graph[:10].name
DF_75th = round(DF_graph.describe().roi['75%'], 2)
DF_AVG = round(DF_graph.describe().roi['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders 90min Stat

# %%
DF_x = DF_90min_graph[:10].pts_per_90min
DF_y = DF_90min_graph[:10].name
DF_75th = round(DF_90min_graph.describe().pts_per_90min['75%'], 2)
DF_AVG = round(DF_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF pts_per_90min = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF pts_per_90min = ' + str(DF_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders

# %%
MD_x = MD_graph[:10].roi
MD_y = MD_graph[:10].name
MD_75th = round(MD_graph.describe().roi['75%'], 2)
MD_AVG = round(MD_graph.describe().roi['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD ROI = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD ROI = ' + str(MD_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders 90min Stat

# %%
MD_x = MD_90min_graph[:10].pts_per_90min
MD_y = MD_90min_graph[:10].name
MD_75th = round(MD_90min_graph.describe().pts_per_90min['75%'], 2)
MD_AVG = round(MD_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD pts_per_90min = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD pts_per_90min = ' + str(MD_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers

# %%
ST_x = ST_graph[:10].roi
ST_y = ST_graph[:10].name
ST_75th = round(ST_graph.describe().roi['75%'], 2)
ST_AVG = round(ST_graph.describe().roi['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers 90min Stat

# %%
ST_x = ST_90min_graph[:10].pts_per_90min
ST_y = ST_90min_graph[:10].name
ST_75th = round(ST_90min_graph.describe().pts_per_90min['75%'], 2)
ST_AVG = round(ST_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
team_df
# Out:
#           code  strength Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV       Liverpool      4  4  0  0  12   3   +9  12
# 2           43         5  MCI        Man City      4  3  0  1  14   3  +11  10
# 3           13         3  LEI       Leicester      4  2  0  2   6   3   +3   8
# 4           31         3  CRY  Crystal Palace      4  2  1  1   3   2   +1   7
# 5            3         4  ARS         Arsenal      4  2  1  1   6   6    0   7
# 6           11         3  EVE         Everton      4  2  1  1   4   4    0   7
# 7           21         3  WHU        West Ham      4  2  1  1   6   7   -1   7
# 8            1         4  MUN         Man Utd      4  1  1  2   7   4   +3   5
# 9            6         4  TOT           Spurs      4  1  1  2   7   6   +1   5
# 10          49         2  SHU   Sheffield Utd      4  1  1  2   5   5    0   5
# 11           8         4  CHE         Chelsea      4  1  1  2   6   9   -3   5
# 12          90         3  BUR         Burnley      4  1  2  1   5   6   -1   4
# 13          20         3  SOU     Southampton      4  1  2  1   4   6   -2   4
# 14           4         3  NEW       Newcastle      4  1  2  1   3   5   -2   4
# 15          91         3  BOU     Bournemouth      4  1  2  1   5   8   -3   4
# 16          36         2  BHA        Brighton      4  1  2  1   4   7   -3   4
# 17          39         3  WOL          Wolves      4  0  1  3   4   5   -1   3
# 18           7         2  AVL     Aston Villa      4  1  3  0   4   6   -2   3
# 19          45         2  NOR         Norwich      4  1  3  0   6  10   -4   3
# 20          57         3  WAT         Watford      4  0  3  1   2   8   -6   1

# %% [markdown]
# ### Team Stats

# %%
teams_stats = team_df.iloc[:,2:12]

# %%
teams_stats.GF = [int(item) for item in teams_stats.GF]
teams_stats.GA = [int(item) for item in teams_stats.GA]

# %%
teams_stats
# Out:
#          Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1         LIV       Liverpool      4  4  0  0  12   3   +9  12
# 2         MCI        Man City      4  3  0  1  14   3  +11  10
# 3         LEI       Leicester      4  2  0  2   6   3   +3   8
# 4         CRY  Crystal Palace      4  2  1  1   3   2   +1   7
# 5         ARS         Arsenal      4  2  1  1   6   6    0   7
# 6         EVE         Everton      4  2  1  1   4   4    0   7
# 7         WHU        West Ham      4  2  1  1   6   7   -1   7
# 8         MUN         Man Utd      4  1  1  2   7   4   +3   5
# 9         TOT           Spurs      4  1  1  2   7   6   +1   5
# 10        SHU   Sheffield Utd      4  1  1  2   5   5    0   5
# 11        CHE         Chelsea      4  1  1  2   6   9   -3   5
# 12        BUR         Burnley      4  1  2  1   5   6   -1   4
# 13        SOU     Southampton      4  1  2  1   4   6   -2   4
# 14        NEW       Newcastle      4  1  2  1   3   5   -2   4
# 15        BOU     Bournemouth      4  1  2  1   5   8   -3   4
# 16        BHA        Brighton      4  1  2  1   4   7   -3   4
# 17        WOL          Wolves      4  0  1  3   4   5   -1   3
# 18        AVL     Aston Villa      4  1  3  0   4   6   -2   3
# 19        NOR         Norwich      4  1  3  0   6  10   -4   3
# 20        WAT         Watford      4  0  3  1   2   8   -6   1

# %% [markdown]
# ### Worst/ Best  Defence vs. Offence

# %%
worst_defence_df = teams_stats.sort_values(by = ['GA'], ascending = False)

# %%
worst_defence_df.head()
# Out:
#          Team         name Played  W  L  D  GF  GA  GD Pts
# Position
# 19        NOR      Norwich      4  1  3  0   6  10  -4   3
# 11        CHE      Chelsea      4  1  1  2   6   9  -3   5
# 15        BOU  Bournemouth      4  1  2  1   5   8  -3   4
# 20        WAT      Watford      4  0  3  1   2   8  -6   1
# 7         WHU     West Ham      4  2  1  1   6   7  -1   7

# %%
best_defence_df = teams_stats.sort_values(by = ['GA'], ascending = True)

# %%
best_defence_df.head()
# Out:
#          Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 4         CRY  Crystal Palace      4  2  1  1   3   2   +1   7
# 1         LIV       Liverpool      4  4  0  0  12   3   +9  12
# 2         MCI        Man City      4  3  0  1  14   3  +11  10
# 3         LEI       Leicester      4  2  0  2   6   3   +3   8
# 6         EVE         Everton      4  2  1  1   4   4    0   7

# %%
GA = list(zip(worst_defence_df.name, worst_defence_df.GA))
GA_bottom5 = GA[:5]
GA_top5 = sorted(GA[-5:], key = lambda x: x[1])

# %%
GA_bottom5, GA_top5
# Out:
# ([('Norwich', 10),
#   ('Chelsea', 9),
#   ('Bournemouth', 8),
#   ('Watford', 8),
#   ('West Ham', 7)],
#  [('Crystal Palace', 2),
#   ('Man City', 3),
#   ('Leicester', 3),
#   ('Liverpool', 3),
#   ('Man Utd', 4)])

# %%
teams_stats.GA.median()
# Out:
# 6.0

# %%
X = [item[0] for item in GA_bottom5]
Y = [int(item[1]) for item in GA_bottom5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 5 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GA_top5]
Y = [int(item[1]) for item in GA_top5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 5 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
offense_df = teams_stats.sort_values(by = ['GF'], ascending = False)

# %%
offense_df.head()
# Out:
#          Team       name Played  W  L  D  GF  GA   GD Pts
# Position
# 2         MCI   Man City      4  3  0  1  14   3  +11  10
# 1         LIV  Liverpool      4  4  0  0  12   3   +9  12
# 9         TOT      Spurs      4  1  1  2   7   6   +1   5
# 8         MUN    Man Utd      4  1  1  2   7   4   +3   5
# 7         WHU   West Ham      4  2  1  1   6   7   -1   7

# %%
GF = list(zip(offense_df.name, offense_df.GF))
GF_top5 = GF[:5]
GF_bottom5 = GF[-5:]

# %%
GF_top5, GF_bottom5
# Out:
# ([('Man City', 14),
#   ('Liverpool', 12),
#   ('Spurs', 7),
#   ('Man Utd', 7),
#   ('West Ham', 6)],
#  [('Wolves', 4),
#   ('Aston Villa', 4),
#   ('Crystal Palace', 3),
#   ('Newcastle', 3),
#   ('Watford', 2)])

# %%
X = [item[0] for item in GF_top5]
Y = [int(item[1]) for item in GF_top5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 5 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GF_bottom5]
Y = [int(item[1]) for item in GF_bottom5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 5 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stats_df = player_df[player_df.minutes >= min_min]

# %%
stats_df.tail()
# Out:
#      bonus  cost  minutes                        name  position  \
# 395      0   4.9      166               Ryan Bertrand  Defender
# 288      0   5.4      146                Ashley Young  Defender
# 20       0   5.9      270  David Luiz Moreira Marinho  Defender
# 349      0   4.0      270                Grant Hanley  Defender
# 155      0   4.9      360                  Kurt Zouma  Defender
#
#      pts_per_90min  red_cards   roi     status  team_code    team_name  \
# 395           1.08          0  0.41  available         20  Southampton
# 288           1.22          0  0.37  available          1      Man Utd
# 20            0.66          0  0.34  available          3      Arsenal
# 349           0.33          0  0.25   doubtful         45      Norwich
# 155           0.25          0  0.20  available          8      Chelsea
#
#      total_points  transfers_in  transfers_out
# 395             2          4156          31895
# 288             2          5833          13977
# 20              2         38981         236470
# 349             1        111058          83292
# 155             1         40660          99437

# %% [markdown]
# ### Cobine Team and Player Stats

# %%
team_dic = {item:[] for item in team_names}

for row, player in stats_df.iterrows():
    for name in team_names:
        if player.team_name == name:
            playa = dict(name = player['name'], position = player.position, cost = player.cost, minutes = player.minutes, 
                         points = player.total_points,  roi = player.roi, pts_per_90min = player.pts_per_90min, 
                         bonus = player.bonus, red_cards = player.red_cards)
            team_dic[name].append(playa)

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes                 name    position  pts_per_90min  \
# 350      6   7.0      352          Teemu Pukki     Forward           9.43
# 394      6   5.0      360   Jannik Vestergaard    Defender           5.48
# 359      2   4.8      347        Todd Cantwell  Midfielder           5.43
# 163      2   5.6      360  Patrick van Aanholt    Defender           5.98
# 376      4   4.2      347       John Lundstram    Defender           4.66
#
#      red_cards   roi     status  team_code       team_name  total_points  \
# 350          0  5.29  available         45         Norwich            37
# 394          0  4.40  available         20     Southampton            22
# 359          0  4.38  available         45         Norwich            21
# 163          0  4.29  available         31  Crystal Palace            24
# 376          0  4.29  available         49   Sheffield Utd            18
#
#      transfers_in  transfers_out
# 350       2386244         277547
# 394        163535          18608
# 359       1251203         157944
# 163        401943         127895
# 376       1006663         124729

# %%
team_dic['Liverpool']
# Out:
# [{'name': 'Joel Matip',
#   'position': 'Defender',
#   'cost': 5.4,
#   'minutes': 270,
#   'points': 17,
#   'roi': 3.15,
#   'pts_per_90min': 5.65,
#   'bonus': 1,
#   'red_cards': 0},
#  {'name': 'Trent Alexander-Arnold',
#   'position': 'Defender',
#   'cost': 7.1,
#   'minutes': 360,
#   'points': 22,
#   'roi': 3.1,
#   'pts_per_90min': 5.48,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Virgil van Dijk',
#   'position': 'Defender',
#   'cost': 6.5,
#   'minutes': 360,
#   'points': 19,
#   'roi': 2.92,
#   'pts_per_90min': 4.74,
#   'bonus': 1,
#   'red_cards': 0},
#  {'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'cost': 12.5,
#   'minutes': 348,
#   'points': 36,
#   'roi': 2.88,
#   'pts_per_90min': 9.28,
#   'bonus': 5,
#   'red_cards': 0},
#  {'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'cost': 9.5,
#   'minutes': 344,
#   'points': 27,
#   'roi': 2.84,
#   'pts_per_90min': 7.04,
#   'bonus': 5,
#   'red_cards': 0},
#  {'name': 'Adrián San Miguel del Castillo',
#   'position': 'Goalkeeper',
#   'cost': 4.6,
#   'minutes': 321,
#   'points': 12,
#   'roi': 2.61,
#   'pts_per_90min': 3.35,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Fabio Henrique Tavares',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 286,
#   'points': 12,
#   'roi': 2.18,
#   'pts_per_90min': 3.76,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Sadio Mané',
#   'position': 'Midfielder',
#   'cost': 11.5,
#   'minutes': 266,
#   'points': 25,
#   'roi': 2.17,
#   'pts_per_90min': 8.43,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Georginio Wijnaldum',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 338,
#   'points': 10,
#   'roi': 1.82,
#   'pts_per_90min': 2.65,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Andrew Robertson',
#   'position': 'Defender',
#   'cost': 6.9,
#   'minutes': 360,
#   'points': 12,
#   'roi': 1.74,
#   'pts_per_90min': 2.99,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Jordan Henderson',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 251,
#   'points': 8,
#   'roi': 1.45,
#   'pts_per_90min': 2.86,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Alex Oxlade-Chamberlain',
#   'position': 'Midfielder',
#   'cost': 6.4,
#   'minutes': 120,
#   'points': 4,
#   'roi': 0.62,
#   'pts_per_90min': 2.98,
#   'bonus': 0,
#   'red_cards': 0}]

# %% [markdown]
# ### Get Final Stats per Team using Pandas

# %%
team_stats = {item:{} for item in team_names}

for team in team_names:
    active_players = len(stats_df[stats_df.team_name == team].cost)
    tot_cost = round(stats_df[stats_df.team_name == team].cost.sum(), 3)
    tot_pts = round(stats_df[stats_df.team_name == team].total_points.sum(), 3)
    avg_player_roi = round(tot_pts / tot_cost, 3)
    avg_pts_per_player = round(tot_pts / active_players, 3)
    
    stats = dict(active_players = active_players, tot_cost = tot_cost, tot_pts = tot_pts,
               avg_pts_per_player = avg_pts_per_player,  avg_player_roi =  avg_player_roi)
    
    team_stats[team].update(stats)

# %%
team_stats['Newcastle']
# Out:
# {'active_players': 13,
#  'tot_cost': 65.1,
#  'tot_pts': 134,
#  'avg_pts_per_player': 10.308,
#  'avg_player_roi': 2.058}

# %%
team_stats_df = pd.DataFrame(team_stats).T

# %%
team_stats_df.sort_values(by = ['avg_pts_per_player'], ascending = False, inplace = True)

# %%
team_stats_df
# Out:
#                 active_players  avg_player_roi  avg_pts_per_player  tot_cost  \
# Man City                  13.0           2.492              18.846      98.3
# Liverpool                 12.0           2.348              17.000      86.9
# Leicester                 13.0           2.352              13.462      74.4
# Everton                   13.0           2.090              12.538      78.0
# Man Utd                   13.0           2.013              12.385      80.0
# Burnley                   12.0           2.297              12.250      64.0
# Wolves                    12.0           2.082              11.417      65.8
# Arsenal                   13.0           1.785              11.231      81.8
# Crystal Palace            15.0           2.075              11.067      80.0
# Aston Villa               13.0           2.173              11.000      65.8
# West Ham                  14.0           1.941              10.857      78.3
# Sheffield Utd             13.0           2.198              10.769      63.7
# Norwich                   11.0           2.118              10.455      54.3
# Newcastle                 13.0           2.058              10.308      65.1
# Spurs                     13.0           1.556              10.308      86.1
# Brighton                  12.0           1.955              10.083      61.9
# Southampton               12.0           1.961              10.083      61.7
# Chelsea                   12.0           1.559               9.250      71.2
# Bournemouth               12.0           1.672               9.083      65.2
# Watford                   13.0           1.310               6.923      68.7
#
#                 tot_pts
# Man City          245.0
# Liverpool         204.0
# Leicester         175.0
# Everton           163.0
# Man Utd           161.0
# Burnley           147.0
# Wolves            137.0
# Arsenal           146.0
# Crystal Palace    166.0
# Aston Villa       143.0
# West Ham          152.0
# Sheffield Utd     140.0
# Norwich           115.0
# Newcastle         134.0
# Spurs             134.0
# Brighton          121.0
# Southampton       121.0
# Chelsea           111.0
# Bournemouth       109.0
# Watford            90.0

# %% [markdown]
# ### Build a team using 90min Stat

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_90min:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 10.0
# Player Selected: Rui Pedro dos Santos Patrício
# GK budget left: 4.9
# Player Selected: Angus Gunn
# GK budget left: 0.40000000000000036
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn']
# ['Wolves', 'Southampton']

# %% [markdown]
# ### Select top 3 players by points per position

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 22.4 42.0 26.0
# Player Selected: Patrick van Aanholt
# DF budget left: 16.799999999999997
# Player Selected: Raheem Sterling
# MD budget left: 29.7
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City']

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Sergio Agüero
# ST budget left: 13.9
# 5
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with 90_min_stats

# %%
for item in DF_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Lucas Digne
# DF budget left: 10.699999999999998
# Player Selected: Joel Matip
# DF budget left: 5.299999999999997
# 7
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Lucas Digne', 'Joel Matip']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Everton', 'Liverpool']

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Kevin De Bruyne
# MD budget left: 25.2
# Player Selected: Mohamed Salah
# MD budget left: 12.7
# Player Selected: Sadio Mané
# MD budget left: 1.1999999999999993
# 10
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Lucas Digne', 'Joel Matip', 'Kevin De Bruyne', 'Mohamed Salah', 'Sadio Mané']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Everton', 'Liverpool', 'Man City', 'Liverpool', 'Liverpool']

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Tammy Abraham
# ST budget left: 7.8999999999999995
# Player Selected: Jordan Ayew
# ST budget left: 2.8
# 12
# ['Rui Pedro dos Santos Patrício', 'Angus Gunn', 'Patrick van Aanholt', 'Raheem Sterling', 'Sergio Agüero', 'Lucas Digne', 'Joel Matip', 'Kevin De Bruyne', 'Mohamed Salah', 'Sadio Mané', 'Tammy Abraham', 'Jordan Ayew']
# ['Wolves', 'Southampton', 'Crystal Palace', 'Man City', 'Man City', 'Everton', 'Liverpool', 'Man City', 'Liverpool', 'Liverpool', 'Chelsea', 'Crystal Palace']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                           name    position  \
# 0       2   5.1      360  Rui Pedro dos Santos Patrício  Goalkeeper
# 1       1   4.5      360                     Angus Gunn  Goalkeeper
# 2       2   5.6      360            Patrick van Aanholt    Defender
# 3       4  12.3      360                Raheem Sterling  Midfielder
# 4       6  12.1      266                  Sergio Agüero     Forward
# 5       3   6.1      342                    Lucas Digne    Defender
# 6       1   5.4      270                     Joel Matip    Defender
# 7       6   9.8      326                Kevin De Bruyne  Midfielder
# 8       5  12.5      348                  Mohamed Salah  Midfielder
# 9       3  11.5      266                     Sadio Mané  Midfielder
# 10      6   7.2      251                  Tammy Abraham     Forward
# 11      6   5.1      223                    Jordan Ayew     Forward
#
#     pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 0            4.99          0  3.92  available         39          Wolves
# 1            3.74          0  3.33  available         20     Southampton
# 2            5.98          0  4.29  available         31  Crystal Palace
# 3            9.22          0  3.01  available         43        Man City
# 4           13.48          0  3.31  available         43        Man City
# 5            6.03          0  3.77  available         11         Everton
# 6            5.65          0  3.15  available         14       Liverpool
# 7            9.91          0  3.67  available         43        Man City
# 8            9.28          0  2.88  available         14       Liverpool
# 9            8.43          0  2.17  available         14       Liverpool
# 10          10.00          0  3.89  available          8         Chelsea
# 11           8.04          0  3.92  available         31  Crystal Palace
#
#     total_points  transfers_in  transfers_out
# 0             20        333056          98383
# 1             15         49735          20651
# 2             24        401943         127895
# 3             37       1025539         197881
# 4             40        672193         292073
# 5             23        624597         309277
# 6             17        209382          69673
# 7             36       1280713         235549
# 8             36        582072         557066
# 9             25        586300         361570
# 10            28        928228         165474
# 11            20        391052         153149

# %%
money_x = money_df.pts_per_90min
money_y = money_df.name
ST_75th = round(money_df.describe().pts_per_90min['75%'], 2)
ST_AVG = round(money_df.describe().pts_per_90min['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by pts_per_90min Stat', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
