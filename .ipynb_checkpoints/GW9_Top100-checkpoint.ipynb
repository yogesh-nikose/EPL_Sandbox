# %% [markdown]
# ### Import Major Libraries

# %%
import json
import requests
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# ## Define Gameweek and Periods for FDR calculation

# %%
gameweek = 11
next_n_games = 2

#define percentage of time player needs to have played to be counted as active
min_min = ((gameweek-1)*90)/4     #<---- Currently 25% of playtime
print(min_min)
# Out:
# 225.0

# %% [markdown]
# ## Define Budget, Team Formation, and Budget Allocation by Position

# %%
#Budget
budget = 100

#Team Formation
DF = 3
MD = 4
ST = 3

#Total players needed per position
DF_max = 5
MD_max = 5
ST_max = 3

#Budget Allocation
GK_coef = 0.095
DF_coef = 0.285
MD_coef = 0.36
ST_coef = 0.26

print(sum([GK_coef, DF_coef, MD_coef, ST_coef]))
# Out:
# 1.0

# %% [markdown]
# ## Scraped list of Schedules

# %%
schedules = ['Arsenal NEW (A) BUR (H) LIV (A) TOT (H) WAT (A) AVL (H) MUN (A) BOU (H) SHU (A) CRY (H) WOL (H) LEI (A) SOU (H) NOR (A) BHA (H) WHU (A) MCI (H) EVE (A) BOU (A) CHE (H) MUN (H) CRY (A) SHU (H) CHE (A) BUR (A) NEW (H) EVE (H) MCI (A) WHU (H) BHA (A) SOU (A) NOR (H) WOL (A) LEI (H) TOT (A) LIV (H) AVL (A) WAT (H)',
 'Aston Villa TOT (A) BOU (H) EVE (H) CRY (A) WHU (H) ARS (A) BUR (H) NOR (A) BHA (H) MCI (A) LIV (H) WOL (A) NEW (H) MUN (A) CHE (A) LEI (H) SHU (A) SOU (H) NOR (H) WAT (A) BUR (A) MCI (H) BHA (A) WAT (H) BOU (A) TOT (H) SOU (A) SHU (H) LEI (A) CHE (H) NEW (A) WOL (H) LIV (A) MUN (H) CRY (H) EVE (A) ARS (H) WHU (A)',
 'Bournemouth SHU (H) AVL (A) MCI (H) LEI (A) EVE (H) SOU (A) WHU (H) ARS (A) NOR (H) WAT (A) MUN (H) NEW (A) WOL (H) TOT (A) CRY (A) LIV (H) CHE (A) BUR (H) ARS (H) BHA (A) WHU (A) WAT (H) NOR (A) BHA (H) AVL (H) SHU (A) BUR (A) CHE (H) LIV (A) CRY (H) WOL (A) NEW (H) MUN (A) TOT (H) LEI (H) MCI (A) SOU (H) EVE (A)',
 'Brighton WAT (A) WHU (H) SOU (H) MCI (A) BUR (H) NEW (A) CHE (A) TOT (H) AVL (A) EVE (H) NOR (H) MUN (A) LEI (H) LIV (A) ARS (A) WOL (H) CRY (A) SHU (H) TOT (A) BOU (H) CHE (H) EVE (A) AVL (H) BOU (A) WHU (A) WAT (H) SHU (A) CRY (H) WOL (A) ARS (H) LEI (A) MUN (H) NOR (A) LIV (H) MCI (H) SOU (A) NEW (H) BUR (A)',
 'Burnley SOU (H) ARS (A) WOL (A) LIV (H) BHA (A) NOR (H) AVL (A) EVE (H) LEI (A) CHE (H) SHU (A) WHU (H) WAT (A) CRY (H) MCI (H) TOT (A) NEW (H) BOU (A) EVE (A) MUN (H) AVL (H) CHE (A) LEI (H) MUN (A) ARS (H) SOU (A) BOU (H) NEW (A) TOT (H) MCI (A) WAT (H) CRY (A) SHU (H) WHU (A) LIV (A) WOL (H) NOR (A) BHA (H)',
 'Chelsea MUN (A) LEI (H) NOR (A) SHU (H) WOL (A) LIV (H) BHA (H) SOU (A) NEW (H) BUR (A) WAT (A) CRY (H) MCI (A) WHU (H) AVL (H) EVE (A) BOU (H) TOT (A) SOU (H) ARS (A) BHA (A) BUR (H) NEW (A) ARS (H) LEI (A) MUN (H) TOT (H) BOU (A) EVE (H) AVL (A) MCI (H) WHU (A) WAT (H) CRY (A) SHU (A) NOR (H) LIV (A) WOL (H)',
 'Crystal Palace EVE (H) SHU (A) MUN (A) AVL (H) TOT (A) WOL (H) NOR (H) WHU (A) MCI (H) ARS (A) LEI (H) CHE (A) LIV (H) BUR (A) BOU (H) WAT (A) BHA (H) NEW (A) WHU (H) SOU (A) NOR (A) ARS (H) MCI (A) SOU (H) SHU (H) EVE (A) NEW (H) BHA (A) WAT (H) BOU (A) LIV (A) BUR (H) LEI (A) CHE (H) AVL (A) MUN (H) WOL (A) TOT (H)',
 'Everton CRY (A) WAT (H) AVL (A) WOL (H) BOU (A) SHU (H) MCI (H) BUR (A) WHU (H) BHA (A) TOT (H) SOU (A) NOR (H) LEI (A) LIV (A) CHE (H) MUN (A) ARS (H) BUR (H) NEW (A) MCI (A) BHA (H) WHU (A) NEW (H) WAT (A) CRY (H) ARS (A) MUN (H) CHE (A) LIV (H) NOR (A) LEI (H) TOT (A) SOU (H) WOL (A) AVL (H) SHU (A) BOU (H)',
 'Leicester WOL (H) CHE (A) SHU (A) BOU (H) MUN (A) TOT (H) NEW (H) LIV (A) BUR (H) SOU (A) CRY (A) ARS (H) BHA (A) EVE (H) WAT (H) AVL (A) NOR (H) MCI (A) LIV (H) WHU (A) NEW (A) SOU (H) BUR (A) WHU (H) CHE (H) WOL (A) MCI (H) NOR (A) AVL (H) WAT (A) BHA (H) EVE (A) CRY (H) ARS (A) BOU (A) SHU (H) TOT (A) MUN (H)',
 'Liverpool NOR (H) SOU (A) ARS (H) BUR (A) NEW (H) CHE (A) SHU (A) LEI (H) MUN (A) TOT (H) AVL (A) MCI (H) CRY (A) BHA (H) EVE (H) BOU (A) WAT (H) WHU (A) LEI (A) WOL (H) SHU (H) TOT (A) MUN (H) WOL (A) SOU (H) NOR (A) WHU (H) WAT (A) BOU (H) EVE (A) CRY (H) MCI (A) AVL (H) BHA (A) BUR (H) ARS (A) CHE (H) NEW (A)',
 'Man City WHU (A) TOT (H) BOU (A) BHA (H) NOR (A) WAT (H) EVE (A) WOL (H) CRY (A) AVL (H) SOU (H) LIV (A) CHE (H) NEW (A) BUR (A) MUN (H) ARS (A) LEI (H) WOL (A) SHU (H) EVE (H) AVL (A) CRY (H) SHU (A) TOT (A) WHU (H) LEI (A) ARS (H) MUN (A) BUR (H) CHE (A) LIV (H) SOU (A) NEW (H) BHA (A) BOU (H) WAT (A) NOR (H)',
 'Man Utd CHE (H) WOL (A) CRY (H) SOU (A) LEI (H) WHU (A) ARS (H) NEW (A) LIV (H) NOR (A) BOU (A) BHA (H) SHU (A) AVL (H) TOT (H) MCI (A) EVE (H) WAT (A) NEW (H) BUR (A) ARS (A) NOR (H) LIV (A) BUR (H) WOL (H) CHE (A) WAT (H) EVE (A) MCI (H) TOT (A) SHU (H) BHA (A) BOU (H) AVL (A) SOU (H) CRY (A) WHU (H) LEI (A)',
 'Newcastle ARS (H) NOR (A) TOT (A) WAT (H) LIV (A) BHA (H) LEI (A) MUN (H) CHE (A) WOL (H) WHU (A) BOU (H) AVL (A) MCI (H) SHU (A) SOU (H) BUR (A) CRY (H) MUN (A) EVE (H) LEI (H) WOL (A) CHE (H) EVE (A) NOR (H) ARS (A) CRY (A) BUR (H) SOU (A) SHU (H) AVL (H) BOU (A) WHU (H) MCI (A) WAT (A) TOT (H) BHA (A) LIV (H)',
 'Norwich LIV (A) NEW (H) CHE (H) WHU (A) MCI (H) BUR (A) CRY (A) AVL (H) BOU (A) MUN (H) BHA (A) WAT (H) EVE (A) ARS (H) SOU (A) SHU (H) LEI (A) WOL (H) AVL (A) TOT (H) CRY (H) MUN (A) BOU (H) TOT (A) NEW (A) LIV (H) WOL (A) LEI (H) SHU (A) SOU (H) EVE (H) ARS (A) BHA (H) WAT (A) WHU (H) CHE (A) BUR (H) MCI (A)',
 'Sheffield Utd BOU (A) CRY (H) LEI (H) CHE (A) SOU (H) EVE (A) LIV (H) WAT (A) ARS (H) WHU (A) BUR (H) TOT (A) MUN (H) WOL (A) NEW (H) NOR (A) AVL (H) BHA (A) WAT (H) MCI (A) LIV (A) WHU (H) ARS (A) MCI (H) CRY (A) BOU (H) BHA (H) AVL (A) NOR (H) NEW (A) MUN (A) TOT (H) BUR (A) WOL (H) CHE (H) LEI (A) EVE (H) SOU (A)',
 'Southampton BUR (A) LIV (H) BHA (A) MUN (H) SHU (A) BOU (H) TOT (A) CHE (H) WOL (A) LEI (H) MCI (A) EVE (H) ARS (A) WAT (H) NOR (H) NEW (A) WHU (H) AVL (A) CHE (A) CRY (H) TOT (H) LEI (A) WOL (H) CRY (A) LIV (A) BUR (H) AVL (H) WHU (A) NEW (H) NOR (A) ARS (H) WAT (A) MCI (H) EVE (A) MUN (A) BHA (H) BOU (A) SHU (H)',
 'Spurs AVL (H) MCI (A) NEW (H) ARS (A) CRY (H) LEI (A) SOU (H) BHA (A) WAT (H) LIV (A) EVE (A) SHU (H) WHU (A) BOU (H) MUN (A) BUR (H) WOL (A) CHE (H) BHA (H) NOR (A) SOU (A) LIV (H) WAT (A) NOR (H) MCI (H) AVL (A) CHE (A) WOL (H) BUR (A) MUN (H) WHU (H) SHU (A) EVE (H) BOU (A) ARS (H) NEW (A) LEI (H) CRY (A)',
 'Watford BHA (H) EVE (A) WHU (H) NEW (A) ARS (H) MCI (A) WOL (A) SHU (H) TOT (A) BOU (H) CHE (H) NOR (A) BUR (H) SOU (A) LEI (A) CRY (H) LIV (A) MUN (H) SHU (A) AVL (H) WOL (H) BOU (A) TOT (H) AVL (A) EVE (H) BHA (A) MUN (A) LIV (H) CRY (A) LEI (H) BUR (A) SOU (H) CHE (A) NOR (H) NEW (H) WHU (A) MCI (H) ARS (A)',
 'West Ham MCI (H) BHA (A) WAT (A) NOR (H) AVL (A) MUN (H) BOU (A) CRY (H) EVE (A) SHU (H) NEW (H) BUR (A) TOT (H) CHE (A) WOL (A) ARS (H) SOU (A) LIV (H) CRY (A) LEI (H) BOU (H) SHU (A) EVE (H) LEI (A) BHA (H) MCI (A) LIV (A) SOU (H) ARS (A) WOL (H) TOT (A) CHE (H) NEW (A) BUR (H) NOR (A) WAT (H) MUN (A) AVL (H)',
 'Wolves LEI (A) MUN (H) BUR (H) EVE (A) CHE (H) CRY (A) WAT (H) MCI (A) SOU (H) NEW (A) ARS (A) AVL (H) BOU (A) SHU (H) WHU (H) BHA (A) TOT (H) NOR (A) MCI (H) LIV (A) WAT (A) NEW (H) SOU (A) LIV (H) MUN (A) LEI (H) NOR (H) TOT (A) BHA (H) WHU (A) BOU (H) AVL (A) ARS (H) SHU (A) EVE (H) BUR (A) CRY (H) CHE (A)']

# %% [markdown]
# ### Import Data

# %%
# url = "https://fantasy.premierleague.com/drf/bootstrap-static"
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %% [markdown]
# ### Get Team Table

# %%
table_url = 'https://www.premierleague.com/tables'

def build_table(table_url):
    team_table = pd.read_html(table_url)
    team_df = pd.DataFrame(team_table[0])
    team_df = team_df[team_df['Unnamed: 12'].isna()]
    team_df = team_df.iloc[:,1:10]
    team_df.Club = team_df.Club.map(lambda x: x[-3:])
    team_df.reset_index()
    team_df.index = np.arange(1, len(team_df) + 1)
    team_df.columns = ['Team', 'Played', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']
    team_df.index.name = 'Position'
    
    return team_df

# %%
table_url = 'https://www.premierleague.com/tables'
team_table = pd.read_html(table_url)
team_table[0]
# Out:
#                                         Position  Pos  \
# 0                             1  Previous Position  1
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                             2  Previous Position  2
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                             3  Previous Position  3
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                             4  Previous Position  4
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                             5  Previous Position  5
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                            6  Previous Position  6
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                           7  Previous Position  14
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                            8  Previous Position  9
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                           9  Previous Position  10
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                          10  Previous Position  11
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                           11  Previous Position  7
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                          12  Previous Position  13
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                           13  Previous Position  8
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                          14  Previous Position  16
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                          15  Previous Position  12
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                          16  Previous Position  15
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                          17  Previous Position  18
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                          18  Previous Position  17
# 35  Southampton  Recent Result - Friday 25 October...
# 36                          19  Previous Position  19
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                          20  Previous Position  20
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                  Club  \
# 0                                        LiverpoolLIV
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                  Manchester CityMCI
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                   Leicester CityLEI
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                          ChelseaCHE
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                          ArsenalARS
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                  Crystal PalaceCRY
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                               Manchester UnitedMUN
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                Sheffield UnitedSHU
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                     BournemouthBOU
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                 West Ham UnitedWHU
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                               Tottenham HotspurTOT
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                         Wolverhampton WanderersWOL
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                         BurnleyBUR
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                        Brighton and Hove AlbionBHA
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                     Aston VillaAVL
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                         EvertonEVE
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                Newcastle UnitedNEW
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                     SouthamptonSOU
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                    Norwich CityNOR
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                         WatfordWAT
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                            Played  Pl  \
# 0                                                  10
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                  10
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                  10
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                  10
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                  10
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                 10
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                 10
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                 10
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                 10
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                 10
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                 10
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                 10
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                 10
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                 10
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                 10
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                 10
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                 10
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                 10
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                 10
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                 10
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                Won  W  \
# 0                                                   9
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                   7
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                   6
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                   6
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                   4
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                  4
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                  3
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                  3
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                  3
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                  3
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                  3
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                  2
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                  3
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                  3
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                  3
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                  3
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                  2
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                  2
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                  2
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                  0
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                              Drawn  D  \
# 0                                                   1
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                   1
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                   2
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                   2
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                   4
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                  3
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                  4
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                  4
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                  4
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                  4
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                  3
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                  6
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                  3
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                  3
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                  2
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                  1
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                  3
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                  2
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                  1
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                               Lost  L  \
# 0                                                   0
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                   2
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                   2
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                   2
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                   2
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                  3
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                  3
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                  3
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                  3
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                  3
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                  4
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                  2
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                  4
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                  4
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                  5
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                  6
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                  5
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                  6
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                  7
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                    GF  \
# 0                                                  23
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                  32
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                  25
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                  23
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                  15
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                 10
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                 13
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                  9
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                 13
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                 12
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                 16
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                 13
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                 14
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                 12
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                 15
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                 10
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                  6
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                  9
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                 11
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                    GA  \
# 0                                                   8
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                   9
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                   8
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                  16
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                  14
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                 12
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                 10
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                  8
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                 13
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                 14
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                 15
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                 13
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                 15
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                 14
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                 16
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                 16
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                 15
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                 25
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                 24
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                 21
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                    GD  \
# 0                                                 +15
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                 +23
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                 +17
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                  +7
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                  +1
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                 -2
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                 +3
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                 +1
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                  0
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                 -2
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                 +1
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                  0
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                 -1
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                 -2
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                 -1
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                 -6
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                 -9
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                -16
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                -13
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                -16
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                           Points  Pts  \
# 0                                                  28
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                  22
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                  20
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                  20
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                  16
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                 15
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                 13
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                 13
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                 13
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                 13
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                 12
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                 12
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                 12
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                 12
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                 11
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                 10
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                  9
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                  8
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                  7
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                  Form  \
# 0   W  Sunday 22 September 2019  CHE  1 -2  LIV  W...
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2   W  Saturday 21 September 2019  MCI  8 -0  WAT ...
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4   W  Saturday 21 September 2019  LEI  2 -1  TOT ...
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6   L  Sunday 22 September 2019  CHE  1 -2  LIV  W...
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8   W  Sunday 22 September 2019  ARS  3 -2  AVL  D...
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10  D  Sunday 22 September 2019  CRY  1 -1  WOL  W...
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12  L  Sunday 22 September 2019  WHU  2 -0  MUN  D...
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14  W  Saturday 21 September 2019  EVE  0 -2  SHU ...
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16  W  Friday 20 September 2019  SOU  1 -3  BOU  D...
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18  W  Sunday 22 September 2019  WHU  2 -0  MUN  D...
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20  L  Saturday 21 September 2019  LEI  2 -1  TOT ...
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22  D  Sunday 22 September 2019  CRY  1 -1  WOL  W...
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24  W  Saturday 21 September 2019  BUR  2 -0  NOR ...
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26  D  Saturday 21 September 2019  NEW  0 -0  BHA ...
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28  L  Sunday 22 September 2019  ARS  3 -2  AVL  D...
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30  L  Saturday 21 September 2019  EVE  0 -2  SHU ...
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32  D  Saturday 21 September 2019  NEW  0 -0  BHA ...
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34  L  Friday 20 September 2019  SOU  1 -3  BOU  L...
# 35  Southampton  Recent Result - Friday 25 October...
# 36  L  Saturday 21 September 2019  BUR  2 -0  NOR ...
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38  L  Saturday 21 September 2019  MCI  8 -0  WAT ...
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                                  Next  \
# 0   Aston Villa  Saturday 02 November 2019  AVL  1...
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2   Southampton  Saturday 02 November 2019  MCI  1...
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4   Crystal Palace  Sunday 03 November 2019  CRY  ...
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6   Watford  Saturday 02 November 2019  WAT  17:30...
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8   Wolverhampton Wanderers  Saturday 02 November ...
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10  Leicester City  Sunday 03 November 2019  CRY  ...
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12  AFC Bournemouth  Saturday 02 November 2019  BO...
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14  Burnley  Saturday 02 November 2019  SHU  15:00...
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16  Manchester United  Saturday 02 November 2019  ...
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18  Newcastle United  Saturday 02 November 2019  W...
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20  Everton  Sunday 03 November 2019  EVE  16:30  TOT
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22  Arsenal  Saturday 02 November 2019  ARS  15:00...
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24  Sheffield United  Saturday 02 November 2019  S...
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26  Norwich City  Saturday 02 November 2019  BHA  ...
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28  Liverpool  Saturday 02 November 2019  AVL  15:...
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30  Tottenham Hotspur  Sunday 03 November 2019  EV...
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32  West Ham United  Saturday 02 November 2019  WH...
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34  Manchester City  Saturday 02 November 2019  MC...
# 35  Southampton  Recent Result - Friday 25 October...
# 36  Brighton and Hove Albion  Saturday 02 November...
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38  Chelsea  Saturday 02 November 2019  WAT  17:30...
# 39  Watford  Recent Result - Saturday 26 October 2...
#
#                                           Unnamed: 12
# 0                                                 NaN
# 1   Liverpool  Recent Result - Sunday 27 October 2...
# 2                                                 NaN
# 3   Manchester City  Recent Result - Saturday 26 O...
# 4                                                 NaN
# 5   Leicester City  Recent Result - Friday 25 Octo...
# 6                                                 NaN
# 7   Chelsea  Recent Result - Saturday 26 October 2...
# 8                                                 NaN
# 9   Arsenal  Recent Result - Sunday 27 October 201...
# 10                                                NaN
# 11  Crystal Palace  Recent Result - Sunday 27 Octo...
# 12                                                NaN
# 13  Manchester United  Recent Result - Sunday 27 O...
# 14                                                NaN
# 15  Sheffield United  Recent Result - Saturday 26 ...
# 16                                                NaN
# 17  Bournemouth  Recent Result - Saturday 26 Octob...
# 18                                                NaN
# 19  West Ham United  Recent Result - Saturday 26 O...
# 20                                                NaN
# 21  Tottenham Hotspur  Recent Result - Sunday 27 O...
# 22                                                NaN
# 23  Wolverhampton Wanderers  Recent Result - Sunda...
# 24                                                NaN
# 25  Burnley  Recent Result - Saturday 26 October 2...
# 26                                                NaN
# 27  Brighton and Hove Albion  Recent Result - Satu...
# 28                                                NaN
# 29  Aston Villa  Recent Result - Saturday 26 Octob...
# 30                                                NaN
# 31  Everton  Recent Result - Saturday 26 October 2...
# 32                                                NaN
# 33  Newcastle United  Recent Result - Sunday 27 Oc...
# 34                                                NaN
# 35  Southampton  Recent Result - Friday 25 October...
# 36                                                NaN
# 37  Norwich City  Recent Result - Sunday 27 Octobe...
# 38                                                NaN
# 39  Watford  Recent Result - Saturday 26 October 2...

# %%
table_df = build_table(table_url)

# %%
table_df.head()
# Out:
#          Team Played  W  D  L  GF  GA   GD Pts
# Position
# 1         LIV     10  9  1  0  23   8  +15  28
# 2         MCI     10  7  1  2  32   9  +23  22
# 3         LEI     10  6  2  2  25   8  +17  20
# 4         CHE     10  6  2  2  23  16   +7  20
# 5         ARS     10  4  4  2  15  14   +1  16

# %% [markdown]
# ### Try dynamic FDR Score

# %%
#List of teams
name_list = list(table_df.Team)

#list of points as integers
pts_list = [int(item) for item in table_df.Pts]
top_pts = max(pts_list)

#list of GF as integers
GF_list = [int(item) for item in table_df.GF]
top_GF = max(GF_list)

#list of GA as integers
GA_list = [int(item) for item in table_df.GA]
top_GA = max(GA_list)

# %%
top_pts, top_GF, top_GA
# Out:
# (28, 32, 25)

# %%
name_list[:5]
# Out:
# ['LIV', 'MCI', 'LEI', 'CHE', 'ARS']

# %%
from scipy import stats
stats.percentileofscore(GF_list, 20)
# Out:
# 80.0

# %%
scaled = [pts_list, GF_list, GA_list]

# %% [markdown]
# ### Write Function to try scaled scores

# %%
def scaled_FDR(pts_list, GF_list, GA_list):
    #turn to array so you an use scaler
    arr_pts = np.array(pts_list).reshape(-1, 1)
    arr_GF = np.array(GF_list).reshape(-1, 1)
    arr_GA = np.array(GA_list).reshape(-1, 1)
    
    #instantiate scalers
    minmax = MinMaxScaler()
    robust = RobustScaler()
    
    #apply MinMax
    minmax_pts = minmax.fit_transform(arr_pts)
    minmax_GF = minmax.fit_transform(arr_GF)
    minmax_GA = minmax.fit_transform(arr_GA)
    
    #apply Robust
    robu_pts = robust.fit_transform(arr_pts)
    robu_GF = robust.fit_transform(arr_GF)
    robu_GA = robust.fit_transform(arr_GA)
    
    #add normalzied scores
    sum_minmax = (minmax_pts + minmax_GF + (1 - minmax_GA)).tolist()
    sum_robu = (robu_pts + robu_GF + minmax_GA*(-1)).tolist()
    
    minmax_fin = [item[0] for item in sum_minmax]
    robu_fin = [item[0] for item in sum_robu]
    
    return (minmax_fin, robu_fin)

# %%
scaled_scores = scaled_FDR(pts_list, GF_list, GA_list)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning:
#
# Data with input dtype int64 was converted to float64 by MinMaxScaler.
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning:
#
# Data with input dtype int64 was converted to float64 by MinMaxScaler.
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning:
#
# Data with input dtype int64 was converted to float64 by MinMaxScaler.

# %%
scaled_scores[1]
# Out:
# [5.34920634920635,
#  5.671335200746966,
#  3.9523809523809526,
#  3.1008403361344534,
#  0.8057889822595704,
#  -0.2511671335200746,
#  -0.006535947712418333,
#  -0.6507936507936507,
#  -0.18300653594771238,
#  -0.43230625583566756,
#  0.04855275443510737,
#  -0.4052287581699346,
#  -0.33239962651727356,
#  -0.6545284780578897,
#  -0.42296918767507,
#  -1.5975723622782447,
#  -2.522875816993464,
#  -2.761904761904762,
#  -2.5443510737628383,
#  -3.955182072829132]

# %%
maybs = [item*2 for item in scaled_scores[0]]

# %%
maybs
# Out:
# [5.333333333333334,
#  5.360613810741688,
#  4.785829307568438,
#  3.6965046888320545,
#  2.9913801269299993,
#  2.769347352467557,
#  3.052950648858577,
#  2.9919484702093397,
#  2.700009472387989,
#  2.5082883394903854,
#  2.5999810552240223,
#  2.613052950648859,
#  2.4518329070758735,
#  2.4213318177512555,
#  2.321303400587288,
#  1.8639765084777873,
#  1.5983707492658898,
#  0.5571658615136879,
#  0.736004546746235,
#  0.47058823529411753]

# %%
Team = name_list
strength = maybs

mean_FDR = round(np.mean([item for item in maybs]), 2)
FDR_75 = round(np.percentile([item for item in maybs], 75), 2)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GF + GA) z-scores', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# import plotly.graph_objs as go


# fig = go.Figure([go.Bar(x=Team, y=strength, marker = {'color': '#82DFF1'})])
# fig.add_trace(go.Scatter(
#     x=['LIV', 'WAT'],
#     y=[mean_FDR, mean_FDR],
#     mode="lines",
# ))

# fig.layout.plot_bgcolor = '#082391'                
# fig.update_layout(
#     title='US Export of Plastic Scrap',
#     xaxis_tickfont_size=14,
#     yaxis=dict(
#         title='USD (millions)',
#         showgrid=False,
#         titlefont_size=16,
#         tickfont_size=14,
#     ))

# fig.write_image('figure.png')
# fig.show()

# %%
zipped_list = list(zip(name_list, pts_list, GF_list, GA_list))

# %%
zipped_list[:3]
# Out:
# [('LIV', 28, 23, 8), ('MCI', 22, 32, 9), ('LEI', 20, 25, 8)]

# %%
def get_percentiles(zipped_list):
    listy = []
    for item in zipped_list:
        team = item[0]
        pts_perc = stats.percentileofscore(pts_list, item[1])
        GF_perc = stats.percentileofscore(GF_list, item[2])
        GA_perc = stats.percentileofscore(GA_list, item[3])
        FDR = pts_perc + GF_perc + (100-GA_perc)
        tup = (team, FDR)
        listy.append(tup)
    return listy

# %%
FDR_new = get_percentiles(zipped_list)

# %%
FDR_new
# Out:
# [('LIV', 277.5),
#  ('MCI', 275.0),
#  ('LEI', 272.5),
#  ('CHE', 195.0),
#  ('ARS', 202.5),
#  ('CRY', 172.5),
#  ('MUN', 192.5),
#  ('SHU', 170.0),
#  ('BOU', 180.0),
#  ('WHU', 155.0),
#  ('TOT', 157.5),
#  ('WOL', 160.0),
#  ('BUR', 142.5),
#  ('BHA', 135.0),
#  ('AVL', 122.5),
#  ('EVE', 72.5),
#  ('NEW', 65.0),
#  ('SOU', 32.5),
#  ('NOR', 50.0),
#  ('WAT', 20.0)]

# %%
mean_FDR = np.mean([item[1] for item in FDR_new])

# %%
mean_FDR
# Out:
# 152.5

# %%
Team = [item[0] for item in FDR_new]
strength = [item[1] for item in FDR_new]

mean_FDR = np.mean([item[1] for item in FDR_new])
FDR_75 = np.percentile([item[1] for item in FDR_new], 75)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GA +GF) SUM', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to return percentile for each team

# %% [markdown]
# ## Add player status and ROI, pts-per-90min metrics to final player_df

# %%
def attach_team_and_position(main_players, all_teams, positons):
    players = main_players.copy()
    for team in all_teams:
        for player in players:
            if team['code'] == player['team_code']:
                player['team_name'] = team['name']
    for position in positions:
        for player in players:
            if position['id'] == player['element_type']:
                player['position'] = position['singular_name']
    for player in players:
        if player['status'] == "a":
            player['status'] = "available"
        elif player['status'] == "d":
            player['status'] = "doubtful"
        elif player['status'] == "i":
            player['status'] = "injured"
        elif player['status'] == "s":
            player['status'] = "suspended"
    return players


#### Temporarily took out the "main_players" filter because no players have played 330 minutes ####

# player_positions_teams = attach_team_and_position(main_players, all_teams_new, positions)
player_positions_teams = attach_team_and_position(all_players, all_teams, positions)


def final_players_list(player_positions_teams):
    players = player_positions_teams.copy()
    empty = []
    for player in players:
        stats = dict(team_code = player['team_code'],
        team_name = player['team_name'],
        name = player['first_name'] + " " + player['second_name'],
        status = player['status'],
        position = player['position'],
        cost = (player['now_cost'])/10,
        total_points = player['total_points'],
        roi = round((player['total_points'] / player['now_cost'])*10, 2),
        pts_per_90min = round((player['total_points'] / (player['minutes'] + 1))*90, 2),
        bonus = player['bonus'],
        red_cards = player['red_cards'],
        minutes = player['minutes'],
        transfers_out = player['transfers_out'],
        transfers_in = player['transfers_in'])
        empty.append(stats)
    return empty

# %%
final = final_players_list(player_positions_teams)

# %%
final[0]
# Out:
# {'team_code': 3,
#  'team_name': 'Arsenal',
#  'name': 'Shkodran Mustafi',
#  'status': 'available',
#  'position': 'Defender',
#  'cost': 5.2,
#  'total_points': 0,
#  'roi': 0.0,
#  'pts_per_90min': 0.0,
#  'bonus': 0,
#  'red_cards': 0,
#  'minutes': 0,
#  'transfers_out': 28435,
#  'transfers_in': 6320}

# %%
all_teams[0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1240,
#  'strength_overall_away': 1330,
#  'strength_attack_home': 1210,
#  'strength_attack_away': 1260,
#  'strength_defence_home': 1280,
#  'strength_defence_away': 1330}

# %% [markdown]
# ### Get Total ROI, Points and 90min before filtering injured and FDR

# %%
total_roi = sorted(final, key = lambda x: x['roi'], reverse = True)

# %%
total_roi[:2]
# Out:
# [{'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'John Lundstram',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 4.7,
#   'total_points': 47,
#   'roi': 10.0,
#   'pts_per_90min': 4.87,
#   'bonus': 7,
#   'red_cards': 0,
#   'minutes': 868,
#   'transfers_out': 251051,
#   'transfers_in': 2053545},
#  {'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'Dean Henderson',
#   'status': 'available',
#   'position': 'Goalkeeper',
#   'cost': 4.6,
#   'total_points': 42,
#   'roi': 9.13,
#   'pts_per_90min': 4.2,
#   'bonus': 2,
#   'red_cards': 0,
#   'minutes': 900,
#   'transfers_out': 74689,
#   'transfers_in': 304218}]

# %% [markdown]
# ### Total_Points

# %%
total_max_pts = sorted(total_roi, key = lambda x: x['total_points'], reverse = True)

# %%
total_max_pts[:2]
# Out:
# [{'team_code': 13,
#   'team_name': 'Leicester',
#   'name': 'Jamie Vardy',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 9.3,
#   'total_points': 74,
#   'roi': 7.96,
#   'pts_per_90min': 7.39,
#   'bonus': 13,
#   'red_cards': 0,
#   'minutes': 900,
#   'transfers_out': 542735,
#   'transfers_in': 1323861},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Kevin De Bruyne',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 10.2,
#   'total_points': 72,
#   'roi': 7.06,
#   'pts_per_90min': 9.34,
#   'bonus': 10,
#   'red_cards': 0,
#   'minutes': 693,
#   'transfers_out': 1369611,
#   'transfers_in': 2785920}]

# %% [markdown]
# ### 90 min

# %%
total_90min = sorted(total_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
total_90min = [player for player in total_90min if player['minutes'] >= min_min]

# %%
total_90min[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.1,
#   'total_points': 62,
#   'roi': 5.12,
#   'pts_per_90min': 9.7,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 574,
#   'transfers_out': 852124,
#   'transfers_in': 1280944},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Kevin De Bruyne',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 10.2,
#   'total_points': 72,
#   'roi': 7.06,
#   'pts_per_90min': 9.34,
#   'bonus': 10,
#   'red_cards': 0,
#   'minutes': 693,
#   'transfers_out': 1369611,
#   'transfers_in': 2785920}]

# %% [markdown]
# ### Create Players DataFrame

# %%
player_df = pd.DataFrame(final)

# %%
player_df.sort_values(by = ['roi'], ascending = False, inplace = True)

# %%
player_df.head(10)
# Out:
#      bonus  cost  minutes                           name    position  \
# 392      7   4.7      868                 John Lundstram    Defender
# 405      2   4.6      900                 Dean Henderson  Goalkeeper
# 96       8   4.7      900                    Mathew Ryan  Goalkeeper
# 388      4   4.5      900                 Jack O'Connell    Defender
# 84       4   4.5      900                 Aaron Ramsdale  Goalkeeper
# 386      4   5.0      900                   Enda Stevens    Defender
# 542      4   5.2      900  Rui Pedro dos Santos Patrício  Goalkeeper
# 363      9   6.9      885                    Teemu Pukki     Forward
# 187     11   5.1      709                    Jordan Ayew     Forward
# 389      3   4.5      900                 George Baldock    Defender
#
#      pts_per_90min  red_cards    roi     status  team_code       team_name  \
# 392           4.87          0  10.00  available         49   Sheffield Utd
# 405           4.20          0   9.13  available         49   Sheffield Utd
# 96            4.20          0   8.94  available         36        Brighton
# 388           3.90          0   8.67  available         49   Sheffield Utd
# 84            3.90          0   8.67  available         91     Bournemouth
# 386           4.30          0   8.60  available         49   Sheffield Utd
# 542           4.30          0   8.27  available         39          Wolves
# 363           5.79          0   8.26  available         45         Norwich
# 187           5.32          0   8.24  available         31  Crystal Palace
# 389           3.70          0   8.22  available         49   Sheffield Utd
#
#      total_points  transfers_in  transfers_out
# 392            47       2053545         251051
# 405            42        304218          74689
# 96             42        584946         371529
# 388            39         74944          18389
# 84             39        113074          29887
# 386            43         96932          27134
# 542            43        696928         265969
# 363            57       3220348        1795526
# 187            42        777310         472076
# 389            37         71088          26040

# %% [markdown]
# ### Merge two team tables s owe have all data

# %%
def merged_teams(table_df, all_teams):
    table_dic = table_df.to_dict('records')
    
    for team in table_dic:
        for item in all_teams:
            if team['Team'] == item['short_name']:
                team['code'] = item['code']
                team['name'] = item['name']
                team['strength'] = item['strength']
            
    new_df = pd.DataFrame(table_dic)
    
    new_order = ['code', 'strength', 'Team','name', 'Played', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'Pts']
    
    table_df = new_df[new_order]
    
    table_df.index = np.arange(1, len(table_df) + 1)
    table_df.index.name = 'Position'
    
    return table_df

# %%
team_df = merged_teams(table_df, all_teams)

# %%
team_df.head()
# Out:
#           code  strength Team       name Played  W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV  Liverpool     10  9  0  1  23   8  +15  28
# 2           43         5  MCI   Man City     10  7  2  1  32   9  +23  22
# 3           13         3  LEI  Leicester     10  6  2  2  25   8  +17  20
# 4            8         4  CHE    Chelsea     10  6  2  2  23  16   +7  20
# 5            3         4  ARS    Arsenal     10  4  2  4  15  14   +1  16

# %%
team_names = list(team_df.name)

# %%
team_names.sort()

# %%
team_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %% [markdown]
# ## Create Schedule DF

# %%
def extract_sched(schedules):
    dic = {}
    for i, item in enumerate(schedules):
        name = item.partition(team_names[i])[1]
        sche = item.partition(team_names[i])[2]
        sche = sche.split()
        clean = [item for item in sche if item != "(A)"]
        clean2 = [item for item in clean if item != "(H)"]
        dic[name] = clean2
    return dic

# %%
wonders = extract_sched(schedules)

# %%
schedule_df = pd.DataFrame(wonders)

# %%
schedule_df.index.name = 'Gameweek'

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
schedule_df.Arsenal[0:3]
# Out:
# Gameweek
# 0    NEW
# 1    BUR
# 2    LIV
# Name: Arsenal, dtype: object

# %% [markdown]
# ## Create FDR scores for calculating next-n opponents AVG strength

# %%
scores = list(zip(team_df.Team, team_df.strength))

# %%
scores = dict(scores)

# %%
sorted(scores.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('LIV', 5),
#  ('MCI', 5),
#  ('CHE', 4),
#  ('ARS', 4),
#  ('MUN', 4),
#  ('TOT', 4),
#  ('LEI', 3),
#  ('CRY', 3),
#  ('BOU', 3),
#  ('WHU', 3),
#  ('WOL', 3),
#  ('BUR', 3),
#  ('EVE', 3),
#  ('SHU', 2),
#  ('BHA', 2),
#  ('AVL', 2),
#  ('NEW', 2),
#  ('SOU', 2),
#  ('NOR', 2),
#  ('WAT', 2)]

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
# from pylab import rcParams
# rcParams['figure.figsize'] = 14, 6

sorted_data = sorted(scores.items(), key = lambda x: x[1], reverse = True)

Team = [item[0] for item in sorted_data]
strength = [item[1] for item in sorted_data]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength Fantasy FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
maybs
# Out:
# [5.333333333333334,
#  5.360613810741688,
#  4.785829307568438,
#  3.6965046888320545,
#  2.9913801269299993,
#  2.769347352467557,
#  3.052950648858577,
#  2.9919484702093397,
#  2.700009472387989,
#  2.5082883394903854,
#  2.5999810552240223,
#  2.613052950648859,
#  2.4518329070758735,
#  2.4213318177512555,
#  2.321303400587288,
#  1.8639765084777873,
#  1.5983707492658898,
#  0.5571658615136879,
#  0.736004546746235,
#  0.47058823529411753]

# %%
new_FDR =  list(zip(name_list, maybs))

# %%
new_FDR
# Out:
# [('LIV', 5.333333333333334),
#  ('MCI', 5.360613810741688),
#  ('LEI', 4.785829307568438),
#  ('CHE', 3.6965046888320545),
#  ('ARS', 2.9913801269299993),
#  ('CRY', 2.769347352467557),
#  ('MUN', 3.052950648858577),
#  ('SHU', 2.9919484702093397),
#  ('BOU', 2.700009472387989),
#  ('WHU', 2.5082883394903854),
#  ('TOT', 2.5999810552240223),
#  ('WOL', 2.613052950648859),
#  ('BUR', 2.4518329070758735),
#  ('BHA', 2.4213318177512555),
#  ('AVL', 2.321303400587288),
#  ('EVE', 1.8639765084777873),
#  ('NEW', 1.5983707492658898),
#  ('SOU', 0.5571658615136879),
#  ('NOR', 0.736004546746235),
#  ('WAT', 0.47058823529411753)]

# %%
def get_avg_FDR(sorted_data, new_FDR):
    listy = []
    for item in sorted_data:
        for score in new_FDR:
            if item[0] == score[0]:
                team = item[0]
                avg_FDR = np.round((item[1] + score[1])/2, 2)
                tup = (team, avg_FDR)
                listy.append(tup)
    return listy

# %%
final_avg_FDR = get_avg_FDR(sorted_data, new_FDR)

# %%
final_avg_FDR = sorted(final_avg_FDR, key = lambda x: x[1], reverse = True)
final_avg_FDR
# Out:
# [('MCI', 5.18),
#  ('LIV', 5.17),
#  ('LEI', 3.89),
#  ('CHE', 3.85),
#  ('MUN', 3.53),
#  ('ARS', 3.5),
#  ('TOT', 3.3),
#  ('CRY', 2.88),
#  ('BOU', 2.85),
#  ('WOL', 2.81),
#  ('WHU', 2.75),
#  ('BUR', 2.73),
#  ('SHU', 2.5),
#  ('EVE', 2.43),
#  ('BHA', 2.21),
#  ('AVL', 2.16),
#  ('NEW', 1.8),
#  ('NOR', 1.37),
#  ('SOU', 1.28),
#  ('WAT', 1.24)]

# %%
adjusted_FDR = dict(final_avg_FDR)

# %%
adjusted_FDR
# Out:
# {'MCI': 5.18,
#  'LIV': 5.17,
#  'LEI': 3.89,
#  'CHE': 3.85,
#  'MUN': 3.53,
#  'ARS': 3.5,
#  'TOT': 3.3,
#  'CRY': 2.88,
#  'BOU': 2.85,
#  'WOL': 2.81,
#  'WHU': 2.75,
#  'BUR': 2.73,
#  'SHU': 2.5,
#  'EVE': 2.43,
#  'BHA': 2.21,
#  'AVL': 2.16,
#  'NEW': 1.8,
#  'NOR': 1.37,
#  'SOU': 1.28,
#  'WAT': 1.24}

# %%
Team = [item[0] for item in final_avg_FDR]
strength = [item[1] for item in final_avg_FDR]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength adjusted_FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
schedule_df.columns
# Out:
# Index(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brighton', 'Burnley',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Leicester', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Sheffield Utd',
#        'Southampton', 'Spurs', 'Watford', 'West Ham', 'Wolves'],
#       dtype='object')

# %%
schedule_df.head(10)
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
# 5            AVL         ARS         SOU      NEW     NOR     LIV
# 6            MUN         BUR         WHU      CHE     AVL     BHA
# 7            BOU         NOR         ARS      TOT     EVE     SOU
# 8            SHU         BHA         NOR      AVL     LEI     NEW
# 9            CRY         MCI         WAT      EVE     CHE     BUR
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
# 5                   WOL     SHU       TOT       CHE      WAT     WHU
# 6                   NOR     MCI       NEW       SHU      EVE     ARS
# 7                   WHU     BUR       LIV       LEI      WOL     NEW
# 8                   MCI     WHU       BUR       MUN      CRY     LIV
# 9                   ARS     BHA       SOU       TOT      AVL     NOR
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
# 5              BHA     BUR           EVE         BOU   LEI     MCI      MUN
# 6              LEI     CRY           LIV         TOT   SOU     WOL      BOU
# 7              MUN     AVL           WAT         CHE   BHA     SHU      CRY
# 8              CHE     BOU           ARS         WOL   WAT     TOT      EVE
# 9              WOL     MUN           WHU         LEI   LIV     BOU      SHU
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE
# 5           CRY
# 6           WAT
# 7           MCI
# 8           SOU
# 9           NEW

# %%
def avg_FDR(scores = adjusted_FDR, week = gameweek, periods = next_n_games):
    dic = {}
    for team in schedule_df.columns:
        oponents = schedule_df[team][(week-1):(week+periods)]
        avg_FDR = round(sum([scores[oponent] for oponent in oponents])/len(oponents), 2)
        dic[team] = avg_FDR
    return dic

# %%
calculate_FDR = avg_FDR()

# %%
sorted_FDR = sorted(calculate_FDR.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_FDR
# Out:
# [('Crystal Palace', 4.3),
#  ('Southampton', 3.7),
#  ('Man City', 3.43),
#  ('Liverpool', 3.41),
#  ('Aston Villa', 3.26),
#  ('Sheffield Utd', 3.19),
#  ('Chelsea', 3.1),
#  ('Brighton', 2.93),
#  ('Leicester', 2.86),
#  ('Wolves', 2.84),
#  ('Bournemouth', 2.71),
#  ('Arsenal', 2.66),
#  ('Watford', 2.65),
#  ('West Ham', 2.61),
#  ('Newcastle', 2.59),
#  ('Spurs', 2.56),
#  ('Man Utd', 2.52),
#  ('Burnley', 2.16),
#  ('Everton', 1.98),
#  ('Norwich', 1.96)]

# %%
rcParams['figure.figsize'] = 14, 6

Team = [item[0] for item in sorted_FDR]
FDR = [item[1] for item in sorted_FDR]

FDR_75 = round(np.percentile([item[1] for item in sorted_FDR], 75), 2)
cutoff = FDR_75

plt.bar(Team, FDR)
plt.axhline(y=cutoff, linestyle='-', color='#33D977', label='Cutoff Difficulty(FDR 75th%) = ' + str(cutoff))
plt.ylabel('AVG Opponent Difficulty', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Adjusted_FDR Opponenet Difficulty Next ' + str(next_n_games +1) + ' Games', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('FDR', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Clean final list of available players by FDR score <= 3.56 and status = 'available'

# %%
player_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.7      868  John Lundstram    Defender           4.87
# 405      2   4.6      900  Dean Henderson  Goalkeeper           4.20
# 96       8   4.7      900     Mathew Ryan  Goalkeeper           4.20
# 388      4   4.5      900  Jack O'Connell    Defender           3.90
# 84       4   4.5      900  Aaron Ramsdale  Goalkeeper           3.90
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 392          0  10.00  available         49  Sheffield Utd            47
# 405          0   9.13  available         49  Sheffield Utd            42
# 96           0   8.94  available         36       Brighton            42
# 388          0   8.67  available         49  Sheffield Utd            39
# 84           0   8.67  available         91    Bournemouth            39
#
#      transfers_in  transfers_out
# 392       2053545         251051
# 405        304218          74689
# 96         584946         371529
# 388         74944          18389
# 84         113074          29887

# %%
player_df.shape
# Out:
# (556, 14)

# %%
clean_df = player_df[player_df.status == 'available']

# %%
clean_df.status.value_counts()
# Out:
# available    421
# Name: status, dtype: int64

# %% [markdown]
# ## Remove teams with FDR scores > 3.56 from DF - optional

# %%
teams_low_FDR = [key for (key,value) in calculate_FDR.items() if value <= cutoff]

# %%
teams_low_FDR
# Out:
# ['Arsenal',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Everton',
#  'Leicester',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.7      868  John Lundstram    Defender           4.87
# 405      2   4.6      900  Dean Henderson  Goalkeeper           4.20
# 96       8   4.7      900     Mathew Ryan  Goalkeeper           4.20
# 388      4   4.5      900  Jack O'Connell    Defender           3.90
# 84       4   4.5      900  Aaron Ramsdale  Goalkeeper           3.90
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 392          0  10.00  available         49  Sheffield Utd            47
# 405          0   9.13  available         49  Sheffield Utd            42
# 96           0   8.94  available         36       Brighton            42
# 388          0   8.67  available         49  Sheffield Utd            39
# 84           0   8.67  available         91    Bournemouth            39
#
#      transfers_in  transfers_out
# 392       2053545         251051
# 405        304218          74689
# 96         584946         371529
# 388         74944          18389
# 84         113074          29887

# %%
final_df = clean_df.loc[clean_df.team_name.isin(teams_low_FDR)]

# %%
final_df.head(15)
# Out:
#      bonus  cost  minutes                           name    position  \
# 392      7   4.7      868                 John Lundstram    Defender
# 405      2   4.6      900                 Dean Henderson  Goalkeeper
# 96       8   4.7      900                    Mathew Ryan  Goalkeeper
# 388      4   4.5      900                 Jack O'Connell    Defender
# 84       4   4.5      900                 Aaron Ramsdale  Goalkeeper
# 386      4   5.0      900                   Enda Stevens    Defender
# 542      4   5.2      900  Rui Pedro dos Santos Patrício  Goalkeeper
# 363      9   6.9      885                    Teemu Pukki     Forward
# 389      3   4.5      900                 George Baldock    Defender
# 390      3   4.5      900                      John Egan    Defender
# 334      3   4.4      891               Jamaal Lascelles    Defender
# 225     13   9.3      900                    Jamie Vardy     Forward
# 322      6   5.1      885                Scott McTominay  Midfielder
# 163      6   6.9      862                    Mason Mount  Midfielder
# 160     11   7.8      728                  Tammy Abraham     Forward
#
#      pts_per_90min  red_cards    roi     status  team_code      team_name  \
# 392           4.87          0  10.00  available         49  Sheffield Utd
# 405           4.20          0   9.13  available         49  Sheffield Utd
# 96            4.20          0   8.94  available         36       Brighton
# 388           3.90          0   8.67  available         49  Sheffield Utd
# 84            3.90          0   8.67  available         91    Bournemouth
# 386           4.30          0   8.60  available         49  Sheffield Utd
# 542           4.30          0   8.27  available         39         Wolves
# 363           5.79          0   8.26  available         45        Norwich
# 389           3.70          0   8.22  available         49  Sheffield Utd
# 390           3.70          0   8.22  available         49  Sheffield Utd
# 334           3.63          0   8.18  available          4      Newcastle
# 225           7.39          0   7.96  available         13      Leicester
# 322           4.06          0   7.84  available          1        Man Utd
# 163           5.63          0   7.83  available          8        Chelsea
# 160           7.53          0   7.82  available          8        Chelsea
#
#      total_points  transfers_in  transfers_out
# 392            47       2053545         251051
# 405            42        304218          74689
# 96             42        584946         371529
# 388            39         74944          18389
# 84             39        113074          29887
# 386            43         96932          27134
# 542            43        696928         265969
# 363            57       3220348        1795526
# 389            37         71088          26040
# 390            37         14350           7281
# 334            36         95126         221300
# 225            74       1323861         542735
# 322            40        216456          96727
# 163            54       3064894         705686
# 160            61       3319846         469286

# %%
clean_players = final_df.to_dict('records')

# %%
clean_players[:2]
# Out:
# [{'bonus': 7,
#   'cost': 4.7,
#   'minutes': 868,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 4.87,
#   'red_cards': 0,
#   'roi': 10.0,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 47,
#   'transfers_in': 2053545,
#   'transfers_out': 251051},
#  {'bonus': 2,
#   'cost': 4.6,
#   'minutes': 900,
#   'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.2,
#   'red_cards': 0,
#   'roi': 9.13,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 42,
#   'transfers_in': 304218,
#   'transfers_out': 74689}]

# %% [markdown]
# ## Get list of players by ROI, Total Points and Points Per 90 min

# %%
players_roi = sorted(clean_players, key = lambda x: x['roi'], reverse = True)

# %%
players_roi[:3]
# Out:
# [{'bonus': 7,
#   'cost': 4.7,
#   'minutes': 868,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 4.87,
#   'red_cards': 0,
#   'roi': 10.0,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 47,
#   'transfers_in': 2053545,
#   'transfers_out': 251051},
#  {'bonus': 2,
#   'cost': 4.6,
#   'minutes': 900,
#   'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.2,
#   'red_cards': 0,
#   'roi': 9.13,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 42,
#   'transfers_in': 304218,
#   'transfers_out': 74689},
#  {'bonus': 8,
#   'cost': 4.7,
#   'minutes': 900,
#   'name': 'Mathew Ryan',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.2,
#   'red_cards': 0,
#   'roi': 8.94,
#   'status': 'available',
#   'team_code': 36,
#   'team_name': 'Brighton',
#   'total_points': 42,
#   'transfers_in': 584946,
#   'transfers_out': 371529}]

# %% [markdown]
# ### Total Points

# %%
players_max_pts = sorted(players_roi, key = lambda x: x['total_points'], reverse = True)

# %%
players_max_pts[:3]
# Out:
# [{'bonus': 13,
#   'cost': 9.3,
#   'minutes': 900,
#   'name': 'Jamie Vardy',
#   'position': 'Forward',
#   'pts_per_90min': 7.39,
#   'red_cards': 0,
#   'roi': 7.96,
#   'status': 'available',
#   'team_code': 13,
#   'team_name': 'Leicester',
#   'total_points': 74,
#   'transfers_in': 1323861,
#   'transfers_out': 542735},
#  {'bonus': 11,
#   'cost': 7.8,
#   'minutes': 728,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 7.53,
#   'red_cards': 0,
#   'roi': 7.82,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 61,
#   'transfers_in': 3319846,
#   'transfers_out': 469286},
#  {'bonus': 10,
#   'cost': 11.1,
#   'minutes': 900,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 5.89,
#   'red_cards': 0,
#   'roi': 5.32,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 59,
#   'transfers_in': 1130632,
#   'transfers_out': 1047485}]

# %% [markdown]
# ### Per 90 mins played

# %%
players_90min = sorted(players_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
players_90min = [player for player in players_90min if player['minutes'] >= min_min]

# %%
players_90min[:3]
# Out:
# [{'bonus': 3,
#   'cost': 7.1,
#   'minutes': 401,
#   'name': 'Christian Pulisic',
#   'position': 'Midfielder',
#   'pts_per_90min': 8.51,
#   'red_cards': 0,
#   'roi': 5.35,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 38,
#   'transfers_in': 306435,
#   'transfers_out': 618730},
#  {'bonus': 3,
#   'cost': 4.6,
#   'minutes': 278,
#   'name': 'Aaron Connolly',
#   'position': 'Forward',
#   'pts_per_90min': 8.39,
#   'red_cards': 0,
#   'roi': 5.65,
#   'status': 'available',
#   'team_code': 36,
#   'team_name': 'Brighton',
#   'total_points': 26,
#   'transfers_in': 229252,
#   'transfers_out': 39049},
#  {'bonus': 11,
#   'cost': 7.8,
#   'minutes': 728,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 7.53,
#   'red_cards': 0,
#   'roi': 7.82,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 61,
#   'transfers_in': 3319846,
#   'transfers_out': 469286}]

# %% [markdown]
# ### Create player lists by position and metric we want to select by

# %%
GK_roi = [item for item in players_roi if item['position'] == 'Goalkeeper']
DF_roi = [item for item in players_roi if item['position'] == 'Defender']
MD_roi = [item for item in players_roi if item['position'] == 'Midfielder']
ST_roi = [item for item in players_roi if item['position'] == 'Forward']

# %%
GK_pts = [item for item in players_max_pts if item['position'] == 'Goalkeeper']
DF_pts = [item for item in players_max_pts if item['position'] == 'Defender']
MD_pts = [item for item in players_max_pts if item['position'] == 'Midfielder']
ST_pts = [item for item in players_max_pts if item['position'] == 'Forward']

# %%
GK_90min = [item for item in players_90min if item['position'] == 'Goalkeeper']
DF_90min = [item for item in players_90min if item['position'] == 'Defender']
MD_90min = [item for item in players_90min if item['position'] == 'Midfielder']
ST_90min = [item for item in players_90min if item['position'] == 'Forward']

# %% [markdown]
# ## Start by selecting top GKs by ROI

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_roi:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Dean Henderson
# GK budget left: 4.9
# Player Selected: Mathew Ryan
# GK budget left: 0.20000000000000018
# ['Dean Henderson', 'Mathew Ryan']
# ['Sheffield Utd', 'Brighton']

# %% [markdown]
# ## Select Top player by points from DF, MD, ST

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 28.699999999999996 36.0 26.0
# Player Selected: Ricardo Domingos Barbosa Pereira
# DF budget left: 22.399999999999995
# Player Selected: Mason Mount
# MD budget left: 29.1
# ['Dean Henderson', 'Mathew Ryan', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount']
# ['Sheffield Utd', 'Brighton', 'Leicester', 'Chelsea']

# %%
ST_pts[:3]
# Out:
# [{'bonus': 13,
#   'cost': 9.3,
#   'minutes': 900,
#   'name': 'Jamie Vardy',
#   'position': 'Forward',
#   'pts_per_90min': 7.39,
#   'red_cards': 0,
#   'roi': 7.96,
#   'status': 'available',
#   'team_code': 13,
#   'team_name': 'Leicester',
#   'total_points': 74,
#   'transfers_in': 1323861,
#   'transfers_out': 542735},
#  {'bonus': 11,
#   'cost': 7.8,
#   'minutes': 728,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 7.53,
#   'red_cards': 0,
#   'roi': 7.82,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 61,
#   'transfers_in': 3319846,
#   'transfers_out': 469286},
#  {'bonus': 10,
#   'cost': 11.1,
#   'minutes': 900,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 5.89,
#   'red_cards': 0,
#   'roi': 5.32,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 59,
#   'transfers_in': 1130632,
#   'transfers_out': 1047485}]

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Jamie Vardy
# ST budget left: 16.7
# 5
# ['Dean Henderson', 'Mathew Ryan', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Jamie Vardy']
# ['Sheffield Utd', 'Brighton', 'Leicester', 'Chelsea', 'Leicester']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with top ROI players

# %%
for item in DF_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
        print('# of DFs selected: ' + str(DF_curr))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: John Lundstram
# DF budget left: 17.699999999999996
# # of DFs selected: 2
# Player Selected: Jack O'Connell
# DF budget left: 13.199999999999996
# # of DFs selected: 3
# Player Selected: Jamaal Lascelles
# DF budget left: 8.799999999999995
# # of DFs selected: 4
# Player Selected: Benjamin Chilwell
# DF budget left: 3.2999999999999954
# # of DFs selected: 5
# 9
# ['Dean Henderson', 'Mathew Ryan', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Jamie Vardy', 'John Lundstram', "Jack O'Connell", 'Jamaal Lascelles', 'Benjamin Chilwell']
# ['Sheffield Utd', 'Brighton', 'Leicester', 'Chelsea', 'Leicester', 'Sheffield Utd', 'Sheffield Utd', 'Newcastle', 'Leicester']

# %% [markdown]
# ## Fill MD position

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Scott McTominay
# MD budget left: 27.299999999999997
# Player Selected: Todd Cantwell
# MD budget left: 22.499999999999996
# Player Selected: Andriy Yarmolenko
# MD budget left: 16.499999999999996
# Player Selected: Adama Traoré
# MD budget left: 11.399999999999997
# 13
# ['Dean Henderson', 'Mathew Ryan', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Jamie Vardy', 'John Lundstram', "Jack O'Connell", 'Jamaal Lascelles', 'Benjamin Chilwell', 'Scott McTominay', 'Todd Cantwell', 'Andriy Yarmolenko', 'Adama Traoré']
# ['Sheffield Utd', 'Brighton', 'Leicester', 'Chelsea', 'Leicester', 'Sheffield Utd', 'Sheffield Utd', 'Newcastle', 'Leicester', 'Man Utd', 'Norwich', 'West Ham', 'Wolves']

# %% [markdown]
# ## Fill ST position

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Teemu Pukki
# ST budget left: 21.199999999999996
# Player Selected: Tammy Abraham
# ST budget left: 13.399999999999995
# 15
# ['Dean Henderson', 'Mathew Ryan', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Jamie Vardy', 'John Lundstram', "Jack O'Connell", 'Jamaal Lascelles', 'Benjamin Chilwell', 'Scott McTominay', 'Todd Cantwell', 'Andriy Yarmolenko', 'Adama Traoré', 'Teemu Pukki', 'Tammy Abraham']
# ['Sheffield Utd', 'Brighton', 'Leicester', 'Chelsea', 'Leicester', 'Sheffield Utd', 'Sheffield Utd', 'Newcastle', 'Leicester', 'Man Utd', 'Norwich', 'West Ham', 'Wolves', 'Norwich', 'Chelsea']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                              name    position  \
# 0       2   4.6      900                    Dean Henderson  Goalkeeper
# 1       8   4.7      900                       Mathew Ryan  Goalkeeper
# 2       5   6.3      900  Ricardo Domingos Barbosa Pereira    Defender
# 3       6   6.9      862                       Mason Mount  Midfielder
# 4      13   9.3      900                       Jamie Vardy     Forward
# 5       7   4.7      868                    John Lundstram    Defender
# 6       4   4.5      900                    Jack O'Connell    Defender
# 7       3   4.4      891                  Jamaal Lascelles    Defender
# 8       1   5.5      720                 Benjamin Chilwell    Defender
# 9       6   5.1      885                   Scott McTominay  Midfielder
# 10      2   4.8      810                     Todd Cantwell  Midfielder
# 11      8   6.0      588                 Andriy Yarmolenko  Midfielder
# 12      6   5.1      650                      Adama Traoré  Midfielder
# 13      9   6.9      885                       Teemu Pukki     Forward
# 14     11   7.8      728                     Tammy Abraham     Forward
#
#     pts_per_90min  red_cards    roi     status  team_code      team_name  \
# 0            4.20          0   9.13  available         49  Sheffield Utd
# 1            4.20          0   8.94  available         36       Brighton
# 2            4.79          0   7.62  available         13      Leicester
# 3            5.63          0   7.83  available          8        Chelsea
# 4            7.39          0   7.96  available         13      Leicester
# 5            4.87          0  10.00  available         49  Sheffield Utd
# 6            3.90          0   8.67  available         49  Sheffield Utd
# 7            3.63          0   8.18  available          4      Newcastle
# 8            5.24          0   7.64  available         13      Leicester
# 9            4.06          0   7.84  available          1        Man Utd
# 10           4.11          0   7.71  available         45        Norwich
# 11           6.57          0   7.17  available         21       West Ham
# 12           4.98          0   7.06  available         39         Wolves
# 13           5.79          0   8.26  available         45        Norwich
# 14           7.53          0   7.82  available          8        Chelsea
#
#     total_points  transfers_in  transfers_out
# 0             42        304218          74689
# 1             42        584946         371529
# 2             48        750088         231278
# 3             54       3064894         705686
# 4             74       1323861         542735
# 5             47       2053545         251051
# 6             39         74944          18389
# 7             36         95126         221300
# 8             42        400526         202471
# 9             40        216456          96727
# 10            37       2146131         845270
# 11            43        531401         154830
# 12            36        288968          67046
# 13            57       3220348        1795526
# 14            61       3319846         469286

# %%
money_x = money_df.roi
money_y = money_df.name
ST_75th = round(money_df.describe().roi['75%'], 2)
ST_AVG = round(money_df.describe().roi['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Top 10 ROI players by position

# %%
GK_df = pd.DataFrame(GK_roi)
GK_df.head(10)
# Out:
#    bonus  cost  minutes                           name    position  \
# 0      2   4.6      900                 Dean Henderson  Goalkeeper
# 1      8   4.7      900                    Mathew Ryan  Goalkeeper
# 2      4   4.5      900                 Aaron Ramsdale  Goalkeeper
# 3      4   5.2      900  Rui Pedro dos Santos Patrício  Goalkeeper
# 4      0   5.1      900              Kasper Schmeichel  Goalkeeper
# 5      2   4.7      900                      Nick Pope  Goalkeeper
# 6      1   5.0      900                Martin Dubravka  Goalkeeper
# 7      8   4.8      900                     Ben Foster  Goalkeeper
# 8      5   5.5      900                   David de Gea  Goalkeeper
# 9      2   5.5      900                Jordan Pickford  Goalkeeper
#
#    pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 0            4.2          0  9.13  available         49  Sheffield Utd
# 1            4.2          0  8.94  available         36       Brighton
# 2            3.9          0  8.67  available         91    Bournemouth
# 3            4.3          0  8.27  available         39         Wolves
# 4            3.8          0  7.45  available         13      Leicester
# 5            3.4          0  7.23  available         90        Burnley
# 6            3.6          0  7.20  available          4      Newcastle
# 7            3.4          0  7.08  available         57        Watford
# 8            3.7          0  6.73  available          1        Man Utd
# 9            3.3          0  6.00  available         11        Everton
#
#    total_points  transfers_in  transfers_out
# 0            42        304218          74689
# 1            42        584946         371529
# 2            39        113074          29887
# 3            43        696928         265969
# 4            38        350061         180743
# 5            34        806494         256113
# 6            36         32010          37206
# 7            34         23289          98910
# 8            37        718853         742256
# 9            33        351110         415155

# %%
DF_df = pd.DataFrame(DF_roi)
DF_df.head(10)
# Out:
#    bonus  cost  minutes                              name  position  \
# 0      7   4.7      868                    John Lundstram  Defender
# 1      4   4.5      900                    Jack O'Connell  Defender
# 2      4   5.0      900                      Enda Stevens  Defender
# 3      3   4.5      900                    George Baldock  Defender
# 4      3   4.5      900                         John Egan  Defender
# 5      3   4.4      891                  Jamaal Lascelles  Defender
# 6      1   4.5      864                      Chris Basham  Defender
# 7      1   5.5      720                 Benjamin Chilwell  Defender
# 8      5   6.3      900  Ricardo Domingos Barbosa Pereira  Defender
# 9      7   4.6      900                        Lewis Dunk  Defender
#
#    pts_per_90min  red_cards    roi     status  team_code      team_name  \
# 0           4.87          0  10.00  available         49  Sheffield Utd
# 1           3.90          0   8.67  available         49  Sheffield Utd
# 2           4.30          0   8.60  available         49  Sheffield Utd
# 3           3.70          0   8.22  available         49  Sheffield Utd
# 4           3.70          0   8.22  available         49  Sheffield Utd
# 5           3.63          0   8.18  available          4      Newcastle
# 6           3.64          0   7.78  available         49  Sheffield Utd
# 7           5.24          0   7.64  available         13      Leicester
# 8           4.79          0   7.62  available         13      Leicester
# 9           3.50          0   7.61  available         36       Brighton
#
#    total_points  transfers_in  transfers_out
# 0            47       2053545         251051
# 1            39         74944          18389
# 2            43         96932          27134
# 3            37         71088          26040
# 4            37         14350           7281
# 5            36         95126         221300
# 6            35         10082           6741
# 7            42        400526         202471
# 8            48        750088         231278
# 9            35        636842         354641

# %%
MD_df = pd.DataFrame(MD_roi)
MD_df.head(10)
# Out:
#    bonus  cost  minutes                     name    position  pts_per_90min  \
# 0      6   5.1      885          Scott McTominay  Midfielder           4.06
# 1      6   6.9      862              Mason Mount  Midfielder           5.63
# 2      2   4.8      810            Todd Cantwell  Midfielder           4.11
# 3      4   6.5      891          Youri Tielemans  Midfielder           4.84
# 4      8   6.0      588        Andriy Yarmolenko  Midfielder           6.57
# 5      6   5.1      650             Adama Traoré  Midfielder           4.98
# 6      1   6.0      876            Dwight McNeil  Midfielder           4.31
# 7      2   6.1      569              Ayoze Pérez  Midfielder           6.63
# 8      2   6.1      813             Daniel James  Midfielder           4.53
# 9      5   5.1      862  Jorge Luiz Frello Filho  Midfielder           3.55
#
#    red_cards   roi     status  team_code  team_name  total_points  \
# 0          0  7.84  available          1    Man Utd            40
# 1          0  7.83  available          8    Chelsea            54
# 2          0  7.71  available         45    Norwich            37
# 3          0  7.38  available         13  Leicester            48
# 4          0  7.17  available         21   West Ham            43
# 5          0  7.06  available         39     Wolves            36
# 6          0  7.00  available         90    Burnley            42
# 7          0  6.89  available         13  Leicester            42
# 8          0  6.72  available          1    Man Utd            41
# 9          0  6.67  available          8    Chelsea            34
#
#    transfers_in  transfers_out
# 0        216456          96727
# 1       3064894         705686
# 2       2146131         845270
# 3        350781         297666
# 4        531401         154830
# 5        288968          67046
# 6         42745          38499
# 7        201284         871035
# 8       1226618         676538
# 9        356234         268914

# %%
ST_df = pd.DataFrame(ST_roi)
ST_df.head(10)
# Out:
#    bonus  cost  minutes              name position  pts_per_90min  red_cards  \
# 0      9   6.9      885       Teemu Pukki  Forward           5.79          0
# 1     13   9.3      900       Jamie Vardy  Forward           7.39          0
# 2     11   7.8      728     Tammy Abraham  Forward           7.53          0
# 3      7   6.0      690       Neal Maupay  Forward           5.21          0
# 4      5   6.3      826       Joshua King  Forward           4.46          0
# 5      4   8.0      860     Callum Wilson  Forward           5.33          0
# 6      7   7.2      853      Raúl Jiménez  Forward           4.53          0
# 7      4   6.3      706     Ashley Barnes  Forward           4.58          0
# 8      3   4.6      278    Aaron Connolly  Forward           8.39          0
# 9      5   7.4      810  Sébastien Haller  Forward           4.55          0
#
#     roi     status  team_code    team_name  total_points  transfers_in  \
# 0  8.26  available         45      Norwich            57       3220348
# 1  7.96  available         13    Leicester            74       1323861
# 2  7.82  available          8      Chelsea            61       3319846
# 3  6.67  available         36     Brighton            40        117214
# 4  6.51  available         91  Bournemouth            41        503949
# 5  6.38  available         91  Bournemouth            51        664285
# 6  5.97  available         39       Wolves            43        453709
# 7  5.71  available         90      Burnley            36        997826
# 8  5.65  available         36     Brighton            26        229252
# 9  5.54  available         21     West Ham            41        510374
#
#    transfers_out
# 0        1795526
# 1         542735
# 2         469286
# 3          69451
# 4        1119183
# 5         961999
# 6        1139832
# 7         923237
# 8          39049
# 9         468710

# %% [markdown]
# ## Define Clean df for graphing purposes

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.7      868  John Lundstram    Defender           4.87
# 405      2   4.6      900  Dean Henderson  Goalkeeper           4.20
# 96       8   4.7      900     Mathew Ryan  Goalkeeper           4.20
# 388      4   4.5      900  Jack O'Connell    Defender           3.90
# 84       4   4.5      900  Aaron Ramsdale  Goalkeeper           3.90
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 392          0  10.00  available         49  Sheffield Utd            47
# 405          0   9.13  available         49  Sheffield Utd            42
# 96           0   8.94  available         36       Brighton            42
# 388          0   8.67  available         49  Sheffield Utd            39
# 84           0   8.67  available         91    Bournemouth            39
#
#      transfers_in  transfers_out
# 392       2053545         251051
# 405        304218          74689
# 96         584946         371529
# 388         74944          18389
# 84         113074          29887

# %%
graph_roi = []
for row, player in clean_df.iterrows():
    playa = dict(name = player['name'], position = player.position, team=player.team_name, cost = player.cost, points = player.total_points, minutes = player.minutes, ROI = player.roi, pts_per_90min = player.pts_per_90min)
    graph_roi.append(playa)

# %%
graph_roi[:3]
# Out:
# [{'name': 'John Lundstram',
#   'position': 'Defender',
#   'team': 'Sheffield Utd',
#   'cost': 4.7,
#   'points': 47,
#   'minutes': 868,
#   'ROI': 10.0,
#   'pts_per_90min': 4.87},
#  {'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'team': 'Sheffield Utd',
#   'cost': 4.6,
#   'points': 42,
#   'minutes': 900,
#   'ROI': 9.13,
#   'pts_per_90min': 4.2},
#  {'name': 'Mathew Ryan',
#   'position': 'Goalkeeper',
#   'team': 'Brighton',
#   'cost': 4.7,
#   'points': 42,
#   'minutes': 900,
#   'ROI': 8.94,
#   'pts_per_90min': 4.2}]

# %% [markdown]
# ### Graph by ROI

# %%
GK_graph = clean_df[clean_df['position'] == 'Goalkeeper']
DF_graph = clean_df[clean_df['position'] == 'Defender']
MD_graph = clean_df[clean_df['position'] == 'Midfielder']
ST_graph = clean_df[clean_df['position'] == 'Forward']

# %% [markdown]
# ### Graph by 90_min Stat

# %%
sorted_players_90min = sorted(graph_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
sorted_players_90min = [player for player in sorted_players_90min if player['minutes'] >= min_min]

# %%
sorted_players_90min[:3]
# Out:
# [{'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'team': 'Man City',
#   'cost': 12.1,
#   'points': 62,
#   'minutes': 574,
#   'ROI': 5.12,
#   'pts_per_90min': 9.7},
#  {'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'team': 'Man City',
#   'cost': 10.2,
#   'points': 72,
#   'minutes': 693,
#   'ROI': 7.06,
#   'pts_per_90min': 9.34},
#  {'name': 'Riyad Mahrez',
#   'position': 'Midfielder',
#   'team': 'Man City',
#   'cost': 8.5,
#   'points': 46,
#   'minutes': 457,
#   'ROI': 5.41,
#   'pts_per_90min': 9.04}]

# %%
df_90min = pd.DataFrame(sorted_players_90min)

# %%
df_90min.head()
# Out:
#     ROI  cost  minutes               name  points    position  pts_per_90min  \
# 0  5.12  12.1      574      Sergio Agüero      62     Forward           9.70
# 1  7.06  10.2      693    Kevin De Bruyne      72  Midfielder           9.34
# 2  5.41   8.5      457       Riyad Mahrez      46  Midfielder           9.04
# 3  4.34   5.3      238       James Milner      23  Midfielder           8.66
# 4  5.35   7.1      401  Christian Pulisic      38  Midfielder           8.51
#
#         team
# 0   Man City
# 1   Man City
# 2   Man City
# 3  Liverpool
# 4    Chelsea

# %%
GK_90min_graph = df_90min[df_90min['position'] == 'Goalkeeper']
DF_90min_graph = df_90min[df_90min['position'] == 'Defender']
MD_90min_graph = df_90min[df_90min['position'] == 'Midfielder']
ST_90min_graph = df_90min[df_90min['position'] == 'Forward']

# %%
GK_90min_graph.head()
# Out:
#      ROI  cost  minutes                           name  points    position  \
# 69  7.21   6.1      900      Ederson Santana de Moraes      44  Goalkeeper
# 75  8.27   5.2      900  Rui Pedro dos Santos Patrício      43  Goalkeeper
# 80  9.13   4.6      900                 Dean Henderson      42  Goalkeeper
# 81  8.94   4.7      900                    Mathew Ryan      42  Goalkeeper
# 95  8.67   4.5      900                 Aaron Ramsdale      39  Goalkeeper
#
#     pts_per_90min           team
# 69            4.4       Man City
# 75            4.3         Wolves
# 80            4.2  Sheffield Utd
# 81            4.2       Brighton
# 95            3.9    Bournemouth

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %% [markdown]
# ## Top 10 Keepers ROI

# %%
GK_x = GK_graph[:10].roi
GK_y = GK_graph[:10].name
GK_75th = round(GK_graph.describe().roi['75%'], 2)
GK_AVG = round(GK_graph.describe().roi['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK ROI = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK ROI = ' + str(GK_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Keepers 90_min

# %%
GK_x = GK_90min_graph[:10].pts_per_90min
GK_y = GK_90min_graph[:10].name
GK_75th = round(GK_90min_graph.describe().pts_per_90min['75%'], 2)
GK_AVG = round(GK_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK pts_per_90min = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK pts_per_90min = ' + str(GK_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders

# %%
DF_x = DF_graph[:10].roi
DF_y = DF_graph[:10].name
DF_75th = round(DF_graph.describe().roi['75%'], 2)
DF_AVG = round(DF_graph.describe().roi['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders 90min Stat

# %%
DF_x = DF_90min_graph[:10].pts_per_90min
DF_y = DF_90min_graph[:10].name
DF_75th = round(DF_90min_graph.describe().pts_per_90min['75%'], 2)
DF_AVG = round(DF_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF pts_per_90min = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF pts_per_90min = ' + str(DF_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders

# %%
MD_x = MD_graph[:10].roi
MD_y = MD_graph[:10].name
MD_75th = round(MD_graph.describe().roi['75%'], 2)
MD_AVG = round(MD_graph.describe().roi['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD ROI = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD ROI = ' + str(MD_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders 90min Stat

# %%
MD_x = MD_90min_graph[:10].pts_per_90min
MD_y = MD_90min_graph[:10].name
MD_75th = round(MD_90min_graph.describe().pts_per_90min['75%'], 2)
MD_AVG = round(MD_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD pts_per_90min = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD pts_per_90min = ' + str(MD_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers

# %%
ST_x = ST_graph[:10].roi
ST_y = ST_graph[:10].name
ST_75th = round(ST_graph.describe().roi['75%'], 2)
ST_AVG = round(ST_graph.describe().roi['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers 90min Stat

# %%
ST_x = ST_90min_graph[:10].pts_per_90min
ST_y = ST_90min_graph[:10].name
ST_75th = round(ST_90min_graph.describe().pts_per_90min['75%'], 2)
ST_AVG = round(ST_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
team_df
# Out:
#           code  strength Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV       Liverpool     10  9  0  1  23   8  +15  28
# 2           43         5  MCI        Man City     10  7  2  1  32   9  +23  22
# 3           13         3  LEI       Leicester     10  6  2  2  25   8  +17  20
# 4            8         4  CHE         Chelsea     10  6  2  2  23  16   +7  20
# 5            3         4  ARS         Arsenal     10  4  2  4  15  14   +1  16
# 6           31         3  CRY  Crystal Palace     10  4  3  3  10  12   -2  15
# 7            1         4  MUN         Man Utd     10  3  3  4  13  10   +3  13
# 8           49         2  SHU   Sheffield Utd     10  3  3  4   9   8   +1  13
# 9           91         3  BOU     Bournemouth     10  3  3  4  13  13    0  13
# 10          21         3  WHU        West Ham     10  3  3  4  12  14   -2  13
# 11           6         4  TOT           Spurs     10  3  4  3  16  15   +1  12
# 12          39         3  WOL          Wolves     10  2  2  6  13  13    0  12
# 13          90         3  BUR         Burnley     10  3  4  3  14  15   -1  12
# 14          36         2  BHA        Brighton     10  3  4  3  12  14   -2  12
# 15           7         2  AVL     Aston Villa     10  3  5  2  15  16   -1  11
# 16          11         3  EVE         Everton     10  3  6  1  10  16   -6  10
# 17           4         2  NEW       Newcastle     10  2  5  3   6  15   -9   9
# 18          20         2  SOU     Southampton     10  2  6  2   9  25  -16   8
# 19          45         2  NOR         Norwich     10  2  7  1  11  24  -13   7
# 20          57         2  WAT         Watford     10  0  5  5   5  21  -16   5

# %% [markdown]
# ### Team Stats

# %%
teams_stats = team_df.iloc[:,2:12]

# %%
teams_stats.GF = [int(item) for item in teams_stats.GF]
teams_stats.GA = [int(item) for item in teams_stats.GA]

# %%
teams_stats
# Out:
#          Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1         LIV       Liverpool     10  9  0  1  23   8  +15  28
# 2         MCI        Man City     10  7  2  1  32   9  +23  22
# 3         LEI       Leicester     10  6  2  2  25   8  +17  20
# 4         CHE         Chelsea     10  6  2  2  23  16   +7  20
# 5         ARS         Arsenal     10  4  2  4  15  14   +1  16
# 6         CRY  Crystal Palace     10  4  3  3  10  12   -2  15
# 7         MUN         Man Utd     10  3  3  4  13  10   +3  13
# 8         SHU   Sheffield Utd     10  3  3  4   9   8   +1  13
# 9         BOU     Bournemouth     10  3  3  4  13  13    0  13
# 10        WHU        West Ham     10  3  3  4  12  14   -2  13
# 11        TOT           Spurs     10  3  4  3  16  15   +1  12
# 12        WOL          Wolves     10  2  2  6  13  13    0  12
# 13        BUR         Burnley     10  3  4  3  14  15   -1  12
# 14        BHA        Brighton     10  3  4  3  12  14   -2  12
# 15        AVL     Aston Villa     10  3  5  2  15  16   -1  11
# 16        EVE         Everton     10  3  6  1  10  16   -6  10
# 17        NEW       Newcastle     10  2  5  3   6  15   -9   9
# 18        SOU     Southampton     10  2  6  2   9  25  -16   8
# 19        NOR         Norwich     10  2  7  1  11  24  -13   7
# 20        WAT         Watford     10  0  5  5   5  21  -16   5

# %% [markdown]
# ### Worst/ Best  Defence vs. Offence

# %%
worst_defence_df = teams_stats.sort_values(by = ['GA'], ascending = False)

# %%
worst_defence_df.head()
# Out:
#          Team         name Played  W  L  D  GF  GA   GD Pts
# Position
# 18        SOU  Southampton     10  2  6  2   9  25  -16   8
# 19        NOR      Norwich     10  2  7  1  11  24  -13   7
# 20        WAT      Watford     10  0  5  5   5  21  -16   5
# 4         CHE      Chelsea     10  6  2  2  23  16   +7  20
# 16        EVE      Everton     10  3  6  1  10  16   -6  10

# %%
best_defence_df = teams_stats.sort_values(by = ['GA'], ascending = True)

# %%
best_defence_df.head()
# Out:
#          Team           name Played  W  L  D  GF  GA   GD Pts
# Position
# 1         LIV      Liverpool     10  9  0  1  23   8  +15  28
# 3         LEI      Leicester     10  6  2  2  25   8  +17  20
# 8         SHU  Sheffield Utd     10  3  3  4   9   8   +1  13
# 2         MCI       Man City     10  7  2  1  32   9  +23  22
# 7         MUN        Man Utd     10  3  3  4  13  10   +3  13

# %%
GA = list(zip(worst_defence_df.name, worst_defence_df.GA))
GA_bottom5 = GA[:7]
GA_top5 = sorted(GA[-7:], key = lambda x: x[1])

# %%
GA_bottom5, GA_top5
# Out:
# ([('Southampton', 25),
#   ('Norwich', 24),
#   ('Watford', 21),
#   ('Chelsea', 16),
#   ('Everton', 16),
#   ('Aston Villa', 16),
#   ('Burnley', 15)],
#  [('Sheffield Utd', 8),
#   ('Leicester', 8),
#   ('Liverpool', 8),
#   ('Man City', 9),
#   ('Man Utd', 10),
#   ('Crystal Palace', 12),
#   ('Bournemouth', 13)])

# %%
teams_stats.GA.median()
# Out:
# 14.0

# %%
X = [item[0] for item in GA_bottom5]
Y = [int(item[1]) for item in GA_bottom5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GA_top5]
Y = [int(item[1]) for item in GA_top5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
offense_df = teams_stats.sort_values(by = ['GF'], ascending = False)

# %%
offense_df.head()
# Out:
#          Team       name Played  W  L  D  GF  GA   GD Pts
# Position
# 2         MCI   Man City     10  7  2  1  32   9  +23  22
# 3         LEI  Leicester     10  6  2  2  25   8  +17  20
# 1         LIV  Liverpool     10  9  0  1  23   8  +15  28
# 4         CHE    Chelsea     10  6  2  2  23  16   +7  20
# 11        TOT      Spurs     10  3  4  3  16  15   +1  12

# %%
GF = list(zip(offense_df.name, offense_df.GF))
GF_top5 = GF[:7]
GF_bottom5 = GF[-7:]

# %%
GF_top5, GF_bottom5
# Out:
# ([('Man City', 32),
#   ('Leicester', 25),
#   ('Liverpool', 23),
#   ('Chelsea', 23),
#   ('Spurs', 16),
#   ('Arsenal', 15),
#   ('Aston Villa', 15)],
#  [('Norwich', 11),
#   ('Crystal Palace', 10),
#   ('Everton', 10),
#   ('Sheffield Utd', 9),
#   ('Southampton', 9),
#   ('Newcastle', 6),
#   ('Watford', 5)])

# %%
X = [item[0] for item in GF_top5]
Y = [int(item[1]) for item in GF_top5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GF_bottom5]
Y = [int(item[1]) for item in GF_bottom5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stats_df = player_df[player_df.minutes >= min_min]

# %%
stats_df.tail()
# Out:
#      bonus  cost  minutes                         name  position  \
# 143      0   5.5      374  Emerson Palmieri dos Santos  Defender
# 210      0   5.4      468                 Fabian Delph  Defender
# 479      0   4.2      559        Francisco Femenía Far  Defender
# 362      0   4.0      270                 Grant Hanley  Defender
# 412      0   4.8      492                Ryan Bertrand  Defender
#
#      pts_per_90min  red_cards   roi     status  team_code    team_name  \
# 143           1.20          0  0.91  available          8      Chelsea
# 210           0.77          0  0.74  available         11      Everton
# 479           0.48          0  0.71  available         57      Watford
# 362           0.33          0  0.25    injured         45      Norwich
# 412          -0.18          1 -0.21  suspended         20  Southampton
#
#      total_points  transfers_in  transfers_out
# 143             5        154125         198571
# 210             4          8100          21377
# 479             3         13011          42913
# 362             1        212778         194057
# 412            -1          8286          47082

# %% [markdown]
# ### Cobine Team and Player Stats

# %%
team_dic = {item:[] for item in team_names}

for row, player in stats_df.iterrows():
    for name in team_names:
        if player.team_name == name:
            playa = dict(name = player['name'], position = player.position, cost = player.cost, minutes = player.minutes, 
                         points = player.total_points,  roi = player.roi, pts_per_90min = player.pts_per_90min, 
                         bonus = player.bonus, red_cards = player.red_cards)
            team_dic[name].append(playa)

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.7      868  John Lundstram    Defender           4.87
# 405      2   4.6      900  Dean Henderson  Goalkeeper           4.20
# 96       8   4.7      900     Mathew Ryan  Goalkeeper           4.20
# 388      4   4.5      900  Jack O'Connell    Defender           3.90
# 84       4   4.5      900  Aaron Ramsdale  Goalkeeper           3.90
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 392          0  10.00  available         49  Sheffield Utd            47
# 405          0   9.13  available         49  Sheffield Utd            42
# 96           0   8.94  available         36       Brighton            42
# 388          0   8.67  available         49  Sheffield Utd            39
# 84           0   8.67  available         91    Bournemouth            39
#
#      transfers_in  transfers_out
# 392       2053545         251051
# 405        304218          74689
# 96         584946         371529
# 388         74944          18389
# 84         113074          29887

# %%
team_dic['Liverpool']
# Out:
# [{'name': 'Andrew Robertson',
#   'position': 'Defender',
#   'cost': 6.9,
#   'minutes': 900,
#   'points': 43,
#   'roi': 6.23,
#   'pts_per_90min': 4.3,
#   'bonus': 6,
#   'red_cards': 0},
#  {'name': 'Trent Alexander-Arnold',
#   'position': 'Defender',
#   'cost': 7.2,
#   'minutes': 900,
#   'points': 43,
#   'roi': 5.97,
#   'pts_per_90min': 4.3,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Joel Matip',
#   'position': 'Defender',
#   'cost': 5.5,
#   'minutes': 630,
#   'points': 32,
#   'roi': 5.82,
#   'pts_per_90min': 4.56,
#   'bonus': 4,
#   'red_cards': 0},
#  {'name': 'Georginio Wijnaldum',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 835,
#   'points': 31,
#   'roi': 5.74,
#   'pts_per_90min': 3.34,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Virgil van Dijk',
#   'position': 'Defender',
#   'cost': 6.5,
#   'minutes': 900,
#   'points': 37,
#   'roi': 5.69,
#   'pts_per_90min': 3.7,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'cost': 9.5,
#   'minutes': 830,
#   'points': 52,
#   'roi': 5.47,
#   'pts_per_90min': 5.63,
#   'bonus': 9,
#   'red_cards': 0},
#  {'name': 'Sadio Mané',
#   'position': 'Midfielder',
#   'cost': 11.9,
#   'minutes': 786,
#   'points': 64,
#   'roi': 5.38,
#   'pts_per_90min': 7.32,
#   'bonus': 8,
#   'red_cards': 0},
#  {'name': 'Adrián San Miguel del Castillo',
#   'position': 'Goalkeeper',
#   'cost': 4.4,
#   'minutes': 681,
#   'points': 23,
#   'roi': 5.23,
#   'pts_per_90min': 3.04,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'cost': 12.4,
#   'minutes': 792,
#   'points': 62,
#   'roi': 5.0,
#   'pts_per_90min': 7.04,
#   'bonus': 7,
#   'red_cards': 0},
#  {'name': 'Jordan Henderson',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 569,
#   'points': 25,
#   'roi': 4.63,
#   'pts_per_90min': 3.95,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'James Milner',
#   'position': 'Midfielder',
#   'cost': 5.3,
#   'minutes': 238,
#   'points': 23,
#   'roi': 4.34,
#   'pts_per_90min': 8.66,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Fabio Henrique Tavares',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 826,
#   'points': 22,
#   'roi': 4.0,
#   'pts_per_90min': 2.39,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Alex Oxlade-Chamberlain',
#   'position': 'Midfielder',
#   'cost': 6.2,
#   'minutes': 225,
#   'points': 8,
#   'roi': 1.29,
#   'pts_per_90min': 3.19,
#   'bonus': 0,
#   'red_cards': 0}]

# %% [markdown]
# ### Get Final Stats per Team using Pandas

# %%
team_stats = {item:{} for item in team_names}

for team in team_names:
    active_players = len(stats_df[stats_df.team_name == team].cost)
    tot_cost = round(stats_df[stats_df.team_name == team].cost.sum(), 3)
    tot_pts = round(stats_df[stats_df.team_name == team].total_points.sum(), 3)
    avg_player_roi = round(tot_pts / tot_cost, 3)
    avg_pts_per_player = round(tot_pts / active_players, 3)
    
    stats = dict(active_players = active_players, tot_cost = tot_cost, tot_pts = tot_pts,
               avg_pts_per_player = avg_pts_per_player,  avg_player_roi =  avg_player_roi)
    
    team_stats[team].update(stats)

# %%
team_stats['Newcastle']
# Out:
# {'active_players': 17,
#  'tot_cost': 83.2,
#  'tot_pts': 326,
#  'avg_pts_per_player': 19.176,
#  'avg_player_roi': 3.918}

# %%
team_stats_df = pd.DataFrame(team_stats).T

# %%
team_stats_df.sort_values(by = ['avg_pts_per_player'], ascending = False, inplace = True)

# %%
team_stats_df
# Out:
#                 active_players  avg_player_roi  avg_pts_per_player  tot_cost  \
# Leicester                 13.0           6.567              38.692      76.6
# Liverpool                 13.0           5.049              35.769      92.1
# Man City                  17.0           4.713              34.235     123.5
# Sheffield Utd             13.0           5.981              29.308      63.7
# Wolves                    14.0           5.107              27.357      75.0
# Crystal Palace            13.0           5.072              27.077      69.4
# Burnley                   14.0           5.020              26.786      74.7
# Chelsea                   16.0           4.411              26.000      94.3
# Bournemouth               14.0           4.892              25.929      74.2
# Aston Villa               16.0           5.069              25.375      80.1
# West Ham                  15.0           4.743              25.267      79.9
# Man Utd                   14.0           4.100              25.071      85.6
# Arsenal                   15.0           4.000              24.000      90.0
# Brighton                  16.0           4.573              22.750      79.6
# Everton                   15.0           3.787              22.467      89.0
# Spurs                     16.0           3.519              21.750      98.9
# Norwich                   14.0           4.145              20.071      67.8
# Newcastle                 17.0           3.918              19.176      83.2
# Watford                   14.0           3.797              18.929      69.8
# Southampton               15.0           3.725              18.800      75.7
#
#                 tot_pts
# Leicester         503.0
# Liverpool         465.0
# Man City          582.0
# Sheffield Utd     381.0
# Wolves            383.0
# Crystal Palace    352.0
# Burnley           375.0
# Chelsea           416.0
# Bournemouth       363.0
# Aston Villa       406.0
# West Ham          379.0
# Man Utd           351.0
# Arsenal           360.0
# Brighton          364.0
# Everton           337.0
# Spurs             348.0
# Norwich           281.0
# Newcastle         326.0
# Watford           265.0
# Southampton       282.0

# %% [markdown]
# ### Build a team using 90min Stat

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_90min:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))
        
print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Rui Pedro dos Santos Patrício
# GK budget left: 4.3
# ['Rui Pedro dos Santos Patrício']
# ['Wolves']

# %% [markdown]
# ### Select top 3 players by points per position

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 32.8 36.0 26.0
# Player Selected: Ricardo Domingos Barbosa Pereira
# DF budget left: 26.499999999999996
# Player Selected: Mason Mount
# MD budget left: 29.1
# ['Rui Pedro dos Santos Patrício', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount']
# ['Wolves', 'Leicester', 'Chelsea']

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# 3
# ['Rui Pedro dos Santos Patrício', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount']
# ['Wolves', 'Leicester', 'Chelsea']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 0

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with 90_min_stats

# %%
for item in DF_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Marcos Alonso
# DF budget left: 20.199999999999996
# Player Selected: Matt Doherty
# DF budget left: 14.199999999999996
# Player Selected: Daryl Janmaat
# DF budget left: 9.899999999999995
# # of DFs selected: 4
# Player Selected: Benjamin Chilwell
# DF budget left: 4.399999999999995
# # of DFs selected: 5
# 7
# ['Rui Pedro dos Santos Patrício', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Marcos Alonso', 'Matt Doherty', 'Daryl Janmaat', 'Benjamin Chilwell']
# ['Wolves', 'Leicester', 'Chelsea', 'Chelsea', 'Wolves', 'Watford', 'Leicester']

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Christian Pulisic
# MD budget left: 26.4
# Player Selected: Harvey Barnes
# MD budget left: 20.5
# Player Selected: Anthony Martial
# MD budget left: 12.9
# Player Selected: Andriy Yarmolenko
# MD budget left: 6.9
# 11
# ['Rui Pedro dos Santos Patrício', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Marcos Alonso', 'Matt Doherty', 'Daryl Janmaat', 'Benjamin Chilwell', 'Christian Pulisic', 'Harvey Barnes', 'Anthony Martial', 'Andriy Yarmolenko']
# ['Wolves', 'Leicester', 'Chelsea', 'Chelsea', 'Wolves', 'Watford', 'Leicester', 'Chelsea', 'Leicester', 'Man Utd', 'West Ham']

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Aaron Connolly
# ST budget left: 28.299999999999997
# Player Selected: Alexandre Lacazette
# ST budget left: 18.999999999999996
# Player Selected: Pierre-Emerick Aubameyang
# ST budget left: 7.899999999999997
# 14
# ['Rui Pedro dos Santos Patrício', 'Ricardo Domingos Barbosa Pereira', 'Mason Mount', 'Marcos Alonso', 'Matt Doherty', 'Daryl Janmaat', 'Benjamin Chilwell', 'Christian Pulisic', 'Harvey Barnes', 'Anthony Martial', 'Andriy Yarmolenko', 'Aaron Connolly', 'Alexandre Lacazette', 'Pierre-Emerick Aubameyang']
# ['Wolves', 'Leicester', 'Chelsea', 'Chelsea', 'Wolves', 'Watford', 'Leicester', 'Chelsea', 'Leicester', 'Man Utd', 'West Ham', 'Brighton', 'Arsenal', 'Arsenal']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                              name    position  \
# 0       4   5.2      900     Rui Pedro dos Santos Patrício  Goalkeeper
# 1       5   6.3      900  Ricardo Domingos Barbosa Pereira    Defender
# 2       6   6.9      862                       Mason Mount  Midfielder
# 3       3   6.3      498                     Marcos Alonso    Defender
# 4       3   6.0      547                      Matt Doherty    Defender
# 5       6   4.3      442                     Daryl Janmaat    Defender
# 6       1   5.5      720                 Benjamin Chilwell    Defender
# 7       3   7.1      401                 Christian Pulisic  Midfielder
# 8       3   5.9      479                     Harvey Barnes  Midfielder
# 9       0   7.6      350                   Anthony Martial  Midfielder
# 10      8   6.0      588                 Andriy Yarmolenko  Midfielder
# 11      3   4.6      278                    Aaron Connolly     Forward
# 12      2   9.3      256               Alexandre Lacazette     Forward
# 13     10  11.1      900         Pierre-Emerick Aubameyang     Forward
#
#     pts_per_90min  red_cards   roi     status  team_code  team_name  \
# 0            4.30          0  8.27  available         39     Wolves
# 1            4.79          0  7.62  available         13  Leicester
# 2            5.63          0  7.83  available          8    Chelsea
# 3            6.49          0  5.71  available          8    Chelsea
# 4            5.91          0  6.00  available         39     Wolves
# 5            5.89          0  6.74  available         57    Watford
# 6            5.24          0  7.64  available         13  Leicester
# 7            8.51          0  5.35  available          8    Chelsea
# 8            6.94          0  6.27  available         13  Leicester
# 9            6.67          0  3.42  available          1    Man Utd
# 10           6.57          0  7.17  available         21   West Ham
# 11           8.39          0  5.65  available         36   Brighton
# 12           7.00          0  2.15  available          3    Arsenal
# 13           5.89          0  5.32  available          3    Arsenal
#
#     total_points  transfers_in  transfers_out
# 0             43        696928         265969
# 1             48        750088         231278
# 2             54       3064894         705686
# 3             36        186147         221026
# 4             36        124489         159707
# 5             29         49216          24847
# 6             42        400526         202471
# 7             38        306435         618730
# 8             37         45999          18558
# 9             26       1031803        1175835
# 10            43        531401         154830
# 11            26        229252          39049
# 12            20         85629         226169
# 13            59       1130632        1047485

# %%
money_x = money_df.pts_per_90min
money_y = money_df.name
ST_75th = round(money_df.describe().pts_per_90min['75%'], 2)
ST_AVG = round(money_df.describe().pts_per_90min['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by pts_per_90min Stat', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('Team_pts_per90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top100_users = pd.read_csv('fEPL_user_data_test.csv', index_col='users')

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# nick tanner               1       568651           699                66
# Andrew Forey              2      4731491           692               120
# Musa Tafida               3       154379           682                84
# kurt JONKERS              4       558922           679                64
# Raushan Uttamchandani     5      1229681           679                68
#
#                                                       formation  \
# users
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Andrew Forey           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Musa Tafida            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kurt JONKERS           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
#
#                                 GKP_1                 GKP_2  \
# users
# nick tanner            Ryan-BHA-start      McGovern-NOR-sub
# Andrew Forey           Ryan-BHA-start  Stekelenburg-EVE-sub
# Musa Tafida            Leno-ARS-start        Button-BHA-sub
# kurt JONKERS           Ryan-BHA-start      McGovern-NOR-sub
# Raushan Uttamchandani  Ryan-BHA-start      McGovern-NOR-sub
#
#                                        DEF_1                DEF_2  \
# users
# nick tanner                   Rico-BOU-start       Dunk-BHA-start
# Andrew Forey             Tarkowski-BUR-start   Chilwell-LEI-start
# Musa Tafida                  Mendy-MCI-start       Dunk-BHA-start
# kurt JONKERS           Azpilicueta-CHE-start  Robertson-LIV-start
# Raushan Uttamchandani      Pieters-BUR-start  Lundstram-SHU-start
#
#                                      DEF_3  ...          DEF_5  \
# users                                       ...
# nick tanner            Lundstram-SHU-start  ...  Kelly-CRY-sub
# Andrew Forey              Tomori-CHE-start  ...   Reid-WHU-sub
# Musa Tafida               Alonso-CHE-start  ...  Lewis-NOR-sub
# kurt JONKERS               Mendy-MCI-start  ...  Kelly-CRY-sub
# Raushan Uttamchandani     Tomori-CHE-start  ...  Kelly-CRY-sub
#
#                                      MID_1                MID_2  \
# users
# nick tanner             Maddison-LEI-start       Mané-LIV-start
# Andrew Forey           De Bruyne-MCI-start   Sterling-MCI-start
# Musa Tafida             Sterling-MCI-start      Noble-WHU-start
# kurt JONKERS                Mané-LIV-start      Iwobi-EVE-start
# Raushan Uttamchandani   Sterling-MCI-start  De Bruyne-MCI-start
#
#                                      MID_3                  MID_4  \
# users
# nick tanner                Mount-CHE-start        Salah-LIV-start
# Andrew Forey               Mount-CHE-start     Maddison-LEI-start
# Musa Tafida                Mount-CHE-start      Willian-CHE-start
# kurt JONKERS           De Bruyne-MCI-start  David Silva-MCI-start
# Raushan Uttamchandani   Trossard-BHA-start         Mané-LIV-start
#
#                                     MID_5                FWD_1  \
# users
# nick tanner              Cantwell-NOR-sub    Abraham-CHE-start
# Andrew Forey               McGinn-AVL-sub    Abraham-CHE-start
# Musa Tafida              Grealish-AVL-sub    Jiménez-WOL-start
# kurt JONKERS           Dendoncker-WOL-sub    Firmino-LIV-start
# Raushan Uttamchandani  Dendoncker-WOL-sub  Lacazette-ARS-start
#
#                                       FWD_2            FWD_3  \
# users
# nick tanner            Aubameyang-ARS-start  Vardy-LEI-start
# Andrew Forey               Agüero-MCI-start  Vardy-LEI-start
# Musa Tafida                 Vardy-LEI-start   Kane-TOT-start
# kurt JONKERS                Vardy-LEI-start  Pukki-NOR-start
# Raushan Uttamchandani     Abraham-CHE-start  Vardy-LEI-start
#
#                                                          user_team_pages
# users
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# Andrew Forey           https://fantasy.premierleague.com/entry/473149...
# Musa Tafida            https://fantasy.premierleague.com/entry/154379...
# kurt JONKERS           https://fantasy.premierleague.com/entry/558922...
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Get Stats of top 100 players

# %%
y =list(top100_users.game_week_points)[:10]
z =list(top100_users.total_points)[:10]

mean = np.mean(y)
maxi = np.max(y)
mini = np.min(y)

plt.scatter(z, y)
plt.ylim(bottom=0)
plt.axhline(y=maxi, color='#1D28D2', linestyle='-', label='Max Top_10 = ' + str(maxi) +'pts')
plt.axhline(y=mean, color='#33D977', linestyle='-', label='Mean Top_10 = ' + str(mean) +'pts')
plt.axhline(y=mini, color='#D2461D', linestyle='-', label='Min Top_10 = ' + str(mini) +'pts')
plt.ylabel('Points GW-'+ str(gameweek-1), fontsize = 24, color = '#073997')
plt.xlabel('Total Points', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Players in the World Stats', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Top10_Stats', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to extract names from player string

# %%
def partition_names(names_list):
    clean_list = [item.partition("-")[0] for item in names_list]
    return clean_list

# %% [markdown]
# ### Function to get the list of all selected players by position

# %%
def get_top100_teams(team_df):
    #create lists by position
    #GK_list
    GK_list = list(team_df.GKP_1)
    GK_list.extend(list(team_df.GKP_2))
    GK_final = partition_names(GK_list)
    
    #DF_list
    DF_list = list(team_df.DEF_1)
    DF_list.extend(list(team_df.DEF_2))
    DF_list.extend(list(team_df.DEF_3))
    DF_list.extend(list(team_df.DEF_4))
    DF_list.extend(list(team_df.DEF_5))
    DF_final = partition_names(DF_list)
    
    #MD_list
    MD_list = list(team_df.MID_1)
    MD_list.extend(list(team_df.MID_2))
    MD_list.extend(list(team_df.MID_3))
    MD_list.extend(list(team_df.MID_4))
    MD_list.extend(list(team_df.MID_5))
    MD_final = partition_names(MD_list)
    
    #ST_list
    ST_list = list(team_df.FWD_1)
    ST_list.extend(list(team_df.FWD_2))
    ST_list.extend(list(team_df.FWD_3))
    ST_final = partition_names(ST_list)
    
    return GK_final, DF_final, MD_final, ST_final

# %%
#get the final clean list of players per position
GK_final, DF_final, MD_final, ST_final = get_top100_teams(top100_users)[0], get_top100_teams(top100_users)[1], get_top100_teams(top100_users)[2], get_top100_teams(top100_users)[3]

# %%
GK_final[:3]
# Out:
# ['Ryan', 'Ryan', 'Leno']

# %%
MD_final[:3]
# Out:
# ['Maddison', 'De Bruyne', 'Sterling']

# %%
DF_final[:3]
# Out:
# ['Rico', 'Tarkowski', 'Mendy']

# %%
ST_final[:3]
# Out:
# ['Abraham', 'Abraham', 'Jiménez']

# %% [markdown]
# ### Function to get you top_n players by position ordered by # of times they were picked

# %%
def return_top_n(players, top_n = 10):
    ranked = Counter(players).most_common(top_n)
    return ranked

# %%
GK_top10 = return_top_n(GK_final)

# %%
GK_top10
# Out:
# [('Button', 37),
#  ('Ryan', 35),
#  ('Schmeichel', 17),
#  ('Ederson', 16),
#  ('Pope', 15),
#  ('Heaton', 15),
#  ('Patrício', 12),
#  ('McGovern', 10),
#  ('Stekelenburg', 7),
#  ('Henderson', 5)]

# %%
DF_top10 = return_top_n(DF_final)

# %%
DF_top10
# Out:
# [('Lundstram', 63),
#  ('Kelly', 44),
#  ('Alexander', 35),
#  ('Rico', 30),
#  ('Robertson', 26),
#  ('Tomori', 24),
#  ('Söyüncü', 22),
#  ('Dunk', 21),
#  ('Chilwell', 18),
#  ('Aké', 17)]

# %%
MD_top10 = return_top_n(MD_final)

# %%
MD_top10
# Out:
# [('De Bruyne', 75),
#  ('Mount', 66),
#  ('Sterling', 58),
#  ('Mané', 46),
#  ('Salah', 26),
#  ('David Silva', 22),
#  ('Cantwell', 21),
#  ('Maddison', 17),
#  ('Bernardo Silva', 15),
#  ('Tielemans', 14)]

# %%
ST_top10 = return_top_n(ST_final)

# %%
ST_top10
# Out:
# [('Vardy', 84),
#  ('Abraham', 70),
#  ('Pukki', 19),
#  ('Aubameyang', 15),
#  ('Callum Wilson', 15),
#  ('Kane', 12),
#  ('Greenwood', 11),
#  ('Agüero', 10),
#  ('Firmino', 9),
#  ('Jiménez', 8)]

# %%
X = [item[0] for item in GK_top10]
Y = [item[1] for item in GK_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Goalkeepers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_GK', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in DF_top10]
Y = [item[1] for item in DF_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Defenders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in MD_top10]
Y = [item[1] for item in MD_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Midfielders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_MD', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in ST_top10]
Y = [item[1] for item in ST_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Strikers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_ST', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top_managers_team = GK_top10[:2]+ DF_top10[:5] + MD_top10[:5] + ST_top10[:3]

# %%
top_managers_team
# Out:
# [('Button', 37),
#  ('Ryan', 35),
#  ('Lundstram', 63),
#  ('Kelly', 44),
#  ('Alexander', 35),
#  ('Rico', 30),
#  ('Robertson', 26),
#  ('De Bruyne', 75),
#  ('Mount', 66),
#  ('Sterling', 58),
#  ('Mané', 46),
#  ('Salah', 26),
#  ('Vardy', 84),
#  ('Abraham', 70),
#  ('Pukki', 19)]

# %%
X = [item[0] for item in top_managers_team]
Y = [item[1] for item in top_managers_team]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top100 Players Optimal Team', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Team', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Latest Injury Updates from independant site that updates faster than the Fantasy site

# %%
injuries = 'http://www.premierinjuries.com/?fbclid=IwAR1Uz0TTwRMOvsq1jlefIztPPg7qtPdnag3zrHxh_39wV4CZoMG0ZWq6MYU'
injuries_tab = pd.read_html(injuries)[0]

# %%
injuries_tab
# Out:
#                        Player                   Reason
# 0               Harry Maguire                    Other
# 1             Marcus Rashford                    Other
# 2          Morgan Gibbs-White        Lower Back Injury
# 3                Keinan Davis             Thigh Injury
# 4                  Naby Keita                    Other
# 5  Jose Angel Esmoris Tasende                    Other
# 6              Domingos Quina  Groin/Hip/Pelvic Injury
# 7                  Yerry Mina              Knee Injury
# 8             Virgil van Dijk             Thigh Injury
# 9              Ibrahim Amadou                    Other

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# nick tanner               1       568651           699                66
# Andrew Forey              2      4731491           692               120
# Musa Tafida               3       154379           682                84
# kurt JONKERS              4       558922           679                64
# Raushan Uttamchandani     5      1229681           679                68
#
#                                                       formation  \
# users
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Andrew Forey           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Musa Tafida            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kurt JONKERS           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
#
#                                 GKP_1                 GKP_2  \
# users
# nick tanner            Ryan-BHA-start      McGovern-NOR-sub
# Andrew Forey           Ryan-BHA-start  Stekelenburg-EVE-sub
# Musa Tafida            Leno-ARS-start        Button-BHA-sub
# kurt JONKERS           Ryan-BHA-start      McGovern-NOR-sub
# Raushan Uttamchandani  Ryan-BHA-start      McGovern-NOR-sub
#
#                                        DEF_1                DEF_2  \
# users
# nick tanner                   Rico-BOU-start       Dunk-BHA-start
# Andrew Forey             Tarkowski-BUR-start   Chilwell-LEI-start
# Musa Tafida                  Mendy-MCI-start       Dunk-BHA-start
# kurt JONKERS           Azpilicueta-CHE-start  Robertson-LIV-start
# Raushan Uttamchandani      Pieters-BUR-start  Lundstram-SHU-start
#
#                                      DEF_3  ...          DEF_5  \
# users                                       ...
# nick tanner            Lundstram-SHU-start  ...  Kelly-CRY-sub
# Andrew Forey              Tomori-CHE-start  ...   Reid-WHU-sub
# Musa Tafida               Alonso-CHE-start  ...  Lewis-NOR-sub
# kurt JONKERS               Mendy-MCI-start  ...  Kelly-CRY-sub
# Raushan Uttamchandani     Tomori-CHE-start  ...  Kelly-CRY-sub
#
#                                      MID_1                MID_2  \
# users
# nick tanner             Maddison-LEI-start       Mané-LIV-start
# Andrew Forey           De Bruyne-MCI-start   Sterling-MCI-start
# Musa Tafida             Sterling-MCI-start      Noble-WHU-start
# kurt JONKERS                Mané-LIV-start      Iwobi-EVE-start
# Raushan Uttamchandani   Sterling-MCI-start  De Bruyne-MCI-start
#
#                                      MID_3                  MID_4  \
# users
# nick tanner                Mount-CHE-start        Salah-LIV-start
# Andrew Forey               Mount-CHE-start     Maddison-LEI-start
# Musa Tafida                Mount-CHE-start      Willian-CHE-start
# kurt JONKERS           De Bruyne-MCI-start  David Silva-MCI-start
# Raushan Uttamchandani   Trossard-BHA-start         Mané-LIV-start
#
#                                     MID_5                FWD_1  \
# users
# nick tanner              Cantwell-NOR-sub    Abraham-CHE-start
# Andrew Forey               McGinn-AVL-sub    Abraham-CHE-start
# Musa Tafida              Grealish-AVL-sub    Jiménez-WOL-start
# kurt JONKERS           Dendoncker-WOL-sub    Firmino-LIV-start
# Raushan Uttamchandani  Dendoncker-WOL-sub  Lacazette-ARS-start
#
#                                       FWD_2            FWD_3  \
# users
# nick tanner            Aubameyang-ARS-start  Vardy-LEI-start
# Andrew Forey               Agüero-MCI-start  Vardy-LEI-start
# Musa Tafida                 Vardy-LEI-start   Kane-TOT-start
# kurt JONKERS                Vardy-LEI-start  Pukki-NOR-start
# Raushan Uttamchandani     Abraham-CHE-start  Vardy-LEI-start
#
#                                                          user_team_pages
# users
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# Andrew Forey           https://fantasy.premierleague.com/entry/473149...
# Musa Tafida            https://fantasy.premierleague.com/entry/154379...
# kurt JONKERS           https://fantasy.premierleague.com/entry/558922...
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
#
# [5 rows x 21 columns]

# %%
test = top100_users.formation

# %% [markdown]
# ### Extract formations as a list in a readable format

# %%
formations = [item.split(",")[1][8] + "-" + item.split(",")[2][8] + "-" + item.split(",")[3][8] for item in test]

# %%
formations[:5]
# Out:
# ['3-4-3', '3-4-3', '3-4-3', '3-4-3', '3-4-3']

# %% [markdown]
# ### Use top_n function to get a tuple of ranked formations by count

# %%
top_form = return_top_n(formations, 6)

# %%
top_form
# Out:
# [('3-4-3', 64), ('3-5-2', 19), ('4-3-3', 9), ('4-4-2', 7), ('4-5-1', 1)]

# %%
X = [item[0] for item in top_form]
Y = [item[1] for item in top_form]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 100 Formations Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Forma', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
