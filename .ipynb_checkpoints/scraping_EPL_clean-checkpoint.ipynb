# %% [markdown]
# # IMPORT THESE:

# %%
import json
import time
import requests
import pandas as pd
from selenium import webdriver
from collections import Counter

# %%
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_colwidth', 600)

# %% [markdown]
# # Scraping weekly EPL stats (by EPL team & players)

# %%
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %%
# ev = get_json_data(url)

# %%
# with open('fantasy_EPL_0.json', 'w', encoding='utf-8') as f:
#     json.dump(ev, f, ensure_ascii=False, indent=4)

# %%
# df = pd.DataFrame(all_players)

# %%
# df.set_index('web_name')

# %%
# df.columns

# %%
# cols = ['web_name', 'now_cost', 'total_points', 'minutes', 'selected_by_percent', 'points_per_game',
#         'goals_scored', 'assists', 'yellow_cards', 'red_cards', 'own_goals',
#         'form', 'ict_index', 'creativity','influence', 'threat', 'value_season', 'bonus', 'bps',
#         'clean_sheets', 'goals_conceded', 'penalties_missed', 'saves', 'penalties_saved', 
#         'special', 'status', 'transfers_in','transfers_out', 'transfers_in_event', 'transfers_out_event',
#         'value_form', 'dreamteam_count', 'in_dreamteam',  'ep_next', 'ep_this', 'event_points',
#         'chance_of_playing_next_round', 'chance_of_playing_this_round', 'cost_change_event', 
#         'cost_change_event_fall', 'cost_change_start', 'cost_change_start_fall', 'element_type', 
#         'code', 'squad_number', 'team', 'team_code', 'id', 'photo', 'news_added', 'first_name', 'second_name']

# %%
# df = df[cols]

# %%
# Test
# df[df.web_name=='Kean']

# %%
# df.to_csv('EPL_fantasy_weeklystats_0.csv', index=False)
# df.to_csv('./testing_AWS_satire/EPL_fantasy_weeklystats_0.csv', index=False)

# %%
# df_t = pd.DataFrame(all_teams)

# %%
# df_t.to_csv('EPL_fantasy_weeklytable_0.csv', index=False)

# %%
# ls

# %%
# aa = pd.read_csv('/Users/asproul/Desktop/projects/fantasy_EPL_update2019/package/foundation/weekly_2019-20_data_scrapes/EPL_fantasy_weeklystats_2.csv')

# %%
# Test:
# aa[aa['total_points']==26]

# %%
games = get_json_data(url)['events']

# %%
df_games = pd.DataFrame(games)
print(list(df_games.deadline_time))
# Out:
# ['2019-08-09T18:00:00Z', '2019-08-17T10:30:00Z', '2019-08-23T18:00:00Z', '2019-08-31T10:30:00Z', '2019-09-14T10:30:00Z', '2019-09-20T18:00:00Z', '2019-09-28T10:30:00Z', '2019-10-05T10:30:00Z', '2019-10-19T10:30:00Z', '2019-10-25T18:00:00Z', '2019-11-02T11:30:00Z', '2019-11-08T19:00:00Z', '2019-11-23T11:30:00Z', '2019-11-30T11:30:00Z', '2019-12-03T18:45:00Z', '2019-12-07T14:00:00Z', '2019-12-14T14:00:00Z', '2019-12-21T14:00:00Z', '2019-12-26T14:00:00Z', '2019-12-28T14:00:00Z', '2020-01-01T14:00:00Z', '2020-01-11T14:00:00Z', '2020-01-18T14:00:00Z', '2020-01-21T18:45:00Z', '2020-02-01T14:00:00Z', '2020-02-08T14:00:00Z', '2020-02-22T14:00:00Z', '2020-02-29T14:00:00Z', '2020-03-07T14:00:00Z', '2020-03-14T14:00:00Z', '2020-03-21T14:00:00Z', '2020-04-04T13:00:00Z', '2020-04-11T13:00:00Z', '2020-04-18T13:00:00Z', '2020-04-25T13:00:00Z', '2020-05-02T13:00:00Z', '2020-05-09T13:00:00Z', '2020-05-17T13:00:00Z']

# %%
deadlines_list = ['2019-08-09T18:00:00Z', '2019-08-17T10:30:00Z', '2019-08-23T18:00:00Z', '2019-08-31T10:30:00Z', '2019-09-14T10:30:00Z', '2019-09-20T18:00:00Z', '2019-09-28T10:30:00Z', '2019-10-05T10:30:00Z', '2019-10-19T10:30:00Z', '2019-10-25T18:00:00Z', '2019-11-02T14:00:00Z', '2019-11-09T14:00:00Z', '2019-11-23T14:00:00Z', '2019-11-30T14:00:00Z', '2019-12-03T18:45:00Z', '2019-12-07T14:00:00Z', '2019-12-14T14:00:00Z', '2019-12-21T14:00:00Z', '2019-12-26T14:00:00Z', '2019-12-28T14:00:00Z', '2020-01-01T14:00:00Z', '2020-01-11T14:00:00Z', '2020-01-18T14:00:00Z', '2020-01-21T18:45:00Z', '2020-02-01T14:00:00Z', '2020-02-08T14:00:00Z', '2020-02-22T14:00:00Z', '2020-02-29T14:00:00Z', '2020-03-07T14:00:00Z', '2020-03-14T14:00:00Z', '2020-03-21T14:00:00Z', '2020-04-04T13:00:00Z', '2020-04-11T13:00:00Z', '2020-04-18T13:00:00Z', '2020-04-25T13:00:00Z', '2020-05-02T13:00:00Z', '2020-05-09T13:00:00Z', '2020-05-17T13:00:00Z']

# %% [markdown]
# -         **Friday, August 9, 2019 at 8:00:00 pm    EDT UTC-4 hours** - New York (USA - New York)
# - **Saturday, August 10, 2019 at 1:00:00 am BST UTC+1 hour** - London (England)
# -           **Saturday, August 10, 2019 at 00:00:00** - Corresponding UTC (GMT)

# %%
import datetime

x = datetime.datetime(2018, 9, 15,13,0,0)


# '2019-08-09T18:00:00Z'

# print(x.strftime("%b %d %Y %H:%M:%S"))
print(x.strftime("%Y-%m-%dT%H:%M:%SZ"))
# Out:
# 2018-09-15T13:00:00Z

# %%
# '2018-09-15T13:00:00Z'
# '2020-04-25T13:00:00Z'
# deadlines_list

# %%
updated_deadline_list = []

# %%
for date in deadlines_list:
    updated_deadline_list.append(pd.Timestamp(date) - pd.Timedelta(minutes=20))

# %%
pd.Timestamp('2018-09-15T13:00:00Z') - pd.Timedelta(minutes=20)
# Out:
# Timestamp('2018-09-15 12:40:00+0000', tz='UTC')

# %%
print(updated_deadline_list)
# Out:
# [Timestamp('2019-08-09 17:40:00+0000', tz='UTC'), Timestamp('2019-08-17 10:10:00+0000', tz='UTC'), Timestamp('2019-08-23 17:40:00+0000', tz='UTC'), Timestamp('2019-08-31 10:10:00+0000', tz='UTC'), Timestamp('2019-09-14 10:10:00+0000', tz='UTC'), Timestamp('2019-09-20 17:40:00+0000', tz='UTC'), Timestamp('2019-09-28 10:10:00+0000', tz='UTC'), Timestamp('2019-10-05 10:10:00+0000', tz='UTC'), Timestamp('2019-10-19 10:10:00+0000', tz='UTC'), Timestamp('2019-10-25 17:40:00+0000', tz='UTC'), Timestamp('2019-11-02 13:40:00+0000', tz='UTC'), Timestamp('2019-11-09 13:40:00+0000', tz='UTC'), Timestamp('2019-11-23 13:40:00+0000', tz='UTC'), Timestamp('2019-11-30 13:40:00+0000', tz='UTC'), Timestamp('2019-12-03 18:25:00+0000', tz='UTC'), Timestamp('2019-12-07 13:40:00+0000', tz='UTC'), Timestamp('2019-12-14 13:40:00+0000', tz='UTC'), Timestamp('2019-12-21 13:40:00+0000', tz='UTC'), Timestamp('2019-12-26 13:40:00+0000', tz='UTC'), Timestamp('2019-12-28 13:40:00+0000', tz='UTC'), Timestamp('2020-01-01 13:40:00+0000', tz='UTC'), Timestamp('2020-01-11 13:40:00+0000', tz='UTC'), Timestamp('2020-01-18 13:40:00+0000', tz='UTC'), Timestamp('2020-01-21 18:25:00+0000', tz='UTC'), Timestamp('2020-02-01 13:40:00+0000', tz='UTC'), Timestamp('2020-02-08 13:40:00+0000', tz='UTC'), Timestamp('2020-02-22 13:40:00+0000', tz='UTC'), Timestamp('2020-02-29 13:40:00+0000', tz='UTC'), Timestamp('2020-03-07 13:40:00+0000', tz='UTC'), Timestamp('2020-03-14 13:40:00+0000', tz='UTC'), Timestamp('2020-03-21 13:40:00+0000', tz='UTC'), Timestamp('2020-04-04 12:40:00+0000', tz='UTC'), Timestamp('2020-04-11 12:40:00+0000', tz='UTC'), Timestamp('2020-04-18 12:40:00+0000', tz='UTC'), Timestamp('2020-04-25 12:40:00+0000', tz='UTC'), Timestamp('2020-05-02 12:40:00+0000', tz='UTC'), Timestamp('2020-05-09 12:40:00+0000', tz='UTC'), Timestamp('2020-05-17 12:40:00+0000', tz='UTC')]

# %% [markdown]
# ---

# %% [markdown]
# # Scraping the weekly top ranked EPL Fantasy Teams (by users)

# %% [markdown]
# #### Notes:

# %%
driver = webdriver.Chrome()
page = 1
url = 'https://fantasy.premierleague.com/leagues/314/standings/c?phase=1&page_new_entries=1&page_standings=' + str(page)
driver.get(url)

# %% [markdown]
# #### Structure of INDIVIDUAL USER url:

# %%
example_base = 'https://fantasy.premierleague.com/'

example_individual_user = 'entry/INTEGER'

example_specific_game_week = 'event/INTEGER'

# %% [markdown]
# #### Agenda:
#
# - get list of top 100 users
# - scrape their weekly roster and points total

# %%
base_url = 'https://fantasy.premierleague.com/'

# %% [markdown]
# ## Implementation:

# %%
driver = webdriver.Chrome()

# %%
users = []
total_points = []
current_week_ranks = []
game_week_points = []
user_team_urls = []
user_id_num = []
lineups = []
user_squad = []
formations = []

# %%
def scrape_weekly_user_points(userz, total_pointz, rankz, gwt_pointz, user_pagez, user_idz):
    pages = [1,2]
    url = 'https://fantasy.premierleague.com/leagues/314/standings/c?phase=1&page_new_entries=1&page_standings='
    for page in pages:
        driver.get(url + str(page))
        time.sleep(1)
        table = driver.find_element_by_css_selector('tbody')
        rows = table.find_elements_by_css_selector('tr')
        for row in rows:
            user = row.find_elements_by_css_selector('td')[1].text.split('\n',1)[-1]
            tot_points = row.find_elements_by_css_selector('td')[3].text
            rank = row.find_elements_by_css_selector('td')[0].text
            user_url = row.find_elements_by_css_selector('td')[1].find_element_by_css_selector('a').get_attribute('href')
            user_id = user_url.split('entry/')[1].split('/event')[0]
            weekly_points = row.find_elements_by_css_selector('td')[2].text
            userz.append(user), total_pointz.append(tot_points), rankz.append(rank)
            gwt_pointz.append(weekly_points), user_pagez.append(user_url), user_idz.append(user_id)
#     return listy1, listy2

# %%
def scrape_user_lineups(urls, uzer_squad, formationz):
    count = 1
    for url in urls:
        driver.get(url)
        time.sleep(1.5)
        driver.find_elements_by_class_name('Tab__Link-sc-19t48gi-1')[1].click()
        time.sleep(.5)
        tables = driver.find_elements_by_css_selector('tbody')
        starter_rows = tables[0].find_elements_by_css_selector('tr')
        team = []
        starters = []
        subs = []
        formation = {'GKP':0, 'DEF':0, 'MID':0, 'FWD':0}
        counts = {'GKP':0, 'DEF':0, 'MID':0, 'FWD':0} 
        for i in range(1, len(starter_rows)+1):
            position = driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[1]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[2]').text
            formation[position] += 1
            counts[position] += 1
            starters.append((driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[1]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[1]').text + '-' + 
                             driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[1]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[1]').text + '-' + 
                             'start' + '=' + 
                             driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[1]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[2]').text + '_' +
                             str(formation[position])))
            
        sub_rows = tables[1].find_elements_by_css_selector('tr')
        for i in range(1, len(sub_rows)+1):
            position = driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[2]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[2]').text
            counts[position] += 1
            subs.append((driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[2]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[1]').text + '-' + 
                         driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[2]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[1]').text + '-' + 
                         'sub' + '=' + 
                        driver.find_element_by_xpath(f'//*[@id="root"]/div[2]/div/div[1]/div[4]/div/div/div/div/div[2]/table/tbody/tr[{str(i)}]/td[3]/button/div/div[2]/div[2]/span[2]').text) + '_' +
                        str(counts[position]))
        starters.extend(subs), team.extend(starters)
        uzer_squad.append(team), formationz.append(formation)
        print(len(urls) - count, 'left to scrape')
        count += 1
    return uzer_squad, formationz

# %%
scrape_weekly_user_points(users, total_points, current_week_ranks, game_week_points,
                          user_team_urls, user_id_num)

# %%
scrape_user_lineups(user_team_urls, user_squad, formations)
# Out:
# 99 left to scrape
# 98 left to scrape
# 97 left to scrape
# 96 left to scrape
# 95 left to scrape
# 94 left to scrape
# 93 left to scrape
# 92 left to scrape
# 91 left to scrape
# 90 left to scrape
# 89 left to scrape
# 88 left to scrape
# 87 left to scrape
# 86 left to scrape
# 85 left to scrape
# 84 left to scrape
# 83 left to scrape
# 82 left to scrape
# 81 left to scrape
# 80 left to scrape
# 79 left to scrape
# 78 left to scrape
# 77 left to scrape
# 76 left to scrape
# 75 left to scrape
# 74 left to scrape
# 73 left to scrape
# 72 left to scrape
# 71 left to scrape
# 70 left to scrape
# 69 left to scrape
# 68 left to scrape
# 67 left to scrape
# 66 left to scrape
# 65 left to scrape
# 64 left to scrape
# 63 left to scrape
# 62 left to scrape
# 61 left to scrape
# 60 left to scrape
# 59 left to scrape
# 58 left to scrape
# 57 left to scrape
# 56 left to scrape
# 55 left to scrape
# 54 left to scrape
# 53 left to scrape
# 52 left to scrape
# 51 left to scrape
# 50 left to scrape
# 49 left to scrape
# 48 left to scrape
# 47 left to scrape
# 46 left to scrape
# 45 left to scrape
# 44 left to scrape
# 43 left to scrape
# 42 left to scrape
# 41 left to scrape
# 40 left to scrape
# 39 left to scrape
# 38 left to scrape
# 37 left to scrape
# 36 left to scrape
# 35 left to scrape
# 34 left to scrape
# 33 left to scrape
# 32 left to scrape
# 31 left to scrape
# 30 left to scrape
# 29 left to scrape
# 28 left to scrape
# 27 left to scrape
# 26 left to scrape
# 25 left to scrape
# 24 left to scrape
# 23 left to scrape
# 22 left to scrape
# 21 left to scrape
# 20 left to scrape
# 19 left to scrape
# 18 left to scrape
# 17 left to scrape
# 16 left to scrape
# 15 left to scrape
# 14 left to scrape
# 13 left to scrape
# 12 left to scrape
# 11 left to scrape
# 10 left to scrape
# 9 left to scrape
# 8 left to scrape
# 7 left to scrape
# 6 left to scrape
# 5 left to scrape
# 4 left to scrape
# 3 left to scrape
# 2 left to scrape
# 1 left to scrape
# 0 left to scrape
# ([['Adrián-LIV-start=GKP_1',
#    'Guilbert-AVL-start=DEF_1',
#    'Mings-AVL-start=DEF_2',
#    'Aurier-TOT-start=DEF_3',
#    'Otamendi-MCI-start=DEF_4',
#    'McGinn-AVL-start=MID_1',
#    'Son-TOT-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Mané-LIV-start=MID_5',
#    'Abraham-CHE-start=FWD_1',
#    'Pope-BUR-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_2',
#    'Kean-EVE-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Pereira-LEI-start=DEF_1',
#    'Otamendi-MCI-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Mings-AVL-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Robertson-LIV-start=DEF_1',
#    'Diop-WHU-start=DEF_2',
#    'Vertonghen-TOT-start=DEF_3',
#    'Guendouzi-ARS-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Bernardo Silva-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5',
#    'Oriol Romeu-SOU-sub=MID_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Guilbert-AVL-start=DEF_1',
#    'Rico-BOU-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5',
#    'Cantwell-NOR-sub=MID_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Boly-WOL-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Mee-BUR-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Lamela-TOT-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Mané-LIV-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Callum Wilson-BOU-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Mendy-MCI-sub=DEF_4',
#    "O'Connell-SHU-sub=DEF_5"],
#   ['Pope-BUR-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Zinchenko-MCI-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Bernardo Silva-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'Ndombele-TOT-start=MID_4',
#    'King-BOU-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Firmino-LIV-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Rico-BOU-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Hayden-NEW-sub=MID_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Son-TOT-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'McGinn-AVL-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Haller-WHU-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Hayden-NEW-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Digne-EVE-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Azpilicueta-CHE-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Lamela-TOT-start=MID_4',
#    'Jiménez-WOL-start=FWD_1',
#    'Barnes-BUR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Dunk-BHA-sub=DEF_4',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Robertson-LIV-start=DEF_2',
#    'Aké-BOU-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'James-MUN-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Johnson-WHU-sub=DEF_5'],
#   ['Kepa-CHE-start=GKP_1',
#    'Aurier-TOT-start=DEF_1',
#    'Otamendi-MCI-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'McGinn-AVL-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Pieters-BUR-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Lundstram-SHU-start=DEF_2',
#    'Dunk-BHA-start=DEF_3',
#    'Walker-MCI-start=DEF_4',
#    'Salah-LIV-start=MID_1',
#    'Cantwell-NOR-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Pukki-NOR-start=FWD_1',
#    'Vardy-LEI-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Rodrigo-MCI-sub=MID_4',
#    'Diop-WHU-sub=DEF_5',
#    'Martial-MUN-sub=MID_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Otamendi-MCI-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Wesley-AVL-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Robertson-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'McGinn-AVL-start=MID_2',
#    'Zaha-CRY-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Aubameyang-ARS-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Simpson-BOU-sub=DEF_4',
#    'Wan-Bissaka-MUN-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Harry Wilson-BOU-start=MID_3',
#    'Mané-LIV-start=MID_4',
#    'David Silva-MCI-start=MID_5',
#    'Abraham-CHE-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Ryan-BHA-sub=GKP_2',
#    'Pukki-NOR-sub=FWD_3',
#    'Dunk-BHA-sub=DEF_4',
#    'Coleman-EVE-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Lundstram-SHU-start=DEF_2',
#    'Vestergaard-SOU-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Cantwell-NOR-start=MID_5',
#    'Agüero-MCI-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'McGovern-NOR-sub=GKP_2',
#    'Rico-BOU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5',
#    'Martinelli-ARS-sub=FWD_3'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Mings-AVL-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'King-BOU-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Otamendi-MCI-sub=DEF_4',
#    'Jorginho-CHE-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Azpilicueta-CHE-start=DEF_1',
#    'Robertson-LIV-start=DEF_2',
#    'Walker-MCI-start=DEF_3',
#    'Mané-LIV-start=MID_1',
#    'Dendoncker-WOL-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'David Silva-MCI-start=MID_4',
#    'Firmino-LIV-start=FWD_1',
#    'Vardy-LEI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Iwobi-EVE-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Lowton-BUR-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Mané-LIV-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Vardy-LEI-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Dunk-BHA-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Lundstram-SHU-start=DEF_1',
#    'Mings-AVL-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Mepham-BOU-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Rico-BOU-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Rico-BOU-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Sterling-MCI-start=MID_5',
#    'Pukki-NOR-start=FWD_1',
#    'King-BOU-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_4',
#    'Digne-EVE-sub=DEF_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'Matip-LIV-start=DEF_1',
#    'Tomori-CHE-start=DEF_2',
#    'Rico-BOU-start=DEF_3',
#    'Kelly-CRY-start=DEF_4',
#    'Mount-CHE-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'Bernardo Silva-MCI-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Sterling-MCI-start=MID_5',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Pope-BUR-sub=GKP_2',
#    'Pukki-NOR-sub=FWD_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Greenwood-MUN-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Cantwell-NOR-sub=MID_5',
#    'Matip-LIV-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Digne-EVE-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'Dendoncker-WOL-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'Pépé-ARS-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Callum Wilson-BOU-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Zinchenko-MCI-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Martial-MUN-sub=MID_5'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'Mings-AVL-start=DEF_1',
#    'Pereira-LEI-start=DEF_2',
#    'Doherty-WOL-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'Grealish-AVL-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Nakamba-AVL-sub=MID_5',
#    'Prödl-WAT-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'Grealish-AVL-start=MID_1',
#    'Felipe Anderson-WHU-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Mané-LIV-start=MID_5',
#    'Joelinton-NEW-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Dubravka-NEW-sub=GKP_2',
#    'Rico-BOU-sub=DEF_4',
#    'Pieters-BUR-sub=DEF_5',
#    'Ings-SOU-sub=FWD_3'],
#   ['Ederson-MCI-start=GKP_1',
#    'Maguire-MUN-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Ward-CRY-start=DEF_3',
#    'Mané-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Cantwell-NOR-start=MID_3',
#    'Neves-WOL-start=MID_4',
#    'James-MUN-start=MID_5',
#    'Abraham-CHE-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Henderson-SHU-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Rashford-MUN-sub=FWD_3',
#    'Mings-AVL-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Chambers-ARS-start=DEF_2',
#    'Aké-BOU-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'McGinn-AVL-start=MID_5',
#    'Pukki-NOR-start=FWD_1',
#    'Jiménez-WOL-start=FWD_2',
#    'Heaton-AVL-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Greenwood-MUN-sub=FWD_3'],
#   ['Adrián-LIV-start=GKP_1',
#    'Zinchenko-MCI-start=DEF_1',
#    'Lundstram-SHU-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Harry Wilson-BOU-start=MID_1',
#    'Pépé-ARS-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Ceballos-ARS-sub=MID_5',
#    'Kelly-CRY-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Ward-CRY-start=DEF_1',
#    'Tomori-CHE-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Mount-CHE-start=MID_5',
#    'Aubameyang-ARS-start=FWD_1',
#    'Barnes-BUR-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Robertson-LIV-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Boly-WOL-start=DEF_4',
#    'Mount-CHE-start=MID_1',
#    'James-MUN-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Abraham-CHE-start=FWD_1',
#    'Barnes-BUR-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_4',
#    'David Silva-MCI-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Aurier-TOT-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Wood-BUR-start=FWD_1',
#    'Haller-WHU-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Lanzini-WHU-sub=MID_5',
#    'Rico-BOU-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Henderson-SHU-start=GKP_1',
#    'Boly-WOL-start=DEF_1',
#    'Otamendi-MCI-start=DEF_2',
#    'van Aanholt-CRY-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Son-TOT-start=MID_3',
#    'McGinn-AVL-start=MID_4',
#    'Pépé-ARS-start=MID_5',
#    'Vardy-LEI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_4',
#    'Balbuena-WHU-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Tarkowski-BUR-start=DEF_3',
#    'Söyüncü-LEI-start=DEF_4',
#    'Mahrez-MCI-start=MID_1',
#    'James-MUN-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Agüero-MCI-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_5',
#    'Ayew-CRY-sub=FWD_3',
#    'Guendouzi-ARS-sub=MID_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Rico-BOU-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Otamendi-MCI-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'Wijnaldum-LIV-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Prödl-WAT-sub=DEF_4',
#    'Douglas Luiz-AVL-sub=MID_5',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Fabianski-WHU-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Zinchenko-MCI-start=DEF_2',
#    'Ward-CRY-start=DEF_3',
#    'Tomori-CHE-start=DEF_4',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'Pukki-NOR-start=FWD_1',
#    'Vardy-LEI-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Douglas Luiz-AVL-sub=MID_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Zinchenko-MCI-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'Yarmolenko-WHU-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Son-TOT-start=MID_5',
#    'Agüero-MCI-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5',
#    'Greenwood-MUN-sub=FWD_3'],
#   ['de Gea-MUN-start=GKP_1',
#    'Ward-CRY-start=DEF_1',
#    'Walker-MCI-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'Montoya-BHA-start=DEF_4',
#    'Dendoncker-WOL-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Kane-TOT-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'McGovern-NOR-sub=GKP_2',
#    'Maddison-LEI-sub=MID_5',
#    'Kilman-WOL-sub=DEF_5',
#    'Parrott-TOT-sub=FWD_3'],
#   ['Patrício-WOL-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Guilbert-AVL-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Heaton-AVL-sub=GKP_2',
#    'Dunk-BHA-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Ceballos-ARS-sub=MID_5'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'Chilwell-LEI-start=DEF_4',
#    'Ceballos-ARS-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'McGinn-AVL-start=MID_4',
#    'Agüero-MCI-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Stearman-SHU-sub=DEF_5',
#    'Guendouzi-ARS-sub=MID_5',
#    'Martinelli-ARS-sub=FWD_3'],
#   ['Patrício-WOL-start=GKP_1',
#    'Pereira-LEI-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Tomori-CHE-start=DEF_3',
#    'Matip-LIV-start=DEF_4',
#    'Son-TOT-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Vardy-LEI-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Henderson-SHU-sub=GKP_2',
#    'Dendoncker-WOL-sub=MID_4',
#    'Hayden-NEW-sub=MID_5',
#    'Diop-WHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Matip-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Pieters-BUR-start=DEF_3',
#    'Söyüncü-LEI-start=DEF_4',
#    'Sterling-MCI-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Adrián-LIV-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_4',
#    'Jorginho-CHE-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Maguire-MUN-start=DEF_2',
#    'Schär-NEW-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Aké-BOU-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Tomori-CHE-start=DEF_4',
#    'Mané-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Vardy-LEI-start=FWD_1',
#    'King-BOU-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Dendoncker-WOL-sub=MID_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Douglas Luiz-AVL-sub=MID_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Söyüncü-LEI-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Pedro-CHE-start=MID_1',
#    'Bernardo Silva-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Firmino-LIV-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Maitland-Niles-ARS-sub=DEF_4',
#    'Wan-Bissaka-MUN-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Robertson-LIV-start=DEF_1',
#    'Lundstram-SHU-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Bernardo Silva-MCI-start=MID_1',
#    'Felipe Anderson-WHU-start=MID_2',
#    'Son-TOT-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Agüero-MCI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Emerson-CHE-sub=DEF_4',
#    'Dendoncker-WOL-sub=MID_5',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Zinchenko-MCI-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Zaha-CRY-start=MID_4',
#    'Firmino-LIV-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lascelles-NEW-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Aké-BOU-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Mané-LIV-start=MID_4',
#    'Cantwell-NOR-start=MID_5',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Norris-WOL-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Henderson-SHU-start=GKP_1',
#    'Zinchenko-MCI-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Lamela-TOT-start=MID_4',
#    'Vardy-LEI-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Gunn-SOU-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Bednarek-SOU-sub=DEF_4',
#    'Baldock-SHU-sub=DEF_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'Evans-LEI-start=DEF_1',
#    'Otamendi-MCI-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'Son-TOT-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Cantwell-NOR-start=MID_4',
#    'Mané-LIV-start=MID_5',
#    'Abraham-CHE-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Greenwood-MUN-sub=FWD_3',
#    'Rico-BOU-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Guilbert-AVL-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Cantwell-NOR-start=MID_4',
#    'McGinn-AVL-start=MID_5',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Heaton-AVL-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Greenwood-MUN-sub=FWD_3'],
#   ['Patrício-WOL-start=GKP_1',
#    'Pieters-BUR-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'McGinn-AVL-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'King-BOU-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Guilbert-AVL-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Rico-BOU-start=DEF_1',
#    'Mings-AVL-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Cantwell-NOR-start=MID_4',
#    'Firmino-LIV-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Henderson-SHU-sub=GKP_2',
#    'Guendouzi-ARS-sub=MID_5',
#    'Dunk-BHA-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Janmaat-WAT-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'Yarmolenko-WHU-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Gibson-BUR-sub=DEF_4',
#    'Hayden-NEW-sub=MID_5',
#    'Hanley-NOR-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Haller-WHU-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Aubameyang-ARS-start=FWD_3',
#    'Fabianski-WHU-sub=GKP_2',
#    'Maddison-LEI-sub=MID_5',
#    'Pieters-BUR-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Alderweireld-TOT-start=DEF_2',
#    'Otamendi-MCI-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Son-TOT-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Wood-BUR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Mings-AVL-sub=DEF_4',
#    'Ward-CRY-sub=DEF_5',
#    'Cantwell-NOR-sub=MID_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Doherty-WOL-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Tielemans-LEI-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Dunk-BHA-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Pereira-LEI-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Guendouzi-ARS-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'James-MUN-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Dendoncker-WOL-sub=MID_5',
#    'Kilman-WOL-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'Pieters-BUR-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Matip-LIV-start=DEF_3',
#    'Lundstram-SHU-start=DEF_4',
#    'James-MUN-start=MID_1',
#    'Ceballos-ARS-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Agüero-MCI-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Aubameyang-ARS-start=FWD_3',
#    'Krul-NOR-sub=GKP_2',
#    'Wan-Bissaka-MUN-sub=DEF_5',
#    'Maddison-LEI-sub=MID_4',
#    'Guendouzi-ARS-sub=MID_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Lamela-TOT-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Moutinho-WOL-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Callum Wilson-BOU-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Stephens-BHA-sub=MID_5',
#    'Gibson-BUR-sub=DEF_4',
#    'Stearman-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Mings-AVL-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'David Silva-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Holding-ARS-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Tomori-CHE-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Diop-WHU-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Tomori-CHE-start=DEF_4',
#    'Cantwell-NOR-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Gunn-SOU-sub=GKP_2',
#    'Greenwood-MUN-sub=FWD_3',
#    'Dunk-BHA-sub=DEF_5',
#    'Hayden-NEW-sub=MID_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Mings-AVL-start=DEF_1',
#    'Digne-EVE-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Son-TOT-start=MID_2',
#    'Cantwell-NOR-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Ryan-BHA-sub=GKP_2',
#    'Maddison-LEI-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Rico-BOU-sub=DEF_4',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Ward-CRY-start=DEF_2',
#    'van Dijk-LIV-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Harry Wilson-BOU-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'Barnes-BUR-start=FWD_3',
#    'Heaton-AVL-sub=GKP_2',
#    'McGinn-AVL-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'Maguire-MUN-start=DEF_1',
#    'Tarkowski-BUR-start=DEF_2',
#    'Aké-BOU-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'Son-TOT-start=MID_3',
#    'Jorginho-CHE-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Dunk-BHA-sub=DEF_4',
#    'Kilman-WOL-sub=DEF_5',
#    'Drinkwater-BUR-sub=MID_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Buendía-NOR-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'Robertson-LIV-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Diop-WHU-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Salah-LIV-start=MID_3',
#    'Tielemans-LEI-start=MID_4',
#    'Haller-WHU-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Bernardo Silva-MCI-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Rico-BOU-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Otamendi-MCI-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Son-TOT-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Vardy-LEI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lascelles-NEW-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Lloris-TOT-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'Söyüncü-LEI-start=DEF_4',
#    'De Bruyne-MCI-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'Mahrez-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Vardy-LEI-start=FWD_2',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Kanté-CHE-sub=MID_5',
#    'Rico-BOU-sub=DEF_5',
#    'Greenwood-MUN-sub=FWD_3'],
#   ['Pope-BUR-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Zinchenko-MCI-start=DEF_2',
#    'Matip-LIV-start=DEF_3',
#    'McGinn-AVL-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Mané-LIV-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Schmeichel-LEI-start=GKP_1',
#    'Diop-WHU-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'Richarlison-EVE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Zaha-CRY-start=MID_4',
#    'Neves-WOL-start=MID_5',
#    'Agüero-MCI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Kelly-CRY-sub=DEF_5',
#    'Greenwood-MUN-sub=FWD_3'],
#   ['Heaton-AVL-start=GKP_1',
#    'Söyüncü-LEI-start=DEF_1',
#    'Lowton-BUR-start=DEF_2',
#    'Dunk-BHA-start=DEF_3',
#    'Willian-CHE-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'Cantwell-NOR-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Mané-LIV-start=MID_5',
#    'Deulofeu-WAT-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Mendy-MCI-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Wickham-CRY-sub=FWD_3'],
#   ['Pope-BUR-start=GKP_1',
#    'Mings-AVL-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Ward-CRY-start=DEF_3',
#    'Son-TOT-start=MID_1',
#    'Guendouzi-ARS-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Rico-BOU-sub=DEF_4',
#    'Hayden-NEW-sub=MID_5',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Ryan-BHA-start=GKP_1',
#    'Digne-EVE-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Kelly-CRY-start=DEF_4',
#    'Salah-LIV-start=MID_1',
#    'Grealish-AVL-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Vardy-LEI-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Maddison-LEI-sub=MID_4',
#    'Prödl-WAT-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['Fabianski-WHU-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'van Dijk-LIV-start=DEF_2',
#    'Boly-WOL-start=DEF_3',
#    'Guendouzi-ARS-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Sterling-MCI-start=MID_5',
#    'Pukki-NOR-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Ryan-BHA-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5',
#    'Connolly-BHA-sub=FWD_3'],
#   ['Pope-BUR-start=GKP_1',
#    'Guilbert-AVL-start=DEF_1',
#    'Azpilicueta-CHE-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Lanzini-WHU-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Maitland-Niles-ARS-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Mings-AVL-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Pieters-BUR-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Pépé-ARS-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Yarmolenko-WHU-start=MID_5',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Button-BHA-sub=GKP_2',
#    'Pukki-NOR-sub=FWD_3',
#    'Lundstram-SHU-sub=DEF_4',
#    'Hanley-NOR-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Chilwell-LEI-start=DEF_1',
#    'Aurier-TOT-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Bernardo Silva-MCI-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Wood-BUR-start=FWD_3',
#    'Foster-WAT-sub=GKP_2',
#    'Stevens-SHU-sub=DEF_4',
#    'Maddison-LEI-sub=MID_5',
#    'Mings-AVL-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Matip-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Pieters-BUR-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Greenwood-MUN-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Norris-WOL-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Dunk-BHA-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Robertson-LIV-start=DEF_1',
#    'Zinchenko-MCI-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Tomori-CHE-start=DEF_4',
#    'De Bruyne-MCI-start=MID_1',
#    'Sterling-MCI-start=MID_2',
#    'McGinn-AVL-start=MID_3',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Aubameyang-ARS-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Guendouzi-ARS-sub=MID_4',
#    'Dendoncker-WOL-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'Rico-BOU-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Digne-EVE-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Cantwell-NOR-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Firmino-LIV-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Maddison-LEI-sub=MID_5',
#    'Mendy-MCI-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Tomori-CHE-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Lanzini-WHU-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Ceballos-ARS-sub=MID_5',
#    'Coleman-EVE-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Mount-CHE-start=MID_4',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Vardy-LEI-start=FWD_3',
#    'Heaton-AVL-sub=GKP_2',
#    'Dendoncker-WOL-sub=MID_5',
#    'van Aanholt-CRY-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Lundstram-SHU-start=DEF_1',
#    'van Aanholt-CRY-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Wijnaldum-LIV-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Agüero-MCI-start=FWD_1',
#    'Callum Wilson-BOU-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Heaton-AVL-sub=GKP_2',
#    'Kelly-CRY-sub=DEF_4',
#    'Guendouzi-ARS-sub=MID_5',
#    'Prödl-WAT-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Maguire-MUN-start=DEF_2',
#    'Dunk-BHA-start=DEF_3',
#    'Lundstram-SHU-start=DEF_4',
#    'Sterling-MCI-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Cantwell-NOR-start=MID_3',
#    'Kane-TOT-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Lloris-TOT-sub=GKP_2',
#    'Fredericks-WHU-sub=DEF_5',
#    'Hayden-NEW-sub=MID_4',
#    'Stephens-BHA-sub=MID_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Rico-BOU-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Salah-LIV-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Agüero-MCI-start=FWD_1',
#    'Barnes-BUR-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Douglas Luiz-AVL-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Reid-WHU-sub=DEF_5'],
#   ['Henderson-SHU-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Pereira-LEI-start=DEF_2',
#    'Doherty-WOL-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'Buendía-NOR-start=MID_2',
#    'De Bruyne-MCI-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Barnes-BUR-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Ederson-MCI-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Surman-BOU-sub=MID_5',
#    'Godfrey-NOR-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Kelly-CRY-start=DEF_1',
#    'Pieters-BUR-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Sterling-MCI-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Lundstram-SHU-sub=DEF_4',
#    'Douglas Luiz-AVL-sub=MID_5',
#    'Tomori-CHE-sub=DEF_5'],
#   ['Heaton-AVL-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'Mount-CHE-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'McGinn-AVL-start=MID_4',
#    'Aubameyang-ARS-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Agüero-MCI-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_4',
#    'Lowton-BUR-sub=DEF_5'],
#   ['Patrício-WOL-start=GKP_1',
#    'Digne-EVE-start=DEF_1',
#    'Kelly-CRY-start=DEF_2',
#    'Alexander-Arnold-LIV-start=DEF_3',
#    'Cantwell-NOR-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mané-LIV-start=MID_3',
#    'Son-TOT-start=MID_4',
#    'Abraham-CHE-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Guilbert-AVL-sub=DEF_4',
#    'Guendouzi-ARS-sub=MID_5',
#    'Lundstram-SHU-sub=DEF_5'],
#   ['Ederson-MCI-start=GKP_1',
#    'Digne-EVE-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Pereira-LEI-start=DEF_3',
#    'Kelly-CRY-start=DEF_4',
#    'De Bruyne-MCI-start=MID_1',
#    'Mané-LIV-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Firmino-LIV-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'King-BOU-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Pulisic-CHE-sub=MID_4',
#    'Lansbury-AVL-sub=MID_5',
#    'Simpson-BOU-sub=DEF_5'],
#   ['Fabianski-WHU-start=GKP_1',
#    'Alexander-Arnold-LIV-start=DEF_1',
#    'Digne-EVE-start=DEF_2',
#    'Robertson-LIV-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Noble-WHU-start=MID_2',
#    'Bernardo Silva-MCI-start=MID_3',
#    'Sterling-MCI-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'King-BOU-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Gibson-BUR-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5',
#    'Dendoncker-WOL-sub=MID_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Lundstram-SHU-start=DEF_3',
#    'Tomori-CHE-start=DEF_4',
#    'Yarmolenko-WHU-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Bernardo Silva-MCI-start=MID_3',
#    'Agüero-MCI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Kane-TOT-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Reid-WHU-sub=DEF_5',
#    'Amartey-LEI-sub=MID_4',
#    'Chong-MUN-sub=MID_5'],
#   ['de Gea-MUN-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Digne-EVE-start=DEF_2',
#    'Dunk-BHA-start=DEF_3',
#    'Kelly-CRY-start=DEF_4',
#    'Son-TOT-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Firmino-LIV-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'McGovern-NOR-sub=GKP_2',
#    'Maddison-LEI-sub=MID_4',
#    'Drinkwater-BUR-sub=MID_5',
#    'Gibson-BUR-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Söyüncü-LEI-start=DEF_3',
#    'Sterling-MCI-start=MID_1',
#    'Mount-CHE-start=MID_2',
#    'Son-TOT-start=MID_3',
#    'De Bruyne-MCI-start=MID_4',
#    'Vardy-LEI-start=FWD_1',
#    'Pukki-NOR-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Rico-BOU-sub=DEF_4',
#    'Willems-NEW-sub=DEF_5'],
#   ['Pope-BUR-start=GKP_1',
#    'van Dijk-LIV-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Mings-AVL-start=DEF_3',
#    'Salah-LIV-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'David Silva-MCI-start=MID_4',
#    'McGinn-AVL-start=MID_5',
#    'Callum Wilson-BOU-start=FWD_1',
#    'Abraham-CHE-start=FWD_2',
#    'Stekelenburg-EVE-sub=GKP_2',
#    'Boly-WOL-sub=DEF_4',
#    'Pukki-NOR-sub=FWD_3',
#    'Kelly-CRY-sub=DEF_5'],
#   ['Fabianski-WHU-start=GKP_1',
#    'Lundstram-SHU-start=DEF_1',
#    'Alexander-Arnold-LIV-start=DEF_2',
#    'Kelly-CRY-start=DEF_3',
#    'De Bruyne-MCI-start=MID_1',
#    'Lamela-TOT-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Pukki-NOR-start=FWD_1',
#    'Kane-TOT-start=FWD_2',
#    'Abraham-CHE-start=FWD_3',
#    'Button-BHA-sub=GKP_2',
#    'Grealish-AVL-sub=MID_5',
#    'Walker-Peters-TOT-sub=DEF_4',
#    'Wan-Bissaka-MUN-sub=DEF_5'],
#   ['Adrián-LIV-start=GKP_1',
#    'Otamendi-MCI-start=DEF_1',
#    'Söyüncü-LEI-start=DEF_2',
#    'Rose-TOT-start=DEF_3',
#    'Son-TOT-start=MID_1',
#    'De Bruyne-MCI-start=MID_2',
#    'Mount-CHE-start=MID_3',
#    'Salah-LIV-start=MID_4',
#    'Wood-BUR-start=FWD_1',
#    'Agüero-MCI-start=FWD_2',
#    'Pukki-NOR-start=FWD_3',
#    'Pope-BUR-sub=GKP_2',
#    'Cantwell-NOR-sub=MID_5',
#    'Rico-BOU-sub=DEF_4',
#    'Lundstram-SHU-sub=DEF_5']],
#  [{'GKP': 1, 'DEF': 4, 'MID': 5, 'FWD': 1},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 4, 'MID': 5, 'FWD': 1},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 4, 'MID': 3, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3},
#   {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}])

# %%
user_squad[0]
# Out:
# ['Adrián-LIV-start=GKP_1',
#  'Guilbert-AVL-start=DEF_1',
#  'Mings-AVL-start=DEF_2',
#  'Aurier-TOT-start=DEF_3',
#  'Otamendi-MCI-start=DEF_4',
#  'McGinn-AVL-start=MID_1',
#  'Son-TOT-start=MID_2',
#  'Salah-LIV-start=MID_3',
#  'De Bruyne-MCI-start=MID_4',
#  'Mané-LIV-start=MID_5',
#  'Abraham-CHE-start=FWD_1',
#  'Pope-BUR-sub=GKP_2',
#  'Greenwood-MUN-sub=FWD_2',
#  'Kean-EVE-sub=FWD_3',
#  'Lundstram-SHU-sub=DEF_5']

# %%
formations[0]
# Out:
# {'GKP': 1, 'DEF': 4, 'MID': 5, 'FWD': 1}

# %%
GKP_1 = []
GKP_2 = []
DEF_1 = []
DEF_2 = []
DEF_3 = []
DEF_4 = []
DEF_5 = []
MID_1 = []
MID_2 = []
MID_3 = []
MID_4 = []
MID_5 = []
FWD_1 = []
FWD_2 = []
FWD_3 = []
def populate(listy):
    for i in range(len(listy)):
        for player in listy[i]:
            if player[-5:] == 'GKP_1':
                GKP_1.append(player[:-6])
            if player[-5:] == 'GKP_2':
                GKP_2.append(player[:-6])
            if player[-5:] == 'DEF_1':
                DEF_1.append(player[:-6])
            if player[-5:] == 'DEF_2':
                DEF_2.append(player[:-6])
            if player[-5:] == 'DEF_3':
                DEF_3.append(player[:-6])
            if player[-5:] == 'DEF_4':
                DEF_4.append(player[:-6])
            if player[-5:] == 'DEF_5':
                DEF_5.append(player[:-6])
            if player[-5:] == 'MID_1':
                MID_1.append(player[:-6])
            if player[-5:] == 'MID_2':
                MID_2.append(player[:-6])
            if player[-5:] == 'MID_3':
                MID_3.append(player[:-6])
            if player[-5:] == 'MID_4':
                MID_4.append(player[:-6])
            if player[-5:] == 'MID_5':
                MID_5.append(player[:-6])
            if player[-5:] == 'FWD_1':
                FWD_1.append(player[:-6])
            if player[-5:] == 'FWD_2':
                FWD_2.append(player[:-6])
            if player[-5:] == 'FWD_3':
                FWD_3.append(player[:-6])

# %%
populate(user_squad)

# %%
print(len(GKP_1), len(GKP_2), len(DEF_1), len(DEF_2), len(DEF_3), len(DEF_4), len(DEF_5), len(MID_1), len(MID_2), len(MID_3), len(MID_4), len(MID_5), len(FWD_1), len(FWD_2), len(FWD_3))
# Out:
# 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100

# %%
print(GKP_1,GKP_2, DEF_1, DEF_2, DEF_3,DEF_4,DEF_5,MID_1,MID_2,MID_3,MID_4,MID_5,FWD_1,FWD_2,FWD_3)
# Out:
# ['Adrián-LIV-start', 'Heaton-AVL-start', 'Heaton-AVL-start', 'Ryan-BHA-start', 'Patrício-WOL-start', 'Pope-BUR-start', 'Heaton-AVL-start', 'Adrián-LIV-start', 'Heaton-AVL-start', 'Kepa-CHE-start', 'Heaton-AVL-start', 'Ryan-BHA-start', 'Ryan-BHA-start', 'Schmeichel-LEI-start', 'Ederson-MCI-start', 'Schmeichel-LEI-start', 'Ryan-BHA-start', 'Adrián-LIV-start', 'Heaton-AVL-start', 'Adrián-LIV-start', 'Ryan-BHA-start', 'de Gea-MUN-start', 'Patrício-WOL-start', 'Heaton-AVL-start', 'Schmeichel-LEI-start', 'Heaton-AVL-start', 'Ederson-MCI-start', 'Adrián-LIV-start', 'Adrián-LIV-start', 'Pope-BUR-start', 'Schmeichel-LEI-start', 'Adrián-LIV-start', 'Henderson-SHU-start', 'Pope-BUR-start', 'Pope-BUR-start', 'Fabianski-WHU-start', 'Adrián-LIV-start', 'de Gea-MUN-start', 'Patrício-WOL-start', 'Schmeichel-LEI-start', 'Patrício-WOL-start', 'Heaton-AVL-start', 'Patrício-WOL-start', 'Ryan-BHA-start', 'Heaton-AVL-start', 'Pope-BUR-start', 'Heaton-AVL-start', 'Pope-BUR-start', 'Henderson-SHU-start', 'de Gea-MUN-start', 'Pope-BUR-start', 'Patrício-WOL-start', 'Ryan-BHA-start', 'Patrício-WOL-start', 'Pope-BUR-start', 'Heaton-AVL-start', 'Patrício-WOL-start', 'Ederson-MCI-start', 'Ederson-MCI-start', 'de Gea-MUN-start', 'Heaton-AVL-start', 'Patrício-WOL-start', 'Heaton-AVL-start', 'Pope-BUR-start', 'Pope-BUR-start', 'Pope-BUR-start', 'de Gea-MUN-start', 'Adrián-LIV-start', 'Ederson-MCI-start', 'Ederson-MCI-start', 'Lloris-TOT-start', 'Pope-BUR-start', 'Schmeichel-LEI-start', 'Heaton-AVL-start', 'Pope-BUR-start', 'Ryan-BHA-start', 'Fabianski-WHU-start', 'Pope-BUR-start', 'Adrián-LIV-start', 'Patrício-WOL-start', 'Patrício-WOL-start', 'Pope-BUR-start', 'de Gea-MUN-start', 'Heaton-AVL-start', 'Ederson-MCI-start', 'Adrián-LIV-start', 'Pope-BUR-start', 'Pope-BUR-start', 'Henderson-SHU-start', 'Heaton-AVL-start', 'Heaton-AVL-start', 'Patrício-WOL-start', 'Ederson-MCI-start', 'Fabianski-WHU-start', 'de Gea-MUN-start', 'de Gea-MUN-start', 'Pope-BUR-start', 'Pope-BUR-start', 'Fabianski-WHU-start', 'Adrián-LIV-start'] ['Pope-BUR-sub', 'Ryan-BHA-sub', 'Ryan-BHA-sub', 'McGovern-NOR-sub', 'Pope-BUR-sub', 'McGovern-NOR-sub', 'Pope-BUR-sub', 'Pope-BUR-sub', 'Pope-BUR-sub', 'Pope-BUR-sub', 'Ryan-BHA-sub', 'McGovern-NOR-sub', 'Button-BHA-sub', 'Ryan-BHA-sub', 'McGovern-NOR-sub', 'Ryan-BHA-sub', 'McGovern-NOR-sub', 'Ryan-BHA-sub', 'Ryan-BHA-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Pope-BUR-sub', 'Button-BHA-sub', 'Ryan-BHA-sub', 'Stekelenburg-EVE-sub', 'Dubravka-NEW-sub', 'Henderson-SHU-sub', 'Heaton-AVL-sub', 'Ryan-BHA-sub', 'Button-BHA-sub', 'Ryan-BHA-sub', 'Pope-BUR-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'McGovern-NOR-sub', 'Ryan-BHA-sub', 'Button-BHA-sub', 'McGovern-NOR-sub', 'Heaton-AVL-sub', 'Button-BHA-sub', 'Henderson-SHU-sub', 'Adrián-LIV-sub', 'Stekelenburg-EVE-sub', 'Button-BHA-sub', 'Ryan-BHA-sub', 'Stekelenburg-EVE-sub', 'Pope-BUR-sub', 'Norris-WOL-sub', 'Gunn-SOU-sub', 'Stekelenburg-EVE-sub', 'Heaton-AVL-sub', 'Button-BHA-sub', 'Henderson-SHU-sub', 'Stekelenburg-EVE-sub', 'Fabianski-WHU-sub', 'Pope-BUR-sub', 'Ryan-BHA-sub', 'Ryan-BHA-sub', 'Krul-NOR-sub', 'Stekelenburg-EVE-sub', 'Pope-BUR-sub', 'Button-BHA-sub', 'Gunn-SOU-sub', 'Ryan-BHA-sub', 'McGovern-NOR-sub', 'Heaton-AVL-sub', 'McGovern-NOR-sub', 'Pope-BUR-sub', 'Stekelenburg-EVE-sub', 'Button-BHA-sub', 'Stekelenburg-EVE-sub', 'Button-BHA-sub', 'Stekelenburg-EVE-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Stekelenburg-EVE-sub', 'Ryan-BHA-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Foster-WAT-sub', 'Norris-WOL-sub', 'Button-BHA-sub', 'Pope-BUR-sub', 'Pope-BUR-sub', 'Heaton-AVL-sub', 'Heaton-AVL-sub', 'Lloris-TOT-sub', 'Button-BHA-sub', 'Ederson-MCI-sub', 'Pope-BUR-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'Button-BHA-sub', 'McGovern-NOR-sub', 'Button-BHA-sub', 'Stekelenburg-EVE-sub', 'Button-BHA-sub', 'Pope-BUR-sub'] ['Guilbert-AVL-start', 'Pereira-LEI-start', 'Robertson-LIV-start', 'Guilbert-AVL-start', 'Boly-WOL-start', 'Kelly-CRY-start', 'Otamendi-MCI-start' ...

# %%
def make_df():
    df = pd.DataFrame()
    df['user_id_num'] = user_id_num
    df['total_points'] = total_points
    df['game_week_points'] = game_week_points
    df['users'] = users
    df['GKP_1'] = GKP_1
    df['GKP_2'] = GKP_2
    df['DEF_1'] = DEF_1
    df['DEF_2'] = DEF_2
    df['DEF_3'] = DEF_3
    df['DEF_4'] = DEF_4
    df['DEF_5'] = DEF_5
    df['MID_1'] = MID_1
    df['MID_2'] = MID_2
    df['MID_3'] = MID_3
    df['MID_4'] = MID_4
    df['MID_5'] = MID_5
    df['FWD_1'] = FWD_1
    df['FWD_2'] = FWD_2
    df['FWD_3'] = FWD_3
    df['user_team_pages'] = user_team_urls
    df.index = current_week_ranks
    df.index.name = 'rank'
    return df

# %%
df = make_df()

# %%
df.to_csv('fEPL_user_data_test.csv')

# %%
df

# %%
hm = pd.read_csv('fEPL_user_data_test.csv', index_col='users')

# %%
hm.head()
# Out:
#                rank  user_id_num  total_points  game_week_points  \
# users
# medhat shawky     1      1240736           530                41
# david croley      2      1966144           526                59
# Luke Goodwin      3      4902703           526                58
# nick tanner       4       568651           522                68
# Boyko Iliev       5       191908           521                54
#
#                             GKP_1             GKP_2                DEF_1  \
# users
# medhat shawky    Adrián-LIV-start      Pope-BUR-sub   Guilbert-AVL-start
# david croley     Heaton-AVL-start      Ryan-BHA-sub    Pereira-LEI-start
# Luke Goodwin     Heaton-AVL-start      Ryan-BHA-sub  Robertson-LIV-start
# nick tanner        Ryan-BHA-start  McGovern-NOR-sub   Guilbert-AVL-start
# Boyko Iliev    Patrício-WOL-start      Pope-BUR-sub       Boly-WOL-start
#
#                                     DEF_2                 DEF_3  \
# users
# medhat shawky             Mings-AVL-start      Aurier-TOT-start
# david croley           Otamendi-MCI-start   Robertson-LIV-start
# Luke Goodwin               Diop-WHU-start  Vertonghen-TOT-start
# nick tanner                Rico-BOU-start   Lundstram-SHU-start
# Boyko Iliev    Alexander-Arnold-LIV-start         Mee-BUR-start
#
#                             DEF_4              DEF_5                MID_1  \
# users
# medhat shawky  Otamendi-MCI-start  Lundstram-SHU-sub     McGinn-AVL-start
# david croley        Mings-AVL-sub       Dunk-BHA-sub      Mount-CHE-start
# Luke Goodwin        Kelly-CRY-sub       Dunk-BHA-sub  Guendouzi-ARS-start
# nick tanner         Kelly-CRY-sub       Dunk-BHA-sub   Sterling-MCI-start
# Boyko Iliev         Mendy-MCI-sub  O'Connell-SHU-sub      Mount-CHE-start
#
#                             MID_2                MID_3  \
# users
# medhat shawky       Son-TOT-start      Salah-LIV-start
# david croley       Mané-LIV-start     McGinn-AVL-start
# Luke Goodwin   Sterling-MCI-start  De Bruyne-MCI-start
# nick tanner        Mané-LIV-start      Mount-CHE-start
# Boyko Iliev      Lamela-TOT-start  De Bruyne-MCI-start
#
#                                   MID_4                MID_5  \
# users
# medhat shawky       De Bruyne-MCI-start       Mané-LIV-start
# david croley        De Bruyne-MCI-start     Cantwell-NOR-sub
# Luke Goodwin   Bernardo Silva-MCI-start  Oriol Romeu-SOU-sub
# nick tanner             Salah-LIV-start     Cantwell-NOR-sub
# Boyko Iliev              Mané-LIV-start     Cantwell-NOR-sub
#
#                            FWD_1                 FWD_2  \
# users
# medhat shawky  Abraham-CHE-start     Greenwood-MUN-sub
# david croley     Pukki-NOR-start     Abraham-CHE-start
# Luke Goodwin     Pukki-NOR-start  Aubameyang-ARS-start
# nick tanner    Abraham-CHE-start       Pukki-NOR-start
# Boyko Iliev      Pukki-NOR-start     Abraham-CHE-start
#
#                                  FWD_3  \
# users
# medhat shawky             Kean-EVE-sub
# david croley          Agüero-MCI-start
# Luke Goodwin           Vardy-LEI-start
# nick tanner            Vardy-LEI-start
# Boyko Iliev    Callum Wilson-BOU-start
#
#                                                  user_team_pages
# users
# medhat shawky  https://fantasy.premierleague.com/entry/124073...
# david croley   https://fantasy.premierleague.com/entry/196614...
# Luke Goodwin   https://fantasy.premierleague.com/entry/490270...
# nick tanner    https://fantasy.premierleague.com/entry/568651...
# Boyko Iliev    https://fantasy.premierleague.com/entry/191908...

# %%
GK = hm[['GKP_1', 'GKP_2']]

# %%
GK.head()
# Out:
#                             GKP_1             GKP_2
# users
# medhat shawky    Adrián-LIV-start      Pope-BUR-sub
# david croley     Heaton-AVL-start      Ryan-BHA-sub
# Luke Goodwin     Heaton-AVL-start      Ryan-BHA-sub
# nick tanner        Ryan-BHA-start  McGovern-NOR-sub
# Boyko Iliev    Patrício-WOL-start      Pope-BUR-sub

# %%
GK_list = list(GK.GKP_1)

# %%
GK_list.extend(list(GK.GKP_2))

# %%
len(GK_list)
# Out:
# 200

# %%
GK_list[:3]
# Out:
# ['Adrián-LIV-start', 'Heaton-AVL-start', 'Heaton-AVL-start']

# %%
test = GK_list[0].partition("-")[0]

# %%
GK_final = [item.partition("-")[0] for item in GK_list]

# %%
GK_final
# Out:
# ['Adrián',
#  'Heaton',
#  'Heaton',
#  'Ryan',
#  'Patrício',
#  'Pope',
#  'Heaton',
#  'Adrián',
#  'Heaton',
#  'Kepa',
#  'Heaton',
#  'Ryan',
#  'Ryan',
#  'Schmeichel',
#  'Ederson',
#  'Schmeichel',
#  'Ryan',
#  'Adrián',
#  'Heaton',
#  'Adrián',
#  'Ryan',
#  'de Gea',
#  'Patrício',
#  'Heaton',
#  'Schmeichel',
#  'Heaton',
#  'Ederson',
#  'Adrián',
#  'Adrián',
#  'Pope',
#  'Schmeichel',
#  'Adrián',
#  'Henderson',
#  'Pope',
#  'Pope',
#  'Fabianski',
#  'Adrián',
#  'de Gea',
#  'Patrício',
#  'Schmeichel',
#  'Patrício',
#  'Heaton',
#  'Patrício',
#  'Ryan',
#  'Heaton',
#  'Pope',
#  'Heaton',
#  'Pope',
#  'Henderson',
#  'de Gea',
#  'Pope',
#  'Patrício',
#  'Ryan',
#  'Patrício',
#  'Pope',
#  'Heaton',
#  'Patrício',
#  'Ederson',
#  'Ederson',
#  'de Gea',
#  'Heaton',
#  'Patrício',
#  'Heaton',
#  'Pope',
#  'Pope',
#  'Pope',
#  'de Gea',
#  'Adrián',
#  'Ederson',
#  'Ederson',
#  'Lloris',
#  'Pope',
#  'Schmeichel',
#  'Heaton',
#  'Pope',
#  'Ryan',
#  'Fabianski',
#  'Pope',
#  'Adrián',
#  'Patrício',
#  'Patrício',
#  'Pope',
#  'de Gea',
#  'Heaton',
#  'Ederson',
#  'Adrián',
#  'Pope',
#  'Pope',
#  'Henderson',
#  'Heaton',
#  'Heaton',
#  'Patrício',
#  'Ederson',
#  'Fabianski',
#  'de Gea',
#  'de Gea',
#  'Pope',
#  'Pope',
#  'Fabianski',
#  'Adrián',
#  'Pope',
#  'Ryan',
#  'Ryan',
#  'McGovern',
#  'Pope',
#  'McGovern',
#  'Pope',
#  'Pope',
#  'Pope',
#  'Pope',
#  'Ryan',
#  'McGovern',
#  'Button',
#  'Ryan',
#  'McGovern',
#  'Ryan',
#  'McGovern',
#  'Ryan',
#  'Ryan',
#  'Button',
#  'Button',
#  'Pope',
#  'Button',
#  'Ryan',
#  'Stekelenburg',
#  'Dubravka',
#  'Henderson',
#  'Heaton',
#  'Ryan',
#  'Button',
#  'Ryan',
#  'Pope',
#  'Button',
#  'Button',
#  'McGovern',
#  'Ryan',
#  'Button',
#  'McGovern',
#  'Heaton',
#  'Button',
#  'Henderson',
#  'Adrián',
#  'Stekelenburg',
#  'Button',
#  'Ryan',
#  'Stekelenburg',
#  'Pope',
#  'Norris',
#  'Gunn',
#  'Stekelenburg',
#  'Heaton',
#  'Button',
#  'Henderson',
#  'Stekelenburg',
#  'Fabianski',
#  'Pope',
#  'Ryan',
#  'Ryan',
#  'Krul',
#  'Stekelenburg',
#  'Pope',
#  'Button',
#  'Gunn',
#  'Ryan',
#  'McGovern',
#  'Heaton',
#  'McGovern',
#  'Pope',
#  'Stekelenburg',
#  'Button',
#  'Stekelenburg',
#  'Button',
#  'Stekelenburg',
#  'Button',
#  'Button',
#  'Stekelenburg',
#  'Ryan',
#  'Button',
#  'Button',
#  'Foster',
#  'Norris',
#  'Button',
#  'Pope',
#  'Pope',
#  'Heaton',
#  'Heaton',
#  'Lloris',
#  'Button',
#  'Ederson',
#  'Pope',
#  'Button',
#  'Button',
#  'Button',
#  'Button',
#  'Button',
#  'McGovern',
#  'Button',
#  'Stekelenburg',
#  'Button',
#  'Pope']

# %%
from collections import Counter

# %%
maybs = Counter(GK_final).most_common(10)

# %%
maybs
# Out:
# [('Pope', 35),
#  ('Button', 27),
#  ('Heaton', 24),
#  ('Ryan', 24),
#  ('Adrián', 13),
#  ('Patrício', 12),
#  ('Stekelenburg', 11),
#  ('McGovern', 10),
#  ('Ederson', 9),
#  ('de Gea', 8)]

# %%
def partition_names(names_list):
    clean_list = [item.partition("-")[0] for item in names_list]
    return clean_list

# %%
def get_top100_teams(team_df):
    #create lists by position
    #GK_list
    GK_list = list(team_df.GKP_1)
    GK_list.extend(list(team_df.GKP_2))
    GK_final = partition_names(GK_list)
    
    #DF_list
    DF_list = list(team_df.DEF_1)
    DF_list.extend(list(team_df.DEF_2))
    DF_list.extend(list(team_df.DEF_3))
    DF_list.extend(list(team_df.DEF_4))
    DF_list.extend(list(team_df.DEF_5))
    DF_final = partition_names(DF_list)
    
    #MD_list
    MD_list = list(team_df.MID_1)
    MD_list.extend(list(team_df.MID_2))
    MD_list.extend(list(team_df.MID_3))
    MD_list.extend(list(team_df.MID_4))
    MD_list.extend(list(team_df.MID_5))
    MD_final = partition_names(MD_list)
    
    #ST_list
    ST_list = list(team_df.FWD_1)
    ST_list.extend(list(team_df.FWD_2))
    ST_list.extend(list(team_df.FWD_3))
    ST_final = partition_names(ST_list)
    
    return GK_final, DF_final, MD_final, ST_final

# %%
GK_final, DF_final, MD_final, ST_final = get_top100_teams(hm)[0], get_top100_teams(hm)[1], get_top100_teams(hm)[2], get_top100_teams(hm)[3]

# %%
GK_final[:3]
# Out:
# ['Adrián', 'Heaton', 'Heaton']

# %%
DF_final[:3]
# Out:
# ['Guilbert', 'Pereira', 'Robertson']

# %%
MD_final[:3]
# Out:
# ['McGinn', 'Mount', 'Guendouzi']

# %%
ST_final[:3]
# Out:
# ['Abraham', 'Pukki', 'Pukki']

# %%
def return_top_n(players, top_n = 10):
    ranked = Counter(players).most_common(top_n)
    return ranked

# %%
GK_top10 = return_top_n(GK_final, top_n = 10)

# %%
GK_top10
# Out:
# [('Pope', 35),
#  ('Button', 27),
#  ('Heaton', 24),
#  ('Ryan', 24),
#  ('Adrián', 13),
#  ('Patrício', 12),
#  ('Stekelenburg', 11),
#  ('McGovern', 10),
#  ('Ederson', 9),
#  ('de Gea', 8)]

# %%
DF_top10 = return_top_n(DF_final, top_n = 10)

# %%
DF_top10
# Out:
# [('Lundstram', 76),
#  ('Kelly', 50),
#  ('Alexander', 48),
#  ('van Dijk', 29),
#  ('Söyüncü', 23),
#  ('Dunk', 20),
#  ('Otamendi', 19),
#  ('Rico', 19),
#  ('Tomori', 17),
#  ('Pieters', 16)]

# %%
MD_top10 = return_top_n(MD_final, top_n = 10)

# %%
MD_top10
# Out:
# [('De Bruyne', 92),
#  ('Mount', 51),
#  ('Cantwell', 48),
#  ('Salah', 46),
#  ('Sterling', 44),
#  ('Son', 27),
#  ('Mané', 27),
#  ('McGinn', 25),
#  ('Dendoncker', 15),
#  ('Guendouzi', 11)]

# %%
ST_top10 = return_top_n(ST_final, top_n = 10)

# %%
ST_top10
# Out:
# [('Pukki', 70),
#  ('Abraham', 56),
#  ('Agüero', 41),
#  ('Vardy', 20),
#  ('Callum Wilson', 18),
#  ('Aubameyang', 16),
#  ('Greenwood', 15),
#  ('Kane', 15),
#  ('Firmino', 14),
#  ('King', 7)]
