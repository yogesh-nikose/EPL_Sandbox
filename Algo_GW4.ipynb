# %% [markdown]
# ## Define Gameweek and Periods for FDR calculation

# %%
gameweek = 4
next_n_games = 2

# %% [markdown]
# ## Define Budget, Team Formation, and Budget Allocation by Position

# %%
#Budget
budget = 100

#Team Formation
DF = 3
MD = 4
ST = 3

#Total players needed per position
DF_max = 5
MD_max = 5
ST_max = 3

#Budget Allocation
GK_coef = 0.1
DF_coef = 0.22
MD_coef = 0.42
ST_coef = 0.26

# %% [markdown]
# ## Scraped list of Schedules

# %%
schedules = ['Arsenal NEW (A) BUR (H) LIV (A) TOT (H) WAT (A) AVL (H) MUN (A) BOU (H) SHU (A) CRY (H) WOL (H) LEI (A) SOU (H) NOR (A) BHA (H) WHU (A) MCI (H) EVE (A) BOU (A) CHE (H) MUN (H) CRY (A) SHU (H) CHE (A) BUR (A) NEW (H) EVE (H) MCI (A) WHU (H) BHA (A) SOU (A) NOR (H) WOL (A) LEI (H) TOT (A) LIV (H) AVL (A) WAT (H)',
 'Aston Villa TOT (A) BOU (H) EVE (H) CRY (A) WHU (H) ARS (A) BUR (H) NOR (A) BHA (H) MCI (A) LIV (H) WOL (A) NEW (H) MUN (A) CHE (A) LEI (H) SHU (A) SOU (H) NOR (H) WAT (A) BUR (A) MCI (H) BHA (A) WAT (H) BOU (A) TOT (H) SOU (A) SHU (H) LEI (A) CHE (H) NEW (A) WOL (H) LIV (A) MUN (H) CRY (H) EVE (A) ARS (H) WHU (A)',
 'Bournemouth SHU (H) AVL (A) MCI (H) LEI (A) EVE (H) SOU (A) WHU (H) ARS (A) NOR (H) WAT (A) MUN (H) NEW (A) WOL (H) TOT (A) CRY (A) LIV (H) CHE (A) BUR (H) ARS (H) BHA (A) WHU (A) WAT (H) NOR (A) BHA (H) AVL (H) SHU (A) BUR (A) CHE (H) LIV (A) CRY (H) WOL (A) NEW (H) MUN (A) TOT (H) LEI (H) MCI (A) SOU (H) EVE (A)',
 'Brighton WAT (A) WHU (H) SOU (H) MCI (A) BUR (H) NEW (A) CHE (A) TOT (H) AVL (A) EVE (H) NOR (H) MUN (A) LEI (H) LIV (A) ARS (A) WOL (H) CRY (A) SHU (H) TOT (A) BOU (H) CHE (H) EVE (A) AVL (H) BOU (A) WHU (A) WAT (H) SHU (A) CRY (H) WOL (A) ARS (H) LEI (A) MUN (H) NOR (A) LIV (H) MCI (H) SOU (A) NEW (H) BUR (A)',
 'Burnley SOU (H) ARS (A) WOL (A) LIV (H) BHA (A) NOR (H) AVL (A) EVE (H) LEI (A) CHE (H) SHU (A) WHU (H) WAT (A) CRY (H) MCI (H) TOT (A) NEW (H) BOU (A) EVE (A) MUN (H) AVL (H) CHE (A) LEI (H) MUN (A) ARS (H) SOU (A) BOU (H) NEW (A) TOT (H) MCI (A) WAT (H) CRY (A) SHU (H) WHU (A) LIV (A) WOL (H) NOR (A) BHA (H)',
 'Chelsea MUN (A) LEI (H) NOR (A) SHU (H) WOL (A) LIV (H) BHA (H) SOU (A) NEW (H) BUR (A) WAT (A) CRY (H) MCI (A) WHU (H) AVL (H) EVE (A) BOU (H) TOT (A) SOU (H) ARS (A) BHA (A) BUR (H) NEW (A) ARS (H) LEI (A) MUN (H) TOT (H) BOU (A) EVE (H) AVL (A) MCI (H) WHU (A) WAT (H) CRY (A) SHU (A) NOR (H) LIV (A) WOL (H)',
 'Crystal Palace EVE (H) SHU (A) MUN (A) AVL (H) TOT (A) WOL (H) NOR (H) WHU (A) MCI (H) ARS (A) LEI (H) CHE (A) LIV (H) BUR (A) BOU (H) WAT (A) BHA (H) NEW (A) WHU (H) SOU (A) NOR (A) ARS (H) MCI (A) SOU (H) SHU (H) EVE (A) NEW (H) BHA (A) WAT (H) BOU (A) LIV (A) BUR (H) LEI (A) CHE (H) AVL (A) MUN (H) WOL (A) TOT (H)',
 'Everton CRY (A) WAT (H) AVL (A) WOL (H) BOU (A) SHU (H) MCI (H) BUR (A) WHU (H) BHA (A) TOT (H) SOU (A) NOR (H) LEI (A) LIV (A) CHE (H) MUN (A) ARS (H) BUR (H) NEW (A) MCI (A) BHA (H) WHU (A) NEW (H) WAT (A) CRY (H) ARS (A) MUN (H) CHE (A) LIV (H) NOR (A) LEI (H) TOT (A) SOU (H) WOL (A) AVL (H) SHU (A) BOU (H)',
 'Leicester WOL (H) CHE (A) SHU (A) BOU (H) MUN (A) TOT (H) NEW (H) LIV (A) BUR (H) SOU (A) CRY (A) ARS (H) BHA (A) EVE (H) WAT (H) AVL (A) NOR (H) MCI (A) LIV (H) WHU (A) NEW (A) SOU (H) BUR (A) WHU (H) CHE (H) WOL (A) MCI (H) NOR (A) AVL (H) WAT (A) BHA (H) EVE (A) CRY (H) ARS (A) BOU (A) SHU (H) TOT (A) MUN (H)',
 'Liverpool NOR (H) SOU (A) ARS (H) BUR (A) NEW (H) CHE (A) SHU (A) LEI (H) MUN (A) TOT (H) AVL (A) MCI (H) CRY (A) BHA (H) EVE (H) BOU (A) WAT (H) WHU (A) LEI (A) WOL (H) SHU (H) TOT (A) MUN (H) WOL (A) SOU (H) NOR (A) WHU (H) WAT (A) BOU (H) EVE (A) CRY (H) MCI (A) AVL (H) BHA (A) BUR (H) ARS (A) CHE (H) NEW (A)',
 'Man City WHU (A) TOT (H) BOU (A) BHA (H) NOR (A) WAT (H) EVE (A) WOL (H) CRY (A) AVL (H) SOU (H) LIV (A) CHE (H) NEW (A) BUR (A) MUN (H) ARS (A) LEI (H) WOL (A) SHU (H) EVE (H) AVL (A) CRY (H) SHU (A) TOT (A) WHU (H) LEI (A) ARS (H) MUN (A) BUR (H) CHE (A) LIV (H) SOU (A) NEW (H) BHA (A) BOU (H) WAT (A) NOR (H)',
 'Man Utd CHE (H) WOL (A) CRY (H) SOU (A) LEI (H) WHU (A) ARS (H) NEW (A) LIV (H) NOR (A) BOU (A) BHA (H) SHU (A) AVL (H) TOT (H) MCI (A) EVE (H) WAT (A) NEW (H) BUR (A) ARS (A) NOR (H) LIV (A) BUR (H) WOL (H) CHE (A) WAT (H) EVE (A) MCI (H) TOT (A) SHU (H) BHA (A) BOU (H) AVL (A) SOU (H) CRY (A) WHU (H) LEI (A)',
 'Newcastle ARS (H) NOR (A) TOT (A) WAT (H) LIV (A) BHA (H) LEI (A) MUN (H) CHE (A) WOL (H) WHU (A) BOU (H) AVL (A) MCI (H) SHU (A) SOU (H) BUR (A) CRY (H) MUN (A) EVE (H) LEI (H) WOL (A) CHE (H) EVE (A) NOR (H) ARS (A) CRY (A) BUR (H) SOU (A) SHU (H) AVL (H) BOU (A) WHU (H) MCI (A) WAT (A) TOT (H) BHA (A) LIV (H)',
 'Norwich LIV (A) NEW (H) CHE (H) WHU (A) MCI (H) BUR (A) CRY (A) AVL (H) BOU (A) MUN (H) BHA (A) WAT (H) EVE (A) ARS (H) SOU (A) SHU (H) LEI (A) WOL (H) AVL (A) TOT (H) CRY (H) MUN (A) BOU (H) TOT (A) NEW (A) LIV (H) WOL (A) LEI (H) SHU (A) SOU (H) EVE (H) ARS (A) BHA (H) WAT (A) WHU (H) CHE (A) BUR (H) MCI (A)',
 'Sheffield Utd BOU (A) CRY (H) LEI (H) CHE (A) SOU (H) EVE (A) LIV (H) WAT (A) ARS (H) WHU (A) BUR (H) TOT (A) MUN (H) WOL (A) NEW (H) NOR (A) AVL (H) BHA (A) WAT (H) MCI (A) LIV (A) WHU (H) ARS (A) MCI (H) CRY (A) BOU (H) BHA (H) AVL (A) NOR (H) NEW (A) MUN (A) TOT (H) BUR (A) WOL (H) CHE (H) LEI (A) EVE (H) SOU (A)',
 'Southampton BUR (A) LIV (H) BHA (A) MUN (H) SHU (A) BOU (H) TOT (A) CHE (H) WOL (A) LEI (H) MCI (A) EVE (H) ARS (A) WAT (H) NOR (H) NEW (A) WHU (H) AVL (A) CHE (A) CRY (H) TOT (H) LEI (A) WOL (H) CRY (A) LIV (A) BUR (H) AVL (H) WHU (A) NEW (H) NOR (A) ARS (H) WAT (A) MCI (H) EVE (A) MUN (A) BHA (H) BOU (A) SHU (H)',
 'Spurs AVL (H) MCI (A) NEW (H) ARS (A) CRY (H) LEI (A) SOU (H) BHA (A) WAT (H) LIV (A) EVE (A) SHU (H) WHU (A) BOU (H) MUN (A) BUR (H) WOL (A) CHE (H) BHA (H) NOR (A) SOU (A) LIV (H) WAT (A) NOR (H) MCI (H) AVL (A) CHE (A) WOL (H) BUR (A) MUN (H) WHU (H) SHU (A) EVE (H) BOU (A) ARS (H) NEW (A) LEI (H) CRY (A)',
 'Watford BHA (H) EVE (A) WHU (H) NEW (A) ARS (H) MCI (A) WOL (A) SHU (H) TOT (A) BOU (H) CHE (H) NOR (A) BUR (H) SOU (A) LEI (A) CRY (H) LIV (A) MUN (H) SHU (A) AVL (H) WOL (H) BOU (A) TOT (H) AVL (A) EVE (H) BHA (A) MUN (A) LIV (H) CRY (A) LEI (H) BUR (A) SOU (H) CHE (A) NOR (H) NEW (H) WHU (A) MCI (H) ARS (A)',
 'West Ham MCI (H) BHA (A) WAT (A) NOR (H) AVL (A) MUN (H) BOU (A) CRY (H) EVE (A) SHU (H) NEW (H) BUR (A) TOT (H) CHE (A) WOL (A) ARS (H) SOU (A) LIV (H) CRY (A) LEI (H) BOU (H) SHU (A) EVE (H) LEI (A) BHA (H) MCI (A) LIV (A) SOU (H) ARS (A) WOL (H) TOT (A) CHE (H) NEW (A) BUR (H) NOR (A) WAT (H) MUN (A) AVL (H)',
 'Wolves LEI (A) MUN (H) BUR (H) EVE (A) CHE (H) CRY (A) WAT (H) MCI (A) SOU (H) NEW (A) ARS (A) AVL (H) BOU (A) SHU (H) WHU (H) BHA (A) TOT (H) NOR (A) MCI (H) LIV (A) WAT (A) NEW (H) SOU (A) LIV (H) MUN (A) LEI (H) NOR (H) TOT (A) BHA (H) WHU (A) BOU (H) AVL (A) ARS (H) SHU (A) EVE (H) BUR (A) CRY (H) CHE (A)']

# %% [markdown]
# ### Import Data

# %%
import json
import requests
import pandas as pd

# url = "https://fantasy.premierleague.com/drf/bootstrap-static"
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %% [markdown]
# ### Get Team Table

# %%
table_url = 'https://www.premierleague.com/tables'

def build_table(table_url):
    team_table = pd.read_html(table_url)
    team_df = pd.DataFrame(team_table[0])
    team_df = team_df[team_df['Unnamed: 12'].isna()]
    team_df = team_df.iloc[:,1:10]
    team_df.Club = team_df.Club.map(lambda x: x[-3:])
    team_df.reset_index()
    team_df.index = np.arange(1, len(team_df) + 1)
    team_df.columns = ['Team', 'Played', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']
    team_df.index.name = 'Position'
    
    return team_df

# %%
table_df = build_table(table_url)

# %%
table_df.head()
# Out:
#          Team Played  W  D  L  GF GA  GD Pts
# Position
# 1         LIV      3  3  0  0   9  3  +6   9
# 2         MCI      3  2  1  0  10  3  +7   7
# 3         ARS      3  2  0  1   4  4   0   6
# 4         LEI      3  1  2  0   3  2  +1   5
# 5         MUN      3  1  1  1   6  3  +3   4

# %% [markdown]
# ## Add player status and ROI, pts-per-90min metrics to final player_df

# %%
def attach_team_and_position(main_players, all_teams, positons):
    players = main_players.copy()
    for team in all_teams:
        for player in players:
            if team['code'] == player['team_code']:
                player['team_name'] = team['name']
    for position in positions:
        for player in players:
            if position['id'] == player['element_type']:
                player['position'] = position['singular_name']
    for player in players:
        if player['status'] == "a":
            player['status'] = "available"
        elif player['status'] == "d":
            player['status'] = "doubtful"
        elif player['status'] == "i":
            player['status'] = "injured"
        elif player['status'] == "s":
            player['status'] = "suspended"
    return players


#### Temporarily took out the "main_players" filter because no players have played 330 minutes ####

# player_positions_teams = attach_team_and_position(main_players, all_teams_new, positions)
player_positions_teams = attach_team_and_position(all_players, all_teams, positions)


def final_players_list(player_positions_teams):
    players = player_positions_teams.copy()
    empty = []
    for player in players:
        stats = dict(team_code = player['team_code'],
        team_name = player['team_name'],
        name = player['first_name'] + " " + player['second_name'],
        status = player['status'],
        position = player['position'],
        cost = (player['now_cost'])/10,
        total_points = player['total_points'],
        roi = round((player['total_points'] / player['now_cost'])*10, 2),
        pts_per_90min = round((player['total_points'] / (player['minutes'] + 1))*90, 2),
        bonus = player['bonus'],
        red_cards = player['red_cards'],
        minutes = player['minutes'],
        transfers_out = player['transfers_out'],
        transfers_in = player['transfers_in'])
        empty.append(stats)
    return empty

# %%
final = final_players_list(player_positions_teams)

# %%
final[0]
# Out:
# {'team_code': 3,
#  'team_name': 'Arsenal',
#  'name': 'Shkodran Mustafi',
#  'status': 'available',
#  'position': 'Defender',
#  'cost': 5.4,
#  'total_points': 0,
#  'roi': 0.0,
#  'pts_per_90min': 0.0,
#  'bonus': 0,
#  'red_cards': 0,
#  'minutes': 0,
#  'transfers_out': 18856,
#  'transfers_in': 3667}

# %%
all_teams[0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1250,
#  'strength_overall_away': 1330,
#  'strength_attack_home': 1240,
#  'strength_attack_away': 1270,
#  'strength_defence_home': 1290,
#  'strength_defence_away': 1330}

# %% [markdown]
# ### Get Total ROI, Points and 90min before filtering injured and FDR

# %%
total_roi = sorted(final, key = lambda x: x['roi'], reverse = True)

# %%
total_roi[:2]
# Out:
# [{'team_code': 45,
#   'team_name': 'Norwich',
#   'name': 'Teemu Pukki',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 7.0,
#   'total_points': 35,
#   'roi': 5.0,
#   'pts_per_90min': 11.98,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 262,
#   'transfers_out': 91732,
#   'transfers_in': 2015231},
#  {'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'John Lundstram',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 4.2,
#   'total_points': 17,
#   'roi': 4.05,
#   'pts_per_90min': 5.93,
#   'bonus': 4,
#   'red_cards': 0,
#   'minutes': 257,
#   'transfers_out': 70880,
#   'transfers_in': 764356}]

# %% [markdown]
# ### Total_Points

# %%
total_max_pts = sorted(total_roi, key = lambda x: x['total_points'], reverse = True)

# %%
total_max_pts[:2]
# Out:
# [{'team_code': 45,
#   'team_name': 'Norwich',
#   'name': 'Teemu Pukki',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 7.0,
#   'total_points': 35,
#   'roi': 5.0,
#   'pts_per_90min': 11.98,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 262,
#   'transfers_out': 91732,
#   'transfers_in': 2015231},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Raheem Sterling',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 12.2,
#   'total_points': 34,
#   'roi': 2.79,
#   'pts_per_90min': 11.29,
#   'bonus': 4,
#   'red_cards': 0,
#   'minutes': 270,
#   'transfers_out': 75026,
#   'transfers_in': 877394}]

# %% [markdown]
# ### 90 min

# %%
total_90min = sorted(total_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = (gameweek*90)/4
total_90min = [player for player in total_90min if player['minutes'] >= min_min]

# %%
total_90min[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Riyad Mahrez',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 8.5,
#   'total_points': 16,
#   'roi': 1.88,
#   'pts_per_90min': 12.86,
#   'bonus': 2,
#   'red_cards': 0,
#   'minutes': 111,
#   'transfers_out': 142379,
#   'transfers_in': 182986},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.0,
#   'total_points': 24,
#   'roi': 2.0,
#   'pts_per_90min': 12.2,
#   'bonus': 3,
#   'red_cards': 0,
#   'minutes': 176,
#   'transfers_out': 254144,
#   'transfers_in': 268991}]

# %% [markdown]
# ### Create Players DataFrame

# %%
player_df = pd.DataFrame(final)

# %%
player_df.sort_values(by = ['roi'], ascending = False, inplace = True)

# %%
player_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %% [markdown]
# ### Merge two team tables s owe have all data

# %%
def merged_teams(table_df, all_teams):
    table_dic = table_df.to_dict('records')
    
    for team in table_dic:
        for item in all_teams:
            if team['Team'] == item['short_name']:
                team['code'] = item['code']
                team['name'] = item['name']
                team['strength'] = item['strength']
            
    new_df = pd.DataFrame(table_dic)
    
    new_order = ['code', 'strength', 'Team','name', 'Played', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'Pts']
    
    table_df = new_df[new_order]
    
    table_df.index = np.arange(1, len(table_df) + 1)
    table_df.index.name = 'Position'
    
    return table_df

# %%
team_df = merged_teams(table_df, all_teams)

# %%
team_df.head()
# Out:
#           code  strength Team       name Played  W  L  D  GF GA  GD Pts
# Position
# 1           14         5  LIV  Liverpool      3  3  0  0   9  3  +6   9
# 2           43         5  MCI   Man City      3  2  0  1  10  3  +7   7
# 3            3         4  ARS    Arsenal      3  2  1  0   4  4   0   6
# 4           13         3  LEI  Leicester      3  1  0  2   3  2  +1   5
# 5            1         4  MUN    Man Utd      3  1  1  1   6  3  +3   4

# %%
team_names = list(team_df.name)

# %%
team_names.sort()

# %%
team_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %% [markdown]
# ## Create Schedule DF

# %%
def extract_sched(schedules):
    dic = {}
    for i, item in enumerate(schedules):
        name = item.partition(team_names[i])[1]
        sche = item.partition(team_names[i])[2]
        sche = sche.split()
        clean = [item for item in sche if item != "(A)"]
        clean2 = [item for item in clean if item != "(H)"]
        dic[name] = clean2
    return dic

# %%
wonders = extract_sched(schedules)

# %%
schedule_df = pd.DataFrame(wonders)

# %%
schedule_df.index.name = 'Gameweek'

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
schedule_df.Arsenal[0:3]
# Out:
# Gameweek
# 0    NEW
# 1    BUR
# 2    LIV
# Name: Arsenal, dtype: object

# %% [markdown]
# ## Create FDR scores for calculating next-n opponents AVG strength

# %%
scores = list(zip(team_df.Team, team_df.strength))

# %%
scores = dict(scores)

# %%
sorted(scores.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('LIV', 5),
#  ('MCI', 5),
#  ('ARS', 4),
#  ('MUN', 4),
#  ('TOT', 4),
#  ('CHE', 4),
#  ('LEI', 3),
#  ('BUR', 3),
#  ('CRY', 3),
#  ('BOU', 3),
#  ('EVE', 3),
#  ('WHU', 3),
#  ('WOL', 3),
#  ('SOU', 3),
#  ('NEW', 3),
#  ('WAT', 3),
#  ('BHA', 2),
#  ('SHU', 2),
#  ('AVL', 2),
#  ('NOR', 2)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

sorted_data = sorted(scores.items(), key = lambda x: x[1], reverse = True)

Team = [item[0] for item in sorted_data]
strength = [item[1] for item in sorted_data]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
schedule_df.columns
# Out:
# Index(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brighton', 'Burnley',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Leicester', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Sheffield Utd',
#        'Southampton', 'Spurs', 'Watford', 'West Ham', 'Wolves'],
#       dtype='object')

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
def avg_FDR(week = gameweek, periods = next_n_games):
    dic = {}
    for team in schedule_df.columns:
        oponents = schedule_df[team][(week-1):(week+periods)]
        avg_FDR = round(sum([scores[oponent] for oponent in oponents])/len(oponents), 2)
        dic[team] = avg_FDR
    return dic

# %%
calculate_FDR = avg_FDR()

# %%
sorted(calculate_FDR.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('Watford', 4.0),
#  ('Brighton', 3.67),
#  ('Leicester', 3.67),
#  ('Norwich', 3.67),
#  ('Aston Villa', 3.33),
#  ('Chelsea', 3.33),
#  ('Liverpool', 3.33),
#  ('Newcastle', 3.33),
#  ('Sheffield Utd', 3.33),
#  ('Spurs', 3.33),
#  ('Wolves', 3.33),
#  ('Arsenal', 3.0),
#  ('Bournemouth', 3.0),
#  ('Burnley', 3.0),
#  ('Crystal Palace', 3.0),
#  ('Man Utd', 3.0),
#  ('Southampton', 3.0),
#  ('Everton', 2.67),
#  ('West Ham', 2.67),
#  ('Man City', 2.33)]

# %%
sorted_FDR = sorted(calculate_FDR.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_FDR
# Out:
# [('Watford', 4.0),
#  ('Brighton', 3.67),
#  ('Leicester', 3.67),
#  ('Norwich', 3.67),
#  ('Aston Villa', 3.33),
#  ('Chelsea', 3.33),
#  ('Liverpool', 3.33),
#  ('Newcastle', 3.33),
#  ('Sheffield Utd', 3.33),
#  ('Spurs', 3.33),
#  ('Wolves', 3.33),
#  ('Arsenal', 3.0),
#  ('Bournemouth', 3.0),
#  ('Burnley', 3.0),
#  ('Crystal Palace', 3.0),
#  ('Man Utd', 3.0),
#  ('Southampton', 3.0),
#  ('Everton', 2.67),
#  ('West Ham', 2.67),
#  ('Man City', 2.33)]

# %%
rcParams['figure.figsize'] = 14, 6

Team = [item[0] for item in sorted_FDR]
FDR = [item[1] for item in sorted_FDR]
cutoff = 3.56

plt.bar(Team, FDR)
plt.axhline(y=cutoff, linestyle='-', color='#33D977', label='Cutoff Difficulty = ' + str(cutoff))
plt.ylabel('AVG Opponent Difficulty', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('AVG Opponenet Difficulty Next ' + str(next_n_games +1) + ' Games', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Clean final list of available players by FDR score <= 3.56 and status = 'available'

# %%
player_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %%
player_df.shape
# Out:
# (529, 14)

# %%
clean_df = player_df[player_df.status == 'available']

# %%
clean_df.status.value_counts()
# Out:
# available    414
# Name: status, dtype: int64

# %% [markdown]
# ## Remove teams with FDR scores > 3.56 from DF - optional

# %%
teams_low_FDR = [key for (key,value) in calculate_FDR.items() if value <= 3.56]

# %%
teams_low_FDR
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'West Ham',
#  'Wolves']

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %%
final_df = clean_df.loc[clean_df.team_name.isin(teams_low_FDR)]

# %%
final_df.head(15)
# Out:
#      bonus  cost  minutes                           name    position  \
# 374      4   4.2      257                 John Lundstram    Defender
# 118      4   6.6      250                  Ashley Barnes     Forward
# 132      2   4.6      270                   Erik Pieters    Defender
# 516      2   5.0      270  Rui Pedro dos Santos Patrício  Goalkeeper
# 161      2   5.5      270            Patrick van Aanholt    Defender
# 371      3   4.5      270                 George Baldock    Defender
# 48       3   4.5      270                   Tyrone Mings    Defender
# 185      4   5.6      270                     Yerry Mina    Defender
# 510      5   5.0      270                     Willy Boly    Defender
# 184      2   6.0      252                    Lucas Digne    Defender
# 3        3   5.1      270         Ainsley Maitland-Niles    Defender
# 121      1   4.5      270                      Nick Pope  Goalkeeper
# 53       2   4.5      188   Douglas Luiz Soares de Paulo  Midfielder
# 271      4  12.2      270                Raheem Sterling  Midfielder
# 186      2   5.5      270                  Michael Keane    Defender
#
#      pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 374           5.93          0  4.05  available         49   Sheffield Utd
# 118           8.96          0  3.79  available         90         Burnley
# 132           5.65          0  3.70  available         90         Burnley
# 516           5.98          0  3.60  available         39          Wolves
# 161           5.98          0  3.27  available         31  Crystal Palace
# 371           4.65          0  3.11  available         49   Sheffield Utd
# 48            4.65          0  3.11  available          7     Aston Villa
# 185           5.65          0  3.04  available         11         Everton
# 510           4.98          0  3.00  available         39          Wolves
# 184           6.40          0  3.00  available         11         Everton
# 3             4.98          0  2.94  available          3         Arsenal
# 121           4.32          0  2.89  available         90         Burnley
# 53            6.19          0  2.89  available          7     Aston Villa
# 271          11.29          0  2.79  available         43        Man City
# 186           4.98          0  2.73  available         11         Everton
#
#      total_points  transfers_in  transfers_out
# 374            17        764356          70880
# 118            25        576469         140415
# 132            17        378392          88959
# 516            18        218974          58834
# 161            18        172764          88280
# 371            14         17223           5264
# 48             14        141045          40018
# 185            17        280807          85465
# 510            15        150398          88763
# 184            18        402412         235570
# 3              15        316013         116872
# 121            13        310764          92317
# 53             13        246338          54203
# 271            34        877394          75026
# 186            15         80334          45409

# %%
clean_players = final_df.to_dict('records')

# %%
clean_players[:2]
# Out:
# [{'bonus': 4,
#   'cost': 4.2,
#   'minutes': 257,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 5.93,
#   'red_cards': 0,
#   'roi': 4.05,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 17,
#   'transfers_in': 764356,
#   'transfers_out': 70880},
#  {'bonus': 4,
#   'cost': 6.6,
#   'minutes': 250,
#   'name': 'Ashley Barnes',
#   'position': 'Forward',
#   'pts_per_90min': 8.96,
#   'red_cards': 0,
#   'roi': 3.79,
#   'status': 'available',
#   'team_code': 90,
#   'team_name': 'Burnley',
#   'total_points': 25,
#   'transfers_in': 576469,
#   'transfers_out': 140415}]

# %% [markdown]
# ## Get list of players by ROI, Total Points and Points Per 90 min

# %%
players_roi = sorted(clean_players, key = lambda x: x['roi'], reverse = True)

# %%
players_roi[:3]
# Out:
# [{'bonus': 4,
#   'cost': 4.2,
#   'minutes': 257,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 5.93,
#   'red_cards': 0,
#   'roi': 4.05,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 17,
#   'transfers_in': 764356,
#   'transfers_out': 70880},
#  {'bonus': 4,
#   'cost': 6.6,
#   'minutes': 250,
#   'name': 'Ashley Barnes',
#   'position': 'Forward',
#   'pts_per_90min': 8.96,
#   'red_cards': 0,
#   'roi': 3.79,
#   'status': 'available',
#   'team_code': 90,
#   'team_name': 'Burnley',
#   'total_points': 25,
#   'transfers_in': 576469,
#   'transfers_out': 140415},
#  {'bonus': 2,
#   'cost': 4.6,
#   'minutes': 270,
#   'name': 'Erik Pieters',
#   'position': 'Defender',
#   'pts_per_90min': 5.65,
#   'red_cards': 0,
#   'roi': 3.7,
#   'status': 'available',
#   'team_code': 90,
#   'team_name': 'Burnley',
#   'total_points': 17,
#   'transfers_in': 378392,
#   'transfers_out': 88959}]

# %% [markdown]
# ### Total Points

# %%
players_max_pts = sorted(players_roi, key = lambda x: x['total_points'], reverse = True)

# %%
players_max_pts[:3]
# Out:
# [{'bonus': 4,
#   'cost': 12.2,
#   'minutes': 270,
#   'name': 'Raheem Sterling',
#   'position': 'Midfielder',
#   'pts_per_90min': 11.29,
#   'red_cards': 0,
#   'roi': 2.79,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 34,
#   'transfers_in': 877394,
#   'transfers_out': 75026},
#  {'bonus': 5,
#   'cost': 12.5,
#   'minutes': 258,
#   'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'pts_per_90min': 10.42,
#   'red_cards': 0,
#   'roi': 2.4,
#   'status': 'available',
#   'team_code': 14,
#   'team_name': 'Liverpool',
#   'total_points': 30,
#   'transfers_in': 428216,
#   'transfers_out': 474724},
#  {'bonus': 4,
#   'cost': 6.6,
#   'minutes': 250,
#   'name': 'Ashley Barnes',
#   'position': 'Forward',
#   'pts_per_90min': 8.96,
#   'red_cards': 0,
#   'roi': 3.79,
#   'status': 'available',
#   'team_code': 90,
#   'team_name': 'Burnley',
#   'total_points': 25,
#   'transfers_in': 576469,
#   'transfers_out': 140415}]

# %% [markdown]
# ### Per 90 mins played

# %%
players_90min = sorted(players_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = (gameweek*90)/2.5
players_90min = [player for player in players_90min if player['minutes'] >= min_min]

# %%
players_90min[:3]
# Out:
# [{'bonus': 3,
#   'cost': 12.0,
#   'minutes': 176,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 12.2,
#   'red_cards': 0,
#   'roi': 2.0,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 24,
#   'transfers_in': 268991,
#   'transfers_out': 254144},
#  {'bonus': 4,
#   'cost': 12.2,
#   'minutes': 270,
#   'name': 'Raheem Sterling',
#   'position': 'Midfielder',
#   'pts_per_90min': 11.29,
#   'red_cards': 0,
#   'roi': 2.79,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 34,
#   'transfers_in': 877394,
#   'transfers_out': 75026},
#  {'bonus': 5,
#   'cost': 12.5,
#   'minutes': 258,
#   'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'pts_per_90min': 10.42,
#   'red_cards': 0,
#   'roi': 2.4,
#   'status': 'available',
#   'team_code': 14,
#   'team_name': 'Liverpool',
#   'total_points': 30,
#   'transfers_in': 428216,
#   'transfers_out': 474724}]

# %% [markdown]
# ### Create player lists by position and metric we want to select by

# %%
GK_roi = [item for item in players_roi if item['position'] == 'Goalkeeper']
DF_roi = [item for item in players_roi if item['position'] == 'Defender']
MD_roi = [item for item in players_roi if item['position'] == 'Midfielder']
ST_roi = [item for item in players_roi if item['position'] == 'Forward']

# %%
GK_pts = [item for item in players_max_pts if item['position'] == 'Goalkeeper']
DF_pts = [item for item in players_max_pts if item['position'] == 'Defender']
MD_pts = [item for item in players_max_pts if item['position'] == 'Midfielder']
ST_pts = [item for item in players_max_pts if item['position'] == 'Forward']

# %%
GK_90min = [item for item in players_90min if item['position'] == 'Goalkeeper']
DF_90min = [item for item in players_90min if item['position'] == 'Defender']
MD_90min = [item for item in players_90min if item['position'] == 'Midfielder']
ST_90min = [item for item in players_90min if item['position'] == 'Forward']

# %% [markdown]
# ## Start by selecting top GKs by ROI

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_roi:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 10.0
# Player Selected: Rui Pedro dos Santos Patrício
# GK budget left: 5.0
# Player Selected: Nick Pope
# GK budget left: 0.5
# ['Rui Pedro dos Santos Patrício', 'Nick Pope']
# ['Wolves', 'Burnley']

# %% [markdown]
# ## Select Top player by points from DF, MD, ST

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 22.5 42.0 26.0
# Player Selected: Patrick van Aanholt
# DF budget left: 17.0
# Player Selected: Raheem Sterling
# MD budget left: 29.8
# ['Rui Pedro dos Santos Patrício', 'Nick Pope', 'Patrick van Aanholt', 'Raheem Sterling']
# ['Wolves', 'Burnley', 'Crystal Palace', 'Man City']

# %%
ST_pts[:3]
# Out:
# [{'bonus': 4,
#   'cost': 6.6,
#   'minutes': 250,
#   'name': 'Ashley Barnes',
#   'position': 'Forward',
#   'pts_per_90min': 8.96,
#   'red_cards': 0,
#   'roi': 3.79,
#   'status': 'available',
#   'team_code': 90,
#   'team_name': 'Burnley',
#   'total_points': 25,
#   'transfers_in': 576469,
#   'transfers_out': 140415},
#  {'bonus': 3,
#   'cost': 12.0,
#   'minutes': 176,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 12.2,
#   'red_cards': 0,
#   'roi': 2.0,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 24,
#   'transfers_in': 268991,
#   'transfers_out': 254144},
#  {'bonus': 4,
#   'cost': 8.7,
#   'minutes': 263,
#   'name': 'Marcus Rashford',
#   'position': 'Forward',
#   'pts_per_90min': 6.48,
#   'red_cards': 0,
#   'roi': 2.18,
#   'status': 'available',
#   'team_code': 1,
#   'team_name': 'Man Utd',
#   'total_points': 19,
#   'transfers_in': 716725,
#   'transfers_out': 346174}]

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Ashley Barnes
# ST budget left: 19.4
# 5
# ['Rui Pedro dos Santos Patrício', 'Nick Pope', 'Patrick van Aanholt', 'Raheem Sterling', 'Ashley Barnes']
# ['Wolves', 'Burnley', 'Crystal Palace', 'Man City', 'Burnley']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with top ROI players

# %%
for item in DF_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Martin Kelly
# DF budget left: 4.100000000000001
# Player Selected: Diego Rico
# DF budget left: 0.10000000000000142
# 9
# ['Rui Pedro dos Santos Patrício', 'Nick Pope', 'Patrick van Aanholt', 'Raheem Sterling', 'Ashley Barnes', 'John Lundstram', 'Erik Pieters', 'Martin Kelly', 'Diego Rico']
# ['Wolves', 'Burnley', 'Crystal Palace', 'Man City', 'Burnley', 'Sheffield Utd', 'Burnley', 'Crystal Palace', 'Bournemouth']

# %% [markdown]
# ## Fill MD position

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Douglas Luiz Soares de Paulo
# MD budget left: 25.400000000000002
# Player Selected: John McGinn
# MD budget left: 19.800000000000004
# Player Selected: Erik Lamela
# MD budget left: 13.800000000000004
# Player Selected: Daniel Ceballos Fernández
# MD budget left: 8.200000000000005
# 13
# ['Rui Pedro dos Santos Patrício', 'Nick Pope', 'Patrick van Aanholt', 'Raheem Sterling', 'Ashley Barnes', 'John Lundstram', 'Erik Pieters', 'Martin Kelly', 'Diego Rico', 'Douglas Luiz Soares de Paulo', 'John McGinn', 'Erik Lamela', 'Daniel Ceballos Fernández']
# ['Wolves', 'Burnley', 'Crystal Palace', 'Man City', 'Burnley', 'Sheffield Utd', 'Burnley', 'Crystal Palace', 'Bournemouth', 'Aston Villa', 'Aston Villa', 'Spurs', 'Arsenal']

# %% [markdown]
# ## Fill ST position

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Divock Origi
# ST budget left: 22.1
# Player Selected: Jordan Ayew
# ST budget left: 17.1
# 15
# ['Rui Pedro dos Santos Patrício', 'Nick Pope', 'Patrick van Aanholt', 'Raheem Sterling', 'Ashley Barnes', 'John Lundstram', 'Erik Pieters', 'Martin Kelly', 'Diego Rico', 'Douglas Luiz Soares de Paulo', 'John McGinn', 'Erik Lamela', 'Daniel Ceballos Fernández', 'Divock Origi', 'Jordan Ayew']
# ['Wolves', 'Burnley', 'Crystal Palace', 'Man City', 'Burnley', 'Sheffield Utd', 'Burnley', 'Crystal Palace', 'Bournemouth', 'Aston Villa', 'Aston Villa', 'Spurs', 'Arsenal', 'Liverpool', 'Crystal Palace']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                           name    position  \
# 0       2   5.0      270  Rui Pedro dos Santos Patrício  Goalkeeper
# 1       1   4.5      270                      Nick Pope  Goalkeeper
# 2       2   5.5      270            Patrick van Aanholt    Defender
# 3       4  12.2      270                Raheem Sterling  Midfielder
# 4       4   6.6      250                  Ashley Barnes     Forward
# 5       4   4.2      257                 John Lundstram    Defender
# 6       2   4.6      270                   Erik Pieters    Defender
# 7       0   4.1      270                   Martin Kelly    Defender
# 8       0   4.0       90                     Diego Rico    Defender
# 9       2   4.5      188   Douglas Luiz Soares de Paulo  Midfielder
# 10      0   5.6      270                    John McGinn  Midfielder
# 11      2   6.0      232                    Erik Lamela  Midfielder
# 12      3   5.6      168      Daniel Ceballos Fernández  Midfielder
# 13      3   5.5       84                   Divock Origi     Forward
# 14      3   5.0      138                    Jordan Ayew     Forward
#
#     pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 0            5.98          0  3.60  available         39          Wolves
# 1            4.32          0  2.89  available         90         Burnley
# 2            5.98          0  3.27  available         31  Crystal Palace
# 3           11.29          0  2.79  available         43        Man City
# 4            8.96          0  3.79  available         90         Burnley
# 5            5.93          0  4.05  available         49   Sheffield Utd
# 6            5.65          0  3.70  available         90         Burnley
# 7            3.32          0  2.44  available         31  Crystal Palace
# 8            1.98          0  0.50  available         91     Bournemouth
# 9            6.19          0  2.89  available          7     Aston Villa
# 10           4.98          0  2.68  available          7     Aston Villa
# 11           5.79          0  2.50  available          6           Spurs
# 12           7.46          0  2.50  available          3         Arsenal
# 13          13.76          0  2.36  available         14       Liverpool
# 14           7.12          0  2.20  available         31  Crystal Palace
#
#     total_points  transfers_in  transfers_out
# 0             18        218974          58834
# 1             13        310764          92317
# 2             18        172764          88280
# 3             34        877394          75026
# 4             25        576469         140415
# 5             17        764356          70880
# 6             17        378392          88959
# 7             10        436881         168059
# 8              2        152182         109532
# 9             13        246338          54203
# 10            15        334831         113024
# 11            15        163213          58151
# 12            14        694079         164583
# 13            13        289454         249085
# 14            11        174523         100332

# %% [markdown]
# ### Top 10 ROI players by position

# %%
GK_df = pd.DataFrame(GK_roi)
GK_df.head(10)
# Out:
#    bonus  cost  minutes                           name    position  \
# 0      2   5.0      270  Rui Pedro dos Santos Patrício  Goalkeeper
# 1      1   4.5      270                      Nick Pope  Goalkeeper
# 2      2   4.5      270                 Dean Henderson  Goalkeeper
# 3      1   5.6      270                Jordan Pickford  Goalkeeper
# 4      2   5.6      270                   David de Gea  Goalkeeper
# 5      0   4.5      270                     Angus Gunn  Goalkeeper
# 6      1   5.0      270                     Bernd Leno  Goalkeeper
# 7      0   4.5      270                     Tom Heaton  Goalkeeper
# 8      0   5.0      270                Martin Dubravka  Goalkeeper
# 9      0   5.0      270                 Vicente Guaita  Goalkeeper
#
#    pts_per_90min  red_cards   roi     status  team_code       team_name  \
# 0           5.98          0  3.60  available         39          Wolves
# 1           4.32          0  2.89  available         90         Burnley
# 2           3.99          0  2.67  available         49   Sheffield Utd
# 3           4.65          0  2.50  available         11         Everton
# 4           4.32          0  2.32  available          1         Man Utd
# 5           3.32          0  2.22  available         20     Southampton
# 6           3.65          0  2.20  available          3         Arsenal
# 7           2.99          0  2.00  available          7     Aston Villa
# 8           3.32          0  2.00  available          4       Newcastle
# 9           2.99          0  1.80  available         31  Crystal Palace
#
#    total_points  transfers_in  transfers_out
# 0            18        218974          58834
# 1            13        310764          92317
# 2            12         51593          21448
# 3            14        258401         111134
# 4            13        547450         177462
# 5            10         15040          11629
# 6            11        152061         117341
# 7             9         95836          73230
# 8            10          9658          13726
# 9             9         14009          10808

# %%
DF_df = pd.DataFrame(DF_roi)
DF_df.head(10)
# Out:
#    bonus  cost  minutes                    name  position  pts_per_90min  \
# 0      4   4.2      257          John Lundstram  Defender           5.93
# 1      2   4.6      270            Erik Pieters  Defender           5.65
# 2      2   5.5      270     Patrick van Aanholt  Defender           5.98
# 3      3   4.5      270          George Baldock  Defender           4.65
# 4      3   4.5      270            Tyrone Mings  Defender           4.65
# 5      4   5.6      270              Yerry Mina  Defender           5.65
# 6      5   5.0      270              Willy Boly  Defender           4.98
# 7      2   6.0      252             Lucas Digne  Defender           6.40
# 8      3   5.1      270  Ainsley Maitland-Niles  Defender           4.98
# 9      2   5.5      270           Michael Keane  Defender           4.98
#
#    red_cards   roi     status  team_code       team_name  total_points  \
# 0          0  4.05  available         49   Sheffield Utd            17
# 1          0  3.70  available         90         Burnley            17
# 2          0  3.27  available         31  Crystal Palace            18
# 3          0  3.11  available         49   Sheffield Utd            14
# 4          0  3.11  available          7     Aston Villa            14
# 5          0  3.04  available         11         Everton            17
# 6          0  3.00  available         39          Wolves            15
# 7          0  3.00  available         11         Everton            18
# 8          0  2.94  available          3         Arsenal            15
# 9          0  2.73  available         11         Everton            15
#
#    transfers_in  transfers_out
# 0        764356          70880
# 1        378392          88959
# 2        172764          88280
# 3         17223           5264
# 4        141045          40018
# 5        280807          85465
# 6        150398          88763
# 7        402412         235570
# 8        316013         116872
# 9         80334          45409

# %%
MD_df = pd.DataFrame(MD_roi)
MD_df.head(10)
# Out:
#    bonus  cost  minutes                          name    position  \
# 0      2   4.5      188  Douglas Luiz Soares de Paulo  Midfielder
# 1      4  12.2      270               Raheem Sterling  Midfielder
# 2      0   5.6      270                   John McGinn  Midfielder
# 3      2   6.0      232                   Erik Lamela  Midfielder
# 4      3   5.6      168     Daniel Ceballos Fernández  Midfielder
# 5      5  12.5      258                 Mohamed Salah  Midfielder
# 6      4   9.7      258               Kevin De Bruyne  Midfielder
# 7      1   6.0      128                  Harry Wilson  Midfielder
# 8      0   6.0      258                 Dwight McNeil  Midfielder
# 9      3   6.5      267                Manuel Lanzini  Midfielder
#
#    pts_per_90min  red_cards   roi     status  team_code    team_name  \
# 0           6.19          0  2.89  available          7  Aston Villa
# 1          11.29          0  2.79  available         43     Man City
# 2           4.98          0  2.68  available          7  Aston Villa
# 3           5.79          0  2.50  available          6        Spurs
# 4           7.46          0  2.50  available          3      Arsenal
# 5          10.42          0  2.40  available         14    Liverpool
# 6           7.99          0  2.37  available         43     Man City
# 7           9.77          0  2.33  available         91  Bournemouth
# 8           4.86          0  2.33  available         90      Burnley
# 9           5.04          0  2.31  available         21     West Ham
#
#    total_points  transfers_in  transfers_out
# 0            13        246338          54203
# 1            34        877394          75026
# 2            15        334831         113024
# 3            15        163213          58151
# 4            14        694079         164583
# 5            30        428216         474724
# 6            23        851645         185340
# 7            14        117176          44192
# 8            14          7286           9423
# 9            15        121575          40361

# %%
ST_df = pd.DataFrame(ST_roi)
ST_df.head(10)
# Out:
#    bonus  cost  minutes              name position  pts_per_90min  red_cards  \
# 0      4   6.6      250     Ashley Barnes  Forward           8.96          0
# 1      3   5.5       84      Divock Origi  Forward          13.76          0
# 2      3   5.0      138       Jordan Ayew  Forward           7.12          0
# 3      4   8.7      263   Marcus Rashford  Forward           6.48          0
# 4      3   6.0      253     Wesley Moraes  Forward           4.61          0
# 5      1   6.0      174        Danny Ings  Forward           6.69          0
# 6      3   7.1      168     Tammy Abraham  Forward           7.99          0
# 7      3   7.4      180  Sébastien Haller  Forward           7.46          0
# 8      3  12.0      176     Sergio Agüero  Forward          12.20          0
# 9      0   7.9      247     Callum Wilson  Forward           5.44          0
#
#     roi     status  team_code       team_name  total_points  transfers_in  \
# 0  3.79  available         90         Burnley            25        576469
# 1  2.36  available         14       Liverpool            13        289454
# 2  2.20  available         31  Crystal Palace            11        174523
# 3  2.18  available          1         Man Utd            19        716725
# 4  2.17  available          7     Aston Villa            13         82594
# 5  2.17  available         20     Southampton            13         54212
# 6  2.11  available          8         Chelsea            15        350279
# 7  2.03  available         21        West Ham            15        128140
# 8  2.00  available         43        Man City            24        268991
# 9  1.90  available         91     Bournemouth            15         72723
#
#    transfers_out
# 0         140415
# 1         249085
# 2         100332
# 3         346174
# 4          43145
# 5          58771
# 6         104418
# 7         132755
# 8         254144
# 9         512055

# %% [markdown]
# ## Define Clean df for graphing purposes

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %%
graph_roi = []
for row, player in clean_df.iterrows():
    playa = dict(name = player['name'], position = player.position, team=player.team_name, cost = player.cost, points = player.total_points, minutes = player.minutes, ROI = player.roi, pts_per_90min = player.pts_per_90min)
    graph_roi.append(playa)

# %%
GK_graph = clean_df[clean_df['position'] == 'Goalkeeper']
DF_graph = clean_df[clean_df['position'] == 'Defender']
MD_graph = clean_df[clean_df['position'] == 'Midfielder']
ST_graph = clean_df[clean_df['position'] == 'Forward']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %% [markdown]
# ## Top 10 Keepers

# %%
GK_x = GK_graph[:10].roi
GK_y = GK_graph[:10].name
GK_75th = round(GK_graph.describe().roi['75%'], 2)
GK_AVG = round(GK_graph.describe().roi['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK ROI = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK ROI = ' + str(GK_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders

# %%
DF_x = DF_graph[:10].roi
DF_y = DF_graph[:10].name
DF_75th = round(DF_graph.describe().roi['75%'], 2)
DF_AVG = round(DF_graph.describe().roi['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 MIdfielders

# %%
MD_x = MD_graph[:10].roi
MD_y = MD_graph[:10].name
MD_75th = round(MD_graph.describe().roi['75%'], 2)
MD_AVG = round(MD_graph.describe().roi['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD ROI = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD ROI = ' + str(MD_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers

# %%
ST_x = ST_graph[:10].roi
ST_y = ST_graph[:10].name
ST_75th = round(ST_graph.describe().roi['75%'], 2)
ST_AVG = round(ST_graph.describe().roi['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
team_df
# Out:
#           code  strength Team            name Played  W  L  D  GF GA  GD Pts
# Position
# 1           14         5  LIV       Liverpool      3  3  0  0   9  3  +6   9
# 2           43         5  MCI        Man City      3  2  0  1  10  3  +7   7
# 3            3         4  ARS         Arsenal      3  2  1  0   4  4   0   6
# 4           13         3  LEI       Leicester      3  1  0  2   3  2  +1   5
# 5            1         4  MUN         Man Utd      3  1  1  1   6  3  +3   4
# 6           90         3  BUR         Burnley      3  1  1  1   5  3  +2   4
# 7            6         4  TOT           Spurs      3  1  1  1   5  4  +1   4
# 8           36         2  BHA        Brighton      3  1  1  1   4  3  +1   4
# 9           49         2  SHU   Sheffield Utd      3  1  1  1   3  3   0   4
# 10          31         3  CRY  Crystal Palace      3  1  1  1   2  2   0   4
# 11          91         3  BOU     Bournemouth      3  1  1  1   4  5  -1   4
# 12          11         3  EVE         Everton      3  1  1  1   1  2  -1   4
# 13           8         4  CHE         Chelsea      3  1  1  1   4  7  -3   4
# 14          21         3  WHU        West Ham      3  1  1  1   4  7  -3   4
# 15          39         3  WOL          Wolves      3  0  0  3   2  2   0   3
# 16           7         2  AVL     Aston Villa      3  1  2  0   4  5  -1   3
# 17          45         2  NOR         Norwich      3  1  2  0   6  8  -2   3
# 18          20         3  SOU     Southampton      3  1  2  0   3  5  -2   3
# 19           4         3  NEW       Newcastle      3  1  2  0   2  4  -2   3
# 20          57         3  WAT         Watford      3  0  3  0   1  7  -6   0

# %% [markdown]
# ### Team Stats

# %%
teams_stats = team_df.iloc[:,2:12]

# %%
teams_stats.GF = [int(item) for item in teams_stats.GF]
teams_stats.GA = [int(item) for item in teams_stats.GA]

# %%
teams_stats
# Out:
#          Team            name Played  W  L  D  GF  GA  GD Pts
# Position
# 1         LIV       Liverpool      3  3  0  0   9   3  +6   9
# 2         MCI        Man City      3  2  0  1  10   3  +7   7
# 3         ARS         Arsenal      3  2  1  0   4   4   0   6
# 4         LEI       Leicester      3  1  0  2   3   2  +1   5
# 5         MUN         Man Utd      3  1  1  1   6   3  +3   4
# 6         BUR         Burnley      3  1  1  1   5   3  +2   4
# 7         TOT           Spurs      3  1  1  1   5   4  +1   4
# 8         BHA        Brighton      3  1  1  1   4   3  +1   4
# 9         SHU   Sheffield Utd      3  1  1  1   3   3   0   4
# 10        CRY  Crystal Palace      3  1  1  1   2   2   0   4
# 11        BOU     Bournemouth      3  1  1  1   4   5  -1   4
# 12        EVE         Everton      3  1  1  1   1   2  -1   4
# 13        CHE         Chelsea      3  1  1  1   4   7  -3   4
# 14        WHU        West Ham      3  1  1  1   4   7  -3   4
# 15        WOL          Wolves      3  0  0  3   2   2   0   3
# 16        AVL     Aston Villa      3  1  2  0   4   5  -1   3
# 17        NOR         Norwich      3  1  2  0   6   8  -2   3
# 18        SOU     Southampton      3  1  2  0   3   5  -2   3
# 19        NEW       Newcastle      3  1  2  0   2   4  -2   3
# 20        WAT         Watford      3  0  3  0   1   7  -6   0

# %% [markdown]
# ### Worst/ Best  Defence vs. Offence

# %%
worst_defence_df = teams_stats.sort_values(by = ['GA'], ascending = False)

# %%
worst_defence_df.head()
# Out:
#          Team         name Played  W  L  D  GF  GA  GD Pts
# Position
# 17        NOR      Norwich      3  1  2  0   6   8  -2   3
# 20        WAT      Watford      3  0  3  0   1   7  -6   0
# 13        CHE      Chelsea      3  1  1  1   4   7  -3   4
# 14        WHU     West Ham      3  1  1  1   4   7  -3   4
# 18        SOU  Southampton      3  1  2  0   3   5  -2   3

# %%
best_defence_df = teams_stats.sort_values(by = ['GA'], ascending = True)

# %%
best_defence_df.head()
# Out:
#          Team            name Played  W  L  D  GF  GA  GD Pts
# Position
# 10        CRY  Crystal Palace      3  1  1  1   2   2   0   4
# 15        WOL          Wolves      3  0  0  3   2   2   0   3
# 12        EVE         Everton      3  1  1  1   1   2  -1   4
# 4         LEI       Leicester      3  1  0  2   3   2  +1   5
# 9         SHU   Sheffield Utd      3  1  1  1   3   3   0   4

# %%
GA = list(zip(defence_df.name, defence_df.GA))
GA_bottom5 = GA[:5]
GA_top5 = sorted(GA[-5:], key = lambda x: x[1])

# %%
GA_bottom5, GA_top5
# Out:
# ([('Norwich', '8'),
#   ('Watford', '7'),
#   ('Chelsea', '7'),
#   ('West Ham', '7'),
#   ('Southampton', '5')],
#  [('Crystal Palace', '2'),
#   ('Everton', '2'),
#   ('Wolves', '2'),
#   ('Leicester', '2'),
#   ('Liverpool', '3')])

# %%
teams_stats.GA.median()
# Out:
# 3.5

# %%
X = [item[0] for item in GA_bottom5]
Y = [int(item[1]) for item in GA_bottom5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 5 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GA_top5]
Y = [int(item[1]) for item in GA_top5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 5 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
offense_df = teams_stats.sort_values(by = ['GF'], ascending = False)

# %%
offense_df.head()
# Out:
#          Team       name Played  W  L  D  GF  GA  GD Pts
# Position
# 2         MCI   Man City      3  2  0  1  10   3  +7   7
# 1         LIV  Liverpool      3  3  0  0   9   3  +6   9
# 17        NOR    Norwich      3  1  2  0   6   8  -2   3
# 5         MUN    Man Utd      3  1  1  1   6   3  +3   4
# 6         BUR    Burnley      3  1  1  1   5   3  +2   4

# %%
GF = list(zip(offense_df.name, offense_df.GF))
GF_top5 = GF[:5]
GF_bottom5 = GF[-5:]

# %%
GF_top5, GF_bottom5
# Out:
# ([('Man City', 10),
#   ('Liverpool', 9),
#   ('Norwich', 6),
#   ('Man Utd', 6),
#   ('Burnley', 5)],
#  [('Crystal Palace', 2),
#   ('Wolves', 2),
#   ('Newcastle', 2),
#   ('Everton', 1),
#   ('Watford', 1)])

# %%
X = [item[0] for item in GF_top5]
Y = [int(item[1]) for item in GF_top5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 5 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GF_bottom5]
Y = [int(item[1]) for item in GF_bottom5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 5 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stats_df = player_df[player_df.minutes >= min_min]

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %% [markdown]
# ### Cobine Team and Player Stats

# %%
team_dic = {item:[] for item in team_names}

for row, player in stats_df.iterrows():
    for name in team_names:
        if player.team_name == name:
            playa = dict(name = player['name'], position = player.position, cost = player.cost, minutes = player.minutes, 
                         points = player.total_points,  roi = player.roi, pts_per_90min = player.pts_per_90min, 
                         bonus = player.bonus, red_cards = player.red_cards)
            team_dic[name].append(playa)

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 348      6   7.0      262     Teemu Pukki     Forward          11.98
# 374      4   4.2      257  John Lundstram    Defender           5.93
# 357      2   4.7      270   Todd Cantwell  Midfielder           6.31
# 118      4   6.6      250   Ashley Barnes     Forward           8.96
# 132      2   4.6      270    Erik Pieters    Defender           5.65
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 348          0  5.00  available         45        Norwich            35
# 374          0  4.05  available         49  Sheffield Utd            17
# 357          0  4.04  available         45        Norwich            19
# 118          0  3.79  available         90        Burnley            25
# 132          0  3.70  available         90        Burnley            17
#
#      transfers_in  transfers_out
# 348       2015231          91732
# 374        764356          70880
# 357        826053          72154
# 118        576469         140415
# 132        378392          88959

# %%
team_dic['Liverpool']
# Out:
# [{'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'cost': 12.5,
#   'minutes': 258,
#   'points': 30,
#   'roi': 2.4,
#   'pts_per_90min': 10.42,
#   'bonus': 5,
#   'red_cards': 0},
#  {'name': 'Joel Matip',
#   'position': 'Defender',
#   'cost': 5.4,
#   'minutes': 180,
#   'points': 11,
#   'roi': 2.04,
#   'pts_per_90min': 5.47,
#   'bonus': 1,
#   'red_cards': 0},
#  {'name': 'Virgil van Dijk',
#   'position': 'Defender',
#   'cost': 6.5,
#   'minutes': 270,
#   'points': 12,
#   'roi': 1.85,
#   'pts_per_90min': 3.99,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Fabio Henrique Tavares',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 196,
#   'points': 9,
#   'roi': 1.64,
#   'pts_per_90min': 4.11,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'cost': 9.5,
#   'minutes': 260,
#   'points': 15,
#   'roi': 1.58,
#   'pts_per_90min': 5.17,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Trent Alexander-Arnold',
#   'position': 'Defender',
#   'cost': 7.0,
#   'minutes': 270,
#   'points': 11,
#   'roi': 1.57,
#   'pts_per_90min': 3.65,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Sadio Mané',
#   'position': 'Midfielder',
#   'cost': 11.5,
#   'minutes': 182,
#   'points': 17,
#   'roi': 1.48,
#   'pts_per_90min': 8.36,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'James Milner',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 98,
#   'points': 8,
#   'roi': 1.45,
#   'pts_per_90min': 7.27,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Adrián San Miguel del Castillo',
#   'position': 'Goalkeeper',
#   'cost': 4.5,
#   'minutes': 231,
#   'points': 6,
#   'roi': 1.33,
#   'pts_per_90min': 2.33,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Georginio Wijnaldum',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 248,
#   'points': 7,
#   'roi': 1.27,
#   'pts_per_90min': 2.53,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Jordan Henderson',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 181,
#   'points': 5,
#   'roi': 0.91,
#   'pts_per_90min': 2.47,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Andrew Robertson',
#   'position': 'Defender',
#   'cost': 6.9,
#   'minutes': 270,
#   'points': 6,
#   'roi': 0.87,
#   'pts_per_90min': 1.99,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Alex Oxlade-Chamberlain',
#   'position': 'Midfielder',
#   'cost': 6.4,
#   'minutes': 101,
#   'points': 3,
#   'roi': 0.47,
#   'pts_per_90min': 2.65,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Joseph Gomez',
#   'position': 'Defender',
#   'cost': 5.4,
#   'minutes': 90,
#   'points': 2,
#   'roi': 0.37,
#   'pts_per_90min': 1.98,
#   'bonus': 0,
#   'red_cards': 0}]

# %% [markdown]
# ### Get Final Stats per Team using Pandas

# %%
team_stats = {item:{} for item in team_names}

for team in team_names:
    active_players = len(stats_df[stats_df.team_name == team].cost)
    tot_cost = round(stats_df[stats_df.team_name == team].cost.sum(), 3)
    tot_pts = round(stats_df[stats_df.team_name == team].total_points.sum(), 3)
    avg_player_roi = round(tot_pts / tot_cost, 3)
    avg_pts_per_player = round(tot_pts / active_players, 3)
    
    stats = dict(active_players = active_players, tot_cost = tot_cost, tot_pts = tot_pts,
               avg_pts_per_player = avg_pts_per_player,  avg_player_roi =  avg_player_roi)
    
    team_stats[team].update(stats)

# %%
team_stats['Newcastle']
# Out:
# {'active_players': 12,
#  'tot_cost': 59.9,
#  'tot_pts': 97,
#  'avg_pts_per_player': 8.083,
#  'avg_player_roi': 1.619}

# %%
team_stats_df = pd.DataFrame(team_stats).T

# %%
team_stats_df.sort_values(by = ['avg_pts_per_player'], ascending = False, inplace = True)

# %%
team_stats_df
# Out:
#                 active_players  avg_player_roi  avg_pts_per_player  tot_cost  \
# Man City                  15.0           1.584              11.933     113.0
# Burnley                   11.0           2.190              11.727      58.9
# Man Utd                   11.0           1.738              11.091      70.2
# Wolves                    11.0           1.941              10.727      60.8
# Liverpool                 14.0           1.455              10.143      97.6
# Everton                   12.0           1.699              10.083      71.2
# Leicester                 12.0           1.735               9.917      68.6
# Aston Villa               13.0           1.945               9.846      65.8
# Brighton                  12.0           1.771               9.167      62.1
# Sheffield Utd             13.0           1.737               8.538      63.9
# Norwich                   12.0           1.723               8.500      59.2
# Arsenal                   13.0           1.430               8.462      76.9
# Newcastle                 12.0           1.619               8.083      59.9
# Spurs                     13.0           1.212               8.077      86.6
# Crystal Palace            14.0           1.411               7.571      75.1
# Southampton               13.0           1.381               7.077      66.6
# Bournemouth               13.0           1.279               6.846      69.6
# Chelsea                   14.0           1.024               6.071      83.0
# West Ham                  17.0           1.003               5.471      92.7
# Watford                   13.0           0.906               4.846      69.5
#
#                 tot_pts
# Man City          179.0
# Burnley           129.0
# Man Utd           122.0
# Wolves            118.0
# Liverpool         142.0
# Everton           121.0
# Leicester         119.0
# Aston Villa       128.0
# Brighton          110.0
# Sheffield Utd     111.0
# Norwich           102.0
# Arsenal           110.0
# Newcastle          97.0
# Spurs             105.0
# Crystal Palace    106.0
# Southampton        92.0
# Bournemouth        89.0
# Chelsea            85.0
# West Ham           93.0
# Watford            63.0
