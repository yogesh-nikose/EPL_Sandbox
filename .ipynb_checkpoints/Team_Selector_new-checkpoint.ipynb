# %% [markdown]
# ### Import Major Libraries

# %%
import json
import requests
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# ## Define Gameweek and Periods for FDR calculation

# %%
gameweek = 19
next_n_games = 2

#define percentage of time player needs to have played to be counted as active
min_min = ((gameweek-1)*90)/3.33     #<---- Currently 30% of playtime
print(min_min)
# Out:
# 486.48648648648646

# %% [markdown]
# ## Define Budget, Team Formation, and Budget Allocation by Position

# %%
#Budget
budget = 100

#Team Formation
DF = 3
MD = 4
ST = 3

#Total players needed per position
DF_max = 5
MD_max = 5
ST_max = 3

#Budget Allocation
GK_coef = 0.095
DF_coef = 0.285
MD_coef = 0.36
ST_coef = 0.26

print(sum([GK_coef, DF_coef, MD_coef, ST_coef]))
# Out:
# 1.0

# %% [markdown]
# ## Scraped list of Schedules

# %%
schedules = ['Arsenal NEW (A) BUR (H) LIV (A) TOT (H) WAT (A) AVL (H) MUN (A) BOU (H) SHU (A) CRY (H) WOL (H) LEI (A) SOU (H) NOR (A) BHA (H) WHU (A) MCI (H) EVE (A) BOU (A) CHE (H) MUN (H) CRY (A) SHU (H) CHE (A) BUR (A) NEW (H) EVE (H) MCI (A) WHU (H) BHA (A) SOU (A) NOR (H) WOL (A) LEI (H) TOT (A) LIV (H) AVL (A) WAT (H)',
 'Aston Villa TOT (A) BOU (H) EVE (H) CRY (A) WHU (H) ARS (A) BUR (H) NOR (A) BHA (H) MCI (A) LIV (H) WOL (A) NEW (H) MUN (A) CHE (A) LEI (H) SHU (A) SOU (H) NOR (H) WAT (A) BUR (A) MCI (H) BHA (A) WAT (H) BOU (A) TOT (H) SOU (A) SHU (H) LEI (A) CHE (H) NEW (A) WOL (H) LIV (A) MUN (H) CRY (H) EVE (A) ARS (H) WHU (A)',
 'Bournemouth SHU (H) AVL (A) MCI (H) LEI (A) EVE (H) SOU (A) WHU (H) ARS (A) NOR (H) WAT (A) MUN (H) NEW (A) WOL (H) TOT (A) CRY (A) LIV (H) CHE (A) BUR (H) ARS (H) BHA (A) WHU (A) WAT (H) NOR (A) BHA (H) AVL (H) SHU (A) BUR (A) CHE (H) LIV (A) CRY (H) WOL (A) NEW (H) MUN (A) TOT (H) LEI (H) MCI (A) SOU (H) EVE (A)',
 'Brighton WAT (A) WHU (H) SOU (H) MCI (A) BUR (H) NEW (A) CHE (A) TOT (H) AVL (A) EVE (H) NOR (H) MUN (A) LEI (H) LIV (A) ARS (A) WOL (H) CRY (A) SHU (H) TOT (A) BOU (H) CHE (H) EVE (A) AVL (H) BOU (A) WHU (A) WAT (H) SHU (A) CRY (H) WOL (A) ARS (H) LEI (A) MUN (H) NOR (A) LIV (H) MCI (H) SOU (A) NEW (H) BUR (A)',
 'Burnley SOU (H) ARS (A) WOL (A) LIV (H) BHA (A) NOR (H) AVL (A) EVE (H) LEI (A) CHE (H) SHU (A) WHU (H) WAT (A) CRY (H) MCI (H) TOT (A) NEW (H) BOU (A) EVE (A) MUN (H) AVL (H) CHE (A) LEI (H) MUN (A) ARS (H) SOU (A) BOU (H) NEW (A) TOT (H) MCI (A) WAT (H) CRY (A) SHU (H) WHU (A) LIV (A) WOL (H) NOR (A) BHA (H)',
 'Chelsea MUN (A) LEI (H) NOR (A) SHU (H) WOL (A) LIV (H) BHA (H) SOU (A) NEW (H) BUR (A) WAT (A) CRY (H) MCI (A) WHU (H) AVL (H) EVE (A) BOU (H) TOT (A) SOU (H) ARS (A) BHA (A) BUR (H) NEW (A) ARS (H) LEI (A) MUN (H) TOT (H) BOU (A) EVE (H) AVL (A) MCI (H) WHU (A) WAT (H) CRY (A) SHU (A) NOR (H) LIV (A) WOL (H)',
 'Crystal Palace EVE (H) SHU (A) MUN (A) AVL (H) TOT (A) WOL (H) NOR (H) WHU (A) MCI (H) ARS (A) LEI (H) CHE (A) LIV (H) BUR (A) BOU (H) WAT (A) BHA (H) NEW (A) WHU (H) SOU (A) NOR (A) ARS (H) MCI (A) SOU (H) SHU (H) EVE (A) NEW (H) BHA (A) WAT (H) BOU (A) LIV (A) BUR (H) LEI (A) CHE (H) AVL (A) MUN (H) WOL (A) TOT (H)',
 'Everton CRY (A) WAT (H) AVL (A) WOL (H) BOU (A) SHU (H) MCI (H) BUR (A) WHU (H) BHA (A) TOT (H) SOU (A) NOR (H) LEI (A) LIV (A) CHE (H) MUN (A) ARS (H) BUR (H) NEW (A) MCI (A) BHA (H) WHU (A) NEW (H) WAT (A) CRY (H) ARS (A) MUN (H) CHE (A) LIV (H) NOR (A) LEI (H) TOT (A) SOU (H) WOL (A) AVL (H) SHU (A) BOU (H)',
 'Leicester WOL (H) CHE (A) SHU (A) BOU (H) MUN (A) TOT (H) NEW (H) LIV (A) BUR (H) SOU (A) CRY (A) ARS (H) BHA (A) EVE (H) WAT (H) AVL (A) NOR (H) MCI (A) LIV (H) WHU (A) NEW (A) SOU (H) BUR (A) WHU (H) CHE (H) WOL (A) MCI (H) NOR (A) AVL (H) WAT (A) BHA (H) EVE (A) CRY (H) ARS (A) BOU (A) SHU (H) TOT (A) MUN (H)',
 'Liverpool NOR (H) SOU (A) ARS (H) BUR (A) NEW (H) CHE (A) SHU (A) LEI (H) MUN (A) TOT (H) AVL (A) MCI (H) CRY (A) BHA (H) EVE (H) BOU (A) WAT (H) WHU (A) LEI (A) WOL (H) SHU (H) TOT (A) MUN (H) WOL (A) SOU (H) NOR (A) WHU (H) WAT (A) BOU (H) EVE (A) CRY (H) MCI (A) AVL (H) BHA (A) BUR (H) ARS (A) CHE (H) NEW (A)',
 'Man City WHU (A) TOT (H) BOU (A) BHA (H) NOR (A) WAT (H) EVE (A) WOL (H) CRY (A) AVL (H) SOU (H) LIV (A) CHE (H) NEW (A) BUR (A) MUN (H) ARS (A) LEI (H) WOL (A) SHU (H) EVE (H) AVL (A) CRY (H) SHU (A) TOT (A) WHU (H) LEI (A) ARS (H) MUN (A) BUR (H) CHE (A) LIV (H) SOU (A) NEW (H) BHA (A) BOU (H) WAT (A) NOR (H)',
 'Man Utd CHE (H) WOL (A) CRY (H) SOU (A) LEI (H) WHU (A) ARS (H) NEW (A) LIV (H) NOR (A) BOU (A) BHA (H) SHU (A) AVL (H) TOT (H) MCI (A) EVE (H) WAT (A) NEW (H) BUR (A) ARS (A) NOR (H) LIV (A) BUR (H) WOL (H) CHE (A) WAT (H) EVE (A) MCI (H) TOT (A) SHU (H) BHA (A) BOU (H) AVL (A) SOU (H) CRY (A) WHU (H) LEI (A)',
 'Newcastle ARS (H) NOR (A) TOT (A) WAT (H) LIV (A) BHA (H) LEI (A) MUN (H) CHE (A) WOL (H) WHU (A) BOU (H) AVL (A) MCI (H) SHU (A) SOU (H) BUR (A) CRY (H) MUN (A) EVE (H) LEI (H) WOL (A) CHE (H) EVE (A) NOR (H) ARS (A) CRY (A) BUR (H) SOU (A) SHU (H) AVL (H) BOU (A) WHU (H) MCI (A) WAT (A) TOT (H) BHA (A) LIV (H)',
 'Norwich LIV (A) NEW (H) CHE (H) WHU (A) MCI (H) BUR (A) CRY (A) AVL (H) BOU (A) MUN (H) BHA (A) WAT (H) EVE (A) ARS (H) SOU (A) SHU (H) LEI (A) WOL (H) AVL (A) TOT (H) CRY (H) MUN (A) BOU (H) TOT (A) NEW (A) LIV (H) WOL (A) LEI (H) SHU (A) SOU (H) EVE (H) ARS (A) BHA (H) WAT (A) WHU (H) CHE (A) BUR (H) MCI (A)',
 'Sheffield Utd BOU (A) CRY (H) LEI (H) CHE (A) SOU (H) EVE (A) LIV (H) WAT (A) ARS (H) WHU (A) BUR (H) TOT (A) MUN (H) WOL (A) NEW (H) NOR (A) AVL (H) BHA (A) WAT (H) MCI (A) LIV (A) WHU (H) ARS (A) MCI (H) CRY (A) BOU (H) BHA (H) AVL (A) NOR (H) NEW (A) MUN (A) TOT (H) BUR (A) WOL (H) CHE (H) LEI (A) EVE (H) SOU (A)',
 'Southampton BUR (A) LIV (H) BHA (A) MUN (H) SHU (A) BOU (H) TOT (A) CHE (H) WOL (A) LEI (H) MCI (A) EVE (H) ARS (A) WAT (H) NOR (H) NEW (A) WHU (H) AVL (A) CHE (A) CRY (H) TOT (H) LEI (A) WOL (H) CRY (A) LIV (A) BUR (H) AVL (H) WHU (A) NEW (H) NOR (A) ARS (H) WAT (A) MCI (H) EVE (A) MUN (A) BHA (H) BOU (A) SHU (H)',
 'Spurs AVL (H) MCI (A) NEW (H) ARS (A) CRY (H) LEI (A) SOU (H) BHA (A) WAT (H) LIV (A) EVE (A) SHU (H) WHU (A) BOU (H) MUN (A) BUR (H) WOL (A) CHE (H) BHA (H) NOR (A) SOU (A) LIV (H) WAT (A) NOR (H) MCI (H) AVL (A) CHE (A) WOL (H) BUR (A) MUN (H) WHU (H) SHU (A) EVE (H) BOU (A) ARS (H) NEW (A) LEI (H) CRY (A)',
 'Watford BHA (H) EVE (A) WHU (H) NEW (A) ARS (H) MCI (A) WOL (A) SHU (H) TOT (A) BOU (H) CHE (H) NOR (A) BUR (H) SOU (A) LEI (A) CRY (H) LIV (A) MUN (H) SHU (A) AVL (H) WOL (H) BOU (A) TOT (H) AVL (A) EVE (H) BHA (A) MUN (A) LIV (H) CRY (A) LEI (H) BUR (A) SOU (H) CHE (A) NOR (H) NEW (H) WHU (A) MCI (H) ARS (A)',
 'West Ham MCI (H) BHA (A) WAT (A) NOR (H) AVL (A) MUN (H) BOU (A) CRY (H) EVE (A) SHU (H) NEW (H) BUR (A) TOT (H) CHE (A) WOL (A) ARS (H) SOU (A) LIV (H) CRY (A) LEI (H) BOU (H) SHU (A) EVE (H) LEI (A) BHA (H) MCI (A) LIV (A) SOU (H) ARS (A) WOL (H) TOT (A) CHE (H) NEW (A) BUR (H) NOR (A) WAT (H) MUN (A) AVL (H)',
 'Wolves LEI (A) MUN (H) BUR (H) EVE (A) CHE (H) CRY (A) WAT (H) MCI (A) SOU (H) NEW (A) ARS (A) AVL (H) BOU (A) SHU (H) WHU (H) BHA (A) TOT (H) NOR (A) MCI (H) LIV (A) WAT (A) NEW (H) SOU (A) LIV (H) MUN (A) LEI (H) NOR (H) TOT (A) BHA (H) WHU (A) BOU (H) AVL (A) ARS (H) SHU (A) EVE (H) BUR (A) CRY (H) CHE (A)']

# %% [markdown]
# ### Import Data

# %%
# url = "https://fantasy.premierleague.com/drf/bootstrap-static"
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %%
all_players[0]
# Out:
# {'chance_of_playing_next_round': 100,
#  'chance_of_playing_this_round': 100,
#  'code': 69140,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': -3,
#  'cost_change_start_fall': 3,
#  'dreamteam_count': 0,
#  'element_type': 2,
#  'ep_next': '1.2',
#  'ep_this': '1.2',
#  'event_points': 0,
#  'first_name': 'Shkodran',
#  'form': '0.7',
#  'id': 1,
#  'in_dreamteam': False,
#  'news': '',
#  'news_added': '2019-11-28T23:00:21.541666Z',
#  'now_cost': 52,
#  'photo': '69140.jpg',
#  'points_per_game': '4.0',
#  'second_name': 'Mustafi',
#  'selected_by_percent': '0.3',
#  'special': False,
#  'squad_number': None,
#  'status': 'a',
#  'team': 1,
#  'team_code': 3,
#  'total_points': 4,
#  'transfers_in': 7964,
#  'transfers_in_event': 59,
#  'transfers_out': 32375,
#  'transfers_out_event': 168,
#  'value_form': '0.1',
#  'value_season': '0.8',
#  'web_name': 'Mustafi',
#  'minutes': 90,
#  'goals_scored': 0,
#  'assists': 1,
#  'clean_sheets': 0,
#  'goals_conceded': 2,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 0,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 0,
#  'bps': 24,
#  'influence': '19.8',
#  'creativity': '0.8',
#  'threat': '54.0',
#  'ict_index': '7.5'}

# %% [markdown]
# ### Get Team Table

# %%
table_url = 'https://www.premierleague.com/tables'

def build_table(table_url):
    team_table = pd.read_html(table_url)
    team_df = pd.DataFrame(team_table[0])
    team_df = team_df[team_df['Unnamed: 12'].isna()]
    team_df = team_df.iloc[:,1:10]
    team_df.Club = team_df.Club.map(lambda x: x[-3:])
    team_df.reset_index()
    team_df.index = np.arange(1, len(team_df) + 1)
    team_df.columns = ['Team', 'Played', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']
    team_df.index.name = 'Position'
    
    return team_df

# %%
table_url = 'https://www.premierleague.com/tables'
team_table = pd.read_html(table_url)
team_table[0]
# Out:
#                                         Position  Pos  \
# 0                             1  Previous Position  1
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                             2  Previous Position  2
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                             3  Previous Position  3
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                             4  Previous Position  4
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                             5  Previous Position  7
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                            6  Previous Position  8
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                            7  Previous Position  5
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                            8  Previous Position  6
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                           9  Previous Position  11
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                          10  Previous Position  12
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                          11  Previous Position  10
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                           12  Previous Position  9
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                          13  Previous Position  13
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                          14  Previous Position  14
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                          15  Previous Position  16
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                          16  Previous Position  15
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                          17  Previous Position  18
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                          18  Previous Position  17
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                          19  Previous Position  19
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                          20  Previous Position  20
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                  Club  \
# 0                                        LiverpoolLIV
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                   Leicester CityLEI
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                  Manchester CityMCI
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                          ChelseaCHE
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                 Sheffield UnitedSHU
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                         Wolverhampton WanderersWOL
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                               Tottenham HotspurTOT
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                               Manchester UnitedMUN
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                Newcastle UnitedNEW
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                         BurnleyBUR
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                         ArsenalARS
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                  Crystal PalaceCRY
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                        Brighton and Hove AlbionBHA
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                     BournemouthBOU
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                         EvertonEVE
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                 West Ham UnitedWHU
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                     SouthamptonSOU
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                     Aston VillaAVL
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                    Norwich CityNOR
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                         WatfordWAT
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                            Played  Pl  \
# 0                                                  17
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                  18
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                  18
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  18
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                  18
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                 18
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                 18
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                 18
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                 18
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                 18
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                 18
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                 18
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                 18
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                 18
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                 18
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                 17
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                 18
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 18
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                 18
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                 18
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                Won  W  \
# 0                                                  16
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                  12
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                  12
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  10
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                   7
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                  6
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                  7
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                  6
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                  7
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                  7
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                  5
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                  6
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                  5
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                  5
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                  5
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                  5
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                  5
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                  4
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                  3
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                  2
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                              Drawn  D  \
# 0                                                   1
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                   3
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                   2
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                   2
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                   7
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                  9
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                  5
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                  7
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                  4
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                  3
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                  8
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                  5
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                  5
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                  4
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                  4
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                  4
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                  3
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                  3
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                  3
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                  6
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                               Lost  L  \
# 0                                                   0
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                   3
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                   4
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                   6
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                   4
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                  3
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                  6
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                  5
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                  7
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                  8
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                  5
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                  7
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                  8
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                  9
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                  9
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                  8
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                 10
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 11
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                 12
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                 10
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                    GF  \
# 0                                                  42
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                  41
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                  50
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  33
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                  22
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                 26
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                 32
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                 26
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                 18
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                 23
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                 24
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                 15
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                 21
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                 19
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                 20
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                 19
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                 21
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 24
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                 19
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                 11
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                    GA  \
# 0                                                  14
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                  14
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                  20
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  25
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                  16
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                 22
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                 26
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                 22
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                 24
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                 29
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                 27
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                 20
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                 26
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                 25
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                 29
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                 28
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                 37
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 33
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                 37
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                 32
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                    GD  \
# 0                                                 +28
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                 +27
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                 +30
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  +8
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                  +6
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                 +4
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                 +6
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                 +4
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                 -6
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                 -6
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                 -3
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                 -5
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                 -5
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                 -6
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                 -9
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                 -9
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                -16
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 -9
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                -18
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                -21
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                           Points  Pts  \
# 0                                                  49
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                  39
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                  38
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                  32
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                  28
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                 27
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                 26
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                 25
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                 25
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                 24
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                 23
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                 23
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                 20
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                 19
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                 19
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                 19
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                 18
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                 15
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                 12
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                 12
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                  Form  \
# 0   W  Saturday 23 November 2019  CRY  1 -2  LIV  ...
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2   W  Sunday 1 December 2019  LEI  2 -1  EVE  W  ...
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4   D  Saturday 30 November 2019  NEW  2 -2  MCI  ...
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6   L  Saturday 30 November 2019  CHE  0 -1  WHU  ...
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8   D  Sunday 1 December 2019  WOL  1 -1  SHU  L  ...
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10  D  Sunday 1 December 2019  WOL  1 -1  SHU  W  ...
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12  W  Saturday 30 November 2019  TOT  3 -2  BOU  ...
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14  D  Sunday 1 December 2019  MUN  2 -2  AVL  W  ...
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16  D  Saturday 30 November 2019  NEW  2 -2  MCI  ...
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18  L  Saturday 30 November 2019  BUR  0 -2  CRY  ...
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20  D  Sunday 1 December 2019  NOR  2 -2  ARS  L  ...
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22  W  Saturday 30 November 2019  BUR  0 -2  CRY  ...
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24  L  Saturday 30 November 2019  LIV  2 -1  BHA  ...
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26  L  Saturday 30 November 2019  TOT  3 -2  BOU  ...
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28  L  Sunday 1 December 2019  LEI  2 -1  EVE  L  ...
# 29  Everton  Recent Result - Saturday 21 December ...
# 30  L  Saturday 23 November 2019  WHU  2 -3  TOT  ...
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32  W  Saturday 30 November 2019  SOU  2 -1  WAT  ...
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34  D  Sunday 1 December 2019  MUN  2 -2  AVL  L  ...
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36  D  Sunday 1 December 2019  NOR  2 -2  ARS  L  ...
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38  L  Saturday 30 November 2019  SOU  2 -1  WAT  ...
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                                  Next  \
# 0   Leicester City  Thursday 26 December 2019  LEI...
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2   Liverpool  Thursday 26 December 2019  LEI  20:...
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4   Wolverhampton Wanderers  Friday 27 December 20...
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6   Southampton  Thursday 26 December 2019  CHE  1...
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8   Watford  Thursday 26 December 2019  SHU  15:00...
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10  Manchester City  Friday 27 December 2019  WOL ...
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12  Brighton and Hove Albion  Thursday 26 December...
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14  Newcastle United  Thursday 26 December 2019  M...
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16  Manchester United  Thursday 26 December 2019  ...
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18  Everton  Thursday 26 December 2019  EVE  15:00...
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20  AFC Bournemouth  Thursday 26 December 2019  BO...
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22  West Ham United  Thursday 26 December 2019  CR...
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24  Tottenham Hotspur  Thursday 26 December 2019  ...
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26  Arsenal  Thursday 26 December 2019  BOU  15:00...
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28  Burnley  Thursday 26 December 2019  EVE  15:00...
# 29  Everton  Recent Result - Saturday 21 December ...
# 30  Crystal Palace  Thursday 26 December 2019  CRY...
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32  Chelsea  Thursday 26 December 2019  CHE  15:00...
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34  Norwich City  Thursday 26 December 2019  AVL  ...
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36  Aston Villa  Thursday 26 December 2019  AVL  1...
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38  Sheffield United  Thursday 26 December 2019  S...
# 39  Watford  Recent Result - Sunday 22 December 20...
#
#                                           Unnamed: 12
# 0                                                 NaN
# 1   Liverpool  Recent Result - Saturday 14 Decembe...
# 2                                                 NaN
# 3   Leicester City  Recent Result - Saturday 21 De...
# 4                                                 NaN
# 5   Manchester City  Recent Result - Saturday 21 D...
# 6                                                 NaN
# 7   Chelsea  Recent Result - Sunday 22 December 20...
# 8                                                 NaN
# 9   Sheffield United  Recent Result - Saturday 21 ...
# 10                                                NaN
# 11  Wolverhampton Wanderers  Recent Result - Satur...
# 12                                                NaN
# 13  Tottenham Hotspur  Recent Result - Sunday 22 D...
# 14                                                NaN
# 15  Manchester United  Recent Result - Sunday 22 D...
# 16                                                NaN
# 17  Newcastle United  Recent Result - Saturday 21 ...
# 18                                                NaN
# 19  Burnley  Recent Result - Saturday 21 December ...
# 20                                                NaN
# 21  Arsenal  Recent Result - Saturday 21 December ...
# 22                                                NaN
# 23  Crystal Palace  Recent Result - Saturday 21 De...
# 24                                                NaN
# 25  Brighton and Hove Albion  Recent Result - Satu...
# 26                                                NaN
# 27  Bournemouth  Recent Result - Saturday 21 Decem...
# 28                                                NaN
# 29  Everton  Recent Result - Saturday 21 December ...
# 30                                                NaN
# 31  West Ham United  Recent Result - Saturday 14 D...
# 32                                                NaN
# 33  Southampton  Recent Result - Saturday 21 Decem...
# 34                                                NaN
# 35  Aston Villa  Recent Result - Saturday 21 Decem...
# 36                                                NaN
# 37  Norwich City  Recent Result - Saturday 21 Dece...
# 38                                                NaN
# 39  Watford  Recent Result - Sunday 22 December 20...

# %%
table_df = build_table(table_url)

# %%
table_df.head()
# Out:
#          Team Played   W  D  L  GF  GA   GD Pts
# Position
# 1         LIV     17  16  1  0  42  14  +28  49
# 2         LEI     18  12  3  3  41  14  +27  39
# 3         MCI     18  12  2  4  50  20  +30  38
# 4         CHE     18  10  2  6  33  25   +8  32
# 5         SHU     18   7  7  4  22  16   +6  28

# %% [markdown]
# ### Try dynamic FDR Score

# %%
#List of teams
name_list = list(table_df.Team)

#list of points as integers
pts_list = [int(item) for item in table_df.Pts]
top_pts = max(pts_list)

#list of GF as integers
GF_list = [int(item) for item in table_df.GF]
top_GF = max(GF_list)

#list of GA as integers
GA_list = [int(item) for item in table_df.GA]
top_GA = max(GA_list)

# %%
top_pts, top_GF, top_GA
# Out:
# (49, 50, 37)

# %%
name_list[:5]
# Out:
# ['LIV', 'LEI', 'MCI', 'CHE', 'SHU']

# %%
from scipy import stats
stats.percentileofscore(GF_list, 20)
# Out:
# 35.0

# %%
scaled = [pts_list, GF_list, GA_list]

# %% [markdown]
# ### Write Function to try scaled scores

# %%
def scaled_FDR(pts_list, GF_list, GA_list):
    #turn to array so you an use scaler
    arr_pts = np.array(pts_list).reshape(-1, 1)
    arr_GF = np.array(GF_list).reshape(-1, 1)
    arr_GA = np.array(GA_list).reshape(-1, 1)
    
    #instantiate scalers
    minmax = MinMaxScaler()
    robust = RobustScaler()
    
    #apply MinMax
    minmax_pts = minmax.fit_transform(arr_pts)
    minmax_GF = minmax.fit_transform(arr_GF)
    minmax_GA = minmax.fit_transform(arr_GA)
    
    #apply Robust
    robu_pts = robust.fit_transform(arr_pts)
    robu_GF = robust.fit_transform(arr_GF)
    robu_GA = robust.fit_transform(arr_GA)
    
    #add normalzied scores
    sum_minmax = (minmax_pts + minmax_GF + (1 - minmax_GA)).tolist()
    sum_robu = (robu_pts + robu_GF + minmax_GA*(-1)).tolist()
    
    minmax_fin = [item[0] for item in sum_minmax]
    robu_fin = [item[0] for item in sum_robu]
    
    return (minmax_fin, robu_fin)

# %%
scaled_scores = scaled_FDR(pts_list, GF_list, GA_list)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
scaled_scores[1]
# Out:
# [5.385026737967914,
#  4.055258467023172,
#  4.732000310005425,
#  1.7873362783848719,
#  0.3996744943036503,
#  0.4881810431682554,
#  0.8989382314190499,
#  0.24575680074401296,
#  -0.7823761915833527,
#  -0.532744323025653,
#  -0.4493528636751142,
#  -1.2038285669999222,
#  -1.122452142912501,
#  -1.4354801209021155,
#  -1.4917461055568473,
#  -1.5659149035108113,
#  -1.843137254901961,
#  -1.6799193985894751,
#  -2.805704099821747,
#  -3.529489266062156]

# %%
maybs = [item*2 for item in scaled_scores[0]]

# %%
maybs
# Out:
# [5.589743589743589,
#  4.997920997920998,
#  4.883666274970623,
#  3.2527644701557747,
#  3.255054385489168,
#  2.8843894061285367,
#  2.7902015728102687,
#  2.7762812980204283,
#  2.1921118442857574,
#  1.9596854379463076,
#  2.1308264786525664,
#  2.2779836692880173,
#  1.9017746843833803,
#  1.832113049504354,
#  1.5355690138298834,
#  1.5712434842869625,
#  0.8371448371448371,
#  1.1766549157853508,
#  0.41025641025641024,
#  0.43478260869565233]

# %%
Team = name_list
strength = maybs

mean_FDR = round(np.mean([item for item in maybs]), 2)
FDR_75 = round(np.percentile([item for item in maybs], 75), 2)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GF + GA) z-scores', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# import plotly.graph_objs as go


# fig = go.Figure([go.Bar(x=Team, y=strength, marker = {'color': '#82DFF1'})])
# fig.add_trace(go.Scatter(
#     x=['LIV', 'WAT'],
#     y=[mean_FDR, mean_FDR],
#     mode="lines",
# ))

# fig.layout.plot_bgcolor = '#082391'                
# fig.update_layout(
#     title='US Export of Plastic Scrap',
#     xaxis_tickfont_size=14,
#     yaxis=dict(
#         title='USD (millions)',
#         showgrid=False,
#         titlefont_size=16,
#         tickfont_size=14,
#     ))

# fig.write_image('figure.png')
# fig.show()

# %%
zipped_list = list(zip(name_list, pts_list, GF_list, GA_list))

# %%
zipped_list[:3]
# Out:
# [('LIV', 49, 42, 14), ('LEI', 39, 41, 14), ('MCI', 38, 50, 20)]

# %%
def get_percentiles(zipped_list):
    listy = []
    for item in zipped_list:
        team = item[0]
        pts_perc = stats.percentileofscore(pts_list, item[1])
        GF_perc = stats.percentileofscore(GF_list, item[2])
        GA_perc = stats.percentileofscore(GA_list, item[3])
        FDR = pts_perc + GF_perc + (100-GA_perc)
        tup = (team, FDR)
        listy.append(tup)
    return listy

# %%
FDR_new = get_percentiles(zipped_list)

# %%
FDR_new
# Out:
# [('LIV', 287.5),
#  ('LEI', 277.5),
#  ('MCI', 267.5),
#  ('CHE', 222.5),
#  ('SHU', 215.0),
#  ('WOL', 215.0),
#  ('TOT', 192.5),
#  ('MUN', 202.5),
#  ('NEW', 137.5),
#  ('BUR', 132.5),
#  ('ARS', 145.0),
#  ('CRY', 135.0),
#  ('BHA', 125.0),
#  ('BOU', 107.5),
#  ('EVE', 87.5),
#  ('WHU', 85.0),
#  ('SOU', 65.0),
#  ('AVL', 87.5),
#  ('NOR', 35.0),
#  ('WAT', 27.5)]

# %%
mean_FDR = np.mean([item[1] for item in FDR_new])

# %%
mean_FDR
# Out:
# 152.5

# %%
Team = [item[0] for item in FDR_new]
strength = [item[1] for item in FDR_new]

mean_FDR = np.mean([item[1] for item in FDR_new])
FDR_75 = np.percentile([item[1] for item in FDR_new], 75)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GA +GF) SUM', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to return percentile for each team

# %% [markdown]
# ## Add player status and ROI, pts-per-90min metrics to final player_df

# %%
def attach_team_and_position(main_players, all_teams, positons):
    players = main_players.copy()
    for team in all_teams:
        for player in players:
            if team['code'] == player['team_code']:
                player['team_name'] = team['name']
    for position in positions:
        for player in players:
            if position['id'] == player['element_type']:
                player['position'] = position['singular_name']
    for player in players:
        if player['status'] == "a":
            player['status'] = "available"
        elif player['status'] == "d":
            player['status'] = "doubtful"
        elif player['status'] == "i":
            player['status'] = "injured"
        elif player['status'] == "s":
            player['status'] = "suspended"
    return players


#### Temporarily took out the "main_players" filter because no players have played 330 minutes ####

# player_positions_teams = attach_team_and_position(main_players, all_teams_new, positions)
player_positions_teams = attach_team_and_position(all_players, all_teams, positions)


def final_players_list(player_positions_teams):
    players = player_positions_teams.copy()
    empty = []
    for player in players:
        stats = dict(team_code = player['team_code'],
        team_name = player['team_name'],
        name = player['first_name'] + " " + player['second_name'],
        status = player['status'],
        position = player['position'],
        cost = (player['now_cost'])/10,
        total_points = player['total_points'],
        roi = round((player['total_points'] / player['now_cost'])*10, 2),
        pts_per_90min = round((player['total_points'] / (player['minutes'] + 1))*90, 2),
        bonus = player['bonus'],
        red_cards = player['red_cards'],
        minutes = player['minutes'],
        transfers_out = player['transfers_out'],
        transfers_in = player['transfers_in'])
        empty.append(stats)
    return empty

# %%
final = final_players_list(player_positions_teams)

# %%
final[0]
# Out:
# {'team_code': 3,
#  'team_name': 'Arsenal',
#  'name': 'Shkodran Mustafi',
#  'status': 'available',
#  'position': 'Defender',
#  'cost': 5.2,
#  'total_points': 4,
#  'roi': 0.77,
#  'pts_per_90min': 3.96,
#  'bonus': 0,
#  'red_cards': 0,
#  'minutes': 90,
#  'transfers_out': 32375,
#  'transfers_in': 7964}

# %%
all_teams[0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1230,
#  'strength_overall_away': 1270,
#  'strength_attack_home': 1150,
#  'strength_attack_away': 1190,
#  'strength_defence_home': 1280,
#  'strength_defence_away': 1330}

# %% [markdown]
# ### Get Total ROI, Points and 90min before filtering injured and FDR

# %%
total_roi = sorted(final, key = lambda x: x['roi'], reverse = True)

# %%
total_roi[:2]
# Out:
# [{'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'John Lundstram',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 5.2,
#   'total_points': 95,
#   'roi': 18.27,
#   'pts_per_90min': 5.38,
#   'bonus': 12,
#   'red_cards': 0,
#   'minutes': 1588,
#   'transfers_out': 357562,
#   'transfers_in': 3205737},
#  {'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'George Baldock',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 5.0,
#   'total_points': 83,
#   'roi': 16.6,
#   'pts_per_90min': 4.61,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 1620,
#   'transfers_out': 85090,
#   'transfers_in': 733062}]

# %% [markdown]
# ### Total_Points

# %%
total_max_pts = sorted(total_roi, key = lambda x: x['total_points'], reverse = True)

# %%
total_max_pts[:2]
# Out:
# [{'team_code': 13,
#   'team_name': 'Leicester',
#   'name': 'Jamie Vardy',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 10.1,
#   'total_points': 142,
#   'roi': 14.06,
#   'pts_per_90min': 7.88,
#   'bonus': 25,
#   'red_cards': 0,
#   'minutes': 1620,
#   'transfers_out': 688600,
#   'transfers_in': 3524409},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Kevin De Bruyne',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 10.4,
#   'total_points': 120,
#   'roi': 11.54,
#   'pts_per_90min': 7.7,
#   'bonus': 16,
#   'red_cards': 0,
#   'minutes': 1402,
#   'transfers_out': 2054597,
#   'transfers_in': 3961098}]

# %% [markdown]
# ### 90 min

# %%
total_90min = sorted(total_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
total_90min = [player for player in total_90min if player['minutes'] >= min_min]

# %%
total_90min[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Riyad Mahrez',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 8.3,
#   'total_points': 77,
#   'roi': 9.28,
#   'pts_per_90min': 9.01,
#   'bonus': 10,
#   'red_cards': 0,
#   'minutes': 768,
#   'transfers_out': 843031,
#   'transfers_in': 884281},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 11.7,
#   'total_points': 73,
#   'roi': 6.24,
#   'pts_per_90min': 8.09,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 811,
#   'transfers_out': 2056342,
#   'transfers_in': 1357021}]

# %% [markdown]
# ### Create Players DataFrame

# %%
player_df = pd.DataFrame(final)

# %%
player_df.sort_values(by = ['roi'], ascending = False, inplace = True)

# %%
player_df.head(10)
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
# 234      7   5.2     1591     Jonny Evans    Defender           4.41
# 389      8   4.8     1275   Todd Cantwell  Midfielder           5.01
# 130      7   4.7     1620       Nick Pope  Goalkeeper           3.83
# 505     13   4.8     1620      Ben Foster  Goalkeeper           3.89
# 100     11   4.8     1620     Mathew Ryan  Goalkeeper           3.89
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
# 234          0  15.00  available         13      Leicester            78
# 389          0  14.79  available         45        Norwich            71
# 130          0  14.68  available         90        Burnley            69
# 505          0  14.58  available         57        Watford            70
# 100          0  14.58  available         36       Brighton            70
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630
# 234        469687         152486
# 389       2751018        1434312
# 130       1016121         472453
# 505         85242         144902
# 100        872157         531905

# %% [markdown]
# ### Merge two team tables s owe have all data

# %%
def merged_teams(table_df, all_teams):
    table_dic = table_df.to_dict('records')
    
    for team in table_dic:
        for item in all_teams:
            if team['Team'] == item['short_name']:
                team['code'] = item['code']
                team['name'] = item['name']
                team['strength'] = item['strength']
            
    new_df = pd.DataFrame(table_dic)
    
    new_order = ['code', 'strength', 'Team','name', 'Played', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'Pts']
    
    table_df = new_df[new_order]
    
    table_df.index = np.arange(1, len(table_df) + 1)
    table_df.index.name = 'Position'
    
    return table_df

# %%
team_df = merged_teams(table_df, all_teams)

# %%
team_df.head()
# Out:
#           code  strength Team           name Played   W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV      Liverpool     17  16  0  1  42  14  +28  49
# 2           13         4  LEI      Leicester     18  12  3  3  41  14  +27  39
# 3           43         5  MCI       Man City     18  12  4  2  50  20  +30  38
# 4            8         4  CHE        Chelsea     18  10  6  2  33  25   +8  32
# 5           49         3  SHU  Sheffield Utd     18   7  4  7  22  16   +6  28

# %%
team_names = list(team_df.name)

# %%
team_names.sort()

# %%
team_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %% [markdown]
# ## Create Schedule DF

# %%
def extract_sched(schedules):
    dic = {}
    for i, item in enumerate(schedules):
        name = item.partition(team_names[i])[1]
        sche = item.partition(team_names[i])[2]
        sche = sche.split()
        clean = [item for item in sche if item != "(A)"]
        clean2 = [item for item in clean if item != "(H)"]
        dic[name] = clean2
    return dic

# %%
wonders = extract_sched(schedules)

# %%
schedule_df = pd.DataFrame(wonders)

# %%
schedule_df.index.name = 'Gameweek'

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
schedule_df.Arsenal[0:3]
# Out:
# Gameweek
# 0    NEW
# 1    BUR
# 2    LIV
# Name: Arsenal, dtype: object

# %% [markdown]
# ## Create FDR scores for calculating next-n opponents AVG strength

# %%
scores = list(zip(team_df.Team, team_df.strength))

# %%
scores = dict(scores)

# %%
sorted(scores.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('LIV', 5),
#  ('MCI', 5),
#  ('LEI', 4),
#  ('CHE', 4),
#  ('TOT', 4),
#  ('MUN', 4),
#  ('ARS', 4),
#  ('SHU', 3),
#  ('WOL', 3),
#  ('NEW', 3),
#  ('BUR', 3),
#  ('CRY', 3),
#  ('BHA', 3),
#  ('BOU', 3),
#  ('EVE', 3),
#  ('WHU', 3),
#  ('WAT', 3),
#  ('SOU', 2),
#  ('AVL', 2),
#  ('NOR', 2)]

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
# from pylab import rcParams
# rcParams['figure.figsize'] = 14, 6

sorted_data = sorted(scores.items(), key = lambda x: x[1], reverse = True)

Team = [item[0] for item in sorted_data]
strength = [item[1] for item in sorted_data]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength Fantasy FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
maybs
# Out:
# [5.589743589743589,
#  4.997920997920998,
#  4.883666274970623,
#  3.2527644701557747,
#  3.255054385489168,
#  2.8843894061285367,
#  2.7902015728102687,
#  2.7762812980204283,
#  2.1921118442857574,
#  1.9596854379463076,
#  2.1308264786525664,
#  2.2779836692880173,
#  1.9017746843833803,
#  1.832113049504354,
#  1.5355690138298834,
#  1.5712434842869625,
#  0.8371448371448371,
#  1.1766549157853508,
#  0.41025641025641024,
#  0.43478260869565233]

# %%
new_FDR =  list(zip(name_list, maybs))

# %%
new_FDR
# Out:
# [('LIV', 5.589743589743589),
#  ('LEI', 4.997920997920998),
#  ('MCI', 4.883666274970623),
#  ('CHE', 3.2527644701557747),
#  ('SHU', 3.255054385489168),
#  ('WOL', 2.8843894061285367),
#  ('TOT', 2.7902015728102687),
#  ('MUN', 2.7762812980204283),
#  ('NEW', 2.1921118442857574),
#  ('BUR', 1.9596854379463076),
#  ('ARS', 2.1308264786525664),
#  ('CRY', 2.2779836692880173),
#  ('BHA', 1.9017746843833803),
#  ('BOU', 1.832113049504354),
#  ('EVE', 1.5355690138298834),
#  ('WHU', 1.5712434842869625),
#  ('SOU', 0.8371448371448371),
#  ('AVL', 1.1766549157853508),
#  ('NOR', 0.41025641025641024),
#  ('WAT', 0.43478260869565233)]

# %%
def get_avg_FDR(sorted_data, new_FDR):
    listy = []
    for item in sorted_data:
        for score in new_FDR:
            if item[0] == score[0]:
                team = item[0]
                avg_FDR = np.round((item[1] + score[1])/2, 2)
                tup = (team, avg_FDR)
                listy.append(tup)
    return listy

# %%
final_avg_FDR = get_avg_FDR(sorted_data, new_FDR)

# %%
final_avg_FDR = sorted(final_avg_FDR, key = lambda x: x[1], reverse = True)
final_avg_FDR
# Out:
# [('LIV', 5.29),
#  ('MCI', 4.94),
#  ('LEI', 4.5),
#  ('CHE', 3.63),
#  ('TOT', 3.4),
#  ('MUN', 3.39),
#  ('SHU', 3.13),
#  ('ARS', 3.07),
#  ('WOL', 2.94),
#  ('CRY', 2.64),
#  ('NEW', 2.6),
#  ('BUR', 2.48),
#  ('BHA', 2.45),
#  ('BOU', 2.42),
#  ('WHU', 2.29),
#  ('EVE', 2.27),
#  ('WAT', 1.72),
#  ('AVL', 1.59),
#  ('SOU', 1.42),
#  ('NOR', 1.21)]

# %%
adjusted_FDR = dict(final_avg_FDR)

# %%
adjusted_FDR
# Out:
# {'LIV': 5.29,
#  'MCI': 4.94,
#  'LEI': 4.5,
#  'CHE': 3.63,
#  'TOT': 3.4,
#  'MUN': 3.39,
#  'SHU': 3.13,
#  'ARS': 3.07,
#  'WOL': 2.94,
#  'CRY': 2.64,
#  'NEW': 2.6,
#  'BUR': 2.48,
#  'BHA': 2.45,
#  'BOU': 2.42,
#  'WHU': 2.29,
#  'EVE': 2.27,
#  'WAT': 1.72,
#  'AVL': 1.59,
#  'SOU': 1.42,
#  'NOR': 1.21}

# %%
Team = [item[0] for item in final_avg_FDR]
strength = [item[1] for item in final_avg_FDR]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength adjusted_FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
schedule_df.columns
# Out:
# Index(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brighton', 'Burnley',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Leicester', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Sheffield Utd',
#        'Southampton', 'Spurs', 'Watford', 'West Ham', 'Wolves'],
#       dtype='object')

# %%
schedule_df.head(10)
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
# 5            AVL         ARS         SOU      NEW     NOR     LIV
# 6            MUN         BUR         WHU      CHE     AVL     BHA
# 7            BOU         NOR         ARS      TOT     EVE     SOU
# 8            SHU         BHA         NOR      AVL     LEI     NEW
# 9            CRY         MCI         WAT      EVE     CHE     BUR
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
# 5                   WOL     SHU       TOT       CHE      WAT     WHU
# 6                   NOR     MCI       NEW       SHU      EVE     ARS
# 7                   WHU     BUR       LIV       LEI      WOL     NEW
# 8                   MCI     WHU       BUR       MUN      CRY     LIV
# 9                   ARS     BHA       SOU       TOT      AVL     NOR
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
# 5              BHA     BUR           EVE         BOU   LEI     MCI      MUN
# 6              LEI     CRY           LIV         TOT   SOU     WOL      BOU
# 7              MUN     AVL           WAT         CHE   BHA     SHU      CRY
# 8              CHE     BOU           ARS         WOL   WAT     TOT      EVE
# 9              WOL     MUN           WHU         LEI   LIV     BOU      SHU
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE
# 5           CRY
# 6           WAT
# 7           MCI
# 8           SOU
# 9           NEW

# %%
def avg_FDR(scores = adjusted_FDR, week = gameweek, periods = next_n_games):
    dic = {}
    for team in schedule_df.columns:
        oponents = schedule_df[team][(week-1):(week+periods)]
        avg_FDR = round(sum([scores[oponent] for oponent in oponents])/len(oponents), 2)
        dic[team] = avg_FDR
    return dic

# %%
calculate_FDR = avg_FDR()

# %%
sorted_FDR = sorted(calculate_FDR.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_FDR
# Out:
# [('Sheffield Utd', 3.98),
#  ('Wolves', 3.98),
#  ('Liverpool', 3.52),
#  ('Leicester', 3.39),
#  ('Newcastle', 3.39),
#  ('Everton', 3.34),
#  ('Southampton', 3.22),
#  ('West Ham', 3.19),
#  ('Arsenal', 3.15),
#  ('Brighton', 3.15),
#  ('Man City', 2.78),
#  ('Man Utd', 2.72),
#  ('Bournemouth', 2.6),
#  ('Watford', 2.55),
#  ('Norwich', 2.54),
#  ('Burnley', 2.42),
#  ('Chelsea', 2.31),
#  ('Aston Villa', 1.8),
#  ('Spurs', 1.69),
#  ('Crystal Palace', 1.64)]

# %%
rcParams['figure.figsize'] = 14, 6

Team = [item[0] for item in sorted_FDR]
FDR = [item[1] for item in sorted_FDR]

FDR_75 = round(np.percentile([item[1] for item in sorted_FDR], 75), 2)
cutoff = FDR_75

plt.bar(Team, FDR)
plt.axhline(y=cutoff, linestyle='-', color='#33D977', label='Cutoff Difficulty(FDR 75th%) = ' + str(cutoff))
plt.ylabel('AVG Opponent Difficulty', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Adjusted_FDR Opponenet Difficulty Next ' + str(next_n_games +1) + ' Games', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('FDR', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Clean final list of available players by FDR score <= 3.56 and status = 'available'

# %%
player_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630

# %%
player_df.shape
# Out:
# (578, 14)

# %%
clean_df = player_df[player_df.status == 'available']

# %%
clean_df.status.value_counts()
# Out:
# available    434
# Name: status, dtype: int64

# %% [markdown]
# ## Remove teams with FDR scores > 3.56 from DF - optional

# %%
teams_low_FDR = [key for (key,value) in calculate_FDR.items() if value <= cutoff]

# %%
teams_low_FDR
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Man City',
#  'Man Utd',
#  'Norwich',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham']

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630

# %%
final_df = clean_df.loc[clean_df.team_name.isin(teams_low_FDR)]

# %%
final_df.head(15)
# Out:
#      bonus  cost  minutes             name    position  pts_per_90min  \
# 85      10   4.6     1620   Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250       Danny Ings     Forward           7.12
# 389      8   4.8     1275    Todd Cantwell  Midfielder           5.01
# 130      7   4.7     1620        Nick Pope  Goalkeeper           3.83
# 505     13   4.8     1620       Ben Foster  Goalkeeper           3.89
# 100     11   4.8     1620      Mathew Ryan  Goalkeeper           3.89
# 380     16   6.6     1605      Teemu Pukki     Forward           5.32
# 182     10   5.1     1440   Vicente Guaita  Goalkeeper           4.43
# 121      9   5.1     1620  James Tarkowski    Defender           3.83
# 95       9   4.7     1530       Lewis Dunk    Defender           3.64
# 166     19   7.9     1300    Tammy Abraham     Forward           6.99
# 114     12   5.8     1334      Neal Maupay     Forward           4.85
# 13       3   5.0     1620       Bernd Leno  Goalkeeper           3.44
# 179      4   4.4     1044     Martin Kelly    Defender           4.65
# 382      6   4.5     1440         Tim Krul  Goalkeeper           3.31
#
#      red_cards    roi     status  team_code       team_name  total_points  \
# 85           0  15.65  available         91     Bournemouth            72
# 436          0  15.23  available         20     Southampton            99
# 389          0  14.79  available         45         Norwich            71
# 130          0  14.68  available         90         Burnley            69
# 505          0  14.58  available         57         Watford            70
# 100          0  14.58  available         36        Brighton            70
# 380          0  14.39  available         45         Norwich            95
# 182          0  13.92  available         31  Crystal Palace            71
# 121          0  13.53  available         90         Burnley            69
# 95           0  13.19  available         36        Brighton            62
# 166          0  12.78  available          8         Chelsea           101
# 114          0  12.41  available         36        Brighton            72
# 13           0  12.40  available          3         Arsenal            62
# 179          0  12.27  available         31  Crystal Palace            54
# 382          0  11.78  available         45         Norwich            53
#
#      transfers_in  transfers_out
# 85         487246         146400
# 436       1214100         408630
# 389       2751018        1434312
# 130       1016121         472453
# 505         85242         144902
# 100        872157         531905
# 380       3541121        2919375
# 182        248814          68169
# 121        336000         157192
# 95         961220         598027
# 166       4573961        2437070
# 114        275693         186313
# 13         354269         390938
# 179       1595472         904399
# 382        151122         102842

# %%
clean_players = final_df.to_dict('records')

# %%
clean_players[:2]
# Out:
# [{'bonus': 10,
#   'cost': 4.6,
#   'minutes': 1620,
#   'name': 'Aaron Ramsdale',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.0,
#   'red_cards': 0,
#   'roi': 15.65,
#   'status': 'available',
#   'team_code': 91,
#   'team_name': 'Bournemouth',
#   'total_points': 72,
#   'transfers_in': 487246,
#   'transfers_out': 146400},
#  {'bonus': 21,
#   'cost': 6.5,
#   'minutes': 1250,
#   'name': 'Danny Ings',
#   'position': 'Forward',
#   'pts_per_90min': 7.12,
#   'red_cards': 0,
#   'roi': 15.23,
#   'status': 'available',
#   'team_code': 20,
#   'team_name': 'Southampton',
#   'total_points': 99,
#   'transfers_in': 1214100,
#   'transfers_out': 408630}]

# %% [markdown]
# ## Get list of players by ROI, Total Points and Points Per 90 min

# %%
players_roi = sorted(clean_players, key = lambda x: x['roi'], reverse = True)

# %%
players_roi[:3]
# Out:
# [{'bonus': 10,
#   'cost': 4.6,
#   'minutes': 1620,
#   'name': 'Aaron Ramsdale',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.0,
#   'red_cards': 0,
#   'roi': 15.65,
#   'status': 'available',
#   'team_code': 91,
#   'team_name': 'Bournemouth',
#   'total_points': 72,
#   'transfers_in': 487246,
#   'transfers_out': 146400},
#  {'bonus': 21,
#   'cost': 6.5,
#   'minutes': 1250,
#   'name': 'Danny Ings',
#   'position': 'Forward',
#   'pts_per_90min': 7.12,
#   'red_cards': 0,
#   'roi': 15.23,
#   'status': 'available',
#   'team_code': 20,
#   'team_name': 'Southampton',
#   'total_points': 99,
#   'transfers_in': 1214100,
#   'transfers_out': 408630},
#  {'bonus': 8,
#   'cost': 4.8,
#   'minutes': 1275,
#   'name': 'Todd Cantwell',
#   'position': 'Midfielder',
#   'pts_per_90min': 5.01,
#   'red_cards': 0,
#   'roi': 14.79,
#   'status': 'available',
#   'team_code': 45,
#   'team_name': 'Norwich',
#   'total_points': 71,
#   'transfers_in': 2751018,
#   'transfers_out': 1434312}]

# %% [markdown]
# ### Total Points

# %%
players_max_pts = sorted(players_roi, key = lambda x: x['total_points'], reverse = True)

# %%
players_max_pts[:3]
# Out:
# [{'bonus': 16,
#   'cost': 10.4,
#   'minutes': 1402,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 7.7,
#   'red_cards': 0,
#   'roi': 11.54,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 120,
#   'transfers_in': 3961098,
#   'transfers_out': 2054597},
#  {'bonus': 20,
#   'cost': 9.1,
#   'minutes': 1576,
#   'name': 'Marcus Rashford',
#   'position': 'Forward',
#   'pts_per_90min': 5.99,
#   'red_cards': 0,
#   'roi': 11.54,
#   'status': 'available',
#   'team_code': 1,
#   'team_name': 'Man Utd',
#   'total_points': 105,
#   'transfers_in': 2462471,
#   'transfers_out': 1800838},
#  {'bonus': 18,
#   'cost': 10.8,
#   'minutes': 1607,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 5.88,
#   'red_cards': 0,
#   'roi': 9.72,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 105,
#   'transfers_in': 1493073,
#   'transfers_out': 2042964}]

# %% [markdown]
# ### Per 90 mins played

# %%
players_90min = sorted(players_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
players_90min = [player for player in players_90min if player['minutes'] >= min_min]

# %%
players_90min[:3]
# Out:
# [{'bonus': 10,
#   'cost': 8.3,
#   'minutes': 768,
#   'name': 'Riyad Mahrez',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.01,
#   'red_cards': 0,
#   'roi': 9.28,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 77,
#   'transfers_in': 884281,
#   'transfers_out': 843031},
#  {'bonus': 6,
#   'cost': 11.7,
#   'minutes': 811,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 8.09,
#   'red_cards': 0,
#   'roi': 6.24,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 73,
#   'transfers_in': 1357021,
#   'transfers_out': 2056342},
#  {'bonus': 16,
#   'cost': 10.4,
#   'minutes': 1402,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 7.7,
#   'red_cards': 0,
#   'roi': 11.54,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 120,
#   'transfers_in': 3961098,
#   'transfers_out': 2054597}]

# %% [markdown]
# ### Create player lists by position and metric we want to select by

# %%
GK_roi = [item for item in players_roi if item['position'] == 'Goalkeeper']
DF_roi = [item for item in players_roi if item['position'] == 'Defender']
MD_roi = [item for item in players_roi if item['position'] == 'Midfielder']
ST_roi = [item for item in players_roi if item['position'] == 'Forward']

# %%
GK_pts = [item for item in players_max_pts if item['position'] == 'Goalkeeper']
DF_pts = [item for item in players_max_pts if item['position'] == 'Defender']
MD_pts = [item for item in players_max_pts if item['position'] == 'Midfielder']
ST_pts = [item for item in players_max_pts if item['position'] == 'Forward']

# %%
GK_90min = [item for item in players_90min if item['position'] == 'Goalkeeper']
DF_90min = [item for item in players_90min if item['position'] == 'Defender']
MD_90min = [item for item in players_90min if item['position'] == 'Midfielder']
ST_90min = [item for item in players_90min if item['position'] == 'Forward']

# %% [markdown]
# ## Start by selecting top GKs by ROI

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_roi:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Aaron Ramsdale
# GK budget left: 4.9
# Player Selected: Nick Pope
# GK budget left: 0.20000000000000018
# ['Aaron Ramsdale', 'Nick Pope']
# ['Bournemouth', 'Burnley']

# %% [markdown]
# ## Select Top player by points from DF, MD, ST

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 28.699999999999996 36.0 26.0
# Player Selected: James Tarkowski
# DF budget left: 23.599999999999994
# Player Selected: Kevin De Bruyne
# MD budget left: 25.6
# ['Aaron Ramsdale', 'Nick Pope', 'James Tarkowski', 'Kevin De Bruyne']
# ['Bournemouth', 'Burnley', 'Burnley', 'Man City']

# %%
ST_pts[:3]
# Out:
# [{'bonus': 20,
#   'cost': 9.1,
#   'minutes': 1576,
#   'name': 'Marcus Rashford',
#   'position': 'Forward',
#   'pts_per_90min': 5.99,
#   'red_cards': 0,
#   'roi': 11.54,
#   'status': 'available',
#   'team_code': 1,
#   'team_name': 'Man Utd',
#   'total_points': 105,
#   'transfers_in': 2462471,
#   'transfers_out': 1800838},
#  {'bonus': 18,
#   'cost': 10.8,
#   'minutes': 1607,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 5.88,
#   'red_cards': 0,
#   'roi': 9.72,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 105,
#   'transfers_in': 1493073,
#   'transfers_out': 2042964},
#  {'bonus': 19,
#   'cost': 7.9,
#   'minutes': 1300,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 6.99,
#   'red_cards': 0,
#   'roi': 12.78,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 101,
#   'transfers_in': 4573961,
#   'transfers_out': 2437070}]

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Marcus Rashford
# ST budget left: 16.9
# 5
# ['Aaron Ramsdale', 'Nick Pope', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford']
# ['Bournemouth', 'Burnley', 'Burnley', 'Man City', 'Man Utd']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with top ROI players

# %%
for item in DF_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
        print('# of DFs selected: ' + str(DF_curr))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Lewis Dunk
# DF budget left: 18.899999999999995
# # of DFs selected: 2
# Player Selected: Martin Kelly
# DF budget left: 14.499999999999995
# # of DFs selected: 3
# Player Selected: Angelo Ogbonna
# DF budget left: 9.999999999999995
# # of DFs selected: 4
# Player Selected: Ben Mee
# DF budget left: 4.999999999999995
# # of DFs selected: 5
# 9
# ['Aaron Ramsdale', 'Nick Pope', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Lewis Dunk', 'Martin Kelly', 'Angelo Ogbonna', 'Ben Mee']
# ['Bournemouth', 'Burnley', 'Burnley', 'Man City', 'Man Utd', 'Brighton', 'Crystal Palace', 'West Ham', 'Burnley']

# %% [markdown]
# ## Fill MD position

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Todd Cantwell
# MD budget left: 25.799999999999994
# Player Selected: Jack Grealish
# MD budget left: 19.499999999999993
# Player Selected: Mason Mount
# MD budget left: 12.999999999999993
# Player Selected: James Ward-Prowse
# MD budget left: 7.0999999999999925
# 13
# ['Aaron Ramsdale', 'Nick Pope', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Lewis Dunk', 'Martin Kelly', 'Angelo Ogbonna', 'Ben Mee', 'Todd Cantwell', 'Jack Grealish', 'Mason Mount', 'James Ward-Prowse']
# ['Bournemouth', 'Burnley', 'Burnley', 'Man City', 'Man Utd', 'Brighton', 'Crystal Palace', 'West Ham', 'Burnley', 'Norwich', 'Aston Villa', 'Chelsea', 'Southampton']

# %% [markdown]
# ## Fill ST position

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Danny Ings
# ST budget left: 17.499999999999993
# Player Selected: Teemu Pukki
# ST budget left: 10.899999999999993
# 15
# ['Aaron Ramsdale', 'Nick Pope', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Lewis Dunk', 'Martin Kelly', 'Angelo Ogbonna', 'Ben Mee', 'Todd Cantwell', 'Jack Grealish', 'Mason Mount', 'James Ward-Prowse', 'Danny Ings', 'Teemu Pukki']
# ['Bournemouth', 'Burnley', 'Burnley', 'Man City', 'Man Utd', 'Brighton', 'Crystal Palace', 'West Ham', 'Burnley', 'Norwich', 'Aston Villa', 'Chelsea', 'Southampton', 'Southampton', 'Norwich']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes               name    position  pts_per_90min  \
# 0      10   4.6     1620     Aaron Ramsdale  Goalkeeper           4.00
# 1       7   4.7     1620          Nick Pope  Goalkeeper           3.83
# 2       9   5.1     1620    James Tarkowski    Defender           3.83
# 3      16  10.4     1402    Kevin De Bruyne  Midfielder           7.70
# 4      20   9.1     1576    Marcus Rashford     Forward           5.99
# 5       9   4.7     1530         Lewis Dunk    Defender           3.64
# 6       4   4.4     1044       Martin Kelly    Defender           4.65
# 7       0   4.5     1170     Angelo Ogbonna    Defender           3.84
# 8       0   5.0     1620            Ben Mee    Defender           2.78
# 9       8   4.8     1275      Todd Cantwell  Midfielder           5.01
# 10      8   6.3     1433      Jack Grealish  Midfielder           4.64
# 11      6   6.5     1504        Mason Mount  Midfielder           4.43
# 12      6   5.9     1620  James Ward-Prowse  Midfielder           3.61
# 13     21   6.5     1250         Danny Ings     Forward           7.12
# 14     16   6.6     1605        Teemu Pukki     Forward           5.32
#
#     red_cards    roi     status  team_code       team_name  total_points  \
# 0           0  15.65  available         91     Bournemouth            72
# 1           0  14.68  available         90         Burnley            69
# 2           0  13.53  available         90         Burnley            69
# 3           0  11.54  available         43        Man City           120
# 4           0  11.54  available          1         Man Utd           105
# 5           0  13.19  available         36        Brighton            62
# 6           0  12.27  available         31  Crystal Palace            54
# 7           0  11.11  available         21        West Ham            50
# 8           0  10.00  available         90         Burnley            50
# 9           0  14.79  available         45         Norwich            71
# 10          0  11.75  available          7     Aston Villa            74
# 11          0  11.38  available          8         Chelsea            74
# 12          0  11.02  available         20     Southampton            65
# 13          0  15.23  available         20     Southampton            99
# 14          0  14.39  available         45         Norwich            95
#
#     transfers_in  transfers_out
# 0         487246         146400
# 1        1016121         472453
# 2         336000         157192
# 3        3961098        2054597
# 4        2462471        1800838
# 5         961220         598027
# 6        1595472         904399
# 7          78299          33863
# 8          50678          54486
# 9        2751018        1434312
# 10        977579         444441
# 11       3549353        2093418
# 12        190590         113424
# 13       1214100         408630
# 14       3541121        2919375

# %%
money_x = money_df.roi
money_y = money_df.name
ST_75th = round(money_df.describe().roi['75%'], 2)
ST_AVG = round(money_df.describe().roi['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Top 10 ROI players by position

# %%
GK_df = pd.DataFrame(GK_roi)
GK_df.head(10)
# Out:
#    bonus  cost  minutes                       name    position  pts_per_90min  \
# 0     10   4.6     1620             Aaron Ramsdale  Goalkeeper           4.00
# 1      7   4.7     1620                  Nick Pope  Goalkeeper           3.83
# 2     13   4.8     1620                 Ben Foster  Goalkeeper           3.89
# 3     11   4.8     1620                Mathew Ryan  Goalkeeper           3.89
# 4     10   5.1     1440             Vicente Guaita  Goalkeeper           4.43
# 5      3   5.0     1620                 Bernd Leno  Goalkeeper           3.44
# 6      6   4.5     1440                   Tim Krul  Goalkeeper           3.31
# 7      3   5.3     1620            Jordan Pickford  Goalkeeper           3.05
# 8      0   4.5     1530                 Tom Heaton  Goalkeeper           2.65
# 9      2   6.0     1530  Ederson Santana de Moraes  Goalkeeper           3.53
#
#    red_cards    roi     status  team_code       team_name  total_points  \
# 0          0  15.65  available         91     Bournemouth            72
# 1          0  14.68  available         90         Burnley            69
# 2          0  14.58  available         57         Watford            70
# 3          0  14.58  available         36        Brighton            70
# 4          0  13.92  available         31  Crystal Palace            71
# 5          0  12.40  available          3         Arsenal            62
# 6          0  11.78  available         45         Norwich            53
# 7          0  10.38  available         11         Everton            55
# 8          0  10.00  available          7     Aston Villa            45
# 9          0  10.00  available         43        Man City            60
#
#    transfers_in  transfers_out
# 0        487246         146400
# 1       1016121         472453
# 2         85242         144902
# 3        872157         531905
# 4        248814          68169
# 5        354269         390938
# 6        151122         102842
# 7        392618         588769
# 8        259554         308384
# 9        822907        1212823

# %%
DF_df = pd.DataFrame(DF_roi)
DF_df.head(10)
# Out:
#    bonus  cost  minutes                 name  position  pts_per_90min  \
# 0      9   5.1     1620      James Tarkowski  Defender           3.83
# 1      9   4.7     1530           Lewis Dunk  Defender           3.64
# 2      4   4.4     1044         Martin Kelly  Defender           4.65
# 3      0   4.5     1170       Angelo Ogbonna  Defender           3.84
# 4      0   5.0     1620              Ben Mee  Defender           2.78
# 5      5   4.7     1033      Aaron Cresswell  Defender           4.09
# 6     10   5.1     1084         Serge Aurier  Defender           4.15
# 7      1   4.3     1369       Craig Cathcart  Defender           2.76
# 8      3   5.5     1378  Patrick van Aanholt  Defender           3.46
# 9      7   4.8     1080        Fikayo Tomori  Defender           3.83
#
#    red_cards    roi     status  team_code       team_name  total_points  \
# 0          0  13.53  available         90         Burnley            69
# 1          0  13.19  available         36        Brighton            62
# 2          0  12.27  available         31  Crystal Palace            54
# 3          0  11.11  available         21        West Ham            50
# 4          0  10.00  available         90         Burnley            50
# 5          0  10.00  available         21        West Ham            47
# 6          1   9.80  available          6           Spurs            50
# 7          0   9.77  available         57         Watford            42
# 8          0   9.64  available         31  Crystal Palace            53
# 9          0   9.58  available          8         Chelsea            46
#
#    transfers_in  transfers_out
# 0        336000         157192
# 1        961220         598027
# 2       1595472         904399
# 3         78299          33863
# 4         50678          54486
# 5        220153         161425
# 6        802696         287056
# 7         32488         202172
# 8        761374         857949
# 9        762980         474864

# %%
MD_df = pd.DataFrame(MD_roi)
MD_df.head(10)
# Out:
#    bonus  cost  minutes                     name    position  pts_per_90min  \
# 0      8   4.8     1275            Todd Cantwell  Midfielder           5.01
# 1      8   6.3     1433            Jack Grealish  Midfielder           4.64
# 2     16  10.4     1402          Kevin De Bruyne  Midfielder           7.70
# 3      6   6.5     1504              Mason Mount  Midfielder           4.43
# 4      6   5.9     1620        James Ward-Prowse  Midfielder           3.61
# 5      6   5.1     1406          Scott McTominay  Midfielder           3.52
# 6     12   7.0     1187  Willian Borges Da Silva  Midfielder           5.68
# 7      2   6.2     1484             Daniel James  Midfielder           3.94
# 8      7   7.9     1547   Richarlison de Andrade  Midfielder           4.77
# 9      0   5.5     1088           Anwar El Ghazi  Midfielder           4.71
#
#    red_cards    roi     status  team_code    team_name  total_points  \
# 0          0  14.79  available         45      Norwich            71
# 1          0  11.75  available          7  Aston Villa            74
# 2          0  11.54  available         43     Man City           120
# 3          0  11.38  available          8      Chelsea            74
# 4          0  11.02  available         20  Southampton            65
# 5          0  10.78  available          1      Man Utd            55
# 6          0  10.71  available          8      Chelsea            75
# 7          0  10.48  available          1      Man Utd            65
# 8          0  10.38  available         11      Everton            82
# 9          0  10.36  available          7  Aston Villa            57
#
#    transfers_in  transfers_out
# 0       2751018        1434312
# 1        977579         444441
# 2       3961098        2054597
# 3       3549353        2093418
# 4        190590         113424
# 5        388807         288554
# 6        370799         244768
# 7       1688572        1142798
# 8        948683         909689
# 9        217350         167186

# %%
ST_df = pd.DataFrame(ST_roi)
ST_df.head(10)
# Out:
#    bonus  cost  minutes                       name position  pts_per_90min  \
# 0     21   6.5     1250                 Danny Ings  Forward           7.12
# 1     16   6.6     1605                Teemu Pukki  Forward           5.32
# 2     19   7.9     1300              Tammy Abraham  Forward           6.99
# 3     12   5.8     1334                Neal Maupay  Forward           4.85
# 4     11   5.0     1392                Jordan Ayew  Forward           3.75
# 5     20   9.1     1576            Marcus Rashford  Forward           5.99
# 6      8   6.2     1305                 Chris Wood  Forward           4.41
# 7      7   5.7     1532              Wesley Moraes  Forward           3.41
# 8     18  10.8     1607  Pierre-Emerick Aubameyang  Forward           5.88
# 9      6   6.2     1222              Ashley Barnes  Forward           4.19
#
#    red_cards    roi     status  team_code       team_name  total_points  \
# 0          0  15.23  available         20     Southampton            99
# 1          0  14.39  available         45         Norwich            95
# 2          0  12.78  available          8         Chelsea           101
# 3          0  12.41  available         36        Brighton            72
# 4          0  11.60  available         31  Crystal Palace            58
# 5          0  11.54  available          1         Man Utd           105
# 6          0  10.32  available         90         Burnley            64
# 7          0  10.18  available          7     Aston Villa            58
# 8          0   9.72  available          3         Arsenal           105
# 9          0   9.19  available         90         Burnley            57
#
#    transfers_in  transfers_out
# 0       1214100         408630
# 1       3541121        2919375
# 2       4573961        2437070
# 3        275693         186313
# 4       1011275         813311
# 5       2462471        1800838
# 6        176235         220027
# 7        395016         367789
# 8       1493073        2042964
# 9       1122950        1113675

# %% [markdown]
# ## Define Clean df for graphing purposes

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630

# %%
graph_roi = []
for row, player in clean_df.iterrows():
    playa = dict(name = player['name'], position = player.position, team=player.team_name, cost = player.cost, points = player.total_points, minutes = player.minutes, ROI = player.roi, pts_per_90min = player.pts_per_90min)
    graph_roi.append(playa)

# %%
graph_roi[:3]
# Out:
# [{'name': 'John Lundstram',
#   'position': 'Defender',
#   'team': 'Sheffield Utd',
#   'cost': 5.2,
#   'points': 95,
#   'minutes': 1588,
#   'ROI': 18.27,
#   'pts_per_90min': 5.38},
#  {'name': 'George Baldock',
#   'position': 'Defender',
#   'team': 'Sheffield Utd',
#   'cost': 5.0,
#   'points': 83,
#   'minutes': 1620,
#   'ROI': 16.6,
#   'pts_per_90min': 4.61},
#  {'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'team': 'Sheffield Utd',
#   'cost': 4.8,
#   'points': 76,
#   'minutes': 1530,
#   'ROI': 15.83,
#   'pts_per_90min': 4.47}]

# %% [markdown]
# ### Graph by ROI

# %%
GK_graph = clean_df[clean_df['position'] == 'Goalkeeper']
DF_graph = clean_df[clean_df['position'] == 'Defender']
MD_graph = clean_df[clean_df['position'] == 'Midfielder']
ST_graph = clean_df[clean_df['position'] == 'Forward']

# %% [markdown]
# ### Graph by 90_min Stat

# %%
sorted_players_90min = sorted(graph_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
sorted_players_90min = [player for player in sorted_players_90min if player['minutes'] >= min_min]

# %%
sorted_players_90min[:3]
# Out:
# [{'name': 'Riyad Mahrez',
#   'position': 'Midfielder',
#   'team': 'Man City',
#   'cost': 8.3,
#   'points': 77,
#   'minutes': 768,
#   'ROI': 9.28,
#   'pts_per_90min': 9.01},
#  {'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'team': 'Man City',
#   'cost': 11.7,
#   'points': 73,
#   'minutes': 811,
#   'ROI': 6.24,
#   'pts_per_90min': 8.09},
#  {'name': 'Jamie Vardy',
#   'position': 'Forward',
#   'team': 'Leicester',
#   'cost': 10.1,
#   'points': 142,
#   'minutes': 1620,
#   'ROI': 14.06,
#   'pts_per_90min': 7.88}]

# %%
df_90min = pd.DataFrame(sorted_players_90min)

# %%
df_90min.head()
# Out:
#      ROI  cost  minutes           name  points    position  pts_per_90min  \
# 0   9.28   8.3      768   Riyad Mahrez      77  Midfielder           9.01
# 1   6.24  11.7      811  Sergio Agüero      73     Forward           8.09
# 2  14.06  10.1     1620    Jamie Vardy     142     Forward           7.88
# 3   8.52  12.2     1190  Mohamed Salah     104  Midfielder           7.86
# 4  11.57   5.1      678    Lys Mousset      59     Forward           7.82
#
#             team
# 0       Man City
# 1       Man City
# 2      Leicester
# 3      Liverpool
# 4  Sheffield Utd

# %%
GK_90min_graph = df_90min[df_90min['position'] == 'Goalkeeper']
DF_90min_graph = df_90min[df_90min['position'] == 'Defender']
MD_90min_graph = df_90min[df_90min['position'] == 'Midfielder']
ST_90min_graph = df_90min[df_90min['position'] == 'Forward']

# %%
GK_90min_graph.head()
# Out:
#       ROI  cost  minutes               name  points    position  \
# 55  15.83   4.8     1530     Dean Henderson      76  Goalkeeper
# 57  13.92   5.1     1440     Vicente Guaita      71  Goalkeeper
# 67  13.89   5.4     1620  Kasper Schmeichel      75  Goalkeeper
# 80  15.65   4.6     1620     Aaron Ramsdale      72  Goalkeeper
# 86  14.20   5.0     1620    Martin Dubravka      71  Goalkeeper
#
#     pts_per_90min            team
# 55           4.47   Sheffield Utd
# 57           4.43  Crystal Palace
# 67           4.16       Leicester
# 80           4.00     Bournemouth
# 86           3.94       Newcastle

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630

# %% [markdown]
# ## Top 50 players ROI

# %%
X = clean_df[:50].roi
Y = clean_df[:50].name
DF_75th = round(clean_df.describe().roi['75%'], 2)
DF_AVG = round(clean_df.describe().roi['mean'], 2)

plt.bar(Y, X)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG Player ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=90, fontsize =10, color = '#073997')
plt.title('Top 50 Players by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('TOP_50_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Bottom 50 Players by ROI

# %%
no_zero_roi = clean_df[clean_df.roi >0]
no_zero_roi = no_zero_roi[no_zero_roi.minutes > 460]

X = no_zero_roi[-50:].roi
Y = no_zero_roi[-50:].name
DF_75th = round(clean_df.describe().roi['75%'], 2)
DF_AVG = round(clean_df.describe().roi['mean'], 2)

plt.bar(Y, X)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG Player ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=90, fontsize = 10, color = '#073997')
plt.title('Bottom 50 Players by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('Bottom_50_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Keepers ROI

# %%
GK_x = GK_graph[:10].roi
GK_y = GK_graph[:10].name
GK_75th = round(GK_graph.describe().roi['75%'], 2)
GK_AVG = round(GK_graph.describe().roi['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK ROI = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK ROI = ' + str(GK_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Keepers 90_min

# %%
GK_x = GK_90min_graph[:10].pts_per_90min
GK_y = GK_90min_graph[:10].name
GK_75th = round(GK_90min_graph.describe().pts_per_90min['75%'], 2)
GK_AVG = round(GK_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK pts_per_90min = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK pts_per_90min = ' + str(GK_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders

# %%
DF_x = DF_graph[:10].roi
DF_y = DF_graph[:10].name
DF_75th = round(DF_graph.describe().roi['75%'], 2)
DF_AVG = round(DF_graph.describe().roi['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders 90min Stat

# %%
DF_x = DF_90min_graph[:10].pts_per_90min
DF_y = DF_90min_graph[:10].name
DF_75th = round(DF_90min_graph.describe().pts_per_90min['75%'], 2)
DF_AVG = round(DF_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF pts_per_90min = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF pts_per_90min = ' + str(DF_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders

# %%
MD_x = MD_graph[:10].roi
MD_y = MD_graph[:10].name
MD_75th = round(MD_graph.describe().roi['75%'], 2)
MD_AVG = round(MD_graph.describe().roi['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD ROI = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD ROI = ' + str(MD_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders 90min Stat

# %%
MD_x = MD_90min_graph[:10].pts_per_90min
MD_y = MD_90min_graph[:10].name
MD_75th = round(MD_90min_graph.describe().pts_per_90min['75%'], 2)
MD_AVG = round(MD_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD pts_per_90min = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD pts_per_90min = ' + str(MD_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers

# %%
ST_x = ST_graph[:10].roi
ST_y = ST_graph[:10].name
ST_75th = round(ST_graph.describe().roi['75%'], 2)
ST_AVG = round(ST_graph.describe().roi['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers 90min Stat

# %%
ST_x = ST_90min_graph[:10].pts_per_90min
ST_y = ST_90min_graph[:10].name
ST_75th = round(ST_90min_graph.describe().pts_per_90min['75%'], 2)
ST_AVG = round(ST_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
team_df
# Out:
#           code  strength Team            name Played   W   L  D  GF  GA   GD  \
# Position
# 1           14         5  LIV       Liverpool     17  16   0  1  42  14  +28
# 2           13         4  LEI       Leicester     18  12   3  3  41  14  +27
# 3           43         5  MCI        Man City     18  12   4  2  50  20  +30
# 4            8         4  CHE         Chelsea     18  10   6  2  33  25   +8
# 5           49         3  SHU   Sheffield Utd     18   7   4  7  22  16   +6
# 6           39         3  WOL          Wolves     18   6   3  9  26  22   +4
# 7            6         4  TOT           Spurs     18   7   6  5  32  26   +6
# 8            1         4  MUN         Man Utd     18   6   5  7  26  22   +4
# 9            4         3  NEW       Newcastle     18   7   7  4  18  24   -6
# 10          90         3  BUR         Burnley     18   7   8  3  23  29   -6
# 11           3         4  ARS         Arsenal     18   5   5  8  24  27   -3
# 12          31         3  CRY  Crystal Palace     18   6   7  5  15  20   -5
# 13          36         3  BHA        Brighton     18   5   8  5  21  26   -5
# 14          91         3  BOU     Bournemouth     18   5   9  4  19  25   -6
# 15          11         3  EVE         Everton     18   5   9  4  20  29   -9
# 16          21         3  WHU        West Ham     17   5   8  4  19  28   -9
# 17          20         2  SOU     Southampton     18   5  10  3  21  37  -16
# 18           7         2  AVL     Aston Villa     18   4  11  3  24  33   -9
# 19          45         2  NOR         Norwich     18   3  12  3  19  37  -18
# 20          57         3  WAT         Watford     18   2  10  6  11  32  -21
#
#          Pts
# Position
# 1         49
# 2         39
# 3         38
# 4         32
# 5         28
# 6         27
# 7         26
# 8         25
# 9         25
# 10        24
# 11        23
# 12        23
# 13        20
# 14        19
# 15        19
# 16        19
# 17        18
# 18        15
# 19        12
# 20        12

# %% [markdown]
# ### Team Stats

# %%
teams_stats = team_df.iloc[:,2:12]

# %%
teams_stats.GF = [int(item) for item in teams_stats.GF]
teams_stats.GA = [int(item) for item in teams_stats.GA]

# %%
teams_stats
# Out:
#          Team            name Played   W   L  D  GF  GA   GD Pts
# Position
# 1         LIV       Liverpool     17  16   0  1  42  14  +28  49
# 2         LEI       Leicester     18  12   3  3  41  14  +27  39
# 3         MCI        Man City     18  12   4  2  50  20  +30  38
# 4         CHE         Chelsea     18  10   6  2  33  25   +8  32
# 5         SHU   Sheffield Utd     18   7   4  7  22  16   +6  28
# 6         WOL          Wolves     18   6   3  9  26  22   +4  27
# 7         TOT           Spurs     18   7   6  5  32  26   +6  26
# 8         MUN         Man Utd     18   6   5  7  26  22   +4  25
# 9         NEW       Newcastle     18   7   7  4  18  24   -6  25
# 10        BUR         Burnley     18   7   8  3  23  29   -6  24
# 11        ARS         Arsenal     18   5   5  8  24  27   -3  23
# 12        CRY  Crystal Palace     18   6   7  5  15  20   -5  23
# 13        BHA        Brighton     18   5   8  5  21  26   -5  20
# 14        BOU     Bournemouth     18   5   9  4  19  25   -6  19
# 15        EVE         Everton     18   5   9  4  20  29   -9  19
# 16        WHU        West Ham     17   5   8  4  19  28   -9  19
# 17        SOU     Southampton     18   5  10  3  21  37  -16  18
# 18        AVL     Aston Villa     18   4  11  3  24  33   -9  15
# 19        NOR         Norwich     18   3  12  3  19  37  -18  12
# 20        WAT         Watford     18   2  10  6  11  32  -21  12

# %% [markdown]
# ### Worst/ Best  Defence vs. Offence

# %%
worst_defence_df = teams_stats.sort_values(by = ['GA'], ascending = False)

# %%
worst_defence_df.head()
# Out:
#          Team         name Played  W   L  D  GF  GA   GD Pts
# Position
# 19        NOR      Norwich     18  3  12  3  19  37  -18  12
# 17        SOU  Southampton     18  5  10  3  21  37  -16  18
# 18        AVL  Aston Villa     18  4  11  3  24  33   -9  15
# 20        WAT      Watford     18  2  10  6  11  32  -21  12
# 10        BUR      Burnley     18  7   8  3  23  29   -6  24

# %%
best_defence_df = teams_stats.sort_values(by = ['GA'], ascending = True)

# %%
best_defence_df.head()
# Out:
#          Team            name Played   W  L  D  GF  GA   GD Pts
# Position
# 1         LIV       Liverpool     17  16  0  1  42  14  +28  49
# 2         LEI       Leicester     18  12  3  3  41  14  +27  39
# 5         SHU   Sheffield Utd     18   7  4  7  22  16   +6  28
# 3         MCI        Man City     18  12  4  2  50  20  +30  38
# 12        CRY  Crystal Palace     18   6  7  5  15  20   -5  23

# %%
GA = list(zip(worst_defence_df.name, worst_defence_df.GA))
GA_bottom5 = GA[:7]
GA_top5 = sorted(GA[-7:], key = lambda x: x[1])

# %%
GA_bottom5, GA_top5
# Out:
# ([('Norwich', 37),
#   ('Southampton', 37),
#   ('Aston Villa', 33),
#   ('Watford', 32),
#   ('Burnley', 29),
#   ('Everton', 29),
#   ('West Ham', 28)],
#  [('Leicester', 14),
#   ('Liverpool', 14),
#   ('Sheffield Utd', 16),
#   ('Crystal Palace', 20),
#   ('Man City', 20),
#   ('Man Utd', 22),
#   ('Wolves', 22)])

# %%
teams_stats.GA.median()
# Out:
# 25.5

# %%
X = [item[0] for item in GA_bottom5]
Y = [int(item[1]) for item in GA_bottom5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GA_top5]
Y = [int(item[1]) for item in GA_top5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
offense_df = teams_stats.sort_values(by = ['GF'], ascending = False)

# %%
offense_df.head()
# Out:
#          Team       name Played   W  L  D  GF  GA   GD Pts
# Position
# 3         MCI   Man City     18  12  4  2  50  20  +30  38
# 1         LIV  Liverpool     17  16  0  1  42  14  +28  49
# 2         LEI  Leicester     18  12  3  3  41  14  +27  39
# 4         CHE    Chelsea     18  10  6  2  33  25   +8  32
# 7         TOT      Spurs     18   7  6  5  32  26   +6  26

# %%
GF = list(zip(offense_df.name, offense_df.GF))
GF_top5 = GF[:7]
GF_bottom5 = GF[-7:]

# %%
GF_top5, GF_bottom5
# Out:
# ([('Man City', 50),
#   ('Liverpool', 42),
#   ('Leicester', 41),
#   ('Chelsea', 33),
#   ('Spurs', 32),
#   ('Wolves', 26),
#   ('Man Utd', 26)],
#  [('Everton', 20),
#   ('Bournemouth', 19),
#   ('West Ham', 19),
#   ('Norwich', 19),
#   ('Newcastle', 18),
#   ('Crystal Palace', 15),
#   ('Watford', 11)])

# %%
X = [item[0] for item in GF_top5]
Y = [int(item[1]) for item in GF_top5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GF_bottom5]
Y = [int(item[1]) for item in GF_bottom5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stats_df = player_df[player_df.minutes >= min_min]

# %%
stats_df.tail()
# Out:
#      bonus  cost  minutes                 name  position  pts_per_90min  \
# 495      0   4.2      630      Adrian Mariappa  Defender           1.43
# 433      1   4.3      558         Maya Yoshida  Defender           1.61
# 220      0   5.3      629         Fabian Delph  Defender           1.71
# 150      0   4.9      671  Andreas Christensen  Defender           1.47
# 430      0   4.6      554           Yan Valery  Defender           1.46
#
#      red_cards   roi     status  team_code    team_name  total_points  \
# 495          0  2.38  available         57      Watford            10
# 433          0  2.33  available         20  Southampton            10
# 220          0  2.26  available         11      Everton            12
# 150          0  2.24  available          8      Chelsea            11
# 430          0  1.96    injured         20  Southampton             9
#
#      transfers_in  transfers_out
# 495          4195          11872
# 433         15447          25168
# 220          9125          26465
# 150         59473          97737
# 430          6427          23806

# %% [markdown]
# ### Cobine Team and Player Stats

# %%
team_dic = {item:[] for item in team_names}

for row, player in stats_df.iterrows():
    for name in team_names:
        if player.team_name == name:
            playa = dict(name = player['name'], position = player.position, cost = player.cost, minutes = player.minutes, 
                         points = player.total_points,  roi = player.roi, pts_per_90min = player.pts_per_90min, 
                         bonus = player.bonus, red_cards = player.red_cards)
            team_dic[name].append(playa)

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 409     12   5.2     1588  John Lundstram    Defender           5.38
# 406      6   5.0     1620  George Baldock    Defender           4.61
# 422      5   4.8     1530  Dean Henderson  Goalkeeper           4.47
# 85      10   4.6     1620  Aaron Ramsdale  Goalkeeper           4.00
# 436     21   6.5     1250      Danny Ings     Forward           7.12
#
#      red_cards    roi     status  team_code      team_name  total_points  \
# 409          0  18.27  available         49  Sheffield Utd            95
# 406          0  16.60  available         49  Sheffield Utd            83
# 422          0  15.83  available         49  Sheffield Utd            76
# 85           0  15.65  available         91    Bournemouth            72
# 436          0  15.23  available         20    Southampton            99
#
#      transfers_in  transfers_out
# 409       3205737         357562
# 406        733062          85090
# 422        678997         209899
# 85         487246         146400
# 436       1214100         408630

# %%
team_dic['Liverpool']
# Out:
# [{'name': 'Virgil van Dijk',
#   'position': 'Defender',
#   'cost': 6.4,
#   'minutes': 1530,
#   'points': 73,
#   'roi': 11.41,
#   'pts_per_90min': 4.29,
#   'bonus': 7,
#   'red_cards': 0},
#  {'name': 'Andrew Robertson',
#   'position': 'Defender',
#   'cost': 7.0,
#   'minutes': 1456,
#   'points': 73,
#   'roi': 10.43,
#   'pts_per_90min': 4.51,
#   'bonus': 8,
#   'red_cards': 0},
#  {'name': 'Trent Alexander-Arnold',
#   'position': 'Defender',
#   'cost': 7.2,
#   'minutes': 1482,
#   'points': 74,
#   'roi': 10.28,
#   'pts_per_90min': 4.49,
#   'bonus': 7,
#   'red_cards': 0},
#  {'name': 'Sadio Mané',
#   'position': 'Midfielder',
#   'cost': 12.2,
#   'minutes': 1326,
#   'points': 115,
#   'roi': 9.43,
#   'pts_per_90min': 7.8,
#   'bonus': 15,
#   'red_cards': 0},
#  {'name': 'Georginio Wijnaldum',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 1317,
#   'points': 48,
#   'roi': 8.89,
#   'pts_per_90min': 3.28,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Jordan Henderson',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 1085,
#   'points': 48,
#   'roi': 8.89,
#   'pts_per_90min': 3.98,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'cost': 12.2,
#   'minutes': 1190,
#   'points': 104,
#   'roi': 8.52,
#   'pts_per_90min': 7.86,
#   'bonus': 13,
#   'red_cards': 0},
#  {'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'cost': 9.2,
#   'minutes': 1355,
#   'points': 75,
#   'roi': 8.15,
#   'pts_per_90min': 4.98,
#   'bonus': 12,
#   'red_cards': 0},
#  {'name': 'Joel Matip',
#   'position': 'Defender',
#   'cost': 5.2,
#   'minutes': 630,
#   'points': 32,
#   'roi': 6.15,
#   'pts_per_90min': 4.56,
#   'bonus': 4,
#   'red_cards': 0},
#  {'name': 'James Milner',
#   'position': 'Midfielder',
#   'cost': 5.3,
#   'minutes': 548,
#   'points': 32,
#   'roi': 6.04,
#   'pts_per_90min': 5.25,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Adrián San Miguel del Castillo',
#   'position': 'Goalkeeper',
#   'cost': 4.2,
#   'minutes': 783,
#   'points': 25,
#   'roi': 5.95,
#   'pts_per_90min': 2.87,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Fabio Henrique Tavares',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 1006,
#   'points': 32,
#   'roi': 5.93,
#   'pts_per_90min': 2.86,
#   'bonus': 4,
#   'red_cards': 0},
#  {'name': 'Alex Oxlade-Chamberlain',
#   'position': 'Midfielder',
#   'cost': 6.2,
#   'minutes': 507,
#   'points': 25,
#   'roi': 4.03,
#   'pts_per_90min': 4.43,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Alisson Ramses Becker',
#   'position': 'Goalkeeper',
#   'cost': 6.0,
#   'minutes': 743,
#   'points': 24,
#   'roi': 4.0,
#   'pts_per_90min': 2.9,
#   'bonus': 0,
#   'red_cards': 1},
#  {'name': 'Dejan Lovren',
#   'position': 'Defender',
#   'cost': 5.3,
#   'minutes': 669,
#   'points': 16,
#   'roi': 3.02,
#   'pts_per_90min': 2.15,
#   'bonus': 0,
#   'red_cards': 0}]

# %% [markdown]
# ### Get Final Stats per Team using Pandas

# %%
team_stats = {item:{} for item in team_names}

for team in team_names:
    active_players = len(stats_df[stats_df.team_name == team].cost)
    tot_cost = round(stats_df[stats_df.team_name == team].cost.sum(), 3)
    tot_pts = round(stats_df[stats_df.team_name == team].total_points.sum(), 3)
    avg_player_roi = round(tot_pts / tot_cost, 3)
    avg_pts_per_player = round(tot_pts / active_players, 3)
    
    stats = dict(active_players = active_players, tot_cost = tot_cost, tot_pts = tot_pts,
               avg_pts_per_player = avg_pts_per_player,  avg_player_roi =  avg_player_roi)
    
    team_stats[team].update(stats)

# %%
team_stats['Newcastle']
# Out:
# {'active_players': 16,
#  'tot_cost': 77.5,
#  'tot_pts': 650,
#  'avg_pts_per_player': 40.625,
#  'avg_player_roi': 8.387}

# %%
team_stats_df = pd.DataFrame(team_stats).T

# %%
team_stats_df.sort_values(by = ['avg_pts_per_player'], ascending = False, inplace = True)

# %%
team_stats_df
# Out:
#                 active_players  avg_player_roi  avg_pts_per_player  tot_cost  \
# Leicester                 11.0          12.305              77.636      69.4
# Sheffield Utd             13.0          11.914              59.385      64.8
# Man City                  16.0           7.746              56.062     115.8
# Wolves                    12.0          10.046              54.333      64.9
# Liverpool                 15.0           7.758              53.067     102.6
# Chelsea                   14.0           8.485              49.214      81.2
# Burnley                   13.0           9.365              48.769      67.7
# Crystal Palace            13.0           8.878              46.846      68.6
# Aston Villa               14.0           8.791              43.643      69.5
# Man Utd                   13.0           7.305              43.154      76.8
# Bournemouth               15.0           7.941              41.400      78.2
# Brighton                  15.0           8.408              41.200      73.5
# Newcastle                 16.0           8.387              40.625      77.5
# Spurs                     17.0           6.340              40.353     108.2
# West Ham                  15.0           7.433              38.600      77.9
# Arsenal                   16.0           6.389              37.938      95.0
# Everton                   17.0           6.246              35.235      95.9
# Norwich                   16.0           6.917              33.375      77.2
# Watford                   17.0           6.305              31.824      85.8
# Southampton               16.0           6.432              31.438      78.2
#
#                 tot_pts
# Leicester         854.0
# Sheffield Utd     772.0
# Man City          897.0
# Wolves            652.0
# Liverpool         796.0
# Chelsea           689.0
# Burnley           634.0
# Crystal Palace    609.0
# Aston Villa       611.0
# Man Utd           561.0
# Bournemouth       621.0
# Brighton          618.0
# Newcastle         650.0
# Spurs             686.0
# West Ham          579.0
# Arsenal           607.0
# Everton           599.0
# Norwich           534.0
# Watford           541.0
# Southampton       503.0

# %% [markdown]
# ### Build a team using 90min Stat

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_90min:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))
        
print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Vicente Guaita
# GK budget left: 4.4
# Player Selected: Angus Gunn
# GK budget left: 0.0
# ['Vicente Guaita', 'Angus Gunn']
# ['Crystal Palace', 'Southampton']

# %% [markdown]
# ### Select top 3 players by points per position

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 28.499999999999996 36.0 26.0
# Player Selected: James Tarkowski
# DF budget left: 23.4
# Player Selected: Kevin De Bruyne
# MD budget left: 25.6
# ['Vicente Guaita', 'Angus Gunn', 'James Tarkowski', 'Kevin De Bruyne']
# ['Crystal Palace', 'Southampton', 'Burnley', 'Man City']

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Marcus Rashford
# ST budget left: 16.9
# 5
# ['Vicente Guaita', 'Angus Gunn', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford']
# ['Crystal Palace', 'Southampton', 'Burnley', 'Man City', 'Man Utd']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with 90_min_stats

# %%
for item in DF_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Marcos Alonso
# DF budget left: 17.4
# Player Selected: Martin Kelly
# DF budget left: 12.999999999999998
# Player Selected: Nicolás Otamendi
# DF budget left: 7.999999999999998
# # of DFs selected: 4
# Player Selected: Benjamin Mendy
# DF budget left: 2.4999999999999982
# # of DFs selected: 5
# 9
# ['Vicente Guaita', 'Angus Gunn', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Marcos Alonso', 'Martin Kelly', 'Nicolás Otamendi', 'Benjamin Mendy']
# ['Crystal Palace', 'Southampton', 'Burnley', 'Man City', 'Man Utd', 'Chelsea', 'Crystal Palace', 'Man City', 'Man City']

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Bamidele Alli
# MD budget left: 19.3
# Player Selected: Christian Pulisic
# MD budget left: 12.0
# Player Selected: Willian Borges Da Silva
# MD budget left: 5.0
# Player Selected: Todd Cantwell
# MD budget left: 0.20000000000000018
# 13
# ['Vicente Guaita', 'Angus Gunn', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Marcos Alonso', 'Martin Kelly', 'Nicolás Otamendi', 'Benjamin Mendy', 'Bamidele Alli', 'Christian Pulisic', 'Willian Borges Da Silva', 'Todd Cantwell']
# ['Crystal Palace', 'Southampton', 'Burnley', 'Man City', 'Man Utd', 'Chelsea', 'Crystal Palace', 'Man City', 'Man City', 'Spurs', 'Chelsea', 'Chelsea', 'Norwich']

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Danny Ings
# ST budget left: 10.599999999999998
# Player Selected: Alexandre Lacazette
# ST budget left: 1.2999999999999972
# 15
# ['Vicente Guaita', 'Angus Gunn', 'James Tarkowski', 'Kevin De Bruyne', 'Marcus Rashford', 'Marcos Alonso', 'Martin Kelly', 'Nicolás Otamendi', 'Benjamin Mendy', 'Bamidele Alli', 'Christian Pulisic', 'Willian Borges Da Silva', 'Todd Cantwell', 'Danny Ings', 'Alexandre Lacazette']
# ['Crystal Palace', 'Southampton', 'Burnley', 'Man City', 'Man Utd', 'Chelsea', 'Crystal Palace', 'Man City', 'Man City', 'Spurs', 'Chelsea', 'Chelsea', 'Norwich', 'Southampton', 'Arsenal']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                     name    position  pts_per_90min  \
# 0      10   5.1     1440           Vicente Guaita  Goalkeeper           4.43
# 1       3   4.4      900               Angus Gunn  Goalkeeper           2.90
# 2       9   5.1     1620          James Tarkowski    Defender           3.83
# 3      16  10.4     1402          Kevin De Bruyne  Midfielder           7.70
# 4      20   9.1     1576          Marcus Rashford     Forward           5.99
# 5       5   6.0      588            Marcos Alonso    Defender           7.18
# 6       4   4.4     1044             Martin Kelly    Defender           4.65
# 7       2   5.0      904         Nicolás Otamendi    Defender           4.57
# 8       0   5.5      561           Benjamin Mendy    Defender           4.16
# 9       8   8.8      893            Bamidele Alli  Midfielder           6.34
# 10      5   7.3      981        Christian Pulisic  Midfielder           6.05
# 11     12   7.0     1187  Willian Borges Da Silva  Midfielder           5.68
# 12      8   4.8     1275            Todd Cantwell  Midfielder           5.01
# 13     21   6.5     1250               Danny Ings     Forward           7.12
# 14      6   9.3      673      Alexandre Lacazette     Forward           6.41
#
#     red_cards    roi     status  team_code       team_name  total_points  \
# 0           0  13.92  available         31  Crystal Palace            71
# 1           0   6.59  available         20     Southampton            29
# 2           0  13.53  available         90         Burnley            69
# 3           0  11.54  available         43        Man City           120
# 4           0  11.54  available          1         Man Utd           105
# 5           0   7.83  available          8         Chelsea            47
# 6           0  12.27  available         31  Crystal Palace            54
# 7           0   9.20  available         43        Man City            46
# 8           0   4.73  available         43        Man City            26
# 9           0   7.16  available          6           Spurs            63
# 10          0   9.04  available          8         Chelsea            66
# 11          0  10.71  available          8         Chelsea            75
# 12          0  14.79  available         45         Norwich            71
# 13          0  15.23  available         20     Southampton            99
# 14          0   5.16  available          3         Arsenal            48
#
#     transfers_in  transfers_out
# 0         248814          68169
# 1         241814         199266
# 2         336000         157192
# 3        3961098        2054597
# 4        2462471        1800838
# 5         248181         424447
# 6        1595472         904399
# 7         658863         617656
# 8         181355         158944
# 9        1160370         190129
# 10       1385600        1326149
# 11        370799         244768
# 12       2751018        1434312
# 13       1214100         408630
# 14        190434         332047

# %%
money_x = money_df.pts_per_90min
money_y = money_df.name
ST_75th = round(money_df.describe().pts_per_90min['75%'], 2)
ST_AVG = round(money_df.describe().pts_per_90min['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by pts_per_90min Stat', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('Team_pts_per90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top100_users = pd.read_csv('fEPL_user_data_test.csv', index_col='users')

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# Raushan Uttamchandani     1      1229681          1216                55
# Matthew Troha             2       933902          1215                66
# kenneth herlihy           3      1734934          1201                50
# nick tanner               4       568651          1197                32
# Jay Boss                  5      1852022          1193                68
#
#                                                       formation  \
# users
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Matthew Troha          {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kenneth herlihy        {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Jay Boss               {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
#
#                                       GKP_1              GKP_2  \
# users
# Raushan Uttamchandani        Ryan-BHA-start     Martin-WHU-sub
# Matthew Troha          Schmeichel-LEI-start   McGovern-NOR-sub
# kenneth herlihy          Patrício-WOL-start     Button-BHA-sub
# nick tanner                  Ryan-BHA-start   McGovern-NOR-sub
# Jay Boss                Henderson-SHU-start  Gazzaniga-TOT-sub
#
#                                    DEF_1                DEF_2  \
# users
# Raushan Uttamchandani   Aurier-TOT-start      Kelly-CRY-start
# Matthew Troha             Rico-BOU-start  Lundstram-SHU-start
# kenneth herlihy        Söyüncü-LEI-start       Dunk-BHA-start
# nick tanner               Dunk-BHA-start       Rico-BOU-start
# Jay Boss               Söyüncü-LEI-start  Lundstram-SHU-start
#
#                                      DEF_3  ...                     DEF_5  \
# users                                       ...
# Raushan Uttamchandani  Lundstram-SHU-start  ...         Robertson-LIV-sub
# Matthew Troha              Kelly-CRY-start  ...         Robertson-LIV-sub
# kenneth herlihy        Lundstram-SHU-start  ...  Alexander-Arnold-LIV-sub
# nick tanner            Lundstram-SHU-start  ...             Kelly-CRY-sub
# Jay Boss                   Kelly-CRY-start  ...              Dunk-BHA-sub
#
#                                     MID_1                  MID_2  \
# users
# Raushan Uttamchandani       Son-TOT-start    De Bruyne-MCI-start
# Matthew Troha          Cantwell-NOR-start      Pulisic-CHE-start
# kenneth herlihy        Maddison-LEI-start  Richarlison-EVE-start
# nick tanner            Maddison-LEI-start          Son-TOT-start
# Jay Boss               Cantwell-NOR-start          Son-TOT-start
#
#                                       MID_3                  MID_4  \
# users
# Raushan Uttamchandani  Dendoncker-WOL-start  Lucas Moura-TOT-start
# Matthew Troha           De Bruyne-MCI-start         Alli-TOT-start
# kenneth herlihy         De Bruyne-MCI-start     Grealish-AVL-start
# nick tanner             De Bruyne-MCI-start         Alli-TOT-start
# Jay Boss                De Bruyne-MCI-start     Maddison-LEI-start
#
#                                       MID_5              FWD_1  \
# users
# Raushan Uttamchandani          Mané-LIV-sub    Vardy-LEI-start
# Matthew Troha                  Mané-LIV-sub     Kane-TOT-start
# kenneth herlihy        Douglas Luiz-AVL-sub  Jiménez-WOL-start
# nick tanner                  McGinn-AVL-sub     Kane-TOT-start
# Jay Boss                       Mané-LIV-sub  Jiménez-WOL-start
#
#                                     FWD_2               FWD_3  \
# users
# Raushan Uttamchandani      Ings-SOU-start  Rashford-MUN-start
# Matthew Troha              Ings-SOU-start     Vardy-LEI-start
# kenneth herlihy           Vardy-LEI-start  Rashford-MUN-start
# nick tanner            Rashford-MUN-start     Vardy-LEI-start
# Jay Boss                  Vardy-LEI-start      Ings-SOU-start
#
#                                                          user_team_pages
# users
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
# Matthew Troha          https://fantasy.premierleague.com/entry/933902...
# kenneth herlihy        https://fantasy.premierleague.com/entry/173493...
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# Jay Boss               https://fantasy.premierleague.com/entry/185202...
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Get Stats of top 100 players

# %%
y =list(top100_users.game_week_points)
z =list(top100_users.total_points)

mean = np.mean(y)
maxi = np.max(y)
mini = np.min(y)

plt.scatter(z, y)
plt.ylim(bottom=0)
plt.axhline(y=maxi, color='#1D28D2', linestyle='-', label='Max Top_100 = ' + str(maxi) +'pts')
plt.axhline(y=mean, color='#33D977', linestyle='-', label='Mean Top_100 = ' + str(mean) +'pts')
plt.axhline(y=mini, color='#D2461D', linestyle='-', label='Min Top_100 = ' + str(mini) +'pts')
plt.ylabel('Points GW-'+ str(gameweek-1), fontsize = 24, color = '#073997')
plt.xlabel('Total Points', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 100 Players in the World Stats', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Top10_Stats', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to extract names from player string

# %%
def partition_names(names_list):
    clean_list = [item.partition("-")[0] for item in names_list]
    return clean_list

# %% [markdown]
# ### Function to get the list of all selected players by position

# %%
def get_top100_teams(team_df):
    #create lists by position
    #GK_list
    GK_list = list(team_df.GKP_1)
    GK_list.extend(list(team_df.GKP_2))
    GK_final = partition_names(GK_list)
    
    #DF_list
    DF_list = list(team_df.DEF_1)
    DF_list.extend(list(team_df.DEF_2))
    DF_list.extend(list(team_df.DEF_3))
    DF_list.extend(list(team_df.DEF_4))
    DF_list.extend(list(team_df.DEF_5))
    DF_final = partition_names(DF_list)
    
    #MD_list
    MD_list = list(team_df.MID_1)
    MD_list.extend(list(team_df.MID_2))
    MD_list.extend(list(team_df.MID_3))
    MD_list.extend(list(team_df.MID_4))
    MD_list.extend(list(team_df.MID_5))
    MD_final = partition_names(MD_list)
    
    #ST_list
    ST_list = list(team_df.FWD_1)
    ST_list.extend(list(team_df.FWD_2))
    ST_list.extend(list(team_df.FWD_3))
    ST_final = partition_names(ST_list)
    
    return GK_final, DF_final, MD_final, ST_final

# %%
#get the final clean list of players per position
GK_final, DF_final, MD_final, ST_final = get_top100_teams(top100_users)[0], get_top100_teams(top100_users)[1], get_top100_teams(top100_users)[2], get_top100_teams(top100_users)[3]

# %%
GK_final[:3]
# Out:
# ['Ryan', 'Schmeichel', 'Patrício']

# %%
MD_final[:3]
# Out:
# ['Son', 'Cantwell', 'Maddison']

# %%
DF_final[:3]
# Out:
# ['Aurier', 'Rico', 'Söyüncü']

# %%
ST_final[:3]
# Out:
# ['Vardy', 'Kane', 'Jiménez']

# %% [markdown]
# ### Function to get you top_n players by position ordered by # of times they were picked

# %%
def return_top_n(players, top_n = 10):
    ranked = Counter(players).most_common(top_n)
    return ranked

# %%
GK_top10 = return_top_n(GK_final)

# %%
GK_top10
# Out:
# [('Pope', 38),
#  ('Ryan', 32),
#  ('Button', 22),
#  ('Henderson', 20),
#  ('Gazzaniga', 18),
#  ('Schmeichel', 13),
#  ('Guaita', 9),
#  ('Martin', 9),
#  ('Heaton', 8),
#  ('McGovern', 8)]

# %%
DF_top10 = return_top_n(DF_final)

# %%
DF_top10
# Out:
# [('Lundstram', 98),
#  ('Kelly', 72),
#  ('Söyüncü', 51),
#  ('Alexander', 38),
#  ('Rico', 34),
#  ('Aurier', 27),
#  ('Pereira', 23),
#  ('Dunk', 15),
#  ('Robertson', 15),
#  ('Baldock', 13)]

# %%
MD_top10 = return_top_n(MD_final)

# %%
MD_top10
# Out:
# [('De Bruyne', 89),
#  ('Mané', 61),
#  ('Maddison', 54),
#  ('Son', 43),
#  ('Grealish', 34),
#  ('Alli', 29),
#  ('Cantwell', 24),
#  ('Zaha', 22),
#  ('Richarlison', 20),
#  ('Dendoncker', 16)]

# %%
ST_top10 = return_top_n(ST_final)

# %%
ST_top10
# Out:
# [('Vardy', 98),
#  ('Ings', 58),
#  ('Jiménez', 39),
#  ('Abraham', 36),
#  ('Rashford', 32),
#  ('Kane', 13),
#  ('Mousset', 10),
#  ('Greenwood', 3),
#  ('Pukki', 2),
#  ('Connolly', 2)]

# %%
X = [item[0] for item in GK_top10]
Y = [item[1] for item in GK_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Goalkeepers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_GK', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in DF_top10]
Y = [item[1] for item in DF_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Defenders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in MD_top10]
Y = [item[1] for item in MD_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Midfielders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_MD', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in ST_top10]
Y = [item[1] for item in ST_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Strikers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_ST', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top_managers_team = GK_top10[:2]+ DF_top10[:5] + MD_top10[:5] + ST_top10[:3]

# %%
top_managers_team
# Out:
# [('Pope', 38),
#  ('Ryan', 32),
#  ('Lundstram', 98),
#  ('Kelly', 72),
#  ('Söyüncü', 51),
#  ('Alexander', 38),
#  ('Rico', 34),
#  ('De Bruyne', 89),
#  ('Mané', 61),
#  ('Maddison', 54),
#  ('Son', 43),
#  ('Grealish', 34),
#  ('Vardy', 98),
#  ('Ings', 58),
#  ('Jiménez', 39)]

# %%
X = [item[0] for item in top_managers_team]
Y = [item[1] for item in top_managers_team]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top100 Players Optimal Team', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Team', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Latest Injury Updates from independant site that updates faster than the Fantasy site

# %%
injuries = 'http://www.premierinjuries.com/?fbclid=IwAR1Uz0TTwRMOvsq1jlefIztPPg7qtPdnag3zrHxh_39wV4CZoMG0ZWq6MYU'
injuries_tab = pd.read_html(injuries)[0]

# %%
injuries_tab
# Out:
#                     Player                   Reason
# 0       Gabriel Martinelli             Thigh Injury
# 1              Ryan Fraser                    Other
# 2              Simon Moore  Groin/Hip/Pelvic Injury
# 3        Cesar Azpilicueta             Thigh Injury
# 4  Alex Oxlade-Chamberlain        Ankle/Foot Injury
# 5           Ilkay Gundogan                    Other
# 6            Harvey Barnes        Ankle/Foot Injury
# 7             Paul Dummett  Groin/Hip/Pelvic Injury
# 8            Simon Francis         Head/Face Injury
# 9              John McGinn        Ankle/Foot Injury

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# Raushan Uttamchandani     1      1229681          1216                55
# Matthew Troha             2       933902          1215                66
# kenneth herlihy           3      1734934          1201                50
# nick tanner               4       568651          1197                32
# Jay Boss                  5      1852022          1193                68
#
#                                                       formation  \
# users
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Matthew Troha          {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kenneth herlihy        {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Jay Boss               {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
#
#                                       GKP_1              GKP_2  \
# users
# Raushan Uttamchandani        Ryan-BHA-start     Martin-WHU-sub
# Matthew Troha          Schmeichel-LEI-start   McGovern-NOR-sub
# kenneth herlihy          Patrício-WOL-start     Button-BHA-sub
# nick tanner                  Ryan-BHA-start   McGovern-NOR-sub
# Jay Boss                Henderson-SHU-start  Gazzaniga-TOT-sub
#
#                                    DEF_1                DEF_2  \
# users
# Raushan Uttamchandani   Aurier-TOT-start      Kelly-CRY-start
# Matthew Troha             Rico-BOU-start  Lundstram-SHU-start
# kenneth herlihy        Söyüncü-LEI-start       Dunk-BHA-start
# nick tanner               Dunk-BHA-start       Rico-BOU-start
# Jay Boss               Söyüncü-LEI-start  Lundstram-SHU-start
#
#                                      DEF_3  ...                     DEF_5  \
# users                                       ...
# Raushan Uttamchandani  Lundstram-SHU-start  ...         Robertson-LIV-sub
# Matthew Troha              Kelly-CRY-start  ...         Robertson-LIV-sub
# kenneth herlihy        Lundstram-SHU-start  ...  Alexander-Arnold-LIV-sub
# nick tanner            Lundstram-SHU-start  ...             Kelly-CRY-sub
# Jay Boss                   Kelly-CRY-start  ...              Dunk-BHA-sub
#
#                                     MID_1                  MID_2  \
# users
# Raushan Uttamchandani       Son-TOT-start    De Bruyne-MCI-start
# Matthew Troha          Cantwell-NOR-start      Pulisic-CHE-start
# kenneth herlihy        Maddison-LEI-start  Richarlison-EVE-start
# nick tanner            Maddison-LEI-start          Son-TOT-start
# Jay Boss               Cantwell-NOR-start          Son-TOT-start
#
#                                       MID_3                  MID_4  \
# users
# Raushan Uttamchandani  Dendoncker-WOL-start  Lucas Moura-TOT-start
# Matthew Troha           De Bruyne-MCI-start         Alli-TOT-start
# kenneth herlihy         De Bruyne-MCI-start     Grealish-AVL-start
# nick tanner             De Bruyne-MCI-start         Alli-TOT-start
# Jay Boss                De Bruyne-MCI-start     Maddison-LEI-start
#
#                                       MID_5              FWD_1  \
# users
# Raushan Uttamchandani          Mané-LIV-sub    Vardy-LEI-start
# Matthew Troha                  Mané-LIV-sub     Kane-TOT-start
# kenneth herlihy        Douglas Luiz-AVL-sub  Jiménez-WOL-start
# nick tanner                  McGinn-AVL-sub     Kane-TOT-start
# Jay Boss                       Mané-LIV-sub  Jiménez-WOL-start
#
#                                     FWD_2               FWD_3  \
# users
# Raushan Uttamchandani      Ings-SOU-start  Rashford-MUN-start
# Matthew Troha              Ings-SOU-start     Vardy-LEI-start
# kenneth herlihy           Vardy-LEI-start  Rashford-MUN-start
# nick tanner            Rashford-MUN-start     Vardy-LEI-start
# Jay Boss                  Vardy-LEI-start      Ings-SOU-start
#
#                                                          user_team_pages
# users
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
# Matthew Troha          https://fantasy.premierleague.com/entry/933902...
# kenneth herlihy        https://fantasy.premierleague.com/entry/173493...
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# Jay Boss               https://fantasy.premierleague.com/entry/185202...
#
# [5 rows x 21 columns]

# %%
test = top100_users.formation

# %% [markdown]
# ### Extract formations as a list in a readable format

# %%
formations = [item.split(",")[1][8] + "-" + item.split(",")[2][8] + "-" + item.split(",")[3][8] for item in test]

# %%
formations[:5]
# Out:
# ['3-4-3', '3-4-3', '3-4-3', '3-4-3', '3-4-3']

# %% [markdown]
# ### Use top_n function to get a tuple of ranked formations by count

# %%
top_form = return_top_n(formations, 6)

# %%
top_form
# Out:
# [('3-4-3', 59), ('4-3-3', 29), ('3-5-2', 7), ('4-4-2', 4), ('5-2-3', 1)]

# %%
X = [item[0] for item in top_form]
Y = [item[1] for item in top_form]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 100 Formations Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Forma', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
