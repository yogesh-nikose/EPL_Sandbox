# %% [markdown]
# ### Import Major Libraries

# %%
import json
import requests
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# ## Define Gameweek and Periods for FDR calculation

# %%
gameweek = 10
next_n_games = 2

#define percentage of time player needs to have played to be counted as active
min_min = ((gameweek-1)*90)/4     #<---- Currently 25% of playtime
print(min_min)
# Out:
# 202.5

# %% [markdown]
# ## Define Budget, Team Formation, and Budget Allocation by Position

# %%
#Budget
budget = 100

#Team Formation
DF = 3
MD = 4
ST = 3

#Total players needed per position
DF_max = 5
MD_max = 5
ST_max = 3

#Budget Allocation
GK_coef = 0.095
DF_coef = 0.285
MD_coef = 0.36
ST_coef = 0.26

print(sum([GK_coef, DF_coef, MD_coef, ST_coef]))
# Out:
# 1.0

# %% [markdown]
# ## Scraped list of Schedules

# %%
schedules = ['Arsenal NEW (A) BUR (H) LIV (A) TOT (H) WAT (A) AVL (H) MUN (A) BOU (H) SHU (A) CRY (H) WOL (H) LEI (A) SOU (H) NOR (A) BHA (H) WHU (A) MCI (H) EVE (A) BOU (A) CHE (H) MUN (H) CRY (A) SHU (H) CHE (A) BUR (A) NEW (H) EVE (H) MCI (A) WHU (H) BHA (A) SOU (A) NOR (H) WOL (A) LEI (H) TOT (A) LIV (H) AVL (A) WAT (H)',
 'Aston Villa TOT (A) BOU (H) EVE (H) CRY (A) WHU (H) ARS (A) BUR (H) NOR (A) BHA (H) MCI (A) LIV (H) WOL (A) NEW (H) MUN (A) CHE (A) LEI (H) SHU (A) SOU (H) NOR (H) WAT (A) BUR (A) MCI (H) BHA (A) WAT (H) BOU (A) TOT (H) SOU (A) SHU (H) LEI (A) CHE (H) NEW (A) WOL (H) LIV (A) MUN (H) CRY (H) EVE (A) ARS (H) WHU (A)',
 'Bournemouth SHU (H) AVL (A) MCI (H) LEI (A) EVE (H) SOU (A) WHU (H) ARS (A) NOR (H) WAT (A) MUN (H) NEW (A) WOL (H) TOT (A) CRY (A) LIV (H) CHE (A) BUR (H) ARS (H) BHA (A) WHU (A) WAT (H) NOR (A) BHA (H) AVL (H) SHU (A) BUR (A) CHE (H) LIV (A) CRY (H) WOL (A) NEW (H) MUN (A) TOT (H) LEI (H) MCI (A) SOU (H) EVE (A)',
 'Brighton WAT (A) WHU (H) SOU (H) MCI (A) BUR (H) NEW (A) CHE (A) TOT (H) AVL (A) EVE (H) NOR (H) MUN (A) LEI (H) LIV (A) ARS (A) WOL (H) CRY (A) SHU (H) TOT (A) BOU (H) CHE (H) EVE (A) AVL (H) BOU (A) WHU (A) WAT (H) SHU (A) CRY (H) WOL (A) ARS (H) LEI (A) MUN (H) NOR (A) LIV (H) MCI (H) SOU (A) NEW (H) BUR (A)',
 'Burnley SOU (H) ARS (A) WOL (A) LIV (H) BHA (A) NOR (H) AVL (A) EVE (H) LEI (A) CHE (H) SHU (A) WHU (H) WAT (A) CRY (H) MCI (H) TOT (A) NEW (H) BOU (A) EVE (A) MUN (H) AVL (H) CHE (A) LEI (H) MUN (A) ARS (H) SOU (A) BOU (H) NEW (A) TOT (H) MCI (A) WAT (H) CRY (A) SHU (H) WHU (A) LIV (A) WOL (H) NOR (A) BHA (H)',
 'Chelsea MUN (A) LEI (H) NOR (A) SHU (H) WOL (A) LIV (H) BHA (H) SOU (A) NEW (H) BUR (A) WAT (A) CRY (H) MCI (A) WHU (H) AVL (H) EVE (A) BOU (H) TOT (A) SOU (H) ARS (A) BHA (A) BUR (H) NEW (A) ARS (H) LEI (A) MUN (H) TOT (H) BOU (A) EVE (H) AVL (A) MCI (H) WHU (A) WAT (H) CRY (A) SHU (A) NOR (H) LIV (A) WOL (H)',
 'Crystal Palace EVE (H) SHU (A) MUN (A) AVL (H) TOT (A) WOL (H) NOR (H) WHU (A) MCI (H) ARS (A) LEI (H) CHE (A) LIV (H) BUR (A) BOU (H) WAT (A) BHA (H) NEW (A) WHU (H) SOU (A) NOR (A) ARS (H) MCI (A) SOU (H) SHU (H) EVE (A) NEW (H) BHA (A) WAT (H) BOU (A) LIV (A) BUR (H) LEI (A) CHE (H) AVL (A) MUN (H) WOL (A) TOT (H)',
 'Everton CRY (A) WAT (H) AVL (A) WOL (H) BOU (A) SHU (H) MCI (H) BUR (A) WHU (H) BHA (A) TOT (H) SOU (A) NOR (H) LEI (A) LIV (A) CHE (H) MUN (A) ARS (H) BUR (H) NEW (A) MCI (A) BHA (H) WHU (A) NEW (H) WAT (A) CRY (H) ARS (A) MUN (H) CHE (A) LIV (H) NOR (A) LEI (H) TOT (A) SOU (H) WOL (A) AVL (H) SHU (A) BOU (H)',
 'Leicester WOL (H) CHE (A) SHU (A) BOU (H) MUN (A) TOT (H) NEW (H) LIV (A) BUR (H) SOU (A) CRY (A) ARS (H) BHA (A) EVE (H) WAT (H) AVL (A) NOR (H) MCI (A) LIV (H) WHU (A) NEW (A) SOU (H) BUR (A) WHU (H) CHE (H) WOL (A) MCI (H) NOR (A) AVL (H) WAT (A) BHA (H) EVE (A) CRY (H) ARS (A) BOU (A) SHU (H) TOT (A) MUN (H)',
 'Liverpool NOR (H) SOU (A) ARS (H) BUR (A) NEW (H) CHE (A) SHU (A) LEI (H) MUN (A) TOT (H) AVL (A) MCI (H) CRY (A) BHA (H) EVE (H) BOU (A) WAT (H) WHU (A) LEI (A) WOL (H) SHU (H) TOT (A) MUN (H) WOL (A) SOU (H) NOR (A) WHU (H) WAT (A) BOU (H) EVE (A) CRY (H) MCI (A) AVL (H) BHA (A) BUR (H) ARS (A) CHE (H) NEW (A)',
 'Man City WHU (A) TOT (H) BOU (A) BHA (H) NOR (A) WAT (H) EVE (A) WOL (H) CRY (A) AVL (H) SOU (H) LIV (A) CHE (H) NEW (A) BUR (A) MUN (H) ARS (A) LEI (H) WOL (A) SHU (H) EVE (H) AVL (A) CRY (H) SHU (A) TOT (A) WHU (H) LEI (A) ARS (H) MUN (A) BUR (H) CHE (A) LIV (H) SOU (A) NEW (H) BHA (A) BOU (H) WAT (A) NOR (H)',
 'Man Utd CHE (H) WOL (A) CRY (H) SOU (A) LEI (H) WHU (A) ARS (H) NEW (A) LIV (H) NOR (A) BOU (A) BHA (H) SHU (A) AVL (H) TOT (H) MCI (A) EVE (H) WAT (A) NEW (H) BUR (A) ARS (A) NOR (H) LIV (A) BUR (H) WOL (H) CHE (A) WAT (H) EVE (A) MCI (H) TOT (A) SHU (H) BHA (A) BOU (H) AVL (A) SOU (H) CRY (A) WHU (H) LEI (A)',
 'Newcastle ARS (H) NOR (A) TOT (A) WAT (H) LIV (A) BHA (H) LEI (A) MUN (H) CHE (A) WOL (H) WHU (A) BOU (H) AVL (A) MCI (H) SHU (A) SOU (H) BUR (A) CRY (H) MUN (A) EVE (H) LEI (H) WOL (A) CHE (H) EVE (A) NOR (H) ARS (A) CRY (A) BUR (H) SOU (A) SHU (H) AVL (H) BOU (A) WHU (H) MCI (A) WAT (A) TOT (H) BHA (A) LIV (H)',
 'Norwich LIV (A) NEW (H) CHE (H) WHU (A) MCI (H) BUR (A) CRY (A) AVL (H) BOU (A) MUN (H) BHA (A) WAT (H) EVE (A) ARS (H) SOU (A) SHU (H) LEI (A) WOL (H) AVL (A) TOT (H) CRY (H) MUN (A) BOU (H) TOT (A) NEW (A) LIV (H) WOL (A) LEI (H) SHU (A) SOU (H) EVE (H) ARS (A) BHA (H) WAT (A) WHU (H) CHE (A) BUR (H) MCI (A)',
 'Sheffield Utd BOU (A) CRY (H) LEI (H) CHE (A) SOU (H) EVE (A) LIV (H) WAT (A) ARS (H) WHU (A) BUR (H) TOT (A) MUN (H) WOL (A) NEW (H) NOR (A) AVL (H) BHA (A) WAT (H) MCI (A) LIV (A) WHU (H) ARS (A) MCI (H) CRY (A) BOU (H) BHA (H) AVL (A) NOR (H) NEW (A) MUN (A) TOT (H) BUR (A) WOL (H) CHE (H) LEI (A) EVE (H) SOU (A)',
 'Southampton BUR (A) LIV (H) BHA (A) MUN (H) SHU (A) BOU (H) TOT (A) CHE (H) WOL (A) LEI (H) MCI (A) EVE (H) ARS (A) WAT (H) NOR (H) NEW (A) WHU (H) AVL (A) CHE (A) CRY (H) TOT (H) LEI (A) WOL (H) CRY (A) LIV (A) BUR (H) AVL (H) WHU (A) NEW (H) NOR (A) ARS (H) WAT (A) MCI (H) EVE (A) MUN (A) BHA (H) BOU (A) SHU (H)',
 'Spurs AVL (H) MCI (A) NEW (H) ARS (A) CRY (H) LEI (A) SOU (H) BHA (A) WAT (H) LIV (A) EVE (A) SHU (H) WHU (A) BOU (H) MUN (A) BUR (H) WOL (A) CHE (H) BHA (H) NOR (A) SOU (A) LIV (H) WAT (A) NOR (H) MCI (H) AVL (A) CHE (A) WOL (H) BUR (A) MUN (H) WHU (H) SHU (A) EVE (H) BOU (A) ARS (H) NEW (A) LEI (H) CRY (A)',
 'Watford BHA (H) EVE (A) WHU (H) NEW (A) ARS (H) MCI (A) WOL (A) SHU (H) TOT (A) BOU (H) CHE (H) NOR (A) BUR (H) SOU (A) LEI (A) CRY (H) LIV (A) MUN (H) SHU (A) AVL (H) WOL (H) BOU (A) TOT (H) AVL (A) EVE (H) BHA (A) MUN (A) LIV (H) CRY (A) LEI (H) BUR (A) SOU (H) CHE (A) NOR (H) NEW (H) WHU (A) MCI (H) ARS (A)',
 'West Ham MCI (H) BHA (A) WAT (A) NOR (H) AVL (A) MUN (H) BOU (A) CRY (H) EVE (A) SHU (H) NEW (H) BUR (A) TOT (H) CHE (A) WOL (A) ARS (H) SOU (A) LIV (H) CRY (A) LEI (H) BOU (H) SHU (A) EVE (H) LEI (A) BHA (H) MCI (A) LIV (A) SOU (H) ARS (A) WOL (H) TOT (A) CHE (H) NEW (A) BUR (H) NOR (A) WAT (H) MUN (A) AVL (H)',
 'Wolves LEI (A) MUN (H) BUR (H) EVE (A) CHE (H) CRY (A) WAT (H) MCI (A) SOU (H) NEW (A) ARS (A) AVL (H) BOU (A) SHU (H) WHU (H) BHA (A) TOT (H) NOR (A) MCI (H) LIV (A) WAT (A) NEW (H) SOU (A) LIV (H) MUN (A) LEI (H) NOR (H) TOT (A) BHA (H) WHU (A) BOU (H) AVL (A) ARS (H) SHU (A) EVE (H) BUR (A) CRY (H) CHE (A)']

# %% [markdown]
# ### Import Data

# %%
# url = "https://fantasy.premierleague.com/drf/bootstrap-static"
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

def get_json_data(url):
    response = requests.get(url)
    jobs = response.json()
    return jobs

#filter out players with less than 330
all_players = get_json_data(url)['elements']
all_teams = get_json_data(url)['teams']
positions = get_json_data(url)['element_types']

# %% [markdown]
# ### Get Team Table

# %%
table_url = 'https://www.premierleague.com/tables'

def build_table(table_url):
    team_table = pd.read_html(table_url)
    team_df = pd.DataFrame(team_table[0])
    team_df = team_df[team_df['Unnamed: 12'].isna()]
    team_df = team_df.iloc[:,1:10]
    team_df.Club = team_df.Club.map(lambda x: x[-3:])
    team_df.reset_index()
    team_df.index = np.arange(1, len(team_df) + 1)
    team_df.columns = ['Team', 'Played', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']
    team_df.index.name = 'Position'
    
    return team_df

# %%
table_url = 'https://www.premierleague.com/tables'
team_table = pd.read_html(table_url)
team_table[0]
# Out:
#                                         Position  Pos  \
# 0                             1  Previous Position  1
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                             2  Previous Position  2
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                             3  Previous Position  4
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                             4  Previous Position  5
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                             5  Previous Position  3
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                            6  Previous Position  6
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                            7  Previous Position  9
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                            8  Previous Position  7
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                           9  Previous Position  13
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                          10  Previous Position  10
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                           11  Previous Position  8
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                          12  Previous Position  15
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                          13  Previous Position  11
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                          14  Previous Position  12
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                          15  Previous Position  18
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                          16  Previous Position  14
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                          17  Previous Position  17
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                          18  Previous Position  16
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                          19  Previous Position  19
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                          20  Previous Position  20
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                  Club  \
# 0                                        LiverpoolLIV
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                  Manchester CityMCI
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                   Leicester CityLEI
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                          ChelseaCHE
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                          ArsenalARS
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                  Crystal PalaceCRY
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                               Tottenham HotspurTOT
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                         BurnleyBUR
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                Sheffield UnitedSHU
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                     BournemouthBOU
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                 West Ham UnitedWHU
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                     Aston VillaAVL
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                         Wolverhampton WanderersWOL
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                               Manchester UnitedMUN
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                         EvertonEVE
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                        Brighton and Hove AlbionBHA
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                     SouthamptonSOU
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                Newcastle UnitedNEW
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                    Norwich CityNOR
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                         WatfordWAT
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                            Played  Pl  \
# 0                                                   9
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                   9
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                   9
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                   9
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                   9
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                  9
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                  9
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                  9
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  9
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                  9
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                  9
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                  9
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                  9
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                  9
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                  9
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  9
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  9
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  9
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                  9
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  9
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                Won  W  \
# 0                                                   8
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                   6
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                   5
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                   5
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                   4
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                  4
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                  3
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                  3
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  3
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                  3
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                  3
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                  3
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                  2
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                  2
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                  3
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  2
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  2
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  2
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                  2
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  0
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                              Drawn  D  \
# 0                                                   1
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                   1
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                   2
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                   2
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                   3
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                  2
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                  3
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                  3
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  3
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                  3
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                  3
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                  2
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                  5
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                  4
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                  1
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  3
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  2
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  2
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                  1
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  4
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                               Lost  L  \
# 0                                                   0
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                   2
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                   2
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                   2
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                   2
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                  3
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                  3
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                  3
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  3
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                  3
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                  3
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                  4
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                  2
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                  3
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                  5
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  4
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  5
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  5
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                  6
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                    GF  \
# 0                                                  21
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                  29
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                  16
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                  19
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                  13
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                  8
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                 15
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                 12
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  8
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                 13
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                 11
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                 15
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                 12
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                 10
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                  8
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  9
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  9
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  5
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                 10
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  5
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                    GA  \
# 0                                                   7
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                   9
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                   8
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                  14
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                  12
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                 10
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                 13
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                 11
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                  7
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                 13
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                 13
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                 13
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                 12
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                  9
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                 13
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                 12
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                 16
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                 14
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                 21
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                 21
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                    GD  \
# 0                                                 +14
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                 +20
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                  +8
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                  +5
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                  +1
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                 -2
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                 +2
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                 +1
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                 +1
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                  0
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                 -2
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                 +2
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                  0
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                 +1
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                 -5
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                 -3
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                 -7
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                 -9
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                -11
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                -16
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                           Points  Pts  \
# 0                                                  25
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                  19
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                  17
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                  17
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                  15
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                 14
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                 12
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                 12
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                 12
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                 12
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                 12
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                 11
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                 11
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                 10
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                 10
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                  9
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                  8
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                  8
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                  7
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                  4
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                  Form  \
# 0   W  Saturday 14 September 2019  LIV  3 -1  NEW ...
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2   L  Saturday 14 September 2019  NOR  3 -2  MCI ...
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4   L  Saturday 14 September 2019  MUN  1 -0  LEI ...
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6   W  Saturday 14 September 2019  WOL  2 -5  CHE ...
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8   D  Sunday 15 September 2019  WAT  2 -2  ARS  W...
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10  L  Saturday 14 September 2019  TOT  4 -0  CRY ...
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12  W  Saturday 14 September 2019  TOT  4 -0  CRY ...
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14  D  Saturday 14 September 2019  BHA  1 -1  BUR ...
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16  L  Saturday 14 September 2019  SHU  0 -1  SOU ...
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18  W  Sunday 15 September 2019  BOU  3 -1  EVE  W...
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20  D  Monday 16 September 2019  AVL  0 -0  WHU  W...
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22  D  Monday 16 September 2019  AVL  0 -0  WHU  L...
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24  L  Saturday 14 September 2019  WOL  2 -5  CHE ...
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26  W  Saturday 14 September 2019  MUN  1 -0  LEI ...
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28  L  Sunday 15 September 2019  BOU  3 -1  EVE  L...
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30  D  Saturday 14 September 2019  BHA  1 -1  BUR ...
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32  W  Saturday 14 September 2019  SHU  0 -1  SOU ...
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34  L  Saturday 14 September 2019  LIV  3 -1  NEW ...
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36  W  Saturday 14 September 2019  NOR  3 -2  MCI ...
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38  D  Sunday 15 September 2019  WAT  2 -2  ARS  L...
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                                  Next  \
# 0   Tottenham Hotspur  Sunday 27 October 2019  LIV...
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2   Aston Villa  Saturday 26 October 2019  MCI  12...
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4   Southampton  Friday 25 October 2019  SOU  20:0...
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6   Burnley  Saturday 26 October 2019  BUR  17:30 ...
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8   Crystal Palace  Sunday 27 October 2019  ARS  1...
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10   Arsenal  Sunday 27 October 2019  ARS  16:30  CRY
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12  Liverpool  Sunday 27 October 2019  LIV  16:30 ...
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14  Chelsea  Saturday 26 October 2019  BUR  17:30 ...
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16  West Ham United  Saturday 26 October 2019  WHU...
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18  Watford  Saturday 26 October 2019  WAT  15:00 ...
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20  Sheffield United  Saturday 26 October 2019  WH...
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22  Manchester City  Saturday 26 October 2019  MCI...
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24  Newcastle United  Sunday 27 October 2019  NEW ...
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26  Norwich City  Sunday 27 October 2019  NOR  16:...
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28  Brighton and Hove Albion  Saturday 26 October ...
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30  Everton  Saturday 26 October 2019  BHA  15:00 ...
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32  Leicester City  Friday 25 October 2019  SOU  2...
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34  Wolverhampton Wanderers  Sunday 27 October 201...
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36  Manchester United  Sunday 27 October 2019  NOR...
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38  AFC Bournemouth  Saturday 26 October 2019  WAT...
# 39  Watford  Recent Result - Saturday 19 October 2...
#
#                                           Unnamed: 12
# 0                                                 NaN
# 1   Liverpool  Recent Result - Sunday 20 October 2...
# 2                                                 NaN
# 3   Manchester City  Recent Result - Saturday 19 O...
# 4                                                 NaN
# 5   Leicester City  Recent Result - Saturday 19 Oc...
# 6                                                 NaN
# 7   Chelsea  Recent Result - Saturday 19 October 2...
# 8                                                 NaN
# 9   Arsenal  Recent Result - Monday 21 October 201...
# 10                                                NaN
# 11  Crystal Palace  Recent Result - Saturday 19 Oc...
# 12                                                NaN
# 13  Tottenham Hotspur  Recent Result - Saturday 19...
# 14                                                NaN
# 15  Burnley  Recent Result - Saturday 19 October 2...
# 16                                                NaN
# 17  Sheffield United  Recent Result - Monday 21 Oc...
# 18                                                NaN
# 19  Bournemouth  Recent Result - Saturday 19 Octob...
# 20                                                NaN
# 21  West Ham United  Recent Result - Saturday 19 O...
# 22                                                NaN
# 23  Aston Villa  Recent Result - Saturday 19 Octob...
# 24                                                NaN
# 25  Wolverhampton Wanderers  Recent Result - Satur...
# 26                                                NaN
# 27  Manchester United  Recent Result - Sunday 20 O...
# 28                                                NaN
# 29  Everton  Recent Result - Saturday 19 October 2...
# 30                                                NaN
# 31  Brighton and Hove Albion  Recent Result - Satu...
# 32                                                NaN
# 33  Southampton  Recent Result - Saturday 19 Octob...
# 34                                                NaN
# 35  Newcastle United  Recent Result - Saturday 19 ...
# 36                                                NaN
# 37  Norwich City  Recent Result - Saturday 19 Octo...
# 38                                                NaN
# 39  Watford  Recent Result - Saturday 19 October 2...

# %%
table_df = build_table(table_url)

# %%
table_df.head()
# Out:
#          Team Played  W  D  L  GF  GA   GD Pts
# Position
# 1         LIV      9  8  1  0  21   7  +14  25
# 2         MCI      9  6  1  2  29   9  +20  19
# 3         LEI      9  5  2  2  16   8   +8  17
# 4         CHE      9  5  2  2  19  14   +5  17
# 5         ARS      9  4  3  2  13  12   +1  15

# %% [markdown]
# ### Try dynamic FDR Score

# %%
#List of teams
name_list = list(table_df.Team)

#list of points as integers
pts_list = [int(item) for item in table_df.Pts]
top_pts = max(pts_list)

#list of GF as integers
GF_list = [int(item) for item in table_df.GF]
top_GF = max(GF_list)

#list of GA as integers
GA_list = [int(item) for item in table_df.GA]
top_GA = max(GA_list)

# %%
top_pts, top_GF, top_GA
# Out:
# (25, 29, 21)

# %%
name_list[:5]
# Out:
# ['LIV', 'MCI', 'LEI', 'CHE', 'ARS']

# %%
from scipy import stats
stats.percentileofscore(GF_list, 20)
# Out:
# 90.0

# %%
scaled = [pts_list, GF_list, GA_list]

# %% [markdown]
# ### Write Function to try scaled scores

# %%
def scaled_FDR(pts_list, GF_list, GA_list):
    #turn to array so you an use scaler
    arr_pts = np.array(pts_list).reshape(-1, 1)
    arr_GF = np.array(GF_list).reshape(-1, 1)
    arr_GA = np.array(GA_list).reshape(-1, 1)
    
    #instantiate scalers
    minmax = MinMaxScaler()
    robust = RobustScaler()
    
    #apply MinMax
    minmax_pts = minmax.fit_transform(arr_pts)
    minmax_GF = minmax.fit_transform(arr_GF)
    minmax_GA = minmax.fit_transform(arr_GA)
    
    #apply Robust
    robu_pts = robust.fit_transform(arr_pts)
    robu_GF = robust.fit_transform(arr_GF)
    robu_GA = robust.fit_transform(arr_GA)
    
    #add normalzied scores
    sum_minmax = (minmax_pts + minmax_GF + (1 - minmax_GA)).tolist()
    sum_robu = (robu_pts + robu_GF + minmax_GA*(-1)).tolist()
    
    minmax_fin = [item[0] for item in sum_minmax]
    robu_fin = [item[0] for item in sum_robu]
    
    return (minmax_fin, robu_fin)

# %%
scaled_scores = scaled_FDR(pts_list, GF_list, GA_list)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
scaled_scores[1]
# Out:
# [4.408888888888889,
#  4.212698412698412,
#  1.7596825396825397,
#  1.811111111111111,
#  0.5495238095238095,
#  -0.3298412698412698,
#  0.13142857142857156,
#  -0.20571428571428568,
#  -0.56,
#  -0.1885714285714285,
#  -0.5085714285714285,
#  -0.09079365079365065,
#  -0.4993650793650793,
#  -0.8273015873015872,
#  -1.433015873015873,
#  -1.4238095238095236,
#  -1.9317460317460315,
#  -2.428888888888889,
#  -2.351111111111111,
#  -3.8177777777777777]

# %%
maybs = [item*2 for item in scaled_scores[0]]

# %%
maybs
# Out:
# [5.333333333333334,
#  5.142857142857142,
#  4.011904761904762,
#  3.4047619047619047,
#  3.0,
#  2.7738095238095237,
#  2.738095238095238,
#  2.7738095238095237,
#  3.011904761904762,
#  2.571428571428571,
#  2.404761904761905,
#  2.6428571428571432,
#  2.5357142857142856,
#  2.7023809523809526,
#  1.9642857142857144,
#  2.0952380952380953,
#  1.4285714285714288,
#  1.380952380952381,
#  0.7023809523809523,
#  0.0]

# %%
Team = name_list
strength = maybs

mean_FDR = round(np.mean([item for item in maybs]), 2)
FDR_75 = round(np.percentile([item for item in maybs], 75), 2)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GF + GA) z-scores', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
zipped_list = list(zip(name_list, pts_list, GF_list, GA_list))

# %%
zipped_list[:3]
# Out:
# [('LIV', 25, 21, 7), ('MCI', 19, 29, 9), ('LEI', 17, 16, 8)]

# %%
def get_percentiles(zipped_list):
    listy = []
    for item in zipped_list:
        team = item[0]
        pts_perc = stats.percentileofscore(pts_list, item[1])
        GF_perc = stats.percentileofscore(GF_list, item[2])
        GA_perc = stats.percentileofscore(GA_list, item[3])
        FDR = pts_perc + GF_perc + (100-GA_perc)
        tup = (team, FDR)
        listy.append(tup)
    return listy

# %%
FDR_new = get_percentiles(zipped_list)

# %%
FDR_new
# Out:
# [('LIV', 287.5),
#  ('MCI', 272.5),
#  ('LEI', 257.5),
#  ('CHE', 195.0),
#  ('ARS', 202.5),
#  ('CRY', 165.0),
#  ('TOT', 172.5),
#  ('BUR', 182.5),
#  ('SHU', 172.5),
#  ('BOU', 162.5),
#  ('WHU', 145.0),
#  ('AVL', 155.0),
#  ('WOL', 155.0),
#  ('MUN', 152.5),
#  ('EVE', 87.5),
#  ('BHA', 112.5),
#  ('SOU', 60.0),
#  ('NEW', 42.5),
#  ('NOR', 55.0),
#  ('WAT', 15.0)]

# %%
mean_FDR = np.mean([item[1] for item in FDR_new])

# %%
mean_FDR
# Out:
# 152.5

# %%
Team = [item[0] for item in FDR_new]
strength = [item[1] for item in FDR_new]

mean_FDR = np.mean([item[1] for item in FDR_new])
FDR_75 = np.percentile([item[1] for item in FDR_new], 75)

plt.bar(Team, strength)
plt.axhline(y=mean_FDR, linestyle='-', color='#33D977', label='FDR Mean = ' + str(mean_FDR))
plt.axhline(y=FDR_75, linestyle='-', color='red', label='FDR 75th % = ' + str(FDR_75))
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('(Pts + GA +GF) SUM', fontsize = 24, color = '#073997')
plt.legend(fontsize = '12')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to return percentile for each team

# %% [markdown]
# ## Add player status and ROI, pts-per-90min metrics to final player_df

# %%
def attach_team_and_position(main_players, all_teams, positons):
    players = main_players.copy()
    for team in all_teams:
        for player in players:
            if team['code'] == player['team_code']:
                player['team_name'] = team['name']
    for position in positions:
        for player in players:
            if position['id'] == player['element_type']:
                player['position'] = position['singular_name']
    for player in players:
        if player['status'] == "a":
            player['status'] = "available"
        elif player['status'] == "d":
            player['status'] = "doubtful"
        elif player['status'] == "i":
            player['status'] = "injured"
        elif player['status'] == "s":
            player['status'] = "suspended"
    return players


#### Temporarily took out the "main_players" filter because no players have played 330 minutes ####

# player_positions_teams = attach_team_and_position(main_players, all_teams_new, positions)
player_positions_teams = attach_team_and_position(all_players, all_teams, positions)


def final_players_list(player_positions_teams):
    players = player_positions_teams.copy()
    empty = []
    for player in players:
        stats = dict(team_code = player['team_code'],
        team_name = player['team_name'],
        name = player['first_name'] + " " + player['second_name'],
        status = player['status'],
        position = player['position'],
        cost = (player['now_cost'])/10,
        total_points = player['total_points'],
        roi = round((player['total_points'] / player['now_cost'])*10, 2),
        pts_per_90min = round((player['total_points'] / (player['minutes'] + 1))*90, 2),
        bonus = player['bonus'],
        red_cards = player['red_cards'],
        minutes = player['minutes'],
        transfers_out = player['transfers_out'],
        transfers_in = player['transfers_in'])
        empty.append(stats)
    return empty

# %%
final = final_players_list(player_positions_teams)

# %%
final[0]
# Out:
# {'team_code': 3,
#  'team_name': 'Arsenal',
#  'name': 'Shkodran Mustafi',
#  'status': 'available',
#  'position': 'Defender',
#  'cost': 5.2,
#  'total_points': 0,
#  'roi': 0.0,
#  'pts_per_90min': 0.0,
#  'bonus': 0,
#  'red_cards': 0,
#  'minutes': 0,
#  'transfers_out': 27690,
#  'transfers_in': 5997}

# %%
all_teams[0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1240,
#  'strength_overall_away': 1330,
#  'strength_attack_home': 1210,
#  'strength_attack_away': 1260,
#  'strength_defence_home': 1280,
#  'strength_defence_away': 1330}

# %% [markdown]
# ### Get Total ROI, Points and 90min before filtering injured and FDR

# %%
total_roi = sorted(final, key = lambda x: x['roi'], reverse = True)

# %%
total_roi[:2]
# Out:
# [{'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'John Lundstram',
#   'status': 'available',
#   'position': 'Defender',
#   'cost': 4.6,
#   'total_points': 45,
#   'roi': 9.78,
#   'pts_per_90min': 5.2,
#   'bonus': 7,
#   'red_cards': 0,
#   'minutes': 778,
#   'transfers_out': 237023,
#   'transfers_in': 1878762},
#  {'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'name': 'Dean Henderson',
#   'status': 'available',
#   'position': 'Goalkeeper',
#   'cost': 4.6,
#   'total_points': 39,
#   'roi': 8.48,
#   'pts_per_90min': 4.33,
#   'bonus': 2,
#   'red_cards': 0,
#   'minutes': 810,
#   'transfers_out': 67361,
#   'transfers_in': 232557}]

# %% [markdown]
# ### Total_Points

# %%
total_max_pts = sorted(total_roi, key = lambda x: x['total_points'], reverse = True)

# %%
total_max_pts[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Kevin De Bruyne',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 10.1,
#   'total_points': 66,
#   'roi': 6.53,
#   'pts_per_90min': 9.6,
#   'bonus': 10,
#   'red_cards': 0,
#   'minutes': 618,
#   'transfers_out': 1347571,
#   'transfers_in': 2527415},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.2,
#   'total_points': 61,
#   'roi': 5.0,
#   'pts_per_90min': 9.79,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 560,
#   'transfers_out': 611581,
#   'transfers_in': 1229972}]

# %% [markdown]
# ### 90 min

# %%
total_90min = sorted(total_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
total_90min = [player for player in total_90min if player['minutes'] >= min_min]

# %%
total_90min[:2]
# Out:
# [{'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Sergio Agüero',
#   'status': 'available',
#   'position': 'Forward',
#   'cost': 12.2,
#   'total_points': 61,
#   'roi': 5.0,
#   'pts_per_90min': 9.79,
#   'bonus': 6,
#   'red_cards': 0,
#   'minutes': 560,
#   'transfers_out': 611581,
#   'transfers_in': 1229972},
#  {'team_code': 43,
#   'team_name': 'Man City',
#   'name': 'Kevin De Bruyne',
#   'status': 'available',
#   'position': 'Midfielder',
#   'cost': 10.1,
#   'total_points': 66,
#   'roi': 6.53,
#   'pts_per_90min': 9.6,
#   'bonus': 10,
#   'red_cards': 0,
#   'minutes': 618,
#   'transfers_out': 1347571,
#   'transfers_in': 2527415}]

# %% [markdown]
# ### Create Players DataFrame

# %%
player_df = pd.DataFrame(final)

# %%
player_df.sort_values(by = ['roi'], ascending = False, inplace = True)

# %%
player_df.head(10)
# Out:
#      bonus  cost  minutes                           name    position  \
# 392      7   4.6      778                 John Lundstram    Defender
# 405      2   4.6      810                 Dean Henderson  Goalkeeper
# 388      4   4.5      810                 Jack O'Connell    Defender
# 96       6   4.7      810                    Mathew Ryan  Goalkeeper
# 389      3   4.5      810                 George Baldock    Defender
# 542      4   5.2      810  Rui Pedro dos Santos Patrício  Goalkeeper
# 363      9   7.0      795                    Teemu Pukki     Forward
# 386      4   5.0      810                   Enda Stevens    Defender
# 390      3   4.5      810                      John Egan    Defender
# 91       7   4.6      810                     Lewis Dunk    Defender
#
#      pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 392           5.20          0  9.78  available         49  Sheffield Utd
# 405           4.33          0  8.48  available         49  Sheffield Utd
# 388           4.11          0  8.22  available         49  Sheffield Utd
# 96            4.22          0  8.09  available         36       Brighton
# 389           4.00          0  8.00  available         49  Sheffield Utd
# 542           4.55          0  7.88  available         39         Wolves
# 363           6.22          0  7.86  available         45        Norwich
# 386           4.33          0  7.80  available         49  Sheffield Utd
# 390           3.88          0  7.78  available         49  Sheffield Utd
# 91            3.77          0  7.39  available         36       Brighton
#
#      total_points  transfers_in  transfers_out
# 392            45       1878762         237023
# 405            39        232557          67361
# 388            37         23728          13848
# 96             38        549324         354989
# 389            36         60527          23526
# 542            41        659407         237067
# 363            55       3194565        1399282
# 386            39         48300          23422
# 390            35          8942           6335
# 91             34        602766         332033

# %% [markdown]
# ### Merge two team tables s owe have all data

# %%
def merged_teams(table_df, all_teams):
    table_dic = table_df.to_dict('records')
    
    for team in table_dic:
        for item in all_teams:
            if team['Team'] == item['short_name']:
                team['code'] = item['code']
                team['name'] = item['name']
                team['strength'] = item['strength']
            
    new_df = pd.DataFrame(table_dic)
    
    new_order = ['code', 'strength', 'Team','name', 'Played', 'W', 'L', 'D', 'GF', 'GA', 'GD', 'Pts']
    
    table_df = new_df[new_order]
    
    table_df.index = np.arange(1, len(table_df) + 1)
    table_df.index.name = 'Position'
    
    return table_df

# %%
team_df = merged_teams(table_df, all_teams)

# %%
team_df.head()
# Out:
#           code  strength Team       name Played  W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV  Liverpool      9  8  0  1  21   7  +14  25
# 2           43         5  MCI   Man City      9  6  2  1  29   9  +20  19
# 3           13         3  LEI  Leicester      9  5  2  2  16   8   +8  17
# 4            8         4  CHE    Chelsea      9  5  2  2  19  14   +5  17
# 5            3         4  ARS    Arsenal      9  4  2  3  13  12   +1  15

# %%
team_names = list(team_df.name)

# %%
team_names.sort()

# %%
team_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %% [markdown]
# ## Create Schedule DF

# %%
def extract_sched(schedules):
    dic = {}
    for i, item in enumerate(schedules):
        name = item.partition(team_names[i])[1]
        sche = item.partition(team_names[i])[2]
        sche = sche.split()
        clean = [item for item in sche if item != "(A)"]
        clean2 = [item for item in clean if item != "(H)"]
        dic[name] = clean2
    return dic

# %%
wonders = extract_sched(schedules)

# %%
schedule_df = pd.DataFrame(wonders)

# %%
schedule_df.index.name = 'Gameweek'

# %%
schedule_df.head()
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE

# %%
schedule_df.Arsenal[0:3]
# Out:
# Gameweek
# 0    NEW
# 1    BUR
# 2    LIV
# Name: Arsenal, dtype: object

# %% [markdown]
# ## Create FDR scores for calculating next-n opponents AVG strength

# %%
scores = list(zip(team_df.Team, team_df.strength))

# %%
scores = dict(scores)

# %%
sorted(scores.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('LIV', 5),
#  ('MCI', 5),
#  ('CHE', 4),
#  ('ARS', 4),
#  ('TOT', 4),
#  ('MUN', 4),
#  ('LEI', 3),
#  ('CRY', 3),
#  ('BUR', 3),
#  ('BOU', 3),
#  ('WHU', 3),
#  ('WOL', 3),
#  ('EVE', 3),
#  ('SHU', 2),
#  ('AVL', 2),
#  ('BHA', 2),
#  ('SOU', 2),
#  ('NEW', 2),
#  ('NOR', 2),
#  ('WAT', 2)]

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
# from pylab import rcParams
# rcParams['figure.figsize'] = 14, 6

sorted_data = sorted(scores.items(), key = lambda x: x[1], reverse = True)

Team = [item[0] for item in sorted_data]
strength = [item[1] for item in sorted_data]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength Fantasy FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
maybs
# Out:
# [5.333333333333334,
#  5.142857142857142,
#  4.011904761904762,
#  3.4047619047619047,
#  3.0,
#  2.7738095238095237,
#  2.738095238095238,
#  2.7738095238095237,
#  3.011904761904762,
#  2.571428571428571,
#  2.404761904761905,
#  2.6428571428571432,
#  2.5357142857142856,
#  2.7023809523809526,
#  1.9642857142857144,
#  2.0952380952380953,
#  1.4285714285714288,
#  1.380952380952381,
#  0.7023809523809523,
#  0.0]

# %%
new_FDR =  list(zip(name_list, maybs))

# %%
new_FDR
# Out:
# [('LIV', 5.333333333333334),
#  ('MCI', 5.142857142857142),
#  ('LEI', 4.011904761904762),
#  ('CHE', 3.4047619047619047),
#  ('ARS', 3.0),
#  ('CRY', 2.7738095238095237),
#  ('TOT', 2.738095238095238),
#  ('BUR', 2.7738095238095237),
#  ('SHU', 3.011904761904762),
#  ('BOU', 2.571428571428571),
#  ('WHU', 2.404761904761905),
#  ('AVL', 2.6428571428571432),
#  ('WOL', 2.5357142857142856),
#  ('MUN', 2.7023809523809526),
#  ('EVE', 1.9642857142857144),
#  ('BHA', 2.0952380952380953),
#  ('SOU', 1.4285714285714288),
#  ('NEW', 1.380952380952381),
#  ('NOR', 0.7023809523809523),
#  ('WAT', 0.0)]

# %%
def get_avg_FDR(sorted_data, new_FDR):
    listy = []
    for item in sorted_data:
        for score in new_FDR:
            if item[0] == score[0]:
                team = item[0]
                avg_FDR = np.round((item[1] + score[1])/2, 2)
                tup = (team, avg_FDR)
                listy.append(tup)
    return listy

# %%
final_avg_FDR = get_avg_FDR(sorted_data, new_FDR)

# %%
final_avg_FDR = sorted(final_avg_FDR, key = lambda x: x[1], reverse = True)
final_avg_FDR
# Out:
# [('LIV', 5.17),
#  ('MCI', 5.07),
#  ('CHE', 3.7),
#  ('LEI', 3.51),
#  ('ARS', 3.5),
#  ('TOT', 3.37),
#  ('MUN', 3.35),
#  ('CRY', 2.89),
#  ('BUR', 2.89),
#  ('BOU', 2.79),
#  ('WOL', 2.77),
#  ('WHU', 2.7),
#  ('SHU', 2.51),
#  ('EVE', 2.48),
#  ('AVL', 2.32),
#  ('BHA', 2.05),
#  ('SOU', 1.71),
#  ('NEW', 1.69),
#  ('NOR', 1.35),
#  ('WAT', 1.0)]

# %%
adjusted_FDR = dict(final_avg_FDR)

# %%
adjusted_FDR
# Out:
# {'LIV': 5.17,
#  'MCI': 5.07,
#  'CHE': 3.7,
#  'LEI': 3.51,
#  'ARS': 3.5,
#  'TOT': 3.37,
#  'MUN': 3.35,
#  'CRY': 2.89,
#  'BUR': 2.89,
#  'BOU': 2.79,
#  'WOL': 2.77,
#  'WHU': 2.7,
#  'SHU': 2.51,
#  'EVE': 2.48,
#  'AVL': 2.32,
#  'BHA': 2.05,
#  'SOU': 1.71,
#  'NEW': 1.69,
#  'NOR': 1.35,
#  'WAT': 1.0}

# %%
Team = [item[0] for item in final_avg_FDR]
strength = [item[1] for item in final_avg_FDR]

plt.bar(Team, strength)
plt.ylabel('Team Strength', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Team Strength adjusted_FDR Index', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
schedule_df.columns
# Out:
# Index(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brighton', 'Burnley',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Leicester', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Sheffield Utd',
#        'Southampton', 'Spurs', 'Watford', 'West Ham', 'Wolves'],
#       dtype='object')

# %%
schedule_df.head(10)
# Out:
#          Arsenal Aston Villa Bournemouth Brighton Burnley Chelsea  \
# Gameweek
# 0            NEW         TOT         SHU      WAT     SOU     MUN
# 1            BUR         BOU         AVL      WHU     ARS     LEI
# 2            LIV         EVE         MCI      SOU     WOL     NOR
# 3            TOT         CRY         LEI      MCI     LIV     SHU
# 4            WAT         WHU         EVE      BUR     BHA     WOL
# 5            AVL         ARS         SOU      NEW     NOR     LIV
# 6            MUN         BUR         WHU      CHE     AVL     BHA
# 7            BOU         NOR         ARS      TOT     EVE     SOU
# 8            SHU         BHA         NOR      AVL     LEI     NEW
# 9            CRY         MCI         WAT      EVE     CHE     BUR
#
#          Crystal Palace Everton Leicester Liverpool Man City Man Utd  \
# Gameweek
# 0                   EVE     CRY       WOL       NOR      WHU     CHE
# 1                   SHU     WAT       CHE       SOU      TOT     WOL
# 2                   MUN     AVL       SHU       ARS      BOU     CRY
# 3                   AVL     WOL       BOU       BUR      BHA     SOU
# 4                   TOT     BOU       MUN       NEW      NOR     LEI
# 5                   WOL     SHU       TOT       CHE      WAT     WHU
# 6                   NOR     MCI       NEW       SHU      EVE     ARS
# 7                   WHU     BUR       LIV       LEI      WOL     NEW
# 8                   MCI     WHU       BUR       MUN      CRY     LIV
# 9                   ARS     BHA       SOU       TOT      AVL     NOR
#
#          Newcastle Norwich Sheffield Utd Southampton Spurs Watford West Ham  \
# Gameweek
# 0              ARS     LIV           BOU         BUR   AVL     BHA      MCI
# 1              NOR     NEW           CRY         LIV   MCI     EVE      BHA
# 2              TOT     CHE           LEI         BHA   NEW     WHU      WAT
# 3              WAT     WHU           CHE         MUN   ARS     NEW      NOR
# 4              LIV     MCI           SOU         SHU   CRY     ARS      AVL
# 5              BHA     BUR           EVE         BOU   LEI     MCI      MUN
# 6              LEI     CRY           LIV         TOT   SOU     WOL      BOU
# 7              MUN     AVL           WAT         CHE   BHA     SHU      CRY
# 8              CHE     BOU           ARS         WOL   WAT     TOT      EVE
# 9              WOL     MUN           WHU         LEI   LIV     BOU      SHU
#
#          Wolves
# Gameweek
# 0           LEI
# 1           MUN
# 2           BUR
# 3           EVE
# 4           CHE
# 5           CRY
# 6           WAT
# 7           MCI
# 8           SOU
# 9           NEW

# %%
def avg_FDR(scores = adjusted_FDR, week = gameweek, periods = next_n_games):
    dic = {}
    for team in schedule_df.columns:
        oponents = schedule_df[team][(week-1):(week+periods)]
        avg_FDR = round(sum([scores[oponent] for oponent in oponents])/len(oponents), 2)
        dic[team] = avg_FDR
    return dic

# %%
calculate_FDR = avg_FDR()

# %%
sorted_FDR = sorted(calculate_FDR.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_FDR
# Out:
# [('Aston Villa', 4.34),
#  ('Southampton', 3.69),
#  ('Liverpool', 3.59),
#  ('Crystal Palace', 3.57),
#  ('Spurs', 3.39),
#  ('Man City', 3.07),
#  ('Arsenal', 3.06),
#  ('Sheffield Utd', 2.99),
#  ('Burnley', 2.97),
#  ('Newcastle', 2.75),
#  ('Leicester', 2.7),
#  ('Watford', 2.61),
#  ('Wolves', 2.5),
#  ('Brighton', 2.39),
#  ('Everton', 2.38),
#  ('West Ham', 2.36),
#  ('Chelsea', 2.26),
#  ('Norwich', 2.13),
#  ('Man Utd', 2.06),
#  ('Bournemouth', 2.01)]

# %%
rcParams['figure.figsize'] = 14, 6

Team = [item[0] for item in sorted_FDR]
FDR = [item[1] for item in sorted_FDR]

FDR_75 = round(np.percentile([item[1] for item in sorted_FDR], 75), 2)
cutoff = FDR_75

plt.bar(Team, FDR)
plt.axhline(y=cutoff, linestyle='-', color='#33D977', label='Cutoff Difficulty(FDR 75th%) = ' + str(cutoff))
plt.ylabel('AVG Opponent Difficulty', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Adjusted_FDR Opponenet Difficulty Next ' + str(next_n_games +1) + ' Games', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('FDR', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Clean final list of available players by FDR score <= 3.56 and status = 'available'

# %%
player_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.6      778  John Lundstram    Defender           5.20
# 405      2   4.6      810  Dean Henderson  Goalkeeper           4.33
# 388      4   4.5      810  Jack O'Connell    Defender           4.11
# 96       6   4.7      810     Mathew Ryan  Goalkeeper           4.22
# 389      3   4.5      810  George Baldock    Defender           4.00
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 392          0  9.78  available         49  Sheffield Utd            45
# 405          0  8.48  available         49  Sheffield Utd            39
# 388          0  8.22  available         49  Sheffield Utd            37
# 96           0  8.09  available         36       Brighton            38
# 389          0  8.00  available         49  Sheffield Utd            36
#
#      transfers_in  transfers_out
# 392       1878762         237023
# 405        232557          67361
# 388         23728          13848
# 96         549324         354989
# 389         60527          23526

# %%
player_df.shape
# Out:
# (555, 14)

# %%
clean_df = player_df[player_df.status == 'available']

# %%
clean_df.status.value_counts()
# Out:
# available    423
# Name: status, dtype: int64

# %% [markdown]
# ## Remove teams with FDR scores > 3.56 from DF - optional

# %%
teams_low_FDR = [key for (key,value) in calculate_FDR.items() if value <= cutoff]

# %%
teams_low_FDR
# Out:
# ['Arsenal',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Everton',
#  'Leicester',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  'Sheffield Utd',
#  'Watford',
#  'West Ham',
#  'Wolves']

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.6      778  John Lundstram    Defender           5.20
# 405      2   4.6      810  Dean Henderson  Goalkeeper           4.33
# 388      4   4.5      810  Jack O'Connell    Defender           4.11
# 96       6   4.7      810     Mathew Ryan  Goalkeeper           4.22
# 389      3   4.5      810  George Baldock    Defender           4.00
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 392          0  9.78  available         49  Sheffield Utd            45
# 405          0  8.48  available         49  Sheffield Utd            39
# 388          0  8.22  available         49  Sheffield Utd            37
# 96           0  8.09  available         36       Brighton            38
# 389          0  8.00  available         49  Sheffield Utd            36
#
#      transfers_in  transfers_out
# 392       1878762         237023
# 405        232557          67361
# 388         23728          13848
# 96         549324         354989
# 389         60527          23526

# %%
final_df = clean_df.loc[clean_df.team_name.isin(teams_low_FDR)]

# %%
final_df.head(15)
# Out:
#      bonus  cost  minutes                           name    position  \
# 392      7   4.6      778                 John Lundstram    Defender
# 405      2   4.6      810                 Dean Henderson  Goalkeeper
# 388      4   4.5      810                 Jack O'Connell    Defender
# 96       6   4.7      810                    Mathew Ryan  Goalkeeper
# 389      3   4.5      810                 George Baldock    Defender
# 542      4   5.2      810  Rui Pedro dos Santos Patrício  Goalkeeper
# 363      9   7.0      795                    Teemu Pukki     Forward
# 386      4   5.0      810                   Enda Stevens    Defender
# 390      3   4.5      810                      John Egan    Defender
# 91       7   4.6      810                     Lewis Dunk    Defender
# 372      2   4.9      765                  Todd Cantwell  Midfielder
# 399      1   4.5      774                   Chris Basham    Defender
# 137      5   4.8      774                   Erik Pieters    Defender
# 163      6   6.8      772                    Mason Mount  Midfielder
# 160     11   7.8      659                  Tammy Abraham     Forward
#
#      pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 392           5.20          0  9.78  available         49  Sheffield Utd
# 405           4.33          0  8.48  available         49  Sheffield Utd
# 388           4.11          0  8.22  available         49  Sheffield Utd
# 96            4.22          0  8.09  available         36       Brighton
# 389           4.00          0  8.00  available         49  Sheffield Utd
# 542           4.55          0  7.88  available         39         Wolves
# 363           6.22          0  7.86  available         45        Norwich
# 386           4.33          0  7.80  available         49  Sheffield Utd
# 390           3.88          0  7.78  available         49  Sheffield Utd
# 91            3.77          0  7.39  available         36       Brighton
# 372           4.23          0  7.35  available         45        Norwich
# 399           3.83          0  7.33  available         49  Sheffield Utd
# 137           4.06          0  7.29  available         90        Burnley
# 163           5.71          0  7.21  available          8        Chelsea
# 160           7.64          0  7.18  available          8        Chelsea
#
#      total_points  transfers_in  transfers_out
# 392            45       1878762         237023
# 405            39        232557          67361
# 388            37         23728          13848
# 96             38        549324         354989
# 389            36         60527          23526
# 542            41        659407         237067
# 363            55       3194565        1399282
# 386            39         48300          23422
# 390            35          8942           6335
# 91             34        602766         332033
# 372            36       2114104         703036
# 399            33          7663           6233
# 137            35        950435         313631
# 163            49       2955611         624150
# 160            56       3167999         395741

# %%
clean_players = final_df.to_dict('records')

# %%
clean_players[:2]
# Out:
# [{'bonus': 7,
#   'cost': 4.6,
#   'minutes': 778,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 5.2,
#   'red_cards': 0,
#   'roi': 9.78,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 45,
#   'transfers_in': 1878762,
#   'transfers_out': 237023},
#  {'bonus': 2,
#   'cost': 4.6,
#   'minutes': 810,
#   'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.33,
#   'red_cards': 0,
#   'roi': 8.48,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 39,
#   'transfers_in': 232557,
#   'transfers_out': 67361}]

# %% [markdown]
# ## Get list of players by ROI, Total Points and Points Per 90 min

# %%
players_roi = sorted(clean_players, key = lambda x: x['roi'], reverse = True)

# %%
players_roi[:3]
# Out:
# [{'bonus': 7,
#   'cost': 4.6,
#   'minutes': 778,
#   'name': 'John Lundstram',
#   'position': 'Defender',
#   'pts_per_90min': 5.2,
#   'red_cards': 0,
#   'roi': 9.78,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 45,
#   'transfers_in': 1878762,
#   'transfers_out': 237023},
#  {'bonus': 2,
#   'cost': 4.6,
#   'minutes': 810,
#   'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'pts_per_90min': 4.33,
#   'red_cards': 0,
#   'roi': 8.48,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 39,
#   'transfers_in': 232557,
#   'transfers_out': 67361},
#  {'bonus': 4,
#   'cost': 4.5,
#   'minutes': 810,
#   'name': "Jack O'Connell",
#   'position': 'Defender',
#   'pts_per_90min': 4.11,
#   'red_cards': 0,
#   'roi': 8.22,
#   'status': 'available',
#   'team_code': 49,
#   'team_name': 'Sheffield Utd',
#   'total_points': 37,
#   'transfers_in': 23728,
#   'transfers_out': 13848}]

# %% [markdown]
# ### Total Points

# %%
players_max_pts = sorted(players_roi, key = lambda x: x['total_points'], reverse = True)

# %%
players_max_pts[:3]
# Out:
# [{'bonus': 10,
#   'cost': 10.1,
#   'minutes': 618,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.6,
#   'red_cards': 0,
#   'roi': 6.53,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 66,
#   'transfers_in': 2527415,
#   'transfers_out': 1347571},
#  {'bonus': 6,
#   'cost': 12.2,
#   'minutes': 560,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 9.79,
#   'red_cards': 0,
#   'roi': 5.0,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 61,
#   'transfers_in': 1229972,
#   'transfers_out': 611581},
#  {'bonus': 10,
#   'cost': 11.1,
#   'minutes': 810,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 6.33,
#   'red_cards': 0,
#   'roi': 5.14,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 57,
#   'transfers_in': 1057205,
#   'transfers_out': 902306}]

# %% [markdown]
# ### Per 90 mins played

# %%
players_90min = sorted(players_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
players_90min = [player for player in players_90min if player['minutes'] >= min_min]

# %%
players_90min[:3]
# Out:
# [{'bonus': 6,
#   'cost': 12.2,
#   'minutes': 560,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 9.79,
#   'red_cards': 0,
#   'roi': 5.0,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 61,
#   'transfers_in': 1229972,
#   'transfers_out': 611581},
#  {'bonus': 10,
#   'cost': 10.1,
#   'minutes': 618,
#   'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.6,
#   'red_cards': 0,
#   'roi': 6.53,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 66,
#   'transfers_in': 2527415,
#   'transfers_out': 1347571},
#  {'bonus': 6,
#   'cost': 8.6,
#   'minutes': 457,
#   'name': 'Riyad Mahrez',
#   'position': 'Midfielder',
#   'pts_per_90min': 9.04,
#   'red_cards': 0,
#   'roi': 5.35,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 46,
#   'transfers_in': 758197,
#   'transfers_out': 452220}]

# %% [markdown]
# ### Create player lists by position and metric we want to select by

# %%
GK_roi = [item for item in players_roi if item['position'] == 'Goalkeeper']
DF_roi = [item for item in players_roi if item['position'] == 'Defender']
MD_roi = [item for item in players_roi if item['position'] == 'Midfielder']
ST_roi = [item for item in players_roi if item['position'] == 'Forward']

# %%
GK_pts = [item for item in players_max_pts if item['position'] == 'Goalkeeper']
DF_pts = [item for item in players_max_pts if item['position'] == 'Defender']
MD_pts = [item for item in players_max_pts if item['position'] == 'Midfielder']
ST_pts = [item for item in players_max_pts if item['position'] == 'Forward']

# %%
GK_90min = [item for item in players_90min if item['position'] == 'Goalkeeper']
DF_90min = [item for item in players_90min if item['position'] == 'Defender']
MD_90min = [item for item in players_90min if item['position'] == 'Midfielder']
ST_90min = [item for item in players_90min if item['position'] == 'Forward']

# %% [markdown]
# ## Start by selecting top GKs by ROI

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_roi:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))

print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Dean Henderson
# GK budget left: 4.9
# Player Selected: Mathew Ryan
# GK budget left: 0.20000000000000018
# ['Dean Henderson', 'Mathew Ryan']
# ['Sheffield Utd', 'Brighton']

# %% [markdown]
# ## Select Top player by points from DF, MD, ST

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 28.699999999999996 36.0 26.0
# Player Selected: John Lundstram
# DF budget left: 24.099999999999994
# Player Selected: Kevin De Bruyne
# MD budget left: 25.9
# ['Dean Henderson', 'Mathew Ryan', 'John Lundstram', 'Kevin De Bruyne']
# ['Sheffield Utd', 'Brighton', 'Sheffield Utd', 'Man City']

# %%
ST_pts[:3]
# Out:
# [{'bonus': 6,
#   'cost': 12.2,
#   'minutes': 560,
#   'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'pts_per_90min': 9.79,
#   'red_cards': 0,
#   'roi': 5.0,
#   'status': 'available',
#   'team_code': 43,
#   'team_name': 'Man City',
#   'total_points': 61,
#   'transfers_in': 1229972,
#   'transfers_out': 611581},
#  {'bonus': 10,
#   'cost': 11.1,
#   'minutes': 810,
#   'name': 'Pierre-Emerick Aubameyang',
#   'position': 'Forward',
#   'pts_per_90min': 6.33,
#   'red_cards': 0,
#   'roi': 5.14,
#   'status': 'available',
#   'team_code': 3,
#   'team_name': 'Arsenal',
#   'total_points': 57,
#   'transfers_in': 1057205,
#   'transfers_out': 902306},
#  {'bonus': 11,
#   'cost': 7.8,
#   'minutes': 659,
#   'name': 'Tammy Abraham',
#   'position': 'Forward',
#   'pts_per_90min': 7.64,
#   'red_cards': 0,
#   'roi': 7.18,
#   'status': 'available',
#   'team_code': 8,
#   'team_name': 'Chelsea',
#   'total_points': 56,
#   'transfers_in': 3167999,
#   'transfers_out': 395741}]

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Sergio Agüero
# ST budget left: 13.8
# 5
# ['Dean Henderson', 'Mathew Ryan', 'John Lundstram', 'Kevin De Bruyne', 'Sergio Agüero']
# ['Sheffield Utd', 'Brighton', 'Sheffield Utd', 'Man City', 'Man City']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 1

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with top ROI players

# %%
for item in DF_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
        print('# of DFs selected: ' + str(DF_curr))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Jack O'Connell
# DF budget left: 19.599999999999994
# # of DFs selected: 2
# Player Selected: Lewis Dunk
# DF budget left: 14.999999999999995
# # of DFs selected: 3
# Player Selected: Erik Pieters
# DF budget left: 10.199999999999996
# # of DFs selected: 4
# Player Selected: Willy Boly
# DF budget left: 5.199999999999996
# # of DFs selected: 5
# 9
# ['Dean Henderson', 'Mathew Ryan', 'John Lundstram', 'Kevin De Bruyne', 'Sergio Agüero', "Jack O'Connell", 'Lewis Dunk', 'Erik Pieters', 'Willy Boly']
# ['Sheffield Utd', 'Brighton', 'Sheffield Utd', 'Man City', 'Man City', 'Sheffield Utd', 'Brighton', 'Burnley', 'Wolves']

# %% [markdown]
# ## Fill MD position

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Todd Cantwell
# MD budget left: 26.199999999999996
# Player Selected: Mason Mount
# MD budget left: 19.399999999999995
# Player Selected: David Silva
# MD budget left: 11.799999999999995
# Player Selected: Adama Traoré
# MD budget left: 6.699999999999996
# 13
# ['Dean Henderson', 'Mathew Ryan', 'John Lundstram', 'Kevin De Bruyne', 'Sergio Agüero', "Jack O'Connell", 'Lewis Dunk', 'Erik Pieters', 'Willy Boly', 'Todd Cantwell', 'Mason Mount', 'David Silva', 'Adama Traoré']
# ['Sheffield Utd', 'Brighton', 'Sheffield Utd', 'Man City', 'Man City', 'Sheffield Utd', 'Brighton', 'Burnley', 'Wolves', 'Norwich', 'Chelsea', 'Man City', 'Wolves']

# %% [markdown]
# ## Fill ST position

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_roi:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Teemu Pukki
# ST budget left: 13.499999999999996
# Player Selected: Tammy Abraham
# ST budget left: 5.699999999999997
# 15
# ['Dean Henderson', 'Mathew Ryan', 'John Lundstram', 'Kevin De Bruyne', 'Sergio Agüero', "Jack O'Connell", 'Lewis Dunk', 'Erik Pieters', 'Willy Boly', 'Todd Cantwell', 'Mason Mount', 'David Silva', 'Adama Traoré', 'Teemu Pukki', 'Tammy Abraham']
# ['Sheffield Utd', 'Brighton', 'Sheffield Utd', 'Man City', 'Man City', 'Sheffield Utd', 'Brighton', 'Burnley', 'Wolves', 'Norwich', 'Chelsea', 'Man City', 'Wolves', 'Norwich', 'Chelsea']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes             name    position  pts_per_90min  \
# 0       2   4.6      810   Dean Henderson  Goalkeeper           4.33
# 1       6   4.7      810      Mathew Ryan  Goalkeeper           4.22
# 2       7   4.6      778   John Lundstram    Defender           5.20
# 3      10  10.1      618  Kevin De Bruyne  Midfielder           9.60
# 4       6  12.2      560    Sergio Agüero     Forward           9.79
# 5       4   4.5      810   Jack O'Connell    Defender           4.11
# 6       7   4.6      810       Lewis Dunk    Defender           3.77
# 7       5   4.8      774     Erik Pieters    Defender           4.06
# 8       7   5.0      720       Willy Boly    Defender           4.24
# 9       2   4.9      765    Todd Cantwell  Midfielder           4.23
# 10      6   6.8      772      Mason Mount  Midfielder           5.71
# 11      6   7.6      560      David Silva  Midfielder           8.18
# 12      6   5.1      560     Adama Traoré  Midfielder           5.45
# 13      9   7.0      795      Teemu Pukki     Forward           6.22
# 14     11   7.8      659    Tammy Abraham     Forward           7.64
#
#     red_cards   roi     status  team_code      team_name  total_points  \
# 0           0  8.48  available         49  Sheffield Utd            39
# 1           0  8.09  available         36       Brighton            38
# 2           0  9.78  available         49  Sheffield Utd            45
# 3           0  6.53  available         43       Man City            66
# 4           0  5.00  available         43       Man City            61
# 5           0  8.22  available         49  Sheffield Utd            37
# 6           0  7.39  available         36       Brighton            34
# 7           0  7.29  available         90        Burnley            35
# 8           1  6.80  available         39         Wolves            34
# 9           0  7.35  available         45        Norwich            36
# 10          0  7.21  available          8        Chelsea            49
# 11          0  6.71  available         43       Man City            51
# 12          0  6.67  available         39         Wolves            34
# 13          0  7.86  available         45        Norwich            55
# 14          0  7.18  available          8        Chelsea            56
#
#     transfers_in  transfers_out
# 0         232557          67361
# 1         549324         354989
# 2        1878762         237023
# 3        2527415        1347571
# 4        1229972         611581
# 5          23728          13848
# 6         602766         332033
# 7         950435         313631
# 8         317916         334192
# 9        2114104         703036
# 10       2955611         624150
# 11        824669         432989
# 12        233906          38065
# 13       3194565        1399282
# 14       3167999         395741

# %%
money_x = money_df.roi
money_y = money_df.name
ST_75th = round(money_df.describe().roi['75%'], 2)
ST_AVG = round(money_df.describe().roi['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Top 10 ROI players by position

# %%
GK_df = pd.DataFrame(GK_roi)
GK_df.head(10)
# Out:
#    bonus  cost  minutes                           name    position  \
# 0      2   4.6      810                 Dean Henderson  Goalkeeper
# 1      6   4.7      810                    Mathew Ryan  Goalkeeper
# 2      4   5.2      810  Rui Pedro dos Santos Patrício  Goalkeeper
# 3      2   4.7      810                      Nick Pope  Goalkeeper
# 4      3   4.5      810                 Aaron Ramsdale  Goalkeeper
# 5      1   5.0      810                Martin Dubravka  Goalkeeper
# 6      5   5.5      810                   David de Gea  Goalkeeper
# 7      0   5.1      810              Kasper Schmeichel  Goalkeeper
# 8      2   5.5      810                Jordan Pickford  Goalkeeper
# 9      1   5.0      810                     Bernd Leno  Goalkeeper
#
#    pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 0           4.33          0  8.48  available         49  Sheffield Utd
# 1           4.22          0  8.09  available         36       Brighton
# 2           4.55          0  7.88  available         39         Wolves
# 3           3.66          0  7.02  available         90        Burnley
# 4           3.44          0  6.89  available         91    Bournemouth
# 5           3.66          0  6.60  available          4      Newcastle
# 6           3.88          0  6.36  available          1        Man Utd
# 7           3.44          0  6.08  available         13      Leicester
# 8           3.55          0  5.82  available         11        Everton
# 9           3.22          0  5.80  available          3        Arsenal
#
#    total_points  transfers_in  transfers_out
# 0            39        232557          67361
# 1            38        549324         354989
# 2            41        659407         237067
# 3            33        793097         229615
# 4            31         90676          25528
# 5            33         28020          35109
# 6            35        702673         716347
# 7            31        307692         166512
# 8            32        345649         389878
# 9            29        288487         244842

# %%
DF_df = pd.DataFrame(DF_roi)
DF_df.head(10)
# Out:
#    bonus  cost  minutes                              name  position  \
# 0      7   4.6      778                    John Lundstram  Defender
# 1      4   4.5      810                    Jack O'Connell  Defender
# 2      3   4.5      810                    George Baldock  Defender
# 3      4   5.0      810                      Enda Stevens  Defender
# 4      3   4.5      810                         John Egan  Defender
# 5      7   4.6      810                        Lewis Dunk  Defender
# 6      1   4.5      774                      Chris Basham  Defender
# 7      5   4.8      774                      Erik Pieters  Defender
# 8      7   5.0      720                        Willy Boly  Defender
# 9      5   6.2      810  Ricardo Domingos Barbosa Pereira  Defender
#
#    pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 0           5.20          0  9.78  available         49  Sheffield Utd
# 1           4.11          0  8.22  available         49  Sheffield Utd
# 2           4.00          0  8.00  available         49  Sheffield Utd
# 3           4.33          0  7.80  available         49  Sheffield Utd
# 4           3.88          0  7.78  available         49  Sheffield Utd
# 5           3.77          0  7.39  available         36       Brighton
# 6           3.83          0  7.33  available         49  Sheffield Utd
# 7           4.06          0  7.29  available         90        Burnley
# 8           4.24          1  6.80  available         39         Wolves
# 9           4.66          0  6.77  available         13      Leicester
#
#    total_points  transfers_in  transfers_out
# 0            45       1878762         237023
# 1            37         23728          13848
# 2            36         60527          23526
# 3            39         48300          23422
# 4            35          8942           6335
# 5            34        602766         332033
# 6            33          7663           6233
# 7            35        950435         313631
# 8            34        317916         334192
# 9            42        624377         200081

# %%
MD_df = pd.DataFrame(MD_roi)
MD_df.head(10)
# Out:
#    bonus  cost  minutes                     name    position  pts_per_90min  \
# 0      2   4.9      765            Todd Cantwell  Midfielder           4.23
# 1      6   6.8      772              Mason Mount  Midfielder           5.71
# 2      6   7.6      560              David Silva  Midfielder           8.18
# 3      6   5.1      560             Adama Traoré  Midfielder           5.45
# 4     10  10.1      618          Kevin De Bruyne  Midfielder           9.60
# 5      5   5.0      795          Scott McTominay  Midfielder           3.62
# 6      5   5.1      772  Jorge Luiz Frello Filho  Midfielder           3.73
# 7      3   5.0      720            Wilfred Ndidi  Midfielder           3.74
# 8      5   6.0      498        Andriy Yarmolenko  Midfielder           6.31
# 9      4   6.4      801          Youri Tielemans  Midfielder           4.15
#
#    red_cards   roi     status  team_code  team_name  total_points  \
# 0          0  7.35  available         45    Norwich            36
# 1          0  7.21  available          8    Chelsea            49
# 2          0  6.71  available         43   Man City            51
# 3          0  6.67  available         39     Wolves            34
# 4          0  6.53  available         43   Man City            66
# 5          0  6.40  available          1    Man Utd            32
# 6          0  6.27  available          8    Chelsea            32
# 7          0  6.00  available         13  Leicester            30
# 8          0  5.83  available         21   West Ham            35
# 9          0  5.78  available         13  Leicester            37
#
#    transfers_in  transfers_out
# 0       2114104         703036
# 1       2955611         624150
# 2        824669         432989
# 3        233906          38065
# 4       2527415        1347571
# 5        164716          85925
# 6        333267         236612
# 7        268492         177627
# 8        494248         106737
# 9        211030         287280

# %%
ST_df = pd.DataFrame(ST_roi)
ST_df.head(10)
# Out:
#    bonus  cost  minutes              name position  pts_per_90min  red_cards  \
# 0      9   7.0      795       Teemu Pukki  Forward           6.22          0
# 1     11   7.8      659     Tammy Abraham  Forward           7.64          0
# 2      4   8.0      787     Callum Wilson  Forward           5.71          0
# 3      5   6.3      736       Joshua King  Forward           4.76          0
# 4     10   9.1      810       Jamie Vardy  Forward           5.99          0
# 5      7   7.1      763      Raúl Jiménez  Forward           4.83          0
# 6      4   6.2      755        Chris Wood  Forward           4.17          0
# 7     10   8.4      766   Marcus Rashford  Forward           5.51          0
# 8      5   7.4      720  Sébastien Haller  Forward           4.87          0
# 9      4   6.0      600       Neal Maupay  Forward           4.64          0
#
#     roi     status  team_code    team_name  total_points  transfers_in  \
# 0  7.86  available         45      Norwich            55       3194565
# 1  7.18  available          8      Chelsea            56       3167999
# 2  6.25  available         91  Bournemouth            50        629265
# 3  6.19  available         91  Bournemouth            39        466761
# 4  5.93  available         13    Leicester            54        737809
# 5  5.77  available         39       Wolves            41        360089
# 6  5.65  available         90      Burnley            35        103216
# 7  5.60  available          1      Man Utd            47        866867
# 8  5.27  available         21     West Ham            39        486225
# 9  5.17  available         36     Brighton            31         80646
#
#    transfers_out
# 0        1399282
# 1         395741
# 2         824159
# 3        1052244
# 4         530931
# 5        1104605
# 6         117609
# 7        1479400
# 8         429982
# 9          64916

# %% [markdown]
# ## Define Clean df for graphing purposes

# %%
clean_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.6      778  John Lundstram    Defender           5.20
# 405      2   4.6      810  Dean Henderson  Goalkeeper           4.33
# 388      4   4.5      810  Jack O'Connell    Defender           4.11
# 96       6   4.7      810     Mathew Ryan  Goalkeeper           4.22
# 389      3   4.5      810  George Baldock    Defender           4.00
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 392          0  9.78  available         49  Sheffield Utd            45
# 405          0  8.48  available         49  Sheffield Utd            39
# 388          0  8.22  available         49  Sheffield Utd            37
# 96           0  8.09  available         36       Brighton            38
# 389          0  8.00  available         49  Sheffield Utd            36
#
#      transfers_in  transfers_out
# 392       1878762         237023
# 405        232557          67361
# 388         23728          13848
# 96         549324         354989
# 389         60527          23526

# %%
graph_roi = []
for row, player in clean_df.iterrows():
    playa = dict(name = player['name'], position = player.position, team=player.team_name, cost = player.cost, points = player.total_points, minutes = player.minutes, ROI = player.roi, pts_per_90min = player.pts_per_90min)
    graph_roi.append(playa)

# %%
graph_roi[:3]
# Out:
# [{'name': 'John Lundstram',
#   'position': 'Defender',
#   'team': 'Sheffield Utd',
#   'cost': 4.6,
#   'points': 45,
#   'minutes': 778,
#   'ROI': 9.78,
#   'pts_per_90min': 5.2},
#  {'name': 'Dean Henderson',
#   'position': 'Goalkeeper',
#   'team': 'Sheffield Utd',
#   'cost': 4.6,
#   'points': 39,
#   'minutes': 810,
#   'ROI': 8.48,
#   'pts_per_90min': 4.33},
#  {'name': "Jack O'Connell",
#   'position': 'Defender',
#   'team': 'Sheffield Utd',
#   'cost': 4.5,
#   'points': 37,
#   'minutes': 810,
#   'ROI': 8.22,
#   'pts_per_90min': 4.11}]

# %% [markdown]
# ### Graph by ROI

# %%
GK_graph = clean_df[clean_df['position'] == 'Goalkeeper']
DF_graph = clean_df[clean_df['position'] == 'Defender']
MD_graph = clean_df[clean_df['position'] == 'Midfielder']
ST_graph = clean_df[clean_df['position'] == 'Forward']

# %% [markdown]
# ### Graph by 90_min Stat

# %%
sorted_players_90min = sorted(graph_roi, key = lambda x: x['pts_per_90min'], reverse = True)

#define filter of minimum time played
min_min = min_min
sorted_players_90min = [player for player in sorted_players_90min if player['minutes'] >= min_min]

# %%
sorted_players_90min[:3]
# Out:
# [{'name': 'Sergio Agüero',
#   'position': 'Forward',
#   'team': 'Man City',
#   'cost': 12.2,
#   'points': 61,
#   'minutes': 560,
#   'ROI': 5.0,
#   'pts_per_90min': 9.79},
#  {'name': 'Kevin De Bruyne',
#   'position': 'Midfielder',
#   'team': 'Man City',
#   'cost': 10.1,
#   'points': 66,
#   'minutes': 618,
#   'ROI': 6.53,
#   'pts_per_90min': 9.6},
#  {'name': 'James Milner',
#   'position': 'Midfielder',
#   'team': 'Liverpool',
#   'cost': 5.3,
#   'points': 23,
#   'minutes': 225,
#   'ROI': 4.34,
#   'pts_per_90min': 9.16}]

# %%
df_90min = pd.DataFrame(sorted_players_90min)

# %%
df_90min.head()
# Out:
#     ROI  cost  minutes             name  points    position  pts_per_90min  \
# 0  5.00  12.2      560    Sergio Agüero      61     Forward           9.79
# 1  6.53  10.1      618  Kevin De Bruyne      66  Midfielder           9.60
# 2  4.34   5.3      225     James Milner      23  Midfielder           9.16
# 3  5.35   8.6      457     Riyad Mahrez      46  Midfielder           9.04
# 4  5.45   4.4      241     Matt Targett      24    Defender           8.93
#
#           team
# 0     Man City
# 1     Man City
# 2    Liverpool
# 3     Man City
# 4  Aston Villa

# %%
GK_90min_graph = df_90min[df_90min['position'] == 'Goalkeeper']
DF_90min_graph = df_90min[df_90min['position'] == 'Defender']
MD_90min_graph = df_90min[df_90min['position'] == 'Midfielder']
ST_90min_graph = df_90min[df_90min['position'] == 'Forward']

# %%
GK_90min_graph.head()
# Out:
#      ROI  cost  minutes                           name  points    position  \
# 56  7.88   5.2      810  Rui Pedro dos Santos Patrício      41  Goalkeeper
# 63  8.48   4.6      810                 Dean Henderson      39  Goalkeeper
# 72  8.09   4.7      810                    Mathew Ryan      38  Goalkeeper
# 92  6.36   5.5      810                   David de Gea      35  Goalkeeper
# 93  5.74   6.1      810      Ederson Santana de Moraes      35  Goalkeeper
#
#     pts_per_90min           team
# 56           4.55         Wolves
# 63           4.33  Sheffield Utd
# 72           4.22       Brighton
# 92           3.88        Man Utd
# 93           3.88       Man City

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %% [markdown]
# ## Top 10 Keepers ROI

# %%
GK_x = GK_graph[:10].roi
GK_y = GK_graph[:10].name
GK_75th = round(GK_graph.describe().roi['75%'], 2)
GK_AVG = round(GK_graph.describe().roi['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK ROI = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK ROI = ' + str(GK_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Keepers 90_min

# %%
GK_x = GK_90min_graph[:10].pts_per_90min
GK_y = GK_90min_graph[:10].name
GK_75th = round(GK_90min_graph.describe().pts_per_90min['75%'], 2)
GK_AVG = round(GK_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(GK_y, GK_x)
plt.axhline(y=GK_75th, color='r', linestyle='-', label='75th Precentile GK pts_per_90min = ' + str(GK_75th))
plt.axhline(y=GK_AVG, color='#33D977', linestyle='-', label='AVG GK pts_per_90min = ' + str(GK_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Goalkeepers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('GK_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders

# %%
DF_x = DF_graph[:10].roi
DF_y = DF_graph[:10].name
DF_75th = round(DF_graph.describe().roi['75%'], 2)
DF_AVG = round(DF_graph.describe().roi['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF ROI = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF ROI = ' + str(DF_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Defenders 90min Stat

# %%
DF_x = DF_90min_graph[:10].pts_per_90min
DF_y = DF_90min_graph[:10].name
DF_75th = round(DF_90min_graph.describe().pts_per_90min['75%'], 2)
DF_AVG = round(DF_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(DF_y, DF_x)
plt.axhline(y=DF_75th, color='r', linestyle='-', label='75th Precentile DF pts_per_90min = ' + str(DF_75th))
plt.axhline(y=DF_AVG, color='#33D977', linestyle='-', label='AVG DF pts_per_90min = ' + str(DF_AVG))
plt.ylabel('pts_per_90_min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Defenders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('DF_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders

# %%
MD_x = MD_graph[:10].roi
MD_y = MD_graph[:10].name
MD_75th = round(MD_graph.describe().roi['75%'], 2)
MD_AVG = round(MD_graph.describe().roi['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD ROI = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD ROI = ' + str(MD_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Midfielders 90min Stat

# %%
MD_x = MD_90min_graph[:10].pts_per_90min
MD_y = MD_90min_graph[:10].name
MD_75th = round(MD_90min_graph.describe().pts_per_90min['75%'], 2)
MD_AVG = round(MD_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(MD_y, MD_x)
plt.axhline(y=MD_75th, color='r', linestyle='-', label='75th Precentile MD pts_per_90min = ' + str(MD_75th))
plt.axhline(y=MD_AVG, color='#33D977', linestyle='-', label='AVG MD pts_per_90min = ' + str(MD_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Midfielders by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('MD_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers

# %%
ST_x = ST_graph[:10].roi
ST_y = ST_graph[:10].name
ST_75th = round(ST_graph.describe().roi['75%'], 2)
ST_AVG = round(ST_graph.describe().roi['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST ROI = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST ROI = ' + str(ST_AVG))
plt.ylabel('ROI', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by ROI', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_ROI', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Top 10 Strikers 90min Stat

# %%
ST_x = ST_90min_graph[:10].pts_per_90min
ST_y = ST_90min_graph[:10].name
ST_75th = round(ST_90min_graph.describe().pts_per_90min['75%'], 2)
ST_AVG = round(ST_90min_graph.describe().pts_per_90min['mean'], 2)

plt.bar(ST_y, ST_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile ST pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG ST pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Strikers by pts_per_90min', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('ST_90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
team_df
# Out:
#           code  strength Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1           14         5  LIV       Liverpool      9  8  0  1  21   7  +14  25
# 2           43         5  MCI        Man City      9  6  2  1  29   9  +20  19
# 3           13         3  LEI       Leicester      9  5  2  2  16   8   +8  17
# 4            8         4  CHE         Chelsea      9  5  2  2  19  14   +5  17
# 5            3         4  ARS         Arsenal      9  4  2  3  13  12   +1  15
# 6           31         3  CRY  Crystal Palace      9  4  3  2   8  10   -2  14
# 7            6         4  TOT           Spurs      9  3  3  3  15  13   +2  12
# 8           90         3  BUR         Burnley      9  3  3  3  12  11   +1  12
# 9           49         2  SHU   Sheffield Utd      9  3  3  3   8   7   +1  12
# 10          91         3  BOU     Bournemouth      9  3  3  3  13  13    0  12
# 11          21         3  WHU        West Ham      9  3  3  3  11  13   -2  12
# 12           7         2  AVL     Aston Villa      9  3  4  2  15  13   +2  11
# 13          39         3  WOL          Wolves      9  2  2  5  12  12    0  11
# 14           1         4  MUN         Man Utd      9  2  3  4  10   9   +1  10
# 15          11         3  EVE         Everton      9  3  5  1   8  13   -5  10
# 16          36         2  BHA        Brighton      9  2  4  3   9  12   -3   9
# 17          20         2  SOU     Southampton      9  2  5  2   9  16   -7   8
# 18           4         2  NEW       Newcastle      9  2  5  2   5  14   -9   8
# 19          45         2  NOR         Norwich      9  2  6  1  10  21  -11   7
# 20          57         2  WAT         Watford      9  0  5  4   5  21  -16   4

# %% [markdown]
# ### Team Stats

# %%
teams_stats = team_df.iloc[:,2:12]

# %%
teams_stats.GF = [int(item) for item in teams_stats.GF]
teams_stats.GA = [int(item) for item in teams_stats.GA]

# %%
teams_stats
# Out:
#          Team            name Played  W  L  D  GF  GA   GD Pts
# Position
# 1         LIV       Liverpool      9  8  0  1  21   7  +14  25
# 2         MCI        Man City      9  6  2  1  29   9  +20  19
# 3         LEI       Leicester      9  5  2  2  16   8   +8  17
# 4         CHE         Chelsea      9  5  2  2  19  14   +5  17
# 5         ARS         Arsenal      9  4  2  3  13  12   +1  15
# 6         CRY  Crystal Palace      9  4  3  2   8  10   -2  14
# 7         TOT           Spurs      9  3  3  3  15  13   +2  12
# 8         BUR         Burnley      9  3  3  3  12  11   +1  12
# 9         SHU   Sheffield Utd      9  3  3  3   8   7   +1  12
# 10        BOU     Bournemouth      9  3  3  3  13  13    0  12
# 11        WHU        West Ham      9  3  3  3  11  13   -2  12
# 12        AVL     Aston Villa      9  3  4  2  15  13   +2  11
# 13        WOL          Wolves      9  2  2  5  12  12    0  11
# 14        MUN         Man Utd      9  2  3  4  10   9   +1  10
# 15        EVE         Everton      9  3  5  1   8  13   -5  10
# 16        BHA        Brighton      9  2  4  3   9  12   -3   9
# 17        SOU     Southampton      9  2  5  2   9  16   -7   8
# 18        NEW       Newcastle      9  2  5  2   5  14   -9   8
# 19        NOR         Norwich      9  2  6  1  10  21  -11   7
# 20        WAT         Watford      9  0  5  4   5  21  -16   4

# %% [markdown]
# ### Worst/ Best  Defence vs. Offence

# %%
worst_defence_df = teams_stats.sort_values(by = ['GA'], ascending = False)

# %%
worst_defence_df.head()
# Out:
#          Team         name Played  W  L  D  GF  GA   GD Pts
# Position
# 20        WAT      Watford      9  0  5  4   5  21  -16   4
# 19        NOR      Norwich      9  2  6  1  10  21  -11   7
# 17        SOU  Southampton      9  2  5  2   9  16   -7   8
# 4         CHE      Chelsea      9  5  2  2  19  14   +5  17
# 18        NEW    Newcastle      9  2  5  2   5  14   -9   8

# %%
best_defence_df = teams_stats.sort_values(by = ['GA'], ascending = True)

# %%
best_defence_df.head()
# Out:
#          Team           name Played  W  L  D  GF  GA   GD Pts
# Position
# 1         LIV      Liverpool      9  8  0  1  21   7  +14  25
# 9         SHU  Sheffield Utd      9  3  3  3   8   7   +1  12
# 3         LEI      Leicester      9  5  2  2  16   8   +8  17
# 2         MCI       Man City      9  6  2  1  29   9  +20  19
# 14        MUN        Man Utd      9  2  3  4  10   9   +1  10

# %%
GA = list(zip(worst_defence_df.name, worst_defence_df.GA))
GA_bottom5 = GA[:7]
GA_top5 = sorted(GA[-7:], key = lambda x: x[1])

# %%
GA_bottom5, GA_top5
# Out:
# ([('Watford', 21),
#   ('Norwich', 21),
#   ('Southampton', 16),
#   ('Chelsea', 14),
#   ('Newcastle', 14),
#   ('Bournemouth', 13),
#   ('Everton', 13)],
#  [('Sheffield Utd', 7),
#   ('Liverpool', 7),
#   ('Leicester', 8),
#   ('Man City', 9),
#   ('Man Utd', 9),
#   ('Crystal Palace', 10),
#   ('Burnley', 11)])

# %%
teams_stats.GA.median()
# Out:
# 12.5

# %%
X = [item[0] for item in GA_bottom5]
Y = [int(item[1]) for item in GA_bottom5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GA_top5]
Y = [int(item[1]) for item in GA_top5]

median = teams_stats.GA.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GA = ' + str(median))
plt.ylabel('Goals Against', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Defenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
offense_df = teams_stats.sort_values(by = ['GF'], ascending = False)

# %%
offense_df.head()
# Out:
#          Team       name Played  W  L  D  GF  GA   GD Pts
# Position
# 2         MCI   Man City      9  6  2  1  29   9  +20  19
# 1         LIV  Liverpool      9  8  0  1  21   7  +14  25
# 4         CHE    Chelsea      9  5  2  2  19  14   +5  17
# 3         LEI  Leicester      9  5  2  2  16   8   +8  17
# 7         TOT      Spurs      9  3  3  3  15  13   +2  12

# %%
GF = list(zip(offense_df.name, offense_df.GF))
GF_top5 = GF[:7]
GF_bottom5 = GF[-7:]

# %%
GF_top5, GF_bottom5
# Out:
# ([('Man City', 29),
#   ('Liverpool', 21),
#   ('Chelsea', 19),
#   ('Leicester', 16),
#   ('Spurs', 15),
#   ('Aston Villa', 15),
#   ('Arsenal', 13)],
#  [('Brighton', 9),
#   ('Southampton', 9),
#   ('Sheffield Utd', 8),
#   ('Crystal Palace', 8),
#   ('Everton', 8),
#   ('Newcastle', 5),
#   ('Watford', 5)])

# %%
X = [item[0] for item in GF_top5]
Y = [int(item[1]) for item in GF_top5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Best 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Best_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in GF_bottom5]
Y = [int(item[1]) for item in GF_bottom5]

median = teams_stats.GF.median()

plt.bar(X, Y)
plt.ylim(bottom=0)
plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Goals Scored', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Worst 7 Offenses', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Worst_Offense', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stats_df = player_df[player_df.minutes >= min_min]

# %%
stats_df.tail()
# Out:
#      bonus  cost  minutes                         name  position  \
# 447      0   5.3      405             Davinson Sánchez  Defender
# 143      0   5.5      374  Emerson Palmieri dos Santos  Defender
# 210      0   5.4      450                 Fabian Delph  Defender
# 479      0   4.3      559        Francisco Femenía Far  Defender
# 362      0   4.0      270                 Grant Hanley  Defender
#
#      pts_per_90min  red_cards   roi     status  team_code team_name  \
# 447           1.11          0  0.94  available          6     Spurs
# 143           1.20          0  0.91  available          8   Chelsea
# 210           0.80          0  0.74   doubtful         11   Everton
# 479           0.48          0  0.70  available         57   Watford
# 362           0.33          0  0.25    injured         45   Norwich
#
#      total_points  transfers_in  transfers_out
# 447             5         17314          50413
# 143             5        152992         196612
# 210             4          7731          20594
# 479             3         12634          40736
# 362             1        212113         178146

# %% [markdown]
# ### Cobine Team and Player Stats

# %%
team_dic = {item:[] for item in team_names}

for row, player in stats_df.iterrows():
    for name in team_names:
        if player.team_name == name:
            playa = dict(name = player['name'], position = player.position, cost = player.cost, minutes = player.minutes, 
                         points = player.total_points,  roi = player.roi, pts_per_90min = player.pts_per_90min, 
                         bonus = player.bonus, red_cards = player.red_cards)
            team_dic[name].append(playa)

# %%
stats_df.head()
# Out:
#      bonus  cost  minutes            name    position  pts_per_90min  \
# 392      7   4.6      778  John Lundstram    Defender           5.20
# 405      2   4.6      810  Dean Henderson  Goalkeeper           4.33
# 388      4   4.5      810  Jack O'Connell    Defender           4.11
# 96       6   4.7      810     Mathew Ryan  Goalkeeper           4.22
# 389      3   4.5      810  George Baldock    Defender           4.00
#
#      red_cards   roi     status  team_code      team_name  total_points  \
# 392          0  9.78  available         49  Sheffield Utd            45
# 405          0  8.48  available         49  Sheffield Utd            39
# 388          0  8.22  available         49  Sheffield Utd            37
# 96           0  8.09  available         36       Brighton            38
# 389          0  8.00  available         49  Sheffield Utd            36
#
#      transfers_in  transfers_out
# 392       1878762         237023
# 405        232557          67361
# 388         23728          13848
# 96         549324         354989
# 389         60527          23526

# %%
team_dic['Liverpool']
# Out:
# [{'name': 'Andrew Robertson',
#   'position': 'Defender',
#   'cost': 6.9,
#   'minutes': 810,
#   'points': 41,
#   'roi': 5.94,
#   'pts_per_90min': 4.55,
#   'bonus': 6,
#   'red_cards': 0},
#  {'name': 'Trent Alexander-Arnold',
#   'position': 'Defender',
#   'cost': 7.2,
#   'minutes': 810,
#   'points': 42,
#   'roi': 5.83,
#   'pts_per_90min': 4.66,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Joel Matip',
#   'position': 'Defender',
#   'cost': 5.5,
#   'minutes': 630,
#   'points': 32,
#   'roi': 5.82,
#   'pts_per_90min': 4.56,
#   'bonus': 4,
#   'red_cards': 0},
#  {'name': 'Virgil van Dijk',
#   'position': 'Defender',
#   'cost': 6.5,
#   'minutes': 810,
#   'points': 35,
#   'roi': 5.38,
#   'pts_per_90min': 3.88,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Georginio Wijnaldum',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 759,
#   'points': 29,
#   'roi': 5.37,
#   'pts_per_90min': 3.43,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Roberto Firmino',
#   'position': 'Forward',
#   'cost': 9.6,
#   'minutes': 740,
#   'points': 50,
#   'roi': 5.21,
#   'pts_per_90min': 6.07,
#   'bonus': 9,
#   'red_cards': 0},
#  {'name': 'Adrián San Miguel del Castillo',
#   'position': 'Goalkeeper',
#   'cost': 4.5,
#   'minutes': 681,
#   'points': 23,
#   'roi': 5.11,
#   'pts_per_90min': 3.04,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Sadio Mané',
#   'position': 'Midfielder',
#   'cost': 11.8,
#   'minutes': 696,
#   'points': 59,
#   'roi': 5.0,
#   'pts_per_90min': 7.62,
#   'bonus': 8,
#   'red_cards': 0},
#  {'name': 'Mohamed Salah',
#   'position': 'Midfielder',
#   'cost': 12.4,
#   'minutes': 708,
#   'points': 55,
#   'roi': 4.44,
#   'pts_per_90min': 6.98,
#   'bonus': 7,
#   'red_cards': 0},
#  {'name': 'James Milner',
#   'position': 'Midfielder',
#   'cost': 5.3,
#   'minutes': 225,
#   'points': 23,
#   'roi': 4.34,
#   'pts_per_90min': 9.16,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Fabio Henrique Tavares',
#   'position': 'Midfielder',
#   'cost': 5.5,
#   'minutes': 736,
#   'points': 20,
#   'roi': 3.64,
#   'pts_per_90min': 2.44,
#   'bonus': 2,
#   'red_cards': 0},
#  {'name': 'Divock Origi',
#   'position': 'Forward',
#   'cost': 5.3,
#   'minutes': 222,
#   'points': 18,
#   'roi': 3.4,
#   'pts_per_90min': 7.26,
#   'bonus': 3,
#   'red_cards': 0},
#  {'name': 'Jordan Henderson',
#   'position': 'Midfielder',
#   'cost': 5.4,
#   'minutes': 479,
#   'points': 16,
#   'roi': 2.96,
#   'pts_per_90min': 3.0,
#   'bonus': 0,
#   'red_cards': 0},
#  {'name': 'Alex Oxlade-Chamberlain',
#   'position': 'Midfielder',
#   'cost': 6.2,
#   'minutes': 225,
#   'points': 8,
#   'roi': 1.29,
#   'pts_per_90min': 3.19,
#   'bonus': 0,
#   'red_cards': 0}]

# %% [markdown]
# ### Get Final Stats per Team using Pandas

# %%
team_stats = {item:{} for item in team_names}

for team in team_names:
    active_players = len(stats_df[stats_df.team_name == team].cost)
    tot_cost = round(stats_df[stats_df.team_name == team].cost.sum(), 3)
    tot_pts = round(stats_df[stats_df.team_name == team].total_points.sum(), 3)
    avg_player_roi = round(tot_pts / tot_cost, 3)
    avg_pts_per_player = round(tot_pts / active_players, 3)
    
    stats = dict(active_players = active_players, tot_cost = tot_cost, tot_pts = tot_pts,
               avg_pts_per_player = avg_pts_per_player,  avg_player_roi =  avg_player_roi)
    
    team_stats[team].update(stats)

# %%
team_stats['Newcastle']
# Out:
# {'active_players': 15,
#  'tot_cost': 74.4,
#  'tot_pts': 282,
#  'avg_pts_per_player': 18.8,
#  'avg_player_roi': 3.79}

# %%
team_stats_df = pd.DataFrame(team_stats).T

# %%
team_stats_df.sort_values(by = ['avg_pts_per_player'], ascending = False, inplace = True)

# %%
team_stats_df
# Out:
#                 active_players  avg_player_roi  avg_pts_per_player  tot_cost  \
# Liverpool                 14.0           4.626              32.214      97.5
# Man City                  16.0           4.304              31.875     118.5
# Leicester                 13.0           5.119              29.846      75.8
# Sheffield Utd             13.0           5.620              27.538      63.7
# Wolves                    14.0           4.747              25.429      75.0
# Burnley                   14.0           4.733              25.286      74.8
# West Ham                  14.0           4.554              24.429      75.1
# Aston Villa               16.0           4.832              24.250      80.3
# Crystal Palace            13.0           4.524              24.154      69.4
# Bournemouth               14.0           4.261              22.643      74.4
# Chelsea                   16.0           3.811              22.438      94.2
# Arsenal                   14.0           3.844              22.214      80.9
# Everton                   14.0           3.663              21.714      83.0
# Man Utd                   15.0           3.491              21.133      90.8
# Brighton                  15.0           4.080              20.400      75.0
# Spurs                     16.0           3.200              19.938      99.7
# Southampton               15.0           3.773              19.067      75.8
# Newcastle                 15.0           3.790              18.800      74.4
# Norwich                   13.0           3.843              18.769      63.5
# Watford                   15.0           3.017              15.267      75.9
#
#                 tot_pts
# Liverpool         451.0
# Man City          510.0
# Leicester         388.0
# Sheffield Utd     358.0
# Wolves            356.0
# Burnley           354.0
# West Ham          342.0
# Aston Villa       388.0
# Crystal Palace    314.0
# Bournemouth       317.0
# Chelsea           359.0
# Arsenal           311.0
# Everton           304.0
# Man Utd           317.0
# Brighton          306.0
# Spurs             319.0
# Southampton       286.0
# Newcastle         282.0
# Norwich           244.0
# Watford           229.0

# %% [markdown]
# ### Build a team using 90min Stat

# %%
#define money team as empty list and list that tracks count of players selectd per team
money_team = []
players_selected = []
teams_selected = []

#Instantiate initial count per position
#Current players selected for each position
DF_curr = 0
MD_curr = 0 
ST_curr = 0

GK_budget = budget*GK_coef
print(GK_budget)

for item in GK_90min:
    if item['cost'] <= 5.5 and item['cost'] <= GK_budget:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        GK_budget -= item['cost']
        print('Player Selected: ' + item['name'])
        print('GK budget left: ' + str(GK_budget))
        
print(players_selected)
print(teams_selected)
# Out:
# 9.5
# Player Selected: Rui Pedro dos Santos Patrício
# GK budget left: 4.3
# ['Rui Pedro dos Santos Patrício']
# ['Wolves']

# %% [markdown]
# ### Select top 3 players by points per position

# %%
DF_budget = budget*DF_coef + GK_budget
MD_budget = budget*MD_coef
ST_budget = budget*ST_coef

print(DF_budget, MD_budget, ST_budget)

#Select Top Defender
money_team.append(DF_pts[0])
players_selected.append(DF_pts[0]['name'])
teams_selected.append(DF_pts[0]['team_name'])
DF_budget -= DF_pts[0]['cost']
DF_curr += 1
print('Player Selected: ' + DF_pts[0]['name'])
print('DF budget left: ' + str(DF_budget))

#Select Top Midfielder
money_team.append(MD_pts[0])
players_selected.append(MD_pts[0]['name'])
teams_selected.append(MD_pts[0]['team_name'])
MD_budget -= MD_pts[0]['cost']
MD_curr += 1
print('Player Selected: ' + MD_pts[0]['name'])
print('MD budget left: ' + str(MD_budget))


print(players_selected)
print(teams_selected)
# Out:
# 32.8 36.0 26.0
# Player Selected: John Lundstram
# DF budget left: 28.199999999999996
# Player Selected: Kevin De Bruyne
# MD budget left: 25.9
# ['Rui Pedro dos Santos Patrício', 'John Lundstram', 'Kevin De Bruyne']
# ['Wolves', 'Sheffield Utd', 'Man City']

# %%
#Select Top Striker

for item in ST_pts[:3]:
    if teams_selected.count(item['team_name']) < 3 and len(money_team) == 4:
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
    break

print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# 3
# ['Rui Pedro dos Santos Patrício', 'John Lundstram', 'Kevin De Bruyne']
# ['Wolves', 'Sheffield Utd', 'Man City']

# %%
print(DF_curr, MD_curr, ST_curr)
# Out:
# 1 1 0

# %%
print(DF, MD, ST)
# Out:
# 3 4 3

# %% [markdown]
# ### Fill rest of team with 90_min_stats

# %%
for item in DF_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < DF_budget and DF_curr < DF:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        DF_budget -= item['cost']
        DF_curr += 1
        print('Player Selected: ' + item['name'])
        print('DF budget left: ' + str(DF_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and DF_max != DF_curr and item['cost'] <= DF_budget / (DF_max - DF_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            DF_budget -= item['cost']
            DF_curr += 1
            print('Player Selected: ' + item['name'])
            print('DF budget left: ' + str(DF_budget))
            print('# of DFs selected: ' + str(DF_curr))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Matt Doherty
# DF budget left: 22.199999999999996
# Player Selected: Marcos Alonso
# DF budget left: 15.999999999999996
# Player Selected: Jetro Willems
# DF budget left: 11.499999999999996
# # of DFs selected: 4
# Player Selected: Calum Chambers
# DF budget left: 7.099999999999996
# # of DFs selected: 5
# 7
# ['Rui Pedro dos Santos Patrício', 'John Lundstram', 'Kevin De Bruyne', 'Matt Doherty', 'Marcos Alonso', 'Jetro Willems', 'Calum Chambers']
# ['Wolves', 'Sheffield Utd', 'Man City', 'Wolves', 'Chelsea', 'Newcastle', 'Arsenal']

# %%
#move leftover DF budget to MD budget
MD_budget += DF_budget

for item in MD_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < MD_budget and MD_curr < MD:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        MD_budget -= item['cost']
        MD_curr += 1
        print('Player Selected: ' + item['name'])
        print('MD budget left: ' + str(MD_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and MD_max != MD_curr and item['cost'] <= MD_budget / (MD_max - MD_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            MD_budget -= item['cost']
            MD_curr += 1
            print('Player Selected: ' + item['name'])
            print('MD budget left: ' + str(MD_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Riyad Mahrez
# MD budget left: 24.39999999999999
# Player Selected: David Silva
# MD budget left: 16.79999999999999
# Player Selected: Anthony Martial
# MD budget left: 9.29999999999999
# Player Selected: Andriy Yarmolenko
# MD budget left: 3.29999999999999
# 11
# ['Rui Pedro dos Santos Patrício', 'John Lundstram', 'Kevin De Bruyne', 'Matt Doherty', 'Marcos Alonso', 'Jetro Willems', 'Calum Chambers', 'Riyad Mahrez', 'David Silva', 'Anthony Martial', 'Andriy Yarmolenko']
# ['Wolves', 'Sheffield Utd', 'Man City', 'Wolves', 'Chelsea', 'Newcastle', 'Arsenal', 'Man City', 'Man City', 'Man Utd', 'West Ham']

# %%
#move leftover MD budget to ST budget
ST_budget += MD_budget

for item in ST_90min:
    if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and item['cost'] < ST_budget and ST_curr < ST:
        money_team.append(item)
        players_selected.append(item['name'])
        teams_selected.append(item['team_name'])
        ST_budget -= item['cost']
        ST_curr += 1
        print('Player Selected: ' + item['name'])
        print('ST budget left: ' + str(ST_budget))
    else:
        if teams_selected.count(item['team_name']) < 3 and item['name'] not in players_selected and ST_max != ST_curr and item['cost'] <= ST_budget / (ST_max - ST_curr):
            money_team.append(item)
            players_selected.append(item['name'])
            teams_selected.append(item['team_name'])
            ST_budget -= item['cost']
            ST_curr += 1
            print('Player Selected: ' + item['name'])
            print('ST budget left: ' + str(ST_budget))
            
            
print(len(money_team))
print(players_selected)
print(teams_selected)
# Out:
# Player Selected: Tammy Abraham
# ST budget left: 21.49999999999999
# Player Selected: Pierre-Emerick Aubameyang
# ST budget left: 10.39999999999999
# Player Selected: Teemu Pukki
# ST budget left: 3.3999999999999897
# 14
# ['Rui Pedro dos Santos Patrício', 'John Lundstram', 'Kevin De Bruyne', 'Matt Doherty', 'Marcos Alonso', 'Jetro Willems', 'Calum Chambers', 'Riyad Mahrez', 'David Silva', 'Anthony Martial', 'Andriy Yarmolenko', 'Tammy Abraham', 'Pierre-Emerick Aubameyang', 'Teemu Pukki']
# ['Wolves', 'Sheffield Utd', 'Man City', 'Wolves', 'Chelsea', 'Newcastle', 'Arsenal', 'Man City', 'Man City', 'Man Utd', 'West Ham', 'Chelsea', 'Arsenal', 'Norwich']

# %%
money_df = pd.DataFrame(money_team)

# %%
money_df
# Out:
#     bonus  cost  minutes                           name    position  \
# 0       4   5.2      810  Rui Pedro dos Santos Patrício  Goalkeeper
# 1       7   4.6      778                 John Lundstram    Defender
# 2      10  10.1      618                Kevin De Bruyne  Midfielder
# 3       3   6.0      457                   Matt Doherty    Defender
# 4       3   6.2      436                  Marcos Alonso    Defender
# 5       3   4.5      477                  Jetro Willems    Defender
# 6       2   4.4      405                 Calum Chambers    Defender
# 7       6   8.6      457                   Riyad Mahrez  Midfielder
# 8       6   7.6      560                    David Silva  Midfielder
# 9       0   7.5      276                Anthony Martial  Midfielder
# 10      5   6.0      498              Andriy Yarmolenko  Midfielder
# 11     11   7.8      659                  Tammy Abraham     Forward
# 12     10  11.1      810      Pierre-Emerick Aubameyang     Forward
# 13      9   7.0      795                    Teemu Pukki     Forward
#
#     pts_per_90min  red_cards   roi     status  team_code      team_name  \
# 0            4.55          0  7.88  available         39         Wolves
# 1            5.20          0  9.78  available         49  Sheffield Utd
# 2            9.60          0  6.53  available         43       Man City
# 3            6.68          0  5.67  available         39         Wolves
# 4            6.18          0  4.84  available          8        Chelsea
# 5            5.65          0  6.67  available          4      Newcastle
# 6            5.10          0  5.23  available          3        Arsenal
# 7            9.04          0  5.35  available         43       Man City
# 8            8.18          0  6.71  available         43       Man City
# 9            6.50          0  2.67  available          1        Man Utd
# 10           6.31          0  5.83  available         21       West Ham
# 11           7.64          0  7.18  available          8        Chelsea
# 12           6.33          0  5.14  available          3        Arsenal
# 13           6.22          0  7.86  available         45        Norwich
#
#     total_points  transfers_in  transfers_out
# 0             41        659407         237067
# 1             45       1878762         237023
# 2             66       2527415        1347571
# 3             34        106454         147259
# 4             30        116626         210917
# 5             30         49170          17220
# 6             23         90922          57358
# 7             46        758197         452220
# 8             51        824669         432989
# 9             20        925882        1169805
# 10            35        494248         106737
# 11            56       3167999         395741
# 12            57       1057205         902306
# 13            55       3194565        1399282

# %%
money_x = money_df.pts_per_90min
money_y = money_df.name
ST_75th = round(money_df.describe().pts_per_90min['75%'], 2)
ST_AVG = round(money_df.describe().pts_per_90min['mean'], 2)

plt.bar(money_y, money_x)
plt.axhline(y=ST_75th, color='r', linestyle='-', label='75th Precentile pts_per_90min = ' + str(ST_75th))
plt.axhline(y=ST_AVG, color='#33D977', linestyle='-', label='AVG pts_per_90min = ' + str(ST_AVG))
plt.ylabel('pts_per_90min', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Optimal Team by pts_per_90min Stat', fontsize = 24, color = '#073997')
plt.legend( fontsize = 14)
plt.savefig('Team_pts_per90min', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top100_users = pd.read_csv('fEPL_user_data_test.csv', index_col='users')

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# nick tanner               1       568651           633                46
# kurt JONKERS              2       558922           615                55
# Raushan Uttamchandani     2      1229681           615                46
# Eoin Hogan                4      2818293           609                50
# Kittipong Kaewsopon       5       406431           608                35
#
#                                                       formation  \
# users
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kurt JONKERS           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Eoin Hogan             {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2}
# Kittipong Kaewsopon    {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2}
#
#                                       GKP_1             GKP_2  \
# users
# nick tanner                  Ryan-BHA-start  McGovern-NOR-sub
# kurt JONKERS                 Ryan-BHA-start  McGovern-NOR-sub
# Raushan Uttamchandani        Ryan-BHA-start  McGovern-NOR-sub
# Eoin Hogan                 Heaton-AVL-start      Pope-BUR-sub
# Kittipong Kaewsopon    Schmeichel-LEI-start      Ryan-BHA-sub
#
#                                        DEF_1                DEF_2  \
# users
# nick tanner                   Rico-BOU-start  Lundstram-SHU-start
# kurt JONKERS           Azpilicueta-CHE-start  Robertson-LIV-start
# Raushan Uttamchandani    Lundstram-SHU-start     Tomori-CHE-start
# Eoin Hogan                Guilbert-AVL-start  Lundstram-SHU-start
# Kittipong Kaewsopon       van Dijk-LIV-start       Dunk-BHA-start
#
#                                      DEF_3  ...            DEF_5  \
# users                                       ...
# nick tanner             Guilbert-AVL-start  ...    Kelly-CRY-sub
# kurt JONKERS           Lundstram-SHU-start  ...    Kelly-CRY-sub
# Raushan Uttamchandani    Pieters-BUR-start  ...    Kelly-CRY-sub
# Eoin Hogan             Robertson-LIV-start  ...  Johnson-WHU-sub
# Kittipong Kaewsopon      Söyüncü-LEI-start  ...    Kelly-CRY-sub
#
#                                     MID_1                MID_2  \
# users
# nick tanner            Maddison-LEI-start      Mount-CHE-start
# kurt JONKERS               Mané-LIV-start      Iwobi-EVE-start
# Raushan Uttamchandani  Sterling-MCI-start  De Bruyne-MCI-start
# Eoin Hogan                Mount-CHE-start      James-MUN-start
# Kittipong Kaewsopon       Mount-CHE-start       Mané-LIV-start
#
#                                        MID_3                   MID_4  \
# users
# nick tanner                   Mané-LIV-start      Cantwell-NOR-start
# kurt JONKERS           David Silva-MCI-start     De Bruyne-MCI-start
# Raushan Uttamchandani          Son-TOT-start          Mané-LIV-start
# Eoin Hogan                Cantwell-NOR-start     De Bruyne-MCI-start
# Kittipong Kaewsopon    David Silva-MCI-start  Harry Wilson-BOU-start
#
#                                     MID_5              FWD_1  \
# users
# nick tanner                 Salah-LIV-sub  Abraham-CHE-start
# kurt JONKERS           Dendoncker-WOL-sub    Pukki-NOR-start
# Raushan Uttamchandani  Dendoncker-WOL-sub   Wesley-AVL-start
# Eoin Hogan                  Salah-LIV-sub  Abraham-CHE-start
# Kittipong Kaewsopon        Pépé-ARS-start  Abraham-CHE-start
#
#                                    FWD_2            FWD_3  \
# users
# nick tanner               Kane-TOT-start  Vardy-LEI-start
# kurt JONKERS           Firmino-LIV-start  Vardy-LEI-start
# Raushan Uttamchandani  Abraham-CHE-start  Vardy-LEI-start
# Eoin Hogan               Pukki-NOR-start   Agüero-MCI-sub
# Kittipong Kaewsopon       Kane-TOT-start    Pukki-NOR-sub
#
#                                                          user_team_pages
# users
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# kurt JONKERS           https://fantasy.premierleague.com/entry/558922...
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
# Eoin Hogan             https://fantasy.premierleague.com/entry/281829...
# Kittipong Kaewsopon    https://fantasy.premierleague.com/entry/406431...
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Get Stats of top 100 players

# %%
y =list(top100_users.game_week_points)[:10]
z =list(top100_users.total_points)[:10]

mean = np.mean(y)
maxi = np.max(y)
mini = np.min(y)

plt.scatter(z, y)
plt.ylim(bottom=0)
plt.axhline(y=maxi, color='#1D28D2', linestyle='-', label='Max Top_10 = ' + str(maxi) +'pts')
plt.axhline(y=mean, color='#33D977', linestyle='-', label='Mean Top_10 = ' + str(mean) +'pts')
plt.axhline(y=mini, color='#D2461D', linestyle='-', label='Min Top_10 = ' + str(mini) +'pts')
plt.ylabel('Points GW-'+ str(gameweek-1), fontsize = 24, color = '#073997')
plt.xlabel('Total Points', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 10 Players in the World Stats', fontsize = 24, color = '#073997')
plt.legend(fontsize = 14)
plt.savefig('Top10_Stats', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Function to extract names from player string

# %%
def partition_names(names_list):
    clean_list = [item.partition("-")[0] for item in names_list]
    return clean_list

# %% [markdown]
# ### Function to get the list of all selected players by position

# %%
def get_top100_teams(team_df):
    #create lists by position
    #GK_list
    GK_list = list(team_df.GKP_1)
    GK_list.extend(list(team_df.GKP_2))
    GK_final = partition_names(GK_list)
    
    #DF_list
    DF_list = list(team_df.DEF_1)
    DF_list.extend(list(team_df.DEF_2))
    DF_list.extend(list(team_df.DEF_3))
    DF_list.extend(list(team_df.DEF_4))
    DF_list.extend(list(team_df.DEF_5))
    DF_final = partition_names(DF_list)
    
    #MD_list
    MD_list = list(team_df.MID_1)
    MD_list.extend(list(team_df.MID_2))
    MD_list.extend(list(team_df.MID_3))
    MD_list.extend(list(team_df.MID_4))
    MD_list.extend(list(team_df.MID_5))
    MD_final = partition_names(MD_list)
    
    #ST_list
    ST_list = list(team_df.FWD_1)
    ST_list.extend(list(team_df.FWD_2))
    ST_list.extend(list(team_df.FWD_3))
    ST_final = partition_names(ST_list)
    
    return GK_final, DF_final, MD_final, ST_final

# %%
#get the final clean list of players per position
GK_final, DF_final, MD_final, ST_final = get_top100_teams(top100_users)[0], get_top100_teams(top100_users)[1], get_top100_teams(top100_users)[2], get_top100_teams(top100_users)[3]

# %%
GK_final[:3]
# Out:
# ['Ryan', 'Ryan', 'Ryan']

# %%
MD_final[:3]
# Out:
# ['Maddison', 'Mané', 'Sterling']

# %%
DF_final[:3]
# Out:
# ['Rico', 'Azpilicueta', 'Lundstram']

# %%
ST_final[:3]
# Out:
# ['Abraham', 'Pukki', 'Wesley']

# %% [markdown]
# ### Function to get you top_n players by position ordered by # of times they were picked

# %%
def return_top_n(players, top_n = 10):
    ranked = Counter(players).most_common(top_n)
    return ranked

# %%
GK_top10 = return_top_n(GK_final)

# %%
GK_top10
# Out:
# [('Button', 36),
#  ('Pope', 31),
#  ('Ryan', 29),
#  ('Heaton', 17),
#  ('Patrício', 17),
#  ('McGovern', 12),
#  ('Ederson', 10),
#  ('Henderson', 8),
#  ('Schmeichel', 6),
#  ('Stekelenburg', 6)]

# %%
DF_top10 = return_top_n(DF_final)

# %%
DF_top10
# Out:
# [('Lundstram', 75),
#  ('Kelly', 55),
#  ('Alexander', 43),
#  ('Rico', 34),
#  ('Dunk', 26),
#  ('Robertson', 26),
#  ('Tomori', 23),
#  ('Otamendi', 22),
#  ('Söyüncü', 19),
#  ('van Dijk', 16)]

# %%
MD_top10 = return_top_n(MD_final)

# %%
MD_top10
# Out:
# [('De Bruyne', 71),
#  ('Mount', 69),
#  ('Mané', 63),
#  ('Sterling', 44),
#  ('Cantwell', 31),
#  ('Salah', 28),
#  ('McGinn', 20),
#  ('Son', 18),
#  ('David Silva', 16),
#  ('Dendoncker', 16)]

# %%
ST_top10 = return_top_n(ST_final)

# %%
ST_top10
# Out:
# [('Abraham', 63),
#  ('Vardy', 41),
#  ('Pukki', 37),
#  ('Agüero', 27),
#  ('Callum Wilson', 26),
#  ('Greenwood', 22),
#  ('Aubameyang', 15),
#  ('Kane', 13),
#  ('King', 10),
#  ('Firmino', 10)]

# %%
X = [item[0] for item in GK_top10]
Y = [item[1] for item in GK_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Goalkeepers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_GK', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in DF_top10]
Y = [item[1] for item in DF_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Defenders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_DF', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in MD_top10]
Y = [item[1] for item in MD_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Midfielders Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_MD', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = [item[0] for item in ST_top10]
Y = [item[1] for item in ST_top10]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top Strikers Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_ST', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
top_managers_team = GK_top10[:2]+ DF_top10[:5] + MD_top10[:5] + ST_top10[:3]

# %%
top_managers_team
# Out:
# [('Button', 36),
#  ('Pope', 31),
#  ('Lundstram', 75),
#  ('Kelly', 55),
#  ('Alexander', 43),
#  ('Rico', 34),
#  ('Dunk', 26),
#  ('De Bruyne', 71),
#  ('Mount', 69),
#  ('Mané', 63),
#  ('Sterling', 44),
#  ('Cantwell', 31),
#  ('Abraham', 63),
#  ('Vardy', 41),
#  ('Pukki', 37)]

# %%
X = [item[0] for item in top_managers_team]
Y = [item[1] for item in top_managers_team]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top100 Players Optimal Team', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Team', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Latest Injury Updates from independant site that updates faster than the Fantasy site

# %%
injuries = 'http://www.premierinjuries.com/?fbclid=IwAR1Uz0TTwRMOvsq1jlefIztPPg7qtPdnag3zrHxh_39wV4CZoMG0ZWq6MYU'
injuries_tab = pd.read_html(injuries)[0]

# %%
injuries_tab
# Out:
#                        Player                   Reason
# 0  Rodrigo Hernandez Cascante             Thigh Injury
# 1         Oleksandr Zinchenko              Knee Injury
# 2                  Joel Matip              Knee Injury
# 3              James Maddison        Ankle/Foot Injury
# 4               Nemanja Matic                    Other
# 5               Axel Tuanzebe  Groin/Hip/Pelvic Injury
# 6           Cesar Azpilicueta                    Other
# 7        Ruben Da Silva Neves        Ankle/Foot Injury
# 8                Martin Kelly  Groin/Hip/Pelvic Injury
# 9              Vicente Guaita  Groin/Hip/Pelvic Injury

# %%
top100_users.head()
# Out:
#                        rank  user_id_num  total_points  game_week_points  \
# users
# nick tanner               1       568651           633                46
# kurt JONKERS              2       558922           615                55
# Raushan Uttamchandani     2      1229681           615                46
# Eoin Hogan                4      2818293           609                50
# Kittipong Kaewsopon       5       406431           608                35
#
#                                                       formation  \
# users
# nick tanner            {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# kurt JONKERS           {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Raushan Uttamchandani  {'GKP': 1, 'DEF': 3, 'MID': 4, 'FWD': 3}
# Eoin Hogan             {'GKP': 1, 'DEF': 4, 'MID': 4, 'FWD': 2}
# Kittipong Kaewsopon    {'GKP': 1, 'DEF': 3, 'MID': 5, 'FWD': 2}
#
#                                       GKP_1             GKP_2  \
# users
# nick tanner                  Ryan-BHA-start  McGovern-NOR-sub
# kurt JONKERS                 Ryan-BHA-start  McGovern-NOR-sub
# Raushan Uttamchandani        Ryan-BHA-start  McGovern-NOR-sub
# Eoin Hogan                 Heaton-AVL-start      Pope-BUR-sub
# Kittipong Kaewsopon    Schmeichel-LEI-start      Ryan-BHA-sub
#
#                                        DEF_1                DEF_2  \
# users
# nick tanner                   Rico-BOU-start  Lundstram-SHU-start
# kurt JONKERS           Azpilicueta-CHE-start  Robertson-LIV-start
# Raushan Uttamchandani    Lundstram-SHU-start     Tomori-CHE-start
# Eoin Hogan                Guilbert-AVL-start  Lundstram-SHU-start
# Kittipong Kaewsopon       van Dijk-LIV-start       Dunk-BHA-start
#
#                                      DEF_3  ...            DEF_5  \
# users                                       ...
# nick tanner             Guilbert-AVL-start  ...    Kelly-CRY-sub
# kurt JONKERS           Lundstram-SHU-start  ...    Kelly-CRY-sub
# Raushan Uttamchandani    Pieters-BUR-start  ...    Kelly-CRY-sub
# Eoin Hogan             Robertson-LIV-start  ...  Johnson-WHU-sub
# Kittipong Kaewsopon      Söyüncü-LEI-start  ...    Kelly-CRY-sub
#
#                                     MID_1                MID_2  \
# users
# nick tanner            Maddison-LEI-start      Mount-CHE-start
# kurt JONKERS               Mané-LIV-start      Iwobi-EVE-start
# Raushan Uttamchandani  Sterling-MCI-start  De Bruyne-MCI-start
# Eoin Hogan                Mount-CHE-start      James-MUN-start
# Kittipong Kaewsopon       Mount-CHE-start       Mané-LIV-start
#
#                                        MID_3                   MID_4  \
# users
# nick tanner                   Mané-LIV-start      Cantwell-NOR-start
# kurt JONKERS           David Silva-MCI-start     De Bruyne-MCI-start
# Raushan Uttamchandani          Son-TOT-start          Mané-LIV-start
# Eoin Hogan                Cantwell-NOR-start     De Bruyne-MCI-start
# Kittipong Kaewsopon    David Silva-MCI-start  Harry Wilson-BOU-start
#
#                                     MID_5              FWD_1  \
# users
# nick tanner                 Salah-LIV-sub  Abraham-CHE-start
# kurt JONKERS           Dendoncker-WOL-sub    Pukki-NOR-start
# Raushan Uttamchandani  Dendoncker-WOL-sub   Wesley-AVL-start
# Eoin Hogan                  Salah-LIV-sub  Abraham-CHE-start
# Kittipong Kaewsopon        Pépé-ARS-start  Abraham-CHE-start
#
#                                    FWD_2            FWD_3  \
# users
# nick tanner               Kane-TOT-start  Vardy-LEI-start
# kurt JONKERS           Firmino-LIV-start  Vardy-LEI-start
# Raushan Uttamchandani  Abraham-CHE-start  Vardy-LEI-start
# Eoin Hogan               Pukki-NOR-start   Agüero-MCI-sub
# Kittipong Kaewsopon       Kane-TOT-start    Pukki-NOR-sub
#
#                                                          user_team_pages
# users
# nick tanner            https://fantasy.premierleague.com/entry/568651...
# kurt JONKERS           https://fantasy.premierleague.com/entry/558922...
# Raushan Uttamchandani  https://fantasy.premierleague.com/entry/122968...
# Eoin Hogan             https://fantasy.premierleague.com/entry/281829...
# Kittipong Kaewsopon    https://fantasy.premierleague.com/entry/406431...
#
# [5 rows x 21 columns]

# %%
test = top100_users.formation

# %% [markdown]
# ### Extract formations as a list in a readable format

# %%
formations = [item.split(",")[1][8] + "-" + item.split(",")[2][8] + "-" + item.split(",")[3][8] for item in test]

# %%
formations[:5]
# Out:
# ['3-4-3', '3-4-3', '3-4-3', '4-4-2', '3-5-2']

# %% [markdown]
# ### Use top_n function to get a tuple of ranked formations by count

# %%
top_form = return_top_n(formations, 6)

# %%
top_form
# Out:
# [('3-4-3', 39), ('3-5-2', 25), ('4-4-2', 23), ('4-3-3', 9), ('4-5-1', 4)]

# %%
X = [item[0] for item in top_form]
Y = [item[1] for item in top_form]

plt.bar(X, Y)
plt.ylim(bottom=0)
# plt.axhline(y=median, color='#33D977', linestyle='-', label='Median GF = ' + str(median))
plt.ylabel('Times Selected', fontsize = 24, color = '#073997')
plt.xticks(rotation=60, fontsize = 12, color = '#073997')
plt.title('Top 100 Formations Selected', fontsize = 24, color = '#073997')
# plt.legend(fontsize = 14)
plt.savefig('Top100_Forma', bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
